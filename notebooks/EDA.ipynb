# %% [markdown]
# <b><font size="6"> Cars 4 You: Predicting Car Values with ML </font></b><br><br>
#
# `Group 40`
#
# Ana Macedo (20250405)<br>
# Catarina Mendinhas (20250422)<br>
# Lourenço Silva (20250453)<br>
# Maria Fonseca (20250380)<br>

# %% [markdown]
# ## Abstract

# %% [markdown]
# This project aims to develop a predictive model capable of estimating car prices based on their characteristics, using the Cars 4 You dataset. The goal is to support the company’s evaluation process by introducing an automated solution that accelerates car assessments and improves overall efficiency.

# %% [markdown]
# The current phase of the project focuses on data exploration and preparation, including the identification of data quality issues, such as missing values, inconsistent string formats, and incorrect data types. A preliminary exploratory analysis was performed to understand the structure of the dataset, assess the relationships between features, and identify potential variables influencing the car price.

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# The following libraries will help us develop the analyses and model for this project. Pandas and Numpy, provide the efficient tools for data manipulation, cleaning and numerical computations. Matplotlib and Seaborn are used to create clear and informative visualizations. Scikit-learn offers a range of Machine Learning tools for model training, spliting the data and evaluate model performance. Finally, os, math and ceil are imported to support file management and mathematical operations.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from math import ceil
import math

# %% [markdown]
# ## Create Meta Data
#
# Understanding the features helps interpret the data correctly and supports subsequent analysis and modeling steps. This section provides a brief description of each feature in the dataset, explaining its meaning and type.

# %% [markdown]
# **carID:** An atribute that contains an identifier for each car.
#
# **Brand:** The cars main brand (e.g., Ford, Toyota).
#
# **model:** The car model.
#
# **year:** The year of registration of the car.
#
# **price:** The car's price when purchased by Cars 4 You (in £).
#
# **transmission:** The car's type of transmission.
#
# **mileage:** The total reported distance travelled by the car (in miles).
#
# **fuelType:** Type of Fuel used by car (Diesel, Petrol, Hybrid, Electric).
#
# **tax:** The amount of road tax (in £) that, in 2020, was applicable to the car in question.
#
# **mpg:** Average Miles per Gallon.
#
# **engineSize:** Size of Engine in liters (Cubic Decimeters).
#
# **paintQuality%** The mechanic’s assessment of the cars’ overall paint quality and hull integrity (filled by the mechanic during evaluation).
#
# **previousOwner:** Number of previous registered owners of the vehicle.
#
# **hasDamage:** Boolean marker filled by the seller at the time of registration stating whether the car is damaged or not.

# %% [markdown]
# ## Import Dataset

# %% [markdown]
# Here, we are importing with pd.read_csv() the files to start our project and converting them into Pandas DataFrames. CarID was set to index since it's the unique identifier in all data sets.

# %%
sample = pd.read_csv('../data/sample_submission.csv')
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# In this phase, we will explore the dataset to identify inconsistencies, missing values, duplicated values and potential relationships and patterns. This analysis will be very helpfull for the Preprocessing stage where we'll need to correct all these issues to improve the overall performance of our model.

# %% [markdown]
# ### Define new index for our datasets

# %%
sample.set_index('carID', inplace = True)
train.set_index('carID', inplace = True)
test.set_index('carID', inplace = True)

# %% [markdown]
# ### Sample

# %%
print("Initial Analysis of the Sample Submission Dataset")
print('')
print(sample.shape)
print('-----------------------')
print(sample.head())
print('-----------------------')
print(sample.tail())
# Out:
# Initial Analysis of the Sample Submission Dataset
#
# (32567, 1)
# -----------------------
#          price
# carID
# 89856   851000
# 106581  514000
# 80886   323000
# 100174  921000
# 81376   620000
# -----------------------
#          price
# carID
# 105775  412000
# 81363   441000
# 76833   684000
# 91768   835000
# 99627     2000

# %%
print("Continue to analyse the Sample Submission Dataset")
print('------------------------')
print('')
print(sample.info()) #From this output we can see that this dataset hasn't missing values
print('')
print('------------------------')
print(sample.describe())
# Out:
# Continue to analyse the Sample Submission Dataset
# ------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 32567 entries, 89856 to 99627
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   32567 non-null  int64
# dtypes: int64(1)
# memory usage: 508.9 KB
# None
#
# ------------------------
#                price
# count   32567.000000
# mean   498198.943716
# std    288111.809635
# min      1000.000000
# 25%    249000.000000
# 50%    501000.000000
# 75%    746000.000000
# max    999000.000000

# %% [markdown]
# This data is only a sample of how how predictions should be structured.

# %% [markdown]
# ## Initial Analysis Train/Test

# %%
print("Train shape:", train.shape)
print("Test shape:", test.shape)
#Here we can see that the test shape is equal to the sample shape.
# Out:
# Train shape: (75973, 13)
# Test shape: (32567, 12)

# %%
train.head(10)
# Out:
#         Brand      model    year  price transmission        mileage fuelType  \
# carID
# 69512      VW       Golf  2016.0  22290    Semi-Auto   28421.000000   Petrol
# 53000  Toyota      Yaris  2019.0  13790       Manual    4589.000000   Petrol
# 6366     Audi         Q2  2019.0  24990    Semi-Auto    3624.000000   Petrol
# 29021    Ford     FIESTA  2018.0  12500        anual    9102.000000   Petrol
# 10062     BMW   2 Series  2019.0  22995       Manual    1000.000000   Petrol
# 14704     BMW   3 Series  2014.0   8199        anual  101153.348285   Diesel
# 6924     Audi         A3  2017.0  16089       Manual   21396.000000   Petrol
# 50783   Skoda    Octavia  2017.0   7500       Manual  116750.000000   Diesel
# 67071      VW     Passat  2017.0  15999    Semi-Auto   30339.000000   Diesel
# 23348    Ford      Focus  2019.0  15300       Manual   10700.000000   Petrol
#
#          tax        mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 69512    NaN  11.417268         2.0           63.0        4.000000        0.0
# 53000  145.0  47.900000         1.5           50.0        1.000000        0.0
# 6366   145.0  40.900000         1.5           56.0        4.000000        0.0
# 29021  145.0  65.700000         1.0           50.0       -2.340306        0.0
# 10062  145.0  42.800000         1.5           97.0        3.000000        0.0
# 14704   30.0  65.700000         2.0           74.0        0.000000        0.0
# 6924    20.0  60.100000         1.4           75.0        4.000000        0.0
# 50783  145.0  68.900000         1.6           59.0        4.000000        0.0
# 67071  150.0  62.800000         2.0           85.0        4.000000        0.0
# 23348  150.0  60.100000         1.0           35.0        1.000000        0.0

# %%
train.tail(10)
# Out:
#           Brand         model    year  price transmission  mileage fuelType  \
# carID
# 67221        VW         T-Roc  2020.0  25785    Semi-Auto     10.0   Petrol
# 41090  Mercedes     GLC Class  2016.0  24486          NaN  22955.0   Diesel
# 16023      Ford      EcoSport  2017.0  10498       Manual  13613.0   Petrol
# 60263      Opel   Crossland X  2018.0  13995       Manual   1800.0   Petrol
# 44131  Mercedes     GLC Class  2018.0  30495    Semi-Auto  11943.0   Diesel
# 37194  Mercedes       C Class  2015.0  13498       Manual  14480.0    etrol
# 6265       Audi            Q3  2013.0  12495    Semi-Auto  52134.0   Diesel
# 54886    Toyota          Aygo  2017.0   8399    Automatic  11304.0   Petrol
# 860        Audi            Q3  2015.0  12990       Manual  69072.0    iesel
# 15795      Ford        Fiesta  2018.0  10495       Manual  16709.0    Petro
#
#          tax       mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 67221  145.0  39.80000         1.5           65.0             4.0        0.0
# 41090  125.0  56.50000         2.1           72.0             4.0        0.0
# 16023  125.0  88.32164         1.0           57.0             3.0        0.0
# 60263  150.0  57.70000         1.2           69.0             0.0        0.0
# 44131  150.0  56.50000         2.1           74.0             NaN        0.0
# 37194  125.0  53.30000         2.0           78.0             0.0        0.0
# 6265   200.0  47.90000         2.0           38.0             2.0        0.0
# 54886  145.0  67.00000         1.0           57.0             3.0        0.0
# 860    125.0  60.10000         2.0           74.0             2.0        0.0
# 15795  145.0  64.20000         1.1           38.0             1.0        0.0

# %% [markdown]
# From the visualization of the head and tail of the data base we can already understand that some errors exist:
#
#     - Missing values
#     - Values in the columns Year, hasDamage, previousOwners that should be integers as floats (2020.0)
#     - Floats on mpg, previousOwners column with diferent decimal cases length.
#     - It looks like the column hasDamage only contains 0's. It's probably a boolean.
#     - Negative values in columns that shouldn't have, per example in previousOwners column.
# We will further analyse this using describe and info.
#
# It's also possible to see that some strings have the same information written in different forms (Petrol as etrol).
# To solve this problem we will uniformize all the values in data preparation

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75973 entries, 69512 to 15795
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           74452 non-null  object
#  1   model           74456 non-null  object
#  2   year            74482 non-null  float64
#  3   price           75973 non-null  int64
#  4   transmission    74451 non-null  object
#  5   mileage         74510 non-null  float64
#  6   fuelType        74462 non-null  object
#  7   tax             68069 non-null  float64
#  8   mpg             68047 non-null  float64
#  9   engineSize      74457 non-null  float64
#  10  paintQuality%   74449 non-null  float64
#  11  previousOwners  74423 non-null  float64
#  12  hasDamage       74425 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 8.1+ MB

# %% [markdown]
# From info we can see that:
#
#     - the year values as floats is impossible.
#     - The previousOwners, hasDamage also as floats but they should be integers and booleans respectively.
#     - Missing values in all features except the price.
#
# What will we do?
#
#     Analyse with describe to have a different view

# %%
train.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  74482.000000   75973.000000   74510.000000  68069.000000  68047.000000
# mean    2017.096611   16881.889553   23004.184088    120.329078     55.152666
# std        2.208704    9736.926322   22129.788366     65.521176     16.497837
# min     1970.000000     450.000000  -58540.574478    -91.121630    -43.421768
# 25%     2016.000000   10200.000000    7423.250000    125.000000     46.300000
# 50%     2017.000000   14699.000000   17300.000000    145.000000     54.300000
# 75%     2019.000000   20950.000000   32427.500000    145.000000     62.800000
# max     2024.121759  159999.000000  323000.000000    580.000000    470.800000
#
#          engineSize  paintQuality%  previousOwners  hasDamage
# count  74457.000000   74449.000000    74423.000000    74425.0
# mean       1.660136      64.590667        1.994580        0.0
# std        0.573462      21.021065        1.472981        0.0
# min       -0.103493       1.638913       -2.345650        0.0
# 25%        1.200000      47.000000        1.000000        0.0
# 50%        1.600000      65.000000        2.000000        0.0
# 75%        2.000000      82.000000        3.000000        0.0
# max        6.600000     125.594308        6.258371        0.0

# %% [markdown]
# From the numeric describe we can see that we have some weird values:
#
#     1. negative mileage, tax, mpg, engineSize, previousOwners in the minimum value
#     2. hasDamage is a boolean but we can see that instead of 0 and 1 we only have 0 and Nones*
#     3. previousOwner has a float? Should we round it?
#
# *check in the hasDamage column
#
# What will we do:
#
#     1. Count the number of negative values and decide if we should drop or change them.
#     2. Replace the nones by 1's. (data-preparation)
#     3. Count the number of float values and decide to drop or round them.

# %%
train.describe(include='object').T
# Out:
#               count unique     top   freq
# Brand         74452     72    Ford  14808
# model         74456    735   Focus   6353
# transmission  74451     40  Manual  38050
# fuelType      74462     34  Petrol  37995

# %% [markdown]
# From the categorical describe we tell that these columns also have missing values.

# %% [markdown]
# ### Missing Values

# %%
train.isna().sum()
# Out:
# Brand             1521
# model             1517
# year              1491
# price                0
# transmission      1522
# mileage           1463
# fuelType          1511
# tax               7904
# mpg               7926
# engineSize        1516
# paintQuality%     1524
# previousOwners    1550
# hasDamage         1548
# dtype: int64

# %% [markdown]
# Almost every column has missing values, with the exception of the 'price' column which will be our predictor.

# %% [markdown]
# ### Unique Values

# %%
for column in train.columns:
    unique_values = train[column].unique()
    print(f"Unique values on the column '{column}': {unique_values}")
    print('-----------------------------------')
    print('')
# Out:
# Unique values on the column 'Brand': ['VW' 'Toyota' 'Audi' 'Ford' 'BMW' 'Skoda' 'Opel' 'Mercedes' 'FOR'
#  'mercedes' 'Hyundai' 'w' 'ord' 'MW' 'bmw' nan 'yundai' 'BM' 'Toyot' 'udi'
#  'Ope' 'AUDI' 'V' 'opel' 'pel' 'For' 'pe' 'Mercede' 'audi' 'MERCEDES'
#  'OPEL' 'koda' 'FORD' 'Hyunda' 'W' 'Aud' 'vw' 'hyundai' 'skoda' 'ford'
#  'TOYOTA' 'ercedes' 'oyota' 'toyota' 'SKODA' 'Skod' 'HYUNDAI' 'kod' 'v'
#  'for' 'SKOD' 'aud' 'KODA' 'PEL' 'yunda' 'or' 'UDI' 'OYOTA' 'HYUNDA' 'mw'
#  'OPE' 'mercede' 'ERCEDES' 'ercede' 'TOYOT' 'MERCEDE' 'ORD' 'ud' 'ope'
#  'AUD' 'hyunda' 'skod' 'toyot']
# -----------------------------------
#
# Unique values on the column 'model': [' Golf' ' Yaris' ' Q2' ' FIESTA' ' 2 Series' '3 Series' ' A3' ' Octavia'
#  ' Passat' ' Focus' ' Insignia' ' A Clas' ' Q3' ' Fabia' ' A Class' ' Ka+'
#  ' 3 Series' ' GLC Class' ' I30' ' C Class' ' Polo' ' E Class' ' C Clas'
#  ' Q5' ' Up' ' Fiesta' ' C-HR' ' Mokka X' ' Corsa' ' Astra' ' TT'
#  ' 5 Series' ' Aygo' ' 4 Series' ' SLK' ' Viva' ' T-Roc' 'Focus'
#  ' EcoSport' ' Tucson' ' EcoSpor' nan ' X-CLASS' ' CL Class' ' IX20'
#  ' i20' ' Rapid' ' a1' ' Auris' ' sharan' ' I20' ' Adam' ' X3' ' A8'
#  ' GLS Class' ' B-MAX' ' A4' ' Kona' ' I10' ' A1' ' Mokka' ' fiesta'
#  ' S-MAX' ' X2' ' Crossland X' ' Tiguan' ' A5' ' GLE Class' ' C CLASS'
#  ' mokka x' ' Zafira' ' Ioniq' ' A6' ' Mondeo' ' Yeti Outdoor' ' X1'
#  'POLO' ' INSIGNIA' ' Scala' ' S Class' ' 1 Series' ' Kamiq' ' Kuga'
#  ' Tourneo Connect' ' Q7' ' GLA Class' ' Arteon' ' polo' ' SL CLASS'
#  'Tucson' ' Santa Fe' ' Grandland X' ' I800' ' ASTRA' ' RAV4' ' c class'
#  ' Touran' ' Citigo' ' Focu' ' Roomster' ' Prius' ' Corolla' ' Fiest'
#  ' B Class' ' Sharan' ' Q' ' Kodiaq' ' V Class' ' POLO' ' GOLF' ' E Clas'
#  ' Caddy Maxi Life' ' SUPERB' ' Astr' ' Getz' 'T-Roc' ' YARIS'
#  ' Combo Life' ' FOCUS' ' Beetle' ' E CLASS' ' PRIUS' 'Fabia' ' Galaxy'
#  ' M3' ' GTC' ' 2 series' '1 Series' ' 1 SERIES' ' X4' 'Golf' 'Auris'
#  ' KA' ' IX35' ' 3 Serie' 'E Class' ' Grand Tourneo Connect' ' Shara'
#  ' M4' ' 3 series' ' Tourneo Custom' 'Touran' ' Superb' ' focus'
#  '5 Series' ' Z4' ' 2 serie' ' X5' ' Meriva' ' Octavi' ' yeti outdoor'
#  ' Kug' ' RS6' ' Verso' ' Touareg' ' MONDEO' ' Shuttle' ' CLS Class'
#  ' C-MAX' ' Mokka ' ' Puma' ' CLA Class' ' I40' ' q3' ' x1' 'X5'
#  ' Tiguan Allspace' ' 6 Series' ' Caravelle' ' crossland x' ' 4 SERIES'
#  ' Karoq' ' a5' ' I3' 'A4' ' Mokk' 'Ka+' ' Grand C-MAX' ' Pol'
#  ' GRAND C-MAX' ' T-Cross' ' 4 Serie' 'Astra' 'Q3' ' viva' ' 4 serie'
#  ' A7' ' GLE Clas' ' Golf SV' 'A Class' ' A' ' 1 Serie' ' KUGA' ' Gol'
#  ' Agila' ' AURIS' ' Ayg' ' GT86' 'C Class' ' astra' ' corsa' ' Yeti'
#  ' California' '4 series' ' X' 'A5' 'Touareg' ' Land Cruiser' ' MOKKA X'
#  ' a4' ' EDGE' ' i10' ' 5 Serie' ' X6' 'Toura' 'Karoq' ' Caddy Life'
#  ' rav4' ' 8 Series' 'GLC Class' 'Polo' ' Fusion' ' GL Class' ' Scirocco'
#  ' TOURAN' ' kuga' ' Z3' ' SL CLAS' ' fabia' ' Kodia' 'ASTRA' ' tiguan'
#  '2 Series' ' PROACE VERSO' ' hilux' ' Passa' ' Hilux' 'GLA Class'
#  ' Amarok' ' FABIA' ' Edge' 'CLA Class' ' CC' ' x5' ' Insigni' ' 7 Series'
#  'Q5' ' Avensis' ' 5 SERIES' 'Meriva' ' Eos' ' M Class' 'Yaris' ' VERSO'
#  'A1' ' Grandland ' 'Mondeo' 'Corsa' ' Zafira Tourer' ' ECOSPORT' ' RS5'
#  'Tiguan' 'A3' ' TUCSON' ' R8' ' b class' '4 Series' ' Mustang' ' V Clas'
#  ' 5 series' 'GLE Class' ' Tigua' ' I1' ' cl class' ' B-MA' 'Grandland X'
#  'Viva' 'Kuga' ' Antara' ' Q8' ' Ka' ' T-RO' ' Camry' ' FOCU'
#  ' YETI OUTDOOR' ' 1 series' ' Rapi' ' auris' 'Fiesta' 'RAV4' ' CLK'
#  'Mokka X' ' mondeo' ' RS3' ' a3' ' a class' ' Jetta' ' e class'
#  ' 3 SERIES' 'focus' 'Golf SV' ' m class' ' i3' ' golf' ' Kadjar' ' Cors'
#  ' Zafira Toure' ' q5' ' GLC CLASS' 'U' ' PASSAT' ' MERIVA' 'A6' ' Yari'
#  ' SQ5' ' slk' ' B Clas' ' KAMIQ' ' aygo' 'Mokka' 'Prius' ' passat'
#  ' A CLASS' ' VIVA' ' rapid' ' mokka ' ' insignia' ' mokka' ' Citig'
#  ' S-MA' ' RS4' ' puma' ' ayg' ' Supra' ' x2' ' AYGO' ' 4 series' 'golf'
#  ' GALAXY' ' Tucso' ' i8' ' X7' ' Galax' ' t-roc' ' Super' ' sq7'
#  ' G Class' ' i30' ' C-H' ' 2 SERIES' ' GLA CLASS' ' KONA' ' OCTAVIA'
#  ' x-clas' ' x3' 'I10' ' grandland x' ' GLC Clas' ' S3' 'Insignia' 'Focu'
#  ' COMBO LIFE' 'I40' ' I80' ' tt' 'Zafira' ' Crossland ' 'B-MAX'
#  ' 2 Serie' ' Arteo' ' Tigra' ' CORSA' ' Escort' ' GLB Class' ' 3 serie'
#  ' c-hr' ' SCALA' ' MONDE' ' yaris' ' GLA Clas' ' CL Clas' ' Vivaro'
#  ' Verso-S' 'gtc' ' Monde' ' corolla' ' 7 Serie' ' T-Ro' ' up' ' X-CLAS'
#  'Adam' ' gla class' ' TOUAREG' ' Ioni' ' T-Cros' 'Passat' ' gle class'
#  ' Viv' ' M5' '2 Serie' ' kodiaq' ' x-class' ' Veloste' 'Superb'
#  ' Santa F' 'Aygo' ' Zafir' 'Octavia' 'C-MAX' ' S4' ' T-ROC' ' UP'
#  ' citigo' ' Yeti Outdoo' ' edge' ' Auri' ' santa fe' ' mustang' 'Citigo'
#  ' q7' ' Fabi' ' q2' ' IQ' ' glc class' 'RAV' ' A2' ' gt86' ' CL CLASS'
#  ' yeti' 'Hilux' ' TIGUAN' ' Caddy Maxi' '200' 'SL CLASS' ' CITIGO'
#  ' amarok' 'Up' ' verso' ' scirocco' 'Ioniq' 'Q8' ' U' 'Arteon' ' superb'
#  'Q7' ' T-CROSS' ' KA+' ' Streetka' ' Roomste' ' ZAFIRA' ' ecosport'
#  'Scala' ' v class' ' ka+' ' x' ' KAMI' ' c-max' ' karoq' ' Caddy' 'polo'
#  'Z4' 'B Class' ' galaxy' ' octavia' ' TIGUAN ALLSPACE' ' KAROQ' ' ka'
#  ' caravelle' ' Cascada' 'GTC' ' scala' ' s-max' 'C-HR' 'kodiaq' 'B-MA'
#  ' C-MA' ' Accent' 'CLS Class' ' tourneo custom' ' cls class' ' touareg'
#  ' KODIAQ' 'TT' ' Karo' ' 6 SERIES' ' b-max' ' SCIROCCO' ' shuttle' ' Kon'
#  'Octavi' ' tourneo connect' ' Scirocc' ' a6' 'S Class' ' PUMA'
#  ' grand c-max' ' S8' ' RS' ' touran' 'Q2' 'C Clas' 'Kona' ' a' 'X2'
#  ' CROSSLAND X' ' gol' ' tiguan allspace' ' Golf S' ' RAV' ' K' ' S Clas'
#  ' SANTA FE' ' Grand C-MA' ' Toura' 'E CLASS' 'S-MAX' 'M3' ' Beetl' 'rav4'
#  'I20' ' COROLLA' ' s3' ' zafira' 'Mustang' ' V CLASS' 'x1' ' a7'
#  'Santa Fe' 'EcoSport' ' tucson' 'Beetle' ' TIGUA' ' Ada' ' INSIGNI'
#  ' grandland ' ' adam' 'SLK' ' Z' ' CLS Clas' 'Amarok' ' s class'
#  'a class' ' SQ7' ' AVENSIS' ' Ranger' 'Crossland X' 'fiesta' 'X6' 'Fiest'
#  ' golf s' ' golf sv' ' I2' 'Scirocco' ' MOKKA' ' Grand Tourneo Connec'
#  ' M' 'RS6' ' S CLASS' ' Meriv' 'Zafir' ' Caravell' 'Pol' ' C CLAS' ' cc'
#  'Verso' '220' ' super' 'A8' ' VECTRA' ' combo life' '5 SERIES' ' B CLASS'
#  ' CLS CLASS' ' KON' ' Tiguan Allspac' ' IONIQ' ' CLA CLASS' 'Sharan'
#  ' ix20' 'Insigni' 'Tourneo Connect' ' Scal' ' 6 series' ' 8 Serie' '230'
#  'UP' 'Galaxy' ' scal' ' Ampera' 'T-Cross' 'FIESTA' ' Fox' 'Fusion'
#  ' Urban Cruiser' 'astra' 'b class' 'a8' ' GLS Clas' ' ADAM' ' avensis'
#  ' Amaro' 'I30' 'Arteo' ' M2' ' T' ' M CLASS' ' kona' 'M Class' 'IONIQ'
#  'Tigua' '6 Series' ' Coroll' '1 SERIES' ' 1 SERIE' ' Combo Lif' 'Golf S'
#  'Roomster' ' cors' ' GL CLASS' 'CC' 'X1' ' Caddy Maxi Lif' 'aygo' ' yari'
#  'X7' 'X3' ' prius' ' kamiq' ' TUCSO' ' M Clas' 'Z3' 'Supra' ' t-cros'
#  'Yari' ' sl class' ' Touare' ' i40' 'CL Class' ' YARI' ' GOL' ' meriva'
#  'Yeti Outdoor' ' CORS' 'c class' 'A CLASS' ' GLS CLASS' 'TIGUAN' ' S5'
#  'COMBO LIFE' ' Tourneo Custo' ' a clas' 'corsa' 'e class' ' Edg' 'Tucso'
#  ' 7 SERIES' 'A7' ' Yet' 'i3' ' IX2' 'FABIA' ' c clas' '1 series' ' focu'
#  ' 1 serie' ' TOURA' 'Corolla' ' SL' ' i' 'Vectra' ' 7 series' 'q5'
#  ' CLC Class' ' GOLF SV' 'KA' 'tiguan' ' M6' 'CLK' ' gtc' ' SHARAN' 'Gol'
#  ' Hilu' ' GLE CLASS' 'M5' ' gls class' 'Mokka ' '3 Serie' ' glc clas'
#  ' ix35' 'IX35' 'V Class' ' Urban Cruise' 'Rapid' 'Combo Life' ' z4'
#  ' ioniq' ' GRANDLAND X' ' t-cross' 'corolla' 'R8' 'Mokk' 'octavia'
#  ' 6 Serie' ' JETTA' ' Land Cruise' 'ka+' ' rav' 'Grand C-MAX' ' 8 series'
#  'RS3' 'kuga' ' cla class' ' ARTEON' ' r8' ' beetle' ' gl class' 'Yeti'
#  'GL Class' 'IX20' ' Vectra' ' 8 SERIES' ' Vers' ' Terracan'
#  ' ZAFIRA TOURER' 'Kodiaq' 'Zafira Tourer' ' m3' ' AYG' 'Avensis' ' s-ma'
#  'X4' ' m4' 'yaris' 'FOCUS' ' arteon' ' glb class']
# -----------------------------------
#
# Unique values on the column 'year': [2016.         2019.         2018.         2014.         2017.
#  2020.         2013.                   nan 2015.         2023.36707842
#  2011.         2012.         2023.1169636  2003.         2009.
#  2007.         2005.         2011.11118842 2011.21085349 2023.97731126
#  2004.         2010.         2010.56500919 2008.         2024.12175905
#  2006.         2023.60527574 2023.38982198 2010.67696784 2001.
#  2000.         2023.26798867 2010.26863473 2010.37154646 2002.
#  2022.69668507 2009.81675711 2010.7464032  2012.69574039 1996.
#  1998.         2022.87800554 1970.         1999.         1997.        ]
# -----------------------------------
#
# Unique values on the column 'price': [22290 13790 24990 ... 33606 16809 25785]
# -----------------------------------
#
# Unique values on the column 'transmission': ['Semi-Auto' 'Manual' 'anual' 'Semi-Aut' 'Automatic' 'manual' nan
#  'unknown' 'Manua' 'AUTOMATIC' 'MANUAL' 'semi-auto' ' Manual ' 'automatic'
#  'emi-Auto' 'SEMI-AUTO' 'SEMI-AUT' 'Automati' 'ANUAL' 'utomatic' 'unknow'
#  'EMI-AUTO' 'manua' 'anua' 'emi-Aut' 'MANUA' 'emi-auto' 'UTOMATIC'
#  ' manual ' ' MANUAL ' 'UNKNOWN' 'nknown' 'automati' 'Other' 'semi-aut'
#  ' Manual' 'AUTOMATI' 'utomati' 'Manual ' 'manual ' 'nknow']
# -----------------------------------
#
# Unique values on the column 'mileage': [28421.  4589.  3624. ... 13613. 52134. 69072.]
# -----------------------------------
#
# Unique values on the column 'fuelType': ['Petrol' 'Diesel' 'etrol' 'Hybrid' 'diesel' 'iesel' nan 'petrol' 'PETROL'
#  'Diese' 'Petro' 'DIESEL' 'petro' 'HYBRID' 'ybri' 'Other' 'DIESE' 'Hybri'
#  'ETROL' 'ybrid' 'PETRO' 'hybrid' 'IESEL' 'Electric' 'ther' 'iese' 'etro'
#  'ETRO' 'diese' 'Othe' 'YBRID' 'HYBRI' 'OTHER' 'other' 'IESE']
# -----------------------------------
#
# Unique values on the column 'tax': [         nan 145.          30.          20.         150.
#  160.         -56.19320154   0.         125.         200.
#  250.         135.         300.         205.         260.
#  326.02823317 325.         -45.78061049 265.         305.
#  303.14889146 235.         299.47350391 240.         165.
#  140.         540.         155.         220.         120.
#  330.         290.48678508 -20.24107949 -18.33074314 327.91577835
#  270.         115.         185.         316.48718937 570.
#  -49.15354066 316.29630636 -60.6840948  555.         277.38425448
#  -91.12163048  10.         315.         190.         -31.91494466
#  230.         -43.24208237 294.84340933 195.         580.
#  290.         130.         565.         210.         280.
#  255.         520.         295.         245.         110.
#  535.        ]
# -----------------------------------
#
# Unique values on the column 'mpg': [ 11.41726775  47.9         40.9         65.7         42.8
#   60.1         68.9         62.8         67.3         54.3
#   57.7                 nan  56.5         72.4         47.1
#   44.1         46.3         32.5         48.7         74.3
#   43.5         78.5         51.4         50.4         67.
#   28.5         64.2         61.4         41.5         52.3
#   53.3         44.8         35.8         80.7         37.2
#   49.6         42.2         45.6         34.          74.4
#   29.1         76.3         40.3         58.9         39.8
#   55.4         40.4         78.4         83.1         33.2
#   34.5         70.6         35.3         39.2         32.8
#   34.9         61.7         30.         156.9         36.2
#   58.          38.2         69.          37.7         57.6
#   66.         151.04180955   9.42917895  85.6         58.8
#   89.77369267  78.          30.4         36.7        235.
#  134.5         27.70948954  88.32163955  88.3         56.6
#  -43.42176751 100.99894302  31.          38.7         33.6
#   20.74549979  22.1        188.3         47.7         43.4
#   31.4         28.8         76.4         24.6         68.8
#   55.          29.4         94.1         20.71009481  31.7
#   32.1         32.9         30.1         22.4         53.
#   28.          94.78638042   5.5          6.          30.7
#   47.          27.2          1.1         43.          65.6
#   29.7         21.4          9.82146197  86.          29.5
#   23.5         26.4        113.          55.5         81.56893961
#   16.3501525  117.7         43.6        166.          92.82689954
#   22.6         24.8         26.9         33.7        470.8
#  256.8         54.4        166.2          8.8        217.3
#   25.5         23.          21.6        110.34497687 148.7
#   25.4         22.2        141.2         38.1         27.4
#   23.7        122.8         61.1         22.8         20.9
#   44.6         92.11045521  34.4         23.3         42.4
#   27.7         78.6         28.3         14.49714632  20.8
#   23.9        201.8        176.6         21.1         24.1
#   42.1         25.2         19.5        141.3         19.6
#   46.          38.6          2.8         40.          30.8
#   28.2         51.3         51.1         22.3         42.9
#   24.4         17.8        122.9        135.5         26.7
#   33.3         21.9         62.7         20.5        235.4
#   42.          37.6         19.8         26.6         42.16
#   19.          20.3         21.7         54.2         25.9
#   26.3        128.4         20.          19.1        100.9
#   48.4         21.          26.2         19.3         54.7
#   27.9         67.7         53.5       ]
# -----------------------------------
#
# Unique values on the column 'engineSize': [ 2.          1.5         1.          1.4         1.6                nan
#   1.2         3.          1.8         2.1         1.3         0.7395339
#   0.          2.3         1.1         4.          1.7         2.98579344
#   2.2         2.5         2.61964142 -0.1034928   2.78177621  2.63120047
#   3.72371217  0.15452932  4.2         3.2         2.9         2.8
#   0.31340658  2.06411863  3.73923548  2.4         0.18642488  2.6631132
#   5.2         0.19146242  5.          0.30707394  0.37112737  4.4
#   6.2         3.82275785  1.9         0.6         6.6         5.5
#   3.5         4.7         0.16286595  2.7         3.6         2.6
#   4.3         5.4         4.5         4.1         6.        ]
# -----------------------------------
#
# Unique values on the column 'paintQuality%': [ 63.          50.          56.          97.          74.
#   75.          59.          85.          35.          68.
#   45.          30.          69.          53.          57.
#   40.          60.          94.          33.          51.
#   47.          87.          61.          83.          95.
#   46.          54.          80.          77.          90.
#   91.          71.          44.          38.          64.
#   55.          66.          82.          41.          81.
#   79.          72.          34.          88.                  nan
#   43.          31.          32.          96.          84.
#   70.          86.          92.          52.          39.
#   42.          73.          78.          37.          65.
#   93.          89.          99.          36.          62.
#  125.10995148   3.1152953   67.         125.5694986   76.
#   48.           3.17268306  49.           3.25476013 125.59430832
#   98.          58.           3.20741784 125.4535988    3.14037046
#    1.76947364   3.22574362 125.30194543 125.20203342 125.18872876
#  125.36650692   2.72515272 125.00377307   1.63891309]
# -----------------------------------
#
# Unique values on the column 'previousOwners': [ 4.          1.         -2.34030622  3.          0.          2.
#          nan -2.34565     6.25837066 -2.33512284  6.22789796  6.25823052
#   6.23017958 -2.33936045  6.21772443  6.24583495 -2.29943868 -2.34010209
#  -2.31225953  6.2482512  -2.31733109  6.23308217  6.24177863 -2.33744529]
# -----------------------------------
#
# Unique values on the column 'hasDamage': [ 0. nan]
# -----------------------------------

# %% [markdown]
# Comments on the results above for each feature:
# - `Brand` have significant inconsistencies with case sensitivity, ('mercede', 'FOR'), and fragmented entries ('pel', 'udi').
#
# - `Model` have a lot of variations due to leading/trailing spaces, inconsistent casing, typos ('Focu' instead of 'Focus'), and incomplete entries ('A Clas').
#
# - `Year` have decimal/fractional values (e.g., 2023.36707842) suggests data encoding errors or floating-point artifacts.
#
# - `Price` have numeric and diverse.
#
# - `Transmission` column with multiple variants and typos exist for common types (e.g., 'Manual', 'manua', 'anual'). Also we noticed that in this columns there are 'Unknown' values.
#
# - `Mileage` appears mostly clean and numeric.
#
# - `FuelType` have many spelling and case variations (e.g., 'Petrol', 'petrol', 'etrol') exist.
#
# - `Tax` with negative and fractional values are suspicious.
#
# - `MPG` looks like contain outliers and invalid negative values.
#
# - `EngineSize` includes some unusual negative and zero values that should be verified.
#
# - `PaintQuality%` have some values greater than 100%, what is not possible.
#
# - `PreviousOwners` contains unexpected negative/fractional values and NaNs.
#
# - `HasDamage` is Binary flag with values 0 and NaN.

# %% [markdown]
# ### Check for duplicates

# %%
print(f"The duplicates without the index is: {train.duplicated().sum()}") 
print(f"The duplicates with the index is: {train.index.has_duplicates}")

print(f"The percentages of duplicates is: {(train.duplicated().sum()/len(train) * 100).round(4)}%")
# Out:
# The duplicates without the index is: 4
# The duplicates with the index is: False
# The percentages of duplicates is: 0.0053%

# %% [markdown]
# From the code above we conclude that we have 4 entries with the same values but different ID's. Because they represent 0.0053% of the whole dataset we decided to drop them.

# %%
train = train.drop_duplicates()

# %% [markdown]
# ### Count Values

# %%
for column in train.columns:
    count_values = train[column].value_counts()
    print(f"The number of the distinct values in the column '{column}' is: {count_values}")
    print('-----------------------------------')
    print('')
# Out:
# The number of the distinct values in the column 'Brand' is: Brand
# Ford        14806
# Mercedes    10754
# VW           9780
# Opel         8645
# BMW          6968
#             ...
# kod             2
# TOYOT           1
# SKOD            1
# skod            1
# toyot           1
# Name: count, Length: 72, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'model' is: model
#  Focus        6351
#  C Class      4886
#  Fiesta       4130
#  Golf         3081
#  Corsa        2182
#               ...
# UP               1
#  scal            1
#  Fox             1
# astra            1
#  glb class       1
# Name: count, Length: 735, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'year' is: year
# 2019.000000    20270
# 2017.000000    16144
# 2016.000000    11502
# 2018.000000    10303
# 2015.000000     5733
# 2020.000000     3174
# 2014.000000     2930
# 2013.000000     1902
# 2012.000000      478
# 2011.000000      318
# 2010.000000      241
# 2009.000000      228
# 2008.000000      158
# 2007.000000      123
# 2010.676968       82
# 2023.116964       77
# 2005.000000       64
# 2006.000000       62
# 2010.746403       58
# 2023.977311       55
# 2023.389822       53
# 2011.210853       50
# 2010.565009       47
# 2023.267989       43
# 2023.605276       39
# 2009.816757       37
# 2010.371546       35
# 2004.000000       35
# 2024.121759       34
# 2003.000000       29
# 2023.367078       26
# 2002.000000       25
# 2012.695740       21
# 2010.268635       20
# 2022.696685       19
# 2001.000000       15
# 2011.111188       15
# 2022.878006       12
# 2000.000000        6
# 1998.000000        5
# 1999.000000        5
# 1970.000000        2
# 1997.000000        2
# 1996.000000        1
# Name: count, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'price' is: price
# 9995     406
# 10995    360
# 8995     359
# 11000    334
# 12995    329
#         ...
# 21320      1
# 22416      1
# 39923      1
# 6301       1
# 25785      1
# Name: count, Length: 11048, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'transmission' is: transmission
# Manual       38048
# Semi-Auto    15545
# Automatic    14001
# anual          804
# MANUAL         801
# manual         770
# Manua          759
# unknown        690
#  Manual        366
# Semi-Aut       332
# emi-Auto       325
# semi-auto      324
# utomatic       313
# SEMI-AUTO      309
# Automati       304
# AUTOMATIC      289
# automatic      282
# unknow          18
# Manual          16
# UNKNOWN         14
# ANUAL           13
# nknown          13
# anua            12
# SEMI-AUT        11
# MANUA           11
# emi-auto        10
#  MANUAL          9
#  Manual          7
# EMI-AUTO         7
#  manual          6
# automati         6
# AUTOMATI         6
# utomati          6
# Other            5
# emi-Aut          5
# semi-aut         4
# UTOMATIC         2
# manua            2
# manual           1
# nknow            1
# Name: count, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'mileage' is: mileage
# 1000.0     577
# 10.0       560
# 5000.0     507
# 6000.0     340
# 100.0      318
#           ...
# 29248.0      1
# 41240.0      1
# 19704.0      1
# 2268.0       1
# 69072.0      1
# Name: count, Length: 34808, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'fuelType' is: fuelType
# Petrol      37992
# Diesel      28474
# Hybrid       2042
# PETROL        795
# etrol         794
# Petro         785
# petrol        746
# iesel         603
# diesel        599
# Diese         582
# DIESEL        582
# Other         150
# HYBRID         50
# hybrid         46
# Hybri          43
# ybrid          37
# petro          18
# etro           17
# IESEL          16
# ETROL          16
# PETRO          14
# DIESE          10
# iese           10
# diese           8
# ther            6
# Othe            6
# Electric        4
# YBRID           3
# OTHER           3
# HYBRI           2
# other           2
# ybri            1
# ETRO            1
# IESE            1
# Name: count, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'tax' is: tax
# 145.0    32860
# 150.0     7400
# 30.0      5781
# 20.0      5610
# 125.0     4496
#          ...
# 130.0        1
# 520.0        1
# 295.0        1
# 245.0        1
# 535.0        1
# Name: count, Length: 65, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'mpg' is: mpg
# 60.1    4195
# 65.7    3188
# 54.3    2791
# 64.2    2459
# 51.4    2449
#         ...
# 42.4       1
# 61.1       1
# 38.1       1
# 6.0        1
# 53.5       1
# Name: count, Length: 217, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'engineSize' is: engineSize
#  2.000000    20105
#  1.000000    13613
#  1.500000     9156
#  1.400000     7432
#  1.600000     6380
#  1.200000     4749
#  3.000000     3806
#  2.100000     3624
#  1.800000     1192
#  1.300000      920
#  1.700000      618
#  1.100000      385
#  2.500000      312
#  4.000000      295
#  2.200000      295
#  2.300000      181
#  0.000000      180
#  2.900000      116
# -0.103493       84
#  2.631200       80
#  0.307074       65
#  3.723712       63
#  2.985793       52
#  0.186425       52
#  0.739534       52
#  2.064119       51
#  4.400000       46
#  2.400000       43
#  0.154529       39
#  5.000000       38
#  3.739235       38
#  0.313407       35
#  5.500000       31
#  3.822758       27
#  2.800000       26
#  2.619641       25
#  0.162866       24
#  1.900000       23
#  0.191462       21
#  4.200000       20
#  2.781776       19
#  6.200000       19
#  3.200000       19
#  0.371127       18
#  4.700000       18
#  5.200000       17
#  2.663113       17
#  3.500000       12
#  2.700000        7
#  0.600000        4
#  5.400000        2
#  4.100000        1
#  4.500000        1
#  6.600000        1
#  4.300000        1
#  2.600000        1
#  3.600000        1
#  6.000000        1
# Name: count, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'paintQuality%' is: paintQuality%
# 34.000000     1147
# 94.000000     1128
# 54.000000     1114
# 32.000000     1106
# 88.000000     1099
#               ...
# 125.453599      23
# 2.725153        21
# 1.638913        19
# 125.188729      17
# 3.254760        15
# Name: count, Length: 88, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'previousOwners' is: previousOwners
#  0.000000    14879
#  4.000000    14760
#  1.000000    14754
#  3.000000    14648
#  2.000000    14644
# -2.340306       84
#  6.258231       78
#  6.245835       64
# -2.345650       58
# -2.339360       58
#  6.258371       50
#  6.233082       46
# -2.299439       43
#  6.230180       37
# -2.335123       37
# -2.312260       34
#  6.248251       32
# -2.337445       25
#  6.217724       21
#  6.241779       20
# -2.340102       17
#  6.227898       15
# -2.317331       15
# Name: count, dtype: int64
# -----------------------------------
#
# The number of the distinct values in the column 'hasDamage' is: hasDamage
# 0.0    74421
# Name: count, dtype: int64
# -----------------------------------

# %% [markdown]
# Most of all the comments that can be done from the results above were already done after the .unique() analysis.
# With both this analysis we are planning to do the following for each feature:
#
# - `Brand`, `Model`, `Transmission` and `FuelType`: unify capitalization, spacing and correct spelling errors and inconsistent spellings.
#
# - `Year`: convert all values to integers and fix or remove non-sensical decimal values.
#
# - `Price`: drop from the dataset and assign to a target variable.
#
# - `Mileage`, `Tax`, `MPG`, `EngineSize` and `PreviousOwners`: ensure values are numeric and postive, detect and handle unrealistic or extreme values (e.g., negative, float or abnormall values in the feature context).
#
# - `PaintQuality%`: cap values between 0 and 100.
#
# - `HasDamage`: maybe assign the nan values to 1 cause we only have 0's and this should be a boolean feature.
#
# Besides all this notes we need also to consider all the missing value noticed before on the DataFrame.

# %% [markdown]
# ### GroupBy

# %%
print(train.groupby('hasDamage')['price'].mean())

print('--------------------------------------------------------')

print(train.groupby('year')['price'].mean())

print('--------------------------------------------------------')

print(train.groupby('previousOwners')['price'].mean())

print('--------------------------------------------------------')

print(train.groupby('Brand')['price'].mean())
# Out:
# hasDamage
# 0.0    16883.327287
# Name: price, dtype: float64
# --------------------------------------------------------
# year
# 1970.000000    17747.000000
# 1996.000000     3000.000000
# 1997.000000     6972.500000
# 1998.000000    10183.800000
# 1999.000000     3986.000000
# 2000.000000     3869.166667
# 2001.000000     4401.000000
# 2002.000000     3206.920000
# 2003.000000     3452.517241
# 2004.000000     4179.914286
# 2005.000000     3007.468750
# 2006.000000     3958.580645
# 2007.000000     3454.910569
# 2008.000000     3913.069620
# 2009.000000     4141.008772
# 2009.816757    19686.486486
# 2010.000000     5016.514523
# 2010.268635    12568.100000
# 2010.371546    24268.114286
# 2010.565009    11370.425532
# 2010.676968    12834.268293
# 2010.746403    18257.810345
# 2011.000000     6771.940252
# 2011.111188    13038.466667
# 2011.210853    22981.640000
# 2012.000000     7601.456067
# 2012.695740    12633.095238
# 2013.000000     8503.491062
# 2014.000000    10025.783276
# 2015.000000    11654.296180
# 2016.000000    13357.350287
# 2017.000000    14475.293360
# 2018.000000    16314.916238
# 2019.000000    23530.970005
# 2020.000000    28523.561122
# 2022.696685    18240.315789
# 2022.878006    12044.000000
# 2023.116964    13091.064935
# 2023.267989    10435.581395
# 2023.367078    12987.346154
# 2023.389822    15873.886792
# 2023.605276    23876.717949
# 2023.977311    23824.981818
# 2024.121759    20832.794118
# Name: price, dtype: float64
# --------------------------------------------------------
# previousOwners
# -2.345650    17138.000000
# -2.340306    12196.988095
# -2.340102    14144.235294
# -2.339360    25103.706897
# -2.337445    15017.600000
# -2.335123    22344.594595
# -2.317331    16457.400000
# -2.312260    22590.323529
# -2.299439    10813.976744
#  0.000000    16854.936824
#  1.000000    16945.351227
#  2.000000    16875.898525
#  3.000000    16789.507987
#  4.000000    16947.543631
#  6.217724    13609.476190
#  6.227898    10201.400000
#  6.230180    24213.540541
#  6.233082    10370.434783
#  6.241779    14378.650000
#  6.245835    16817.609375
#  6.248251    22069.218750
#  6.258231    11886.000000
#  6.258371    26952.560000
# Name: price, dtype: float64
# --------------------------------------------------------
# Brand
# AUD       14242.500000
# AUDI      22921.319444
# Aud       21950.415493
# Audi      22899.203586
# BM        21653.453901
#               ...
# v         19095.714286
# vw        16370.020725
# w         13126.800000
# yunda     11096.333333
# yundai    12532.485294
# Name: price, Length: 72, dtype: float64

# %% [markdown]
# The mean of price of the cars without damage is approximately 16883. It would be interesting to compare with the one's with damage (1's), but we don't have any information about them.
#
# It's also possible to verify that the price varies depending on the year of manufacture of the cars. This is, the older the car, the cheaper it is.
#
# For the number of previous Owners, we don't see major differences on the average price.
#
# Finally, when analysing the average price per brand, we can already see some differences between brands, per example, Hyundai's cars have lower average than Audi's cars.

# %% [markdown]
# ### Correlation between variables

# %%
numeric_features = train[['year', 'mileage', 'price', 'tax', 'mpg', 'engineSize', 'paintQuality%', 'previousOwners']]
numeric_features.corr(method="pearson").round(3)
# Out:
#                  year  mileage  price    tax    mpg  engineSize  \
# year            1.000   -0.669  0.476  0.179 -0.123      -0.038
# mileage        -0.669    1.000 -0.405 -0.202  0.167       0.099
# price           0.476   -0.405  1.000  0.297 -0.286       0.612
# tax             0.179   -0.202  0.297  1.000 -0.419       0.257
# mpg            -0.123    0.167 -0.286 -0.419  1.000      -0.227
# engineSize     -0.038    0.099  0.612  0.257 -0.227       1.000
# paintQuality%   0.004   -0.001  0.000  0.006 -0.003       0.005
# previousOwners  0.000    0.002 -0.000  0.003 -0.001       0.001
#
#                 paintQuality%  previousOwners
# year                    0.004           0.000
# mileage                -0.001           0.002
# price                   0.000          -0.000
# tax                     0.006           0.003
# mpg                    -0.003          -0.001
# engineSize              0.005           0.001
# paintQuality%           1.000          -0.006
# previousOwners         -0.006           1.000

# %% [markdown]
# From the code before it's difficult to get conclusions. We will visualize this matrix in a easy way of getting conclusions.

# %%
corr = numeric_features.corr(method="pearson").round(2)

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Visualize correlation matrix
fig = plt.figure(figsize=(10, 8))

sns.heatmap(
    corr,
    mask=mask,                # hide upper triangle
    annot=True,               # show values
    cmap="coolwarm",          # divergent color map
    center=0,                 # center colormap in 0
    linewidths=0.5,           # lines between cells to help visualization
    vmin=-1, vmax=1,          # fix scale
    square=True               # make cells square-shaped
)


plt.title("Correlation Matrix (Pearson)", fontsize=14, pad=15)
plt.tight_layout() # improve layout by reducing overlaps
plt.show()

# %%
corr = numeric_features.corr(method="spearman").round(2)

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Visualize correlation matrix
fig = plt.figure(figsize=(10, 8))

sns.heatmap(
    corr,
    mask=mask,                # hide upper triangle
    annot=True,               # show values
    cmap="coolwarm",          # divergent color map
    center=0,                 # center colormap in 0
    linewidths=0.5,           # lines between cells to help visualization
    vmin=-1, vmax=1,          # fix scale
    square=True               # make cells square-shaped
)


plt.title("Correlation Matrix (Spearman)", fontsize=14, pad=15)
plt.tight_layout() # improve layout by reducing overlaps
plt.show()

# %% [markdown]
# So from the correlation analysis with both spearman and pearson methods we can say that our model’s most important numerical predictors will likely be:
# - year, mileage, engineSize
# - tax and mpg might add secondary predictive power.
# - paintQuality%, previousOwners, and hasDamage probably won’t help much unless cleaned or reinterpreted.

# %% [markdown]
# ### Descriptive Statistics and Visualizations
#
# This section starts by split our data in metric and non-metric features

# %%
non_numeric_features = train.drop(columns=numeric_features.columns)
#The variable associated to the numeric features was already created before with the name numeric_features

print("Numeric Features:")
for i, feature in enumerate(numeric_features, 1):
    print(f" {i}. {feature}")

print("\nCategorical Features:")
for i, feature in enumerate(non_numeric_features, 1):
    print(f" {i}. {feature}")
# Out:
# Numeric Features:
#  1. year
#  2. mileage
#  3. price
#  4. tax
#  5. mpg
#  6. engineSize
#  7. paintQuality%
#  8. previousOwners
#
# Categorical Features:
#  1. Brand
#  2. model
#  3. transmission
#  4. fuelType
#  5. hasDamage

# %% [markdown]
# Now we do the histograms for each numeric feature.

# %%
# General settings
sns.set(style="whitegrid", palette="pastel", font_scale=1.3)

sp_rows, sp_cols = 4, 2
fig, axes = plt.subplots(sp_rows, sp_cols, figsize=(24, 15))

# Lista ou set com as features discretas
discrete_features = ["year", "previousOwners"]  # substitua pelos nomes corretos

# Plot data
# Iterate across axes objects and associate each histogram
for ax, feat in zip(axes.flatten(), numeric_features):
    # KDE apenas para features contínuas
    kde_flag = False if feat in discrete_features else True
    sns.histplot(data=train, x=feat, bins=15, kde=kde_flag, ax=ax)
    
    ax.set_title(feat, fontsize=13, pad=10)
    ax.set_ylabel("Frequência")
    ax.grid(True, linestyle="--", alpha=0.6)

# General Layout
fig.suptitle("Distribuição das Variáveis Numéricas", fontsize=18, fontweight='bold', y=0.95)
fig.tight_layout(rect=[0, 0, 1, 0.96])

# Save the figure
save_path = os.path.join("..", "figures", "eda")
os.makedirs(save_path, exist_ok=True)

plt.savefig(os.path.join(save_path, "numeric_variables_histograms.png"), dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# With the evaluation of the histograms we can affirmate that:
#
# `Year` - The distribution is heavily concentrated around recent years (≈2010–2020), with a sharp rise toward newer models. The decrease in 2020 it can be explained by the Covid years.
#
# `Price` - The distribution is strongly right-skewed, most cars are low or mid-priced, but a few luxury vehicles inflate the tail. Some prices are extreme outliers, possibly due to rare high-end models. From here we can say that the market is dominated by affordable vehicles.
#
# `Mileage` - Also right-skewed, which is expected. Most used cars have moderate mileage, and a few have very high values. The histogram shows again negative values.
#
# `Tax` - Sharp peak around a specific value (≈150–200), indicating standardized taxation rates for most vehicles. Some negative or zero values are also noticed.
#
# `Mpg` - Distribution shows that most cars cluster around 20 to 90 mileage per gallon , with few very high or very low values, the negatives values being incorrect.
#
# `EngineSize` - Multiple peaks, possibly due to different engine categories (1.0L, 1.5L, 2.0L, etc.). The pattern may reflect distinct market segments.
#
# `PaintQuality%` - Fairly uniform distribution across mid-to-high values (40–100%), indicating most vehicles have decent paint condition. We can see a few very low or very high values that are outliers. The highest outliers are incorrect values because this column should have values between 0 and 100 since it's a percentage.
#
# `PreviousOwners` - Peaks at 0 to 4 owners, with some repeating density spikes, maybe because the variable is discrete (integer count). In here we confirm the outliers in this column. The negative values don't make sense.

# %% [markdown]
# Now we do the boxplot for each numeric feature.

# %%
# Style settings
sns.set_theme(style="whitegrid", palette="pastel")

# Prepare figure with appropriate number of rows and columns
n_features = len(numeric_features.columns)
n_cols = 2  
n_rows = ceil(n_features / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 3))
axes = axes.flatten()

# Plot boxplots
for i, feat in enumerate(numeric_features.columns):
    ax = axes[i]

    # Boxplot with highlighted median line
    sns.boxplot(
        x=numeric_features[feat],
        ax=ax,
        color='skyblue',
        medianprops={"color": "darkblue", "linewidth": 2},
        boxprops={"alpha": 0.7}
    )
    
    ax.set_title(f"{feat}", fontsize=12, fontweight='bold')
    ax.set_xlabel("")  # Remove automatic x-label
    ax.grid(True, linestyle="--", alpha=0.4)

# Remove empty axes (if the number of features is not a multiple of n_cols)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# General title and layout
plt.suptitle("Boxplots of Numeric Variables", fontsize=18, fontweight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %% [markdown]
# Based on the boxplots shown above, it can be observed that:
#
# `Year` - The distribution is heavily concentrated around recent years, approximately between 2012 and 2022, with a few older vehicles appearing as outliers (from 1970 to 2010).
#
# `Price`- This boxplot is right-skewed, with a large proportion of outliers ranging approximately from £40,000 up to £160,000, showing a wide interval compared to the main body of the data.
#
# `Mileage` - Mileage displays a positively skewed distribution with several high-value outliers and a negative value appears in the data.
#
# `Tax`- The distribution is concentrated around specific values but includes some outliers.
#
# `Mpg`- The distribution is mostly concentrated but includes both low and very high outliers. Some extreme values, such us those above 200 mpg are unrealistic and will be validated.
#
# `EngineSize`- The boxplot shows most engines concentrated between 1.0 and 2.0L, with several larger values appearing as outliers.
#
# `PaintQuality%`- This boxplot shows few distinct values spread across a wide range, with numeric codes representing quality levels.
#
# `PreviousOwners`- The distribution is concentrated between 1 and 3 owners, with a few outliers, including cars with more than 6 owners and some negative values.

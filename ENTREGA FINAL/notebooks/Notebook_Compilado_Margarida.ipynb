# %% [markdown]
# <b><font size="6"> Cars 4 You: Predicting Car Values with ML </font></b><br><br>
#
# `Group 40`
#
# Ana Macedo (20250405)<br>
# Catarina Mendinhas (20250422)<br>
# Lourenço Silva (20250453)<br>
# Maria Fonseca (20250380)<br>

# %% [markdown]
# ### <font color= '#0400ffff'>**Methodology** </font><a class="anchor" id='top'></a>
#
# - [1. Abstract](#1)
# - [2. Import Libraries](#2)
# - [3. Metadata](#3)
# - [4. Import Datasets](#4)
#     - [4.1 Define new index](#4_1)
# - [5. Data Preprocessing](#5)
#     - [5.1 Types Correction](#5_1)
#         - [5.1.1 Year and previousOwners columns correction](#5_1_1)
#         - [5.1.2 hasDamage Column Correction](#5_1_2)
#     - [5.2 Categorical Features correction](#5_2)
#         - [5.2.1 Correct the values](#5_2_1)
#         - [5.2.2 Check corrections](#5_2_2)
#     - [5.3 Invalid Values](#5_3)
#         - [5.3.1 Invalid Values Analysis](#5_3_1)
#         - [5.3.2 Invalid Values Treatment](#5_3_2)
# - [6. Data Partition](#6)
# - [7. Data Transformation](#7)
#     - [7.1 Outliers Treatment](#7_1)
#     - [7.2 Feature Engineering ](#7_2)
#     - [7.3 Missing Values Imputation](#7_3)
#     - [7.4 Scaling Features](#7_4)
#     - [7.5 Save the Processed Data](#7_5)
#     - [7.6 Encoding](#7_6)
# - [8. Feature Selection](#8)
#     - [8.1 Remove paintQuality%](#8_1)
#     - [8.2 Filter Methods](#8_2)
#         - [8.2.1 Removing Constant Features](#8_2_1)
#         - [8.2.2 Correlation between features - Redundant Features](#8_2_2)
#         - [8.2.3 Correlation with the target - Relevant Features](#8_2_3)
#     - [8.3 Wrapped Methods](#8_3)
#         - [8.3.1 RFE](#8_3_1)
#     - [8.4 Embedded Methods](#8_4)
#         - [8.4.1 Lasso](#8_4_1)
#     - [8.5 Comparison between Models](#8_5)
# - [9. Model and Assessment](#9)
#     - [9.1 Create a Sample to Test Models](#9_1)
#     - [9.2 Define the Scores to Evaluate](#9_2)
#     - [9.3 KNN](#9_3)
#         - [9.3.1 Define Model and Grid Parameters](#9_3_1)
#         - [9.3.2 Test KNN using Samples](#9_3_2)
#         - [9.3.3 Test KNN using the entire Dataset](#9_3_3)
# - [10. Save results to Kaggle](#10)
# - [11. End of the Notebook](#11)

# %% [markdown]
# <a class="anchor" id="1">
#
# # **1. Abstract**
#
# [Back to TOP](#TOP)
# </a>
#
# !!!colocar o abstract final depois

# %% [markdown]
# <a class="anchor" id="2">
#
# # **2. Import Libraries**
#
# [Back to TOP](#TOP)
# </a>
#
# The development of the analyses and models for this project relies on a robust set of Python libraries. Pandas and NumPy are utilized for efficient data manipulation, cleaning, and numerical operations, while Matplotlib and Seaborn support the creation of clear and informative visualizations. Auxiliary libraries such as os, math, and difflib facilitate file management, mathematical calculations, and the correction of categorical variables via text similarity, respectively.
#
# Data preprocessing is executed using Scikit-learn, employing tools like OneHotEncoder for encoding, and a combination of MinMaxScaler, StandardScaler, and RobustScaler for normalization, ensuring resilience against outliers. Missing value handling is managed through simple and nearest-neighbor (KNNImputer) imputation strategies.
#
# Feature selection is addressed comprehensively through three methodologies: filter methods (including VarianceThreshold, Spearman correlation, SelectKBest, and Mutual Information), wrapper methods (RFE - Recursive Feature Elimination), and embedded methods (Lasso).
#
# For predictive modeling, the project explores various regression algorithms, including K-Nearest Neighbors (KNN), Random Forest, and Neural Networks (MLPRegressor), with hyperparameter optimization conducted via RandomizedSearchCV. Rigorous performance evaluation is ensured by metrics such as R^2, MAE, MSE, and MAPE, complemented by detailed statistical analysis provided by Statsmodels. Finally, result reproducibility is guaranteed through the definition of random seeds.

# %%
# General Useful Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from math import ceil
import math

# Text Similarity - Categorical Features Correction
from difflib import SequenceMatcher

# Scaling and Encoding
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, TargetEncoder, MinMaxScaler, StandardScaler, RobustScaler

# Missing Value Imputation
from sklearn.impute import KNNImputer, SimpleImputer

# Data Partition
from sklearn.model_selection import train_test_split

#filter methods
from sklearn.feature_selection import VarianceThreshold
from scipy.stats import spearmanr

# spearman 
from sklearn.feature_selection import SelectKBest, f_regression

# mutual information
from sklearn.feature_selection import mutual_info_classif

#wrapper methods
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.feature_selection import RFE

# embedded methods
from sklearn.linear_model import Lasso

from sklearn.model_selection import RandomizedSearchCV, PredefinedSplit

#KNN
from sklearn.neighbors import KNeighborsRegressor

# Random Forest
from sklearn.ensemble import RandomForestRegressor

#Neural Network
from sklearn.neural_network import MLPRegressor

# DecisionTree
from sklearn.tree import DecisionTreeRegressor

#Model evaluation
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, median_absolute_error, mean_absolute_percentage_error
import statsmodels.api as sm

# Load Created Functions
import sys
sys.path.append("../")

from Source.visualizations import *
from Source.data_preprocessing import *
from Source.feature_engineering import *
from Source.feature_selection import *
from Source.model_and_assessment import *

# Set random seed for reproducibility
np.random.seed(40111)


#!pip install tqdm tqdm-joblib

#from tqdm.auto import tqdm
#from tqdm_joblib import tqdm_joblib

# %% [markdown]
# <a class="anchor" id="3">
#
# # **3. Metadata**
#
# [Back to TOP](#TOP)
# </a>
#
# Understanding the features is essential to interpret the data correctly and conduct the subsequent analysis and modeling steps. This section provides a brief description of each feature in the dataset, explaining its meaning and type.

# %% [markdown]
# **carID:** An attribute that contains an identifier for each car.
#
# **Brand:** The car's main brand (e.g., Ford, Toyota).
#
# **model:** The car model.
#
# **year:** The year of registration of the car.
#
# **price:** The car's price when purchased by Cars 4 You (in £).
#
# **transmission:** The car's type of transmission.
#
# **mileage:** The total reported distance travelled by the car (in miles).
#
# **tax:** The amount of road tax (in £) that, in 2020, was applicable to the car in question.
#
# **fuelType:** The type of fuel used by the car (Diesel, Petrol, Hybrid, Electric).
#
# **mpg:** The car's consumption of fuel expressed in average miles per gallon.
#
# **engineSize:** Size of the engine in liters (Cubic Decimeters).
#
# **paintQuality%** The mechanic’s assessment of the cars’ overall paint quality and hull integrity (filled by the mechanic during evaluation).
#
# **previousOwner:** Number of previous registered owners of the vehicle.
#
# **hasDamage:** Boolean marker filled by the seller at the time of registration stating whether the car is damaged or not.

# %% [markdown]
# <a class="anchor" id="4">
#
# # **4. Import Datasets**
#
# [Back to TOP](#TOP)
# </a>
#
# Here, we are importing with pd.read_csv() the files to start our project and converting them into Pandas DataFrames. CarID was set to index since it's the unique identifier in all data sets.

# %%
train = pd.read_csv('../../data/train.csv')
test = pd.read_csv('../../data/test.csv')

# %% [markdown]
# <a class="anchor" id="4">
#
# ## **4.1** Define new index
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# For all partitions we will assign the "carID" column as the index, as it represents the number identifier for each individual car.

# %%
train.set_index('carID', inplace = True)
test.set_index('carID', inplace = True)

# %% [markdown]
# <a class="anchor" id="5">
#
# # **5. Data Cleaning**
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# <a class="anchor" id="5_1">
#
# ## **5.1** Metric Features Correction
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# During the Exploratory Data Analysis (EDA) we identified some erros that will now be treated:
#
# - In the columns `Year`, `hasDamage` and `previousOwners` floats exist but these columns should only have integers as they represent discrete variables and a boolean in the case of hasDamage.
#
# - In some columns negative values exist that make no sense.
#
# - The column hasDamage is binary but only has 0's and Nan, what lead us to think that the Nan values represent the 1's.
#
# For these mistakes we will:
#
# - Consider the integer part to the floats that should be integers.
#
# - Replace the negative values with Nan to later be treated has missing values.
#
# - Fill the Nan values with 1's in the hasDamage feature.

# %% [markdown]
# Regarding the negative tax values, we thought they could represent to incentives on electric vehicles, so we will see if this checks out.

# %%
negtax_electric = train[(train['tax'] < 0) & (train['fuelType'] == 'Electric')]
print(f"Number of rows with negative 'tax' and 'Electric' fuel type: {len(negtax_electric)}")
negtax_electric[['tax', 'fuelType']].head(10)
# Out:
# Number of rows with negative 'tax' and 'Electric' fuel type: 0
# Empty DataFrame
# Columns: [tax, fuelType]
# Index: []

# %% [markdown]
# From this analysis, we see that there are no electric vehicles with negative tax, so we eliminate that possibility and correct all negative values by using a function defined by us on the `data_preprocessing.py` file.

# %%
train = correct_metric_features(train)
test = correct_metric_features(test)

# %% [markdown]
# <a class="anchor" id="5_2">
#
# ## **5.2** Categorical Features Correction
#
# [Back to TOP](#TOP)

# %% [markdown]
# We had identified earlier that the categorical features present a lot of misspellings. We will address that here using a function specifically created to correct these values.

# %% [markdown]
# <a class="anchor" id="5_2_1">
#
# ### **5.2.1** Correct the values
#
# [Back to TOP](#TOP)

# %% [markdown]
# Now we are able to correct the values by calling the function.
#
# To reach the thresholds for each feature, we used a trial and error approach. We found that the optimal thresholds depend both on the length of the word and on the number and similarity between unique observations of each feature.
#
# To address these challenges, we created two thresholds, one for shorter words (<=5 characters) and another for longer words (>5 characters). This was important because the word similarity function we used (SequenceMatcher) uses ratios to identify similar words and so each character has different 'weights' based on the length of the word.
#
# Because of the reduced number of unique observations on most features, we saw that this solution was particularly important for the "model" feature since it has a very high number of unique observations and also very similar model names.

# %%
# Correct 'Brand' column
train = clean_with_diff(train, 'Brand', threshold_short=0.6, threshold_long=0.6)
test = clean_with_diff(test, 'Brand', threshold_short=0.6, threshold_long=0.6)

# Correct 'transmission' column
train = clean_with_diff(train, 'transmission', threshold_short=0.7, threshold_long=0.7)
test = clean_with_diff(test, 'transmission', threshold_short=0.7, threshold_long=0.7)

# Correct 'model' column
train = clean_with_diff(train, 'model', threshold_short=0.70, threshold_long=0.90)
test = clean_with_diff(test, 'model', threshold_short=0.70, threshold_long=0.90)

# Correct 'fuelType' column
train = clean_with_diff(train, 'fuelType', threshold_short=0.8, threshold_long=0.8)
test = clean_with_diff(test, 'fuelType', threshold_short=0.8, threshold_long=0.8)

# %% [markdown]
# <a class="anchor" id="5_2_2">
#
# ### **5.2.2** Check corrections
#
# [Back to TOP](#TOP)
#
# Now we will analyse the results of our treatments for each feature.

# %%
corrected_columns = ['Brand', 'transmission', 'model', 'fuelType']

for column in corrected_columns:
    unique_values_train = train[column].unique()
    print(f"Unique values on the column '{column}' (train): {unique_values_train}")
    print('')
    print('-----------------------------------')
    print('')
# Out:
# Unique values on the column 'Brand' (train): ['VW' 'Toyota' 'Audi' 'Ford' 'BMW' 'Skoda' 'Opel' 'Mercedes' 'Hyundai' nan]
#
# -----------------------------------
#
# Unique values on the column 'transmission' (train): ['Semi-Auto' 'Manual' 'Automatic' nan 'unknown' 'Other']
#
# -----------------------------------
#
# Unique values on the column 'model' (train): [' Golf' ' Yaris' ' Q2' ' Fiesta' ' 2 Series' ' 3 Series' ' A3' ' Octavia'
#  ' Passat' ' Focus' ' Insignia' ' A Class' ' Q3' ' Fabia' ' Ka+'
#  ' GLC Class' ' I10' ' C Class' ' Polo' ' E Class' ' Q5' ' Up' ' C-HR'
#  ' Mokka X' ' Corsa' ' Astra' ' TT' ' 5 Series' ' Aygo' ' 4 Series' ' SLK'
#  ' Viva' ' T-Roc' ' EcoSport' ' Tucson' nan ' X-CLASS' ' X2' ' Rapid'
#  ' A1' ' Auris' ' Sharan' ' Adam' ' X3' ' A8' ' B-MAX' ' A4' ' Kona'
#  ' Mokka' ' S-MAX' ' Crossland X' ' Tiguan' ' A5' ' Zafira' ' Ioniq' ' A6'
#  ' Mondeo' ' Yeti Outdoor' ' X1' ' Scala' ' SL CLASS' ' 1 Series' ' Kamiq'
#  ' Kuga' ' Tourneo Connect' ' Q7' ' Arteon' ' Santa Fe' ' Grandland X'
#  ' I800' ' Touran' ' Citigo' ' Roomster' ' Prius' ' Corolla' ' B Class'
#  ' Kodiaq' ' V Class' ' Caddy Maxi Life' ' Superb' ' Getz' ' Combo Life'
#  ' Beetle' ' Galaxy' ' M3' ' GTC' ' X4' ' 3 Serie'
#  ' Grand Tourneo Connect' ' M4' ' Tourneo Custom' ' Z4' ' X5' ' Meriva'
#  ' RS6' ' Verso' ' Touareg' ' Shuttle' ' CLS Class' ' C-MAX' ' Puma'
#  ' Tiguan Allspace' ' 6 Series' ' Caravelle' ' Karoq' ' Grand C-MAX'
#  ' T-Cross' ' A7' ' GLE Clas' ' Golf SV' 'A Class' ' Agila' ' GT86'
#  ' Yeti' ' California' ' Land Cruiser' ' Edge' ' X6' 'Toura' ' Caddy Life'
#  ' 8 Series' ' Fusion' ' Scirocco' ' Z3' ' SL CLAS' ' PROACE VERSO'
#  ' Hilux' 'GLA Class' ' Amarok' 'CLA Class' ' CC' ' 7 Series' ' Avensis'
#  ' Eos' ' M Class' ' Zafira Tourer' ' R8' ' Mustang' 'GLE Class' ' I1'
#  ' Antara' ' Q8' ' Camry' 'RAV4' ' Jetta' ' Kadjar' 'U' ' Supra' ' X7'
#  ' G Class' 'I10' ' S3' 'Focu' 'I40' ' Tigra' ' Escort' ' GLA Clas'
#  ' CL Clas' ' Vivaro' ' Verso-S' ' M5' '2 Serie' ' Veloste' ' S4' ' IQ'
#  ' A2' ' Caddy Maxi' '200' 'SL CLASS' ' Streetka' ' Caddy' ' Cascada'
#  'B-MA' ' Accent' 'Octavi' ' S8' 'C Clas' 'X2' ' K' ' Ranger' 'Fiest'
#  'Zafir' '220' ' VECTRA' 'Insigni' '230' ' Ampera' ' Fox' ' Urban Cruiser'
#  ' GLS Clas' 'Arteo' ' M2' 'Tigua' 'Golf S' 'Yari' ' S5' 'Tucso' 'i3' 'KA'
#  ' M6' 'CLK' 'Mokka ' 'IX35' 'Mokk' 'RS3' ' Terracan']
#
# -----------------------------------
#
# Unique values on the column 'fuelType' (train): ['Petrol' 'Diesel' 'Hybrid' nan 'Other' 'Electric']
#
# -----------------------------------

# %% [markdown]
# **Important Note:** For most of the columns that were corrected, the function seems to have worked properly. However, in the case of the 'model' column, the results were not as good as in the other columns. This is because the original data contained a high number of unique and incorrect values, some of which were very similar to each other, having just one character difference between the wrong and correct model, but also just one different character from another model's name. This makes it impossible to achieve a perfect correction with this approach.
#
# Example: 2 Serie (wrong), 3 Serie (wrong), 2 Series (correct), 3 Series (correct)
#
# Nevertheless, the vast majority of the data is now properly cleaned and corrected and we will stick with this method.

# %% [markdown]
# Also based on the previous unique values analysis, we decided to check the percentage of the 'Other' category in the 'transmission' column. If the proportion is not significant, we believe it would be reasonable to replace it with an 'Unknown' category, as this simplification could make the next steps of our analysis easier and more consistent.

# %%
(train[train['transmission'] == 'Other'].shape[0] / train.shape[0] * 100).__round__(4)
# Out:
# 0.0066

# %% [markdown]
# The percentage is very small so we are going to replace the category as mentioned before.

# %%
train = replace_category_transmission(train)
test = replace_category_transmission(test)

# %% [markdown]
# **Important:** Before applying any outliers treatment we need to split the data into train and validation sets. This is important to avoid data leakage. After splitting the data we can apply the method using only the training set statistics.

# %% [markdown]
# <a class="anchor" id="6">
#
# # **6. Data Partition**
#
# [Back to TOP](#TOP)

# %% [markdown]
# Define the independent features as X and the dependent as Y

# %%
X = train.drop('price', axis = 1)
y = train['price']

# %% [markdown]
# Split the dataset into train and validation

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size = 0.2, random_state = 0,  shuffle = True)

# %% [markdown]
# <a class="anchor" id="7">
#
# # **7. Data Transformation**
#
# [Back to TOP](#TOP)

# %% [markdown]
# <a class="anchor" id="7_1">
#
# ## **7.1** Outliers Treatment
#
# [Back to TOP](#TOP)

# %% [markdown]
# To identify outliers, we decided to use the **Interquartile Range (IQR) method** and apply it to all numerical features.
#
# The following analysis identifies the number and percentage of outliers per features, helping to evaluate whether data cleaning or transformation is be necessary before modeling.

# %% [markdown]
# Here we will create a function to return a summary of the total number of outliers per feature and how much they represent of the total in percentage. This summary is based on the IQR method and we will analyse the train dataset only.

# %%
outlier_summary(X_train)
# Out:
#            Column  Total Outliers  Percentage (%)
# 0            year            1437            2.36
# 1         mileage            2603            4.28
# 2             tax           15938           26.22
# 3             mpg             922            1.52
# 4      engineSize             494            0.81
# 5   paintQuality%               0            0.00
# 6  previousOwners               0            0.00
# 7       hasDamage            1257            2.07

# %% [markdown]
# From this, we take that most numeric features do not have a big share of outliers, as they represent less than 5% of all observations. Only the feature `tax` has a very big number of ouliers, with 26.23% of the whole population.
#
# We are now going to analyse these graphically through boxplots.

# %%
create_boxplots(X_train)

# %% [markdown]
# We started by applying the IQR method and then we realized it eliminated too much data, which then hurt the model's results and decided to create different thresholds specific for each feature:
#
# - `year:` between 1990 and 2020
# - `mileage`,`tax`, `mpg`: 2.2 IQR multiplier
# - `engineSize:` between 0.9L and 5.5L
# - `previousOwners:` between 0 and 6
#
# To reach the 2.2 IQR multiplier and the upper and lower limits, we used a trial and error approach. We found that 2.2 was a good middle ground because the default multiplier eliminated too many features and this is a way to widen the range of accepted results while eliminating extreme outliers.

# %% [markdown]
# Now specifically for each feature:
#
# - `year:` Cars older than 1990 were extremely rare and introduced high price variance, while years beyond 2020 are not possible (dataset is from 2020); restricting the range improves data realism and model stability.
# - `mileage:` Mileage has a strong right-skew; using a 2.2 IQR multiplier caps extreme values that disproportionately reduce accuracy without removing legitimate high-mileage cases.
# - `tax:` Very high tax values occur infrequently and are often errors or special situations; applying a 2.2 IQR multiplier reduces the effect of unrealistic taxation outliers.
# - `mpg:` Fuel efficiency extremes are uncommon and distort pricing; a 2.2 IQR multiplier tightens the distribution while preserving real variability across models.
# - `engineSize:` Values below 0.9L or above 5.5L correspond to niche or erroneous entries; bounding engine size maintains realistic ranges and limits skew.
# - `previousOwners:` The IQR visualisation shows no outliers for this feature and more than 6 previous owners is highly atypical. It signals noisy observations and capping reduces their undue influence on vehicle price.

# %% [markdown]
# Apply custom thresholds

# %%
X_train_clean = treat_outliers_custom(X_train, X_train)
X_val_clean = treat_outliers_custom(X_train, X_val)
test_clean = treat_outliers_custom(X_train, test)

# %%
X_train = X_train_clean.copy()
X_val = X_val_clean.copy()
test = test_clean.copy()

# %% [markdown]
# Visualize results after the outlier treatment

# %%
create_boxplots(X_train)

# %% [markdown]
# Analysing our results, we see that the distributions are much more balanced, with fewer outliers. The outliers that remain should be significant for our analysis, as they are close to the IQR limits and have a significant number of observations.

# %% [markdown]
# <a class="anchor" id="7_2">
#
# ## **7.2** Feature Engineering
#
# [Back to TOP](#TOP)

# %% [markdown]
# In this stage of the project, we created new features designed to enhance the predictive power of our model. These engineered variables fall into two main groups:
#
# 1. Features derived directly from existing variables, without using statistical aggregates such as mean, median or mode.
# 2. Features computed using aggregate statistics, which must be calculated exclusively on the training set (X_train) to avoid data leakage.
#
# Below, we describe each feature and the motivation behind its inclusion.
#
# **1. Directly Engineered Features**
#
# - `car_age:` calculate the age of the car considering the current year and the year of its registration. This feature helps us to capture depreciation, this is, older cars tend to be cheaper.
#
# - `is_recent_car:` binary flag, 1 if the car is less than 3 years old, otherwise 0. We decided to create this feature because highlights newer cars, usually have higher resale prices.
#
# - `mileage_category:` transforms the original continuous mileage feature into an ordered categorical feature with five usage levels according to the total mileage.  This way it's easier to capture differences in vehicle wear and market value.
#
# - `is_hybrid_or_eletric:` binary indicator that is 1 if the fuel type is Hybrid or Electric. Eco-friendly cars often hold higher market value.
#
# - `is_automatic:`binary indicator that is 1 if the type of transmission is automatic or semi-automatic. Automatics typically cost more to buy and maintain.
#
# - `fuel_eficciency_score:` Ratio of mpg / engineSize. Captures how efficiently the car converts fuel given engine capacity.
#
# - `tax_to_engine_ratio:` Tax value divided by engine size. Indicates how expensive it is to maintain the car relative to its power.
#
# - `tax_efficency:` mpg / tax. Measures how fuel-efficient the car is relative to its yearly tax burden.
#
# - `is_first_owner:` binary indicator that is 1 if there were no previous owners. First-owner cars tend to have less wear, better care and higher prices.
#
# - `ownership_ratio:` previousOwner / car_age. Captures how frequently ownership changed. Frequent changes might signal reliability issues.
#
#
# **2. Features Based on Statistical Aggregation (Train-Only)**
#
# - `brand_median_mileage:` median mileage per brand. Typical mileage level for each brand that is able to capture brand usage patterns.
#
# - `brand_avg_engineSize`: engineSize mean per brand. Represents typical engine capacity of each brand.
#
# - `model_median_tax:` median tax per model. Captures model-specific taxation tendencies.
#
# - `fueltype_avg_mpg:` mpg mean per fuelType. Average fuel efficiency for each fuel type.
#
# - `brand_avg_age:` car_age mean per brand. Average car age per brand, basically compare newer against older brands.
#
# All feature engineering steps were encapsulated in a dedicated function, stored in the file feature_engineering.py, which was already imported and will be now applied to the dataset as needed.

# %%
X_train.shape
# Out:
# (60778, 12)

# %%
X_train_fe = create_features(X_train, X_train, current_year=2020, threshold=3)
X_val_fe = create_features(X_train, X_val, current_year=2020, threshold=3)
test_fe = create_features(X_train, test, current_year=2020, threshold=3)

# Update dataframes to include new features
X_train = X_train_fe.copy()  
X_val = X_val_fe.copy()
test = test_fe.copy()

# %%
X_train.shape
# Out:
# (60778, 26)

# %% [markdown]
# <a class="anchor" id="7_3">
#
# ## **7.3** Missing Values Imputation
#
# [Back to TOP](#TOP)

# %% [markdown]
# Before starting to fill missing values, we plot a table with the missing value percentages. With this we can easily identify columns with many absent entries and decide whether they are relevant for the model or should be discarded or imputed.

# %%
missing_df = missing_values_table(X_train)
missing_df
# Out:
#                   Feature  Missing_Percent
# 0     tax_to_engine_ratio        12.708546
# 1          tax_efficiency        12.701965
# 2   fuel_efficiency_score        12.305439
# 3                     tax        10.867419
# 4                     mpg        10.446214
# 5          previousOwners         2.515713
# 6          is_first_owner         2.515713
# 7                 mileage         2.364342
# 8        mileage_category         2.364342
# 9              engineSize         2.089572
# 10           transmission         2.031985
# 11          paintQuality%         2.025404
# 12                  Brand         1.992497
# 13   brand_avg_engineSize         1.992497
# 14   brand_median_mileage         1.992497
# 15          brand_avg_age         1.992497
# 16                car_age         1.971108
# 17                   year         1.971108
# 18          is_recent_car         1.971108
# 19               fuelType         1.956300
# 20       fueltype_avg_mpg         1.956300
# 21       model_median_tax         1.948073
# 22                  model         1.946428
# 23           is_automatic         0.000000
# 24  is_hybrid_or_electric         0.000000
# 25              hasDamage         0.000000

# %% [markdown]
# Although some features have missing values, none have a sufficiently high percentage to warrant removal. All columns are considered relevant and can be retained for modeling, with missing values handled through imputation where necessary.

# %%
X_train_treated = impute_missing(X_train, X_train, method='simple')
X_val_treated = impute_missing(X_train, X_val, method='simple')
test_treated = impute_missing(X_train, test, method='simple')

# %%
# # Try to impute missing values with KNN to see differences in the model results
# X_train_treated = impute_missing(X_train, X_train, method='knn')
# X_val_treated = impute_missing(X_train, X_val, method='knn')
# test_treated = impute_missing(X_train, test, method='knn')

# %%
X_train = X_train_treated.copy()
X_val = X_val_treated.copy()
test = test_treated.copy()

# %% [markdown]
# Now we verify that there are no missing values left in the datasets

# %%
# Check that there are no missing values left
if all(df.isnull().sum().sum() == 0 for df in [X_train, X_val]):
    print("PERFECT! All datasets are treated and have no missing values.")
else:
    print("ATENTTION!!!! There are still missing values in at least one of the datasets.")
# Out:
# PERFECT! All datasets are treated and have no missing values.

# %% [markdown]
# <a class="anchor" id="7_4">
#
# ## **7.4** Encoding
#
# [Back to TOP](#TOP)

# %% [markdown]
# Before training machine learning models, it is necessary to convert categorical features into a numerical format, as most algorithms cannot process non-numeric data directly. This step, known as encoding, ensures that the categorical information can be effectively interpreted by the models without losing its meaning.
#
# In this section, we will apply `One-Hot Encoding` to features with a small number of categories (Brand, Transmission, fuelType) and use a `Ordinal Encoder` for the features that contains many distinct categories (model). This approach allows us to represent all categorical features in a consistent and efficient way, preparing the dataset for further preprocessing and model development.

# %%
X_train_encoded = encoding_features(X_train, y_train, X_train)
X_val_encoded = encoding_features(X_train, y_train, X_val)
test_encoded = encoding_features(X_train, y_train, test)
# A warning may appear if some categories in validation/test were not present in training. This happens because the Encoder was fitted only on the training data.
# With this, the program emits a warning and assigns zeros to those unseen categories, but continues to run normally.

# %%
# Update dataframes to encoded versions
X_train = X_train_encoded.copy()
X_val = X_val_encoded.copy()
test = test_encoded.copy()

# %%
X_train
# Out:
#          year  mileage    tax   mpg  engineSize  paintQuality%  \
# carID
# 59459  2016.0  29601.0   81.0  62.8         1.0           42.0
# 49082  2017.0  62140.0  145.0  64.2         2.0           40.0
# 14425  2008.0  87470.8  189.0  42.2         2.0           59.0
# 13190  2019.0  11208.0  145.0  52.3         2.0           72.0
# 60655  2019.0   2357.0  145.0  44.8         1.2           81.0
# ...       ...      ...    ...   ...         ...            ...
# 47192  2019.0   4797.0  145.0  62.8         1.6           95.0
# 71813  2012.0  87470.8  189.0  47.7         2.0           99.0
# 4910   2019.0   1800.0  145.0  47.9         1.0           92.0
# 67195  2017.0  29827.0  125.0  57.6         2.0           41.0
# 15659  2017.0  30605.0  145.0  54.3         1.5           34.0
#
#        previousOwners  hasDamage  car_age  is_recent_car  ...  Brand_target  \
# carID                                                     ...
# 59459             2.0        0.0      4.0            0.0  ...  10374.399152
# 49082             3.0        0.0      3.0            1.0  ...  14264.199073
# 14425             1.0        0.0     12.0            0.0  ...  22616.965608
# 13190             4.0        0.0      1.0            1.0  ...  22616.965608
# 60655             3.0        0.0      1.0            1.0  ...  10374.399152
# ...               ...        ...      ...            ...  ...           ...
# 47192             1.0        0.0      1.0            1.0  ...  14264.199073
# 71813             3.0        0.0      8.0            0.0  ...  16922.177681
# 4910              2.0        0.0      1.0            1.0  ...  22810.344043
# 67195             2.0        0.0      3.0            1.0  ...  16922.177681
# 15659             0.0        0.0      3.0            1.0  ...  12940.909573
#
#        model_target  transmission_Manual_ohe  transmission_Semi-Auto_ohe  \
# carID
# 59459   6574.613018                      1.0                         0.0
# 49082  19231.110859                      1.0                         0.0
# 14425  19844.799517                      0.0                         0.0
# 13190  19844.799517                      0.0                         1.0
# 60655  13078.247899                      1.0                         0.0
# ...             ...                      ...                         ...
# 47192  21233.449465                      0.0                         0.0
# 71813  21599.676552                      0.0                         0.0
# 4910   14358.116217                      1.0                         0.0
# 67195  21599.676552                      0.0                         1.0
# 15659  13951.370117                      1.0                         0.0
#
#        transmission_unknown_ohe  fuelType_Electric_ohe  fuelType_Hybrid_ohe  \
# carID
# 59459                       0.0                    0.0                  0.0
# 49082                       0.0                    0.0                  0.0
# 14425                       0.0                    0.0                  0.0
# 13190                       0.0                    0.0                  0.0
# 60655                       0.0                    0.0                  0.0
# ...                         ...                    ...                  ...
# 47192                       0.0                    0.0                  0.0
# 71813                       0.0                    0.0                  0.0
# 4910                        0.0                    0.0                  0.0
# 67195                       0.0                    0.0                  0.0
# 15659                       0.0                    0.0                  0.0
#
#        fuelType_Other_ohe  fuelType_Petrol_ohe  mileage_category_ordinal
# carID
# 59459                 0.0                  1.0                         1
# 49082                 0.0                  0.0                         2
# 14425                 0.0                  1.0                         2
# 13190                 0.0                  0.0                         1
# 60655                 0.0                  1.0                         0
# ...                   ...                  ...                       ...
# 47192                 0.0                  0.0                         0
# 71813                 0.0                  0.0                         2
# 4910                  0.0                  1.0                         0
# 67195                 0.0                  1.0                         1
# 15659                 0.0                  0.0                         1
#
# [60778 rows x 31 columns]

# %% [markdown]
# <a class="anchor" id="7_5">
#
# ## **7.5** Scaling Features
#
# [Back to TOP](#TOP)

# %% [markdown]
# Numerical features are scaled to ensure all features are in a comparable scale. This preserves relative relationships while preventing features with larger ranges from dominating distance or gradient based algorithms, improving model performance and stability.

# %%
# Scale numeric features using our scaling function
X_train_scaled = scaling_features(X_train, X_train, method="standard")
X_val_scaled = scaling_features(X_train, X_val, method="standard")
test_scaled = scaling_features(X_train, test, method="standard")

# %%
# Create copies of the treated datasets
X_train = X_train_scaled.copy()
X_val = X_val_scaled.copy()
test = test_scaled.copy()

# %% [markdown]
# <a class="anchor" id="1">
#
# # **8. Feature Selection**
#
# [Back to TOP](#TOP)
# </a>
#
# In this stage of the project, we design and implement a structured feature selection pipeline. The process begins by removing the feature 'paintQuality%' derived from the mechanic’s evaluation, as these feature will not be considered for modelling.
#
# After this initial reduction, we apply a sequence of filter-based methods to identify and exclude features that are constant, redundant, or highly correlated with the target variable.
#
# Next, we incorporate a wrapper method which is the Recursive Feature Elimination (RFE) to evaluate subsets of features based on model performance. Finally, we use Lasso regression as an embedded method, allowing the model itself to perform feature selection through regularisation.
#
# The rationale is to apply these three complementary approaches (Filter, Wrapper, and Embedded) to the same preprocessed dataset to obtain a robust and diversified assessment of feature relevance. At the end of the process, we compare the sets of features retained by each method. The final subset of features used for modelling is defined by selecting those chosen by at least a predefined number of methods (e.g., 1, 2, or all 3), a threshold that can be adjusted according to project needs.
# This ensures that the final modelling dataset is composed only of the most informative and consistently relevant features.
#
# We also want to note that throughout this notebook we repeatedly inspect the shape of the X_train dataset to verify whether features are being retained or removed as intended during each step of the selection process.

# %% [markdown]
# <a class="anchor" id="5_1">
#
# ## **8.1 Remove paintQuality%**
#
# [Back to TOP](#TOP)
# </a>
#
# This decision is supported by our Exploratory Data Analysis (EDA), where we concluded that these attribute originate from the mechanic’s evaluation. Since the objective of this machine learning project is precisely to replace this stage of the process, the model must operate without relying on such information.

# %%
X_train.shape
# Out:
# (60778, 31)

# %%
X_train = X_train.drop(['paintQuality%'], axis=1, errors='ignore')
X_val = X_val.drop(['paintQuality%'], axis=1, errors='ignore')

# %%
X_train.shape
# Out:
# (60778, 30)

# %% [markdown]
# <a class="anchor" id="5_1">
#
# ## **8.2 Filter Methods**
#
# [Back to TOP](#TOP)
# </a>
#
# Filter methods are ideal for an initial screening of high-dimensional datasets due to their simplicity, even though they are considered less effective than model-based methods.
# In this section, we will explore three filter-based techniques to select the features.

# %% [markdown]
# <a class="anchor" id="5_1_1">
#
# ### **8.2.1 Removing Constant Features**
#
# [Back to TOP](#TOP)
# </a>
#
# This method identifies features that have low or zero variance, which are unlikely to contribute meaningful information to the model, and thus can help to reduce noise and improve efficiency.

# %%
fm_1 = apply_variance_filter(X_train, threshold=0.1, return_summary=True)
# Out:
# Total features kept: 26
# Features selected: ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'previousOwners', 'hasDamage', 'car_age', 'is_recent_car', 'is_hybrid_or_electric', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'tax_efficiency', 'is_first_owner', 'brand_median_mileage', 'brand_avg_engineSize', 'model_median_tax', 'fueltype_avg_mpg', 'brand_avg_age', 'Brand_target', 'model_target', 'transmission_Manual_ohe', 'transmission_Semi-Auto_ohe', 'fuelType_Petrol_ohe', 'mileage_category_ordinal']
# Nº Features eliminated: 4

# %%
#Check the amount of features that were removed
len(fm_1)
# Out:
# 26

# %% [markdown]
# <a class="anchor" id="5_1_2">
#
# ### **8.2.2 Correlation between features - Redundant Features**
#
# [Back to TOP](#TOP)
# </a>
#
# We use correlation measures to identify highly correlated features. Removing redundant features helps reduce multicollinearity and simplifies the dataset, making the model more efficient and easier to interpret.

# %%
fm_2 = remove_highly_correlated_features(X_train[fm_1], threshold=0.8, return_summary=True)
# Out:
# Total features kept: 20
# Features selected: ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'previousOwners', 'hasDamage', 'is_hybrid_or_electric', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'is_first_owner', 'brand_median_mileage', 'brand_avg_engineSize', 'model_median_tax', 'fueltype_avg_mpg', 'brand_avg_age', 'Brand_target', 'model_target', 'transmission_Semi-Auto_ohe']
# Nº Features eliminated: 6

# %%
# Check that some features were removed
len(fm_2)
# Out:
# 20

# %% [markdown]
# <a class="anchor" id="5_1_3">
#
# ### **8.2.3 Correlation with the target - Relevant Features**
#
# [Back to TOP](#TOP)
# </a>
#
# These processes consist of setting a correlation threshold and keeping only the features that show a meaningful relationship with the target feature.
#
# We decided to utilize Spearman correlation because it measures monotonic relationships rather than being strictly limited to linear relationships, as is the case with the Pearson coefficient. This is crucial because, in the context of car pricing, the depreciation (for example mileage) or the impact of other characteristics is often non-linear. Additionally, Spearman is based on rankings, which makes it significantly more robust to outliers, providing a more reliable measure of feature relevance for our dataset.

# %%
filter_cols = spearman_correlation_selection(X_train[fm_2], y_train, threshold=0.2, return_summary=True)
# Out:
# Total features kept: 14
# Features selected by Spearman method: ['model_target', 'year', 'is_automatic', 'fuel_efficiency_score', 'Brand_target', 'engineSize', 'brand_avg_engineSize', 'mileage', 'transmission_Semi-Auto_ohe', 'brand_avg_age', 'mpg', 'tax', 'fueltype_avg_mpg', 'tax_to_engine_ratio']
# Nº Features eliminated: 6

# %% [markdown]
# <a class="anchor" id="5_2">
#
# ## **8.3 Wrapped Methods**
#
# [Back to TOP](#TOP)
# </a>
#
# Wrapper methods evaluate subsets of features by training and assessing a predictive model, making them more computationally expensive but generally more effective than filter approaches. Because they consider feature interactions and model performance directly, they provide a more nuanced selection.
# In this section, we apply a wrapper-based technique to identify the most informative features for our target variable.

# %% [markdown]
# <a class="anchor" id="5_2_1">
#
# ### **8.3.1 RFE**
#
# [Back to TOP](#TOP)
# </a>
#
# Here we use LinearRegression as the estimator for RFE because it is simple, fast to train, and provides a clear interpretation of feature importance through its coefficients.
# We selected 30 features because this represents a meaningful number of predictors while still reducing the dimensionality of the dataset. This choice offers a good balance between model simplicity and information retention, and it also allows for a consistent comparison with the other feature selection methods. We also observed that the filter methods retained fewer than 30 features, which further supports using this threshold for RFE.

# %%
wrapped = rfe_selection(X_train[fm_2], X_val[fm_2], y_train, y_val, LinearRegression, return_summary=True)
wrapped_cols = wrapped[0]
# Out:
# Total Features Kept: 13
# Features Selected by RFE Method: ['year', 'mileage', 'mpg', 'engineSize', 'is_hybrid_or_electric', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'brand_median_mileage', 'brand_avg_engineSize', 'Brand_target', 'model_target', 'transmission_Semi-Auto_ohe']
# Score with 13 features: 2640.815009
# Nº Features eliminated: 7

# %%
train_mae_list = wrapped[1]
val_mae_list = wrapped[2]

plt.plot(list(range(1,len(train_mae_list)+1)), train_mae_list, label="MAE on Training Set", color='yellowgreen')
plt.plot(list(range(1,len(val_mae_list)+1)), val_mae_list, label="MAE on Validation Set", color='dimgray')
plt.xlabel("Number of Features")
plt.ylabel("Mean Absolute Error")
plt.legend()
plt.show()

# %% [markdown]
# <a class="anchor" id="5_3">
#
# ## **8.4 Embedded Methods**
#
# [Back to TOP](#TOP)
# </a>
#
# Embedded methods perform feature selection as part of the model training process itself. By incorporating regularisation or other model-driven selection criteria, they offer a balance between the efficiency of filter methods and the predictive power of wrapper methods.
# Now, we use an embedded method to select features based on their contribution to the model’s optimisation procedure.

# %% [markdown]
# <a class="anchor" id="5_3_1">
#
# ### **8.4.1 Lasso**
#
# [Back to TOP](#TOP)
# </a>
#
# Lasso is a linear regression method that incorporates L1 regularisation to constrain the model’s coefficients. This penalty forces some coefficients to shrink exactly to zero, which means that Lasso performs feature selection as part of the training process. By using this method, we can also define a threshold that helps determine which features should be considered irrelevant when their coefficients are close to zero.

# %%
embedded_cols = lasso_selection(X_train[fm_2], y_train, threshold=0.01, return_summary=True)
# Out:
# Total features kept: 20
# Features selected by Lasso method: ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'previousOwners', 'hasDamage', 'is_hybrid_or_electric', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'is_first_owner', 'brand_median_mileage', 'brand_avg_engineSize', 'model_median_tax', 'fueltype_avg_mpg', 'brand_avg_age', 'Brand_target', 'model_target', 'transmission_Semi-Auto_ohe']
# Nº Features eliminated: 0

# %% [markdown]
# <a class="anchor" id="8_5">
#
# ## **8.5 Feature Importance**
#
# [Back to TOP](#TOP)
# </a>

# %%
mae_importance = DecisionTreeRegressor(criterion='absolute_error', random_state=42).fit(X_train[fm_2], y_train).feature_importances_
df_fi = pd.DataFrame(mae_importance, index=X_train[fm_2].columns, columns=['MAE Importance'])

# %%
df_fi = pd.DataFrame(mae_importance, index=X_train[fm_2].columns, columns=['MAE Importance'])
df_fi['MAE Importance'].sort_values().plot(kind='barh', figsize=(12,6))
# Out:
# <Axes: >

# %%
feature_importance_cols = (
    df_fi
    .sort_values('MAE Importance', ascending=False)
    .head(8)
    .index
    .tolist()
)
feature_importance_cols
# Out:
# ['model_target',
#  'year',
#  'mileage',
#  'engineSize',
#  'fuel_efficiency_score',
#  'mpg',
#  'tax_to_engine_ratio',
#  'previousOwners']

# %% [markdown]
# <a class="anchor" id="5_4">
#
# ## **8.5 Comparison between Models**
#
# [Back to TOP](#TOP)
# </a>
#
# As mentioned previously, we will compare the outputs of the different feature selection methods and identify the features that consistently appear as important for our regression model.
# The function we defined performs this comparison by selecting the features that are retained by at least a minimum number of methods (n_agreed). For example, if n_agreed = 2, the function returns all features that were selected by two or more of the three methods.
#
# We assign the resulting set of selected features to a variable so that we can later use it to build our final modelling dataset, which will include only these chosen predictors.

# %%
comparison_feature_selection(X_train[fm_2], filter_cols, wrapped_cols, embedded_cols, 
                                                 feature_importance_cols, n_agreed=3, return_summary=True)[1]
# Out:
# Total features before selection: 20
# Total features selected by at least 3 methods: 11
# Selected features: ['year', 'mileage', 'mpg', 'engineSize', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'brand_avg_engineSize', 'Brand_target', 'model_target', 'transmission_Semi-Auto_ohe']
#                        Feature  Lasso  RFE  Spearman  Feature Importance  Sum
# 0                         year      1    1         1                   1    4
# 1                      mileage      1    1         1                   1    4
# 2                          tax      1    0         1                   0    2
# 3                          mpg      1    1         1                   1    4
# 4                   engineSize      1    1         1                   1    4
# 5               previousOwners      1    0         0                   1    2
# 6                    hasDamage      1    0         0                   0    1
# 7        is_hybrid_or_electric      1    1         0                   0    2
# 8                 is_automatic      1    1         1                   0    3
# 9        fuel_efficiency_score      1    1         1                   1    4
# 10         tax_to_engine_ratio      1    1         1                   1    4
# 11              is_first_owner      1    0         0                   0    1
# 12        brand_median_mileage      1    1         0                   0    2
# 13        brand_avg_engineSize      1    1         1                   0    3
# 14            model_median_tax      1    0         0                   0    1
# 15            fueltype_avg_mpg      1    0         1                   0    2
# 16               brand_avg_age      1    0         1                   0    2
# 17                Brand_target      1    1         1                   0    3
# 18                model_target      1    1         1                   1    4
# 19  transmission_Semi-Auto_ohe      1    1         1                   0    3

# %%
selected_features = comparison_feature_selection(X_train[fm_2], filter_cols, wrapped_cols, embedded_cols, 
                                                 feature_importance_cols, n_agreed=3)[0]

# Define final datasets with selected features
X_train_final = X_train[selected_features]
X_val_final = X_val[selected_features]
test_final = test[selected_features]

# %% [markdown]
# <a class="anchor" id="1">
#
# # **9. Model and Assessment**
#
# [Back to TOP](#TOP)
# </a>
#
# Having identified the most significant features through the selection process, we now proceed to train and evaluate the regression models. We start by establishing a baseline and progressively explore more complex models to predict car resale prices effectively. This structured workflow ensures that our models are built upon the most relevant data, optimizing both efficiency and accuracy.
#
# Throughout this section, we continue to utilize the custom functions from our .py files to streamline model implementation and performance assessment.

# %% [markdown]
# We begin by concatenating the training and validation datasets and assigning each instance a label that will later be used to create a PredefinedSplit. The purpose of this setup is to ensure that the RandomizedSearchCV uses our custom train–validation split when tuning the hyperparameters of the models we intend to evaluate.

# %%
X_train = X_train_final.copy()
X_val = X_val_final.copy()
test = test_final.copy()

# %%
# Combine train and validation datasets
X_combined = np.concatenate([X_train, X_val], axis=0)
y_combined = np.concatenate([y_train, y_val], axis=0)

# Create a test fold index (-1 for train, 0 for validation)
test_fold = [-1] * len(X_train) + [0] * len(X_val)

print('Test fold: ', len(test_fold))
print('X_combined: ', len(X_combined))
print('y_combined: ', len(y_combined))

# Define the PredefinedSplit
ps = PredefinedSplit(test_fold=test_fold) # aqui diz que os dados de treino são os que têm label -1 e os de validação são os que têm label 0
# Out:
# Test fold:  75973
# X_combined:  75973
# y_combined:  75973

# %% [markdown]
# <a class="anchor" id="5_1">
#
# ## **9.1** Create a Sample to Test Models
#
# [Back to TOP](#TOP)
# </a>
#
# In this subsection, we create a sample of our datasets to test the modelling structure and ensure that the code is correctly implemented. Working with a smaller subset speeds up experimentation and allows us to verify the functionality of our models more efficiently. This approach also helps us identify potential issues earlier in the process.

# %%
X_train_s = X_train.sample(1000, random_state=42)
y_train_s = y_train.loc[X_train_s.index]
X_val_s = X_val.sample(500, random_state=42)
y_val_s = y_val.loc[X_val_s.index]

# Recriar combined sample
sample_X_combined = np.concatenate([X_train_s, X_val_s])
sample_y_combined = np.concatenate([y_train_s, y_val_s])

# Novo fold correto!
sample_test_fold = [-1] * len(X_train_s) + [0] * len(X_val_s)

ps_sample = PredefinedSplit(sample_test_fold)

# %% [markdown]
# <a class="anchor" id="9_2">
#
# ## **9.2** Define the Scores to Evaluate
#
# [Back to TOP](#TOP)
# </a>
#
# In this subsection, we define the evaluation metrics that will be used to assess model performance. We create a dictionary containing the selected scoring functions, which can later be passed directly to the RandomizedSearchCV during hyperparameter tuning.

# %%
scoring = {
    'r2': 'r2',
    'mae': 'neg_mean_absolute_error'
}

# %% [markdown]
# <a class="anchor" id="9_3">
#
# ## **9.3** Test Different Models
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# <a class="anchor" id="9_3_1">
#
# ## **9.3.1** LinearRegression
#
# [Back to TOP](#TOP)
# </a>

# %%
# Linear Regression with Randomized Search CV
model_lr = LinearRegression()

# We test only if the model should calculate the intercept (the base value) or not
param_grid_lr = {
    "fit_intercept": [True, False], 
    "positive": [False, True], # True, forces the coefficients to be positive
    "n_jobs": [None, -1],
}
# Apply Randomized Search CV
rsCV_lr = apply_randomized_search_cv(
    model_lr, 
    param_grid_lr, 
    iterations=2, 
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

# Check results
evaluate_model(rsCV_lr)
# Out:
# Fitting 1 folds for each of 2 candidates, totalling 2 fits
# [CV 1/1] END fit_intercept=True, n_jobs=-1, positive=False; mae: (train=-2636.239, test=-2662.373) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END fit_intercept=True, n_jobs=None, positive=False; mae: (train=-2636.239, test=-2662.373) r2: (train=0.813, test=0.809) total time=   0.0s
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'positive': False, 'n_jobs': -1, 'fit_intercept': True}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'positive': False, 'n_jobs': None, 'fit_intercept': True}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8133313706962529
# Best validation R2: 0.808800530427628
# R2 Gap: 0.5570718690890167 %
# Best train MAE: 2636.238856747732
# Best validation MAE: 2662.372864886035
# MAE Gap: 0.9913368840388064 %
# Best parameters: {'positive': False, 'n_jobs': -1, 'fit_intercept': True}

# %%
# ALTERANDO A FS E FICAMOS COM 20 FEATURES

# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8153412078259057
# Best validation R2: 0.8112872331797634
# R2 Gap: 0.4972120392335107 %
# Best train MAE: 2621.3742491203975
# Best validation MAE: 2642.357565396345
# MAE Gap: 0.8004700695823307 %
# Best parameters: {'positive': False, 'n_jobs': -1, 'fit_intercept': True}




# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8133559243300086
# Best validation R2: 0.8088425208375885
# R2 Gap: 0.5549112457916857 %
# Best train MAE: 2638.1491769684803
# Best validation MAE: 2664.2397591437125
# MAE Gap: 0.9889729664648103 %
# Best parameters: {'positive': False, 'n_jobs': -1, 'fit_intercept': True}

# %% [markdown]
# <a class="anchor" id="9_3_2">
#
# ## **9.3.2** Ridge
#
# [Back to TOP](#TOP)
# </a>

# %%
#Ridge Regression with Randomized Search CV
from sklearn.linear_model import Ridge
model_ridge = Ridge()
# Define parameter grid for Ridge Regression
param_grid_ridge = {
    "alpha": [0.01, 0.1, 1.0, 10.0, 100.0, 500.0],
    "solver": ['auto', 'svd', 'cholesky', 'lsqr']
}   
# 3. Execute Randomized Search CV for Ridge Regression
rsCV_ridge = apply_randomized_search_cv(
    model_ridge, 
    param_grid_ridge, 
    iterations=20,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)       
# Check results
evaluate_model(rsCV_ridge)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV 1/1] END alpha=0.1, solver=cholesky; mae: (train=-2636.237, test=-2662.371) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=10.0, solver=cholesky; mae: (train=-2636.079, test=-2662.196) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=0.1, solver=auto; mae: (train=-2636.237, test=-2662.371) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=100.0, solver=lsqr; mae: (train=-2634.779, test=-2660.742) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=10.0, solver=svd; mae: (train=-2636.079, test=-2662.196) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=0.1, solver=lsqr; mae: (train=-2636.237, test=-2662.371) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=1.0, solver=cholesky; mae: (train=-2636.223, test=-2662.355) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=500.0, solver=svd; mae: (train=-2631.286, test=-2656.669) r2: (train=0.813, test=0.808) total time=   0.0s
# [CV 1/1] END alpha=100.0, solver=cholesky; mae: (train=-2634.779, test=-2660.742) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=500.0, solver=auto; mae: (train=-2631.286, test=-2656.669) r2: (train=0.813, test=0.808) total time=   0.0s
# [CV 1/1] END alpha=500.0, solver=cholesky; mae: (train=-2631.286, test=-2656.669) r2: (train=0.813, test=0.808) total time=   0.0s
# [CV 1/1] END alpha=1.0, solver=auto; mae: (train=-2636.223, test=-2662.355) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=10.0, solver=lsqr; mae: (train=-2636.079, test=-2662.196) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=10.0, solver=auto; mae: (train=-2636.079, test=-2662.196) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=0.01, solver=auto; mae: (train=-2636.239, test=-2662.373) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=1.0, solver=lsqr; mae: (train=-2636.223, test=-2662.355) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=0.01, solver=cholesky; mae: (train=-2636.239, test=-2662.373) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=100.0, solver=auto; mae: (train=-2634.779, test=-2660.742) r2: (train=0.813, test=0.809) total time=   0.0s
# [CV 1/1] END alpha=500.0, solver=lsqr; mae: (train=-2631.286, test=-2656.669) r2: (train=0.813, test=0.808) total time=   0.0s
# [CV 1/1] END alpha=0.01, solver=lsqr; mae: (train=-2636.239, test=-2662.373) r2: (train=0.813, test=0.809) total time=   0.0s
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'solver': 'cholesky', 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.1 | Val MAE=2662.2 | Gap R2=0.005 | Params={'solver': 'cholesky', 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'solver': 'auto', 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2634.8 | Val MAE=2660.7 | Gap R2=0.005 | Params={'solver': 'lsqr', 'alpha': 100.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.1 | Val MAE=2662.2 | Gap R2=0.005 | Params={'solver': 'svd', 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'solver': 'lsqr', 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'solver': 'cholesky', 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2631.3 | Val MAE=2656.7 | Gap R2=0.005 | Params={'solver': 'svd', 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2634.8 | Val MAE=2660.7 | Gap R2=0.005 | Params={'solver': 'cholesky', 'alpha': 100.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2631.3 | Val MAE=2656.7 | Gap R2=0.005 | Params={'solver': 'auto', 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2631.3 | Val MAE=2656.7 | Gap R2=0.005 | Params={'solver': 'cholesky', 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'solver': 'auto', 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.1 | Val MAE=2662.2 | Gap R2=0.005 | Params={'solver': 'lsqr', 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.1 | Val MAE=2662.2 | Gap R2=0.005 | Params={'solver': 'auto', 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'solver': 'auto', 'alpha': 0.01}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'solver': 'lsqr', 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'solver': 'cholesky', 'alpha': 0.01}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2634.8 | Val MAE=2660.7 | Gap R2=0.005 | Params={'solver': 'auto', 'alpha': 100.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2631.3 | Val MAE=2656.7 | Gap R2=0.005 | Params={'solver': 'lsqr', 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'solver': 'lsqr', 'alpha': 0.01}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8131197436422064
# Best validation R2: 0.8082563447118534
# R2 Gap: 0.5981159562758146 %
# Best train MAE: 2631.286132894686
# Best validation MAE: 2656.6690826743616
# MAE Gap: 0.9646594288000016 %
# Best parameters: {'solver': 'lsqr', 'alpha': 500.0}

# %%
# ALTERANDO A FS E FICAMOS COM 20 FEATURES
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8151085980282142
# Best validation R2: 0.8106740933731881
# R2 Gap: 0.5440385079673339 %
# Best train MAE: 2618.624584930066
# Best validation MAE: 2639.448181252241
# MAE Gap: 0.795211212863915 %
# Best parameters: {'solver': 'svd', 'alpha': 500.0}


# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8131463298945936
# Best validation R2: 0.8083148408153084
# R2 Gap: 0.5941721559404329 %
# Best train MAE: 2633.9591076884317
# Best validation MAE: 2659.3526952912057
# MAE Gap: 0.9640843522836416 %
# Best parameters: {'solver': 'auto', 'alpha': 500.0}

# %% [markdown]
# <a class="anchor" id="9_3_3">
#
# ## **9.3.3** Lasso
#
# [Back to TOP](#TOP)
# </a>

# %%
# Lasso Regression with Randomized Search CV
model_lasso = Lasso(random_state=42)

# Define parameter grid for Lasso Regression
param_grid_lasso = {
    "alpha": [0.001, 0.01, 0.1, 1.0, 10.0, 500.0],
    "max_iter": [1000, 5000, 10000]
}
# Apply Randomized Search CV for Lasso Regression
rsCV_lasso = apply_randomized_search_cv(
    model_lasso, 
    param_grid_lasso, 
    iterations=15, 
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

# Check results
evaluate_model(rsCV_lasso)
# Out:
# Fitting 1 folds for each of 15 candidates, totalling 15 fits
# [CV 1/1] END alpha=0.1, max_iter=1000; mae: (train=-2636.198, test=-2662.325) r2: (train=0.813, test=0.809) total time=   0.2s
# [CV 1/1] END alpha=500.0, max_iter=5000; mae: (train=-2715.700, test=-2732.104) r2: (train=0.793, test=0.786) total time=   0.0s
# [CV 1/1] END alpha=0.1, max_iter=5000; mae: (train=-2636.198, test=-2662.325) r2: (train=0.813, test=0.809) total time=   0.2s
# [CV 1/1] END alpha=10.0, max_iter=1000; mae: (train=-2633.919, test=-2659.434) r2: (train=0.813, test=0.809) total time=   0.1s
# [CV 1/1] END alpha=10.0, max_iter=5000; mae: (train=-2633.919, test=-2659.434) r2: (train=0.813, test=0.809) total time=   0.1s
# [CV 1/1] END alpha=10.0, max_iter=10000; mae: (train=-2633.919, test=-2659.434) r2: (train=0.813, test=0.809) total time=   0.1s
# [CV 1/1] END alpha=1.0, max_iter=5000; mae: (train=-2635.849, test=-2661.918) r2: (train=0.813, test=0.809) total time=   0.1s
# [CV 1/1] END alpha=0.01, max_iter=5000; mae: (train=-2636.235, test=-2662.368) r2: (train=0.813, test=0.809) total time=   0.2s
# [CV 1/1] END alpha=0.1, max_iter=10000; mae: (train=-2636.198, test=-2662.325) r2: (train=0.813, test=0.809) total time=   0.2s
# [CV 1/1] END alpha=1.0, max_iter=10000; mae: (train=-2635.849, test=-2661.918) r2: (train=0.813, test=0.809) total time=   0.1s
# [CV 1/1] END alpha=0.001, max_iter=10000; mae: (train=-2636.238, test=-2662.372) r2: (train=0.813, test=0.809) total time=   0.2s
# [CV 1/1] END alpha=0.001, max_iter=1000; mae: (train=-2636.238, test=-2662.372) r2: (train=0.813, test=0.809) total time=   0.3s
# [CV 1/1] END alpha=500.0, max_iter=1000; mae: (train=-2715.700, test=-2732.104) r2: (train=0.793, test=0.786) total time=   0.0s
# [CV 1/1] END alpha=0.01, max_iter=1000; mae: (train=-2636.235, test=-2662.368) r2: (train=0.813, test=0.809) total time=   0.2s
# [CV 1/1] END alpha=0.001, max_iter=5000; mae: (train=-2636.238, test=-2662.372) r2: (train=0.813, test=0.809) total time=   0.2s
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.3 | Gap R2=0.005 | Params={'max_iter': 1000, 'alpha': 0.1}
# Train R2=0.793 | Val R2=0.786 | Train MAE=2715.7 | Val MAE=2732.1 | Gap R2=0.007 | Params={'max_iter': 5000, 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.3 | Gap R2=0.005 | Params={'max_iter': 5000, 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2633.9 | Val MAE=2659.4 | Gap R2=0.005 | Params={'max_iter': 1000, 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2633.9 | Val MAE=2659.4 | Gap R2=0.005 | Params={'max_iter': 5000, 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2633.9 | Val MAE=2659.4 | Gap R2=0.005 | Params={'max_iter': 10000, 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2635.8 | Val MAE=2661.9 | Gap R2=0.005 | Params={'max_iter': 5000, 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'max_iter': 5000, 'alpha': 0.01}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.3 | Gap R2=0.005 | Params={'max_iter': 10000, 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2635.8 | Val MAE=2661.9 | Gap R2=0.005 | Params={'max_iter': 10000, 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'max_iter': 10000, 'alpha': 0.001}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'max_iter': 1000, 'alpha': 0.001}
# Train R2=0.793 | Val R2=0.786 | Train MAE=2715.7 | Val MAE=2732.1 | Gap R2=0.007 | Params={'max_iter': 1000, 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'max_iter': 1000, 'alpha': 0.01}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2636.2 | Val MAE=2662.4 | Gap R2=0.005 | Params={'max_iter': 5000, 'alpha': 0.001}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8132102063025438
# Best validation R2: 0.8085065066763022
# R2 Gap: 0.5784112877318798 %
# Best train MAE: 2633.918787868577
# Best validation MAE: 2659.4341023574684
# MAE Gap: 0.968720622914076 %
# Best parameters: {'max_iter': 1000, 'alpha': 10.0}

# %%
# ALTERANDO A FS E FICAMOS COM 20 FEATURES
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8151986480434059
# Best validation R2: 0.8109014517319679
# R2 Gap: 0.5271348672807394 %
# Best train MAE: 2619.507488232406
# Best validation MAE: 2640.5275221707725
# MAE Gap: 0.8024422160575809 %
# Best parameters: {'max_iter': 1000, 'alpha': 10.0}


# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8132372057436164
# Best validation R2: 0.8085573696085282
# R2 Gap: 0.5754577018901832 %
# Best train MAE: 2636.0988748293953
# Best validation MAE: 2661.61552640847
# MAE Gap: 0.9679702010694168 %
# Best parameters: {'max_iter': 1000, 'alpha': 10.0}

# %% [markdown]
# <a class="anchor" id="9_3_3">
#
# ## **9.4** Decision Trees
#
# [Back to TOP](#TOP)
# </a>

# %%
from sklearn.tree import DecisionTreeRegressor

model_dt = DecisionTreeRegressor(random_state=42)

# Define the optimized parameter grid for Decision Tree Regressor
param_grid_dt = {
    "max_depth": [5, 8, 10, 12, 14],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 15, 20],
    "max_features": [None, "sqrt", "log2"],
    "criterion": ["absolute_error"]
}
   
rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=50, # is a good number to cover this variety
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

# Check results
evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 50 candidates, totalling 50 fits
# [CV 1/1] END criterion=absolute_error, max_depth=12, max_features=log2, min_samples_leaf=15, min_samples_split=20; mae: (train=-1787.402, test=-1943.387) r2: (train=0.889, test=0.874) total time=  24.9s
# [CV 1/1] END criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=15, min_samples_split=5; mae: (train=-1787.402, test=-1943.387) r2: (train=0.889, test=0.874) total time=  25.2s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=5; mae: (train=-3370.501, test=-3428.634) r2: (train=0.690, test=0.683) total time=  23.4s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=sqrt, min_samples_leaf=20, min_samples_split=5; mae: (train=-2362.228, test=-2454.588) r2: (train=0.835, test=0.830) total time=  24.5s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=40; mae: (train=-3370.501, test=-3428.634) r2: (train=0.690, test=0.683) total time=  23.6s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-2014.516, test=-2068.755) r2: (train=0.875, test=0.872) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=20, min_samples_split=10; mae: (train=-1755.306, test=-1907.722) r2: (train=0.884, test=0.873) total time=  25.4s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=sqrt, min_samples_leaf=20, min_samples_split=2; mae: (train=-3370.501, test=-3428.634) r2: (train=0.690, test=0.683) total time=  23.6s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=None, min_samples_leaf=20, min_samples_split=20; mae: (train=-2726.710, test=-2757.916) r2: (train=0.779, test=0.772) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=log2, min_samples_leaf=15, min_samples_split=5; mae: (train=-1670.873, test=-1892.634) r2: (train=0.893, test=0.870) total time=  25.8s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=20, min_samples_split=10; mae: (train=-2362.228, test=-2454.588) r2: (train=0.835, test=0.830) total time=  24.7s
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=None, min_samples_leaf=10, min_samples_split=40; mae: (train=-1433.708, test=-1662.348) r2: (train=0.915, test=0.902) total time= 1.3min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=15, min_samples_split=10; mae: (train=-2317.138, test=-2435.392) r2: (train=0.847, test=0.833) total time=  25.3s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=log2, min_samples_leaf=15, min_samples_split=2; mae: (train=-3370.501, test=-3428.634) r2: (train=0.690, test=0.683) total time=  23.7s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=log2, min_samples_leaf=20, min_samples_split=10; mae: (train=-3370.501, test=-3428.634) r2: (train=0.690, test=0.683) total time=  23.7s
# [CV 1/1] END criterion=absolute_error, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10; mae: (train=-2092.419, test=-2243.361) r2: (train=0.865, test=0.851) total time=  25.8s
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=20, min_samples_split=40; mae: (train=-1755.306, test=-1907.722) r2: (train=0.884, test=0.873) total time=  25.6s
# [CV 1/1] END criterion=absolute_error, max_depth=12, max_features=log2, min_samples_leaf=10, min_samples_split=5; mae: (train=-1687.318, test=-1856.467) r2: (train=0.904, test=0.895) total time=  25.9s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=None, min_samples_leaf=15, min_samples_split=10; mae: (train=-2726.710, test=-2757.916) r2: (train=0.779, test=0.772) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=12, max_features=log2, min_samples_leaf=15, min_samples_split=40; mae: (train=-1833.705, test=-2001.913) r2: (train=0.881, test=0.866) total time=  25.6s
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=None, min_samples_leaf=20, min_samples_split=5; mae: (train=-1503.087, test=-1714.987) r2: (train=0.904, test=0.887) total time= 1.3min
# [CV 1/1] END criterion=absolute_error, max_depth=10, max_features=None, min_samples_leaf=15, min_samples_split=20; mae: (train=-1732.442, test=-1877.304) r2: (train=0.895, test=0.881) total time= 1.3min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=log2, min_samples_leaf=20, min_samples_split=20; mae: (train=-1755.306, test=-1907.722) r2: (train=0.884, test=0.873) total time=  25.6s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=20; mae: (train=-3370.501, test=-3428.634) r2: (train=0.690, test=0.683) total time=  23.8s
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=log2, min_samples_leaf=15, min_samples_split=40; mae: (train=-1690.837, test=-1881.744) r2: (train=0.893, test=0.882) total time=  25.8s
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=log2, min_samples_leaf=10, min_samples_split=20; mae: (train=-1586.924, test=-1808.080) r2: (train=0.908, test=0.893) total time=  26.5s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=sqrt, min_samples_leaf=15, min_samples_split=40; mae: (train=-2434.390, test=-2537.195) r2: (train=0.829, test=0.821) total time=  25.5s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=log2, min_samples_leaf=20, min_samples_split=5; mae: (train=-3370.501, test=-3428.634) r2: (train=0.690, test=0.683) total time=  24.0s
# [CV 1/1] END criterion=absolute_error, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=2; mae: (train=-2092.419, test=-2243.361) r2: (train=0.865, test=0.851) total time=  26.0s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=None, min_samples_leaf=20, min_samples_split=5; mae: (train=-2032.586, test=-2101.942) r2: (train=0.866, test=0.856) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=15, min_samples_split=40; mae: (train=-1833.705, test=-2001.913) r2: (train=0.881, test=0.866) total time=  25.6s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=log2, min_samples_leaf=20, min_samples_split=40; mae: (train=-3370.501, test=-3428.634) r2: (train=0.690, test=0.683) total time=  23.8s
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=20; mae: (train=-1586.924, test=-1808.080) r2: (train=0.908, test=0.893) total time=  26.4s
# [CV 1/1] END criterion=absolute_error, max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=5; mae: (train=-2011.433, test=-2110.468) r2: (train=0.862, test=0.851) total time=  24.8s
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=None, min_samples_leaf=15, min_samples_split=10; mae: (train=-1441.984, test=-1684.332) r2: (train=0.912, test=0.892) total time= 1.3min
# [CV 1/1] END criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=15, min_samples_split=10; mae: (train=-1787.402, test=-1943.387) r2: (train=0.889, test=0.874) total time=  26.0s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=sqrt, min_samples_leaf=20, min_samples_split=10; mae: (train=-2362.228, test=-2454.588) r2: (train=0.835, test=0.830) total time=  25.0s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=sqrt, min_samples_leaf=10, min_samples_split=20; mae: (train=-2357.857, test=-2469.775) r2: (train=0.838, test=0.827) total time=  25.7s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=None, min_samples_leaf=15, min_samples_split=2; mae: (train=-2023.686, test=-2096.677) r2: (train=0.871, test=0.860) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5; mae: (train=-2004.782, test=-2152.979) r2: (train=0.865, test=0.844) total time=  25.7s
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=log2, min_samples_leaf=20, min_samples_split=40; mae: (train=-1755.306, test=-1907.722) r2: (train=0.884, test=0.873) total time=  25.8s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=None, min_samples_leaf=10, min_samples_split=40; mae: (train=-2016.726, test=-2068.525) r2: (train=0.875, test=0.872) total time= 1.3min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=sqrt, min_samples_leaf=10, min_samples_split=2; mae: (train=-2357.857, test=-2469.775) r2: (train=0.838, test=0.827) total time=  26.5s
# [CV 1/1] END criterion=absolute_error, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-2726.710, test=-2757.916) r2: (train=0.779, test=0.772) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=10; mae: (train=-1710.796, test=-1850.612) r2: (train=0.900, test=0.892) total time= 1.3min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=20, min_samples_split=5; mae: (train=-1755.306, test=-1907.722) r2: (train=0.884, test=0.873) total time=  26.2s
# [CV 1/1] END criterion=absolute_error, max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=10; mae: (train=-2011.433, test=-2110.468) r2: (train=0.862, test=0.851) total time=  25.0s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=20, min_samples_split=5; mae: (train=-2362.228, test=-2454.588) r2: (train=0.835, test=0.830) total time=  25.4s
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=None, min_samples_leaf=10, min_samples_split=5; mae: (train=-2014.516, test=-2068.755) r2: (train=0.875, test=0.872) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=log2, min_samples_leaf=15, min_samples_split=20; mae: (train=-1670.873, test=-1892.634) r2: (train=0.893, test=0.870) total time=  26.0s
# Train R2=0.889 | Val R2=0.874 | Train MAE=1787.4 | Val MAE=1943.4 | Gap R2=0.015 | Params={'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_depth': 12, 'criterion': 'absolute_error'}
# Train R2=0.889 | Val R2=0.874 | Train MAE=1787.4 | Val MAE=1943.4 | Gap R2=0.015 | Params={'min_samples_split': 5, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'max_depth': 12, 'criterion': 'absolute_error'}
# Train R2=0.690 | Val R2=0.683 | Train MAE=3370.5 | Val MAE=3428.6 | Gap R2=0.006 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.835 | Val R2=0.830 | Train MAE=2362.2 | Val MAE=2454.6 | Gap R2=0.005 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.690 | Val R2=0.683 | Train MAE=3370.5 | Val MAE=3428.6 | Gap R2=0.006 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.875 | Val R2=0.872 | Train MAE=2014.5 | Val MAE=2068.8 | Gap R2=0.003 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.884 | Val R2=0.873 | Train MAE=1755.3 | Val MAE=1907.7 | Gap R2=0.010 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.690 | Val R2=0.683 | Train MAE=3370.5 | Val MAE=3428.6 | Gap R2=0.006 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.779 | Val R2=0.772 | Train MAE=2726.7 | Val MAE=2757.9 | Gap R2=0.008 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.893 | Val R2=0.870 | Train MAE=1670.9 | Val MAE=1892.6 | Gap R2=0.023 | Params={'min_samples_split': 5, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.835 | Val R2=0.830 | Train MAE=2362.2 | Val MAE=2454.6 | Gap R2=0.005 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.915 | Val R2=0.902 | Train MAE=1433.7 | Val MAE=1662.3 | Gap R2=0.013 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.847 | Val R2=0.833 | Train MAE=2317.1 | Val MAE=2435.4 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.690 | Val R2=0.683 | Train MAE=3370.5 | Val MAE=3428.6 | Gap R2=0.006 | Params={'min_samples_split': 2, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.690 | Val R2=0.683 | Train MAE=3370.5 | Val MAE=3428.6 | Gap R2=0.006 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.865 | Val R2=0.851 | Train MAE=2092.4 | Val MAE=2243.4 | Gap R2=0.013 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'absolute_error'}
# Train R2=0.884 | Val R2=0.873 | Train MAE=1755.3 | Val MAE=1907.7 | Gap R2=0.010 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.904 | Val R2=0.895 | Train MAE=1687.3 | Val MAE=1856.5 | Gap R2=0.009 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 12, 'criterion': 'absolute_error'}
# Train R2=0.779 | Val R2=0.772 | Train MAE=2726.7 | Val MAE=2757.9 | Gap R2=0.008 | Params={'min_samples_split': 10, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.881 | Val R2=0.866 | Train MAE=1833.7 | Val MAE=2001.9 | Gap R2=0.015 | Params={'min_samples_split': 40, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_depth': 12, 'criterion': 'absolute_error'}
# Train R2=0.904 | Val R2=0.887 | Train MAE=1503.1 | Val MAE=1715.0 | Gap R2=0.017 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.895 | Val R2=0.881 | Train MAE=1732.4 | Val MAE=1877.3 | Gap R2=0.015 | Params={'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': 10, 'criterion': 'absolute_error'}
# Train R2=0.884 | Val R2=0.873 | Train MAE=1755.3 | Val MAE=1907.7 | Gap R2=0.010 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.690 | Val R2=0.683 | Train MAE=3370.5 | Val MAE=3428.6 | Gap R2=0.006 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.893 | Val R2=0.882 | Train MAE=1690.8 | Val MAE=1881.7 | Gap R2=0.011 | Params={'min_samples_split': 40, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.908 | Val R2=0.893 | Train MAE=1586.9 | Val MAE=1808.1 | Gap R2=0.015 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.829 | Val R2=0.821 | Train MAE=2434.4 | Val MAE=2537.2 | Gap R2=0.007 | Params={'min_samples_split': 40, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.690 | Val R2=0.683 | Train MAE=3370.5 | Val MAE=3428.6 | Gap R2=0.006 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.865 | Val R2=0.851 | Train MAE=2092.4 | Val MAE=2243.4 | Gap R2=0.013 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'absolute_error'}
# Train R2=0.866 | Val R2=0.856 | Train MAE=2032.6 | Val MAE=2101.9 | Gap R2=0.010 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.881 | Val R2=0.866 | Train MAE=1833.7 | Val MAE=2001.9 | Gap R2=0.015 | Params={'min_samples_split': 40, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'max_depth': 12, 'criterion': 'absolute_error'}
# Train R2=0.690 | Val R2=0.683 | Train MAE=3370.5 | Val MAE=3428.6 | Gap R2=0.006 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.908 | Val R2=0.893 | Train MAE=1586.9 | Val MAE=1808.1 | Gap R2=0.015 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.862 | Val R2=0.851 | Train MAE=2011.4 | Val MAE=2110.5 | Gap R2=0.011 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'absolute_error'}
# Train R2=0.912 | Val R2=0.892 | Train MAE=1442.0 | Val MAE=1684.3 | Gap R2=0.019 | Params={'min_samples_split': 10, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.889 | Val R2=0.874 | Train MAE=1787.4 | Val MAE=1943.4 | Gap R2=0.015 | Params={'min_samples_split': 10, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'max_depth': 12, 'criterion': 'absolute_error'}
# Train R2=0.835 | Val R2=0.830 | Train MAE=2362.2 | Val MAE=2454.6 | Gap R2=0.005 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.838 | Val R2=0.827 | Train MAE=2357.9 | Val MAE=2469.8 | Gap R2=0.012 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.871 | Val R2=0.860 | Train MAE=2023.7 | Val MAE=2096.7 | Gap R2=0.011 | Params={'min_samples_split': 2, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.865 | Val R2=0.844 | Train MAE=2004.8 | Val MAE=2153.0 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'absolute_error'}
# Train R2=0.884 | Val R2=0.873 | Train MAE=1755.3 | Val MAE=1907.7 | Gap R2=0.010 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.875 | Val R2=0.872 | Train MAE=2016.7 | Val MAE=2068.5 | Gap R2=0.003 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.838 | Val R2=0.827 | Train MAE=2357.9 | Val MAE=2469.8 | Gap R2=0.012 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.779 | Val R2=0.772 | Train MAE=2726.7 | Val MAE=2757.9 | Gap R2=0.008 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 5, 'criterion': 'absolute_error'}
# Train R2=0.900 | Val R2=0.892 | Train MAE=1710.8 | Val MAE=1850.6 | Gap R2=0.008 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 10, 'criterion': 'absolute_error'}
# Train R2=0.884 | Val R2=0.873 | Train MAE=1755.3 | Val MAE=1907.7 | Gap R2=0.010 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.862 | Val R2=0.851 | Train MAE=2011.4 | Val MAE=2110.5 | Gap R2=0.011 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'absolute_error'}
# Train R2=0.835 | Val R2=0.830 | Train MAE=2362.2 | Val MAE=2454.6 | Gap R2=0.005 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.875 | Val R2=0.872 | Train MAE=2014.5 | Val MAE=2068.8 | Gap R2=0.003 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.893 | Val R2=0.870 | Train MAE=1670.9 | Val MAE=1892.6 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': 'log2', 'max_depth': 14, 'criterion': 'absolute_error'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9148201596459035
# Best validation R2: 0.9020213688700649
# R2 Gap: 1.399049927014349 %
# Best train MAE: 1433.7083813221889
# Best validation MAE: 1662.3482395524843
# MAE Gap: 15.947445185431649 %
# Best parameters: {'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 14, 'criterion': 'absolute_error'}

# %%
model_dt = DecisionTreeRegressor(random_state=42)

param_grid_final = {
    # Aprendemos que None é o melhor, mantemos apenas esse ou muito profundo
    "max_depth": [None, 30],
    
    # Aprendemos que ver todas as features é crucial
    "max_features": [None], 
    
    # O ccp_alpha=10 foi o vencedor. Vamos procurar à volta dele.
    "ccp_alpha": [5.0, 8.0, 10.0, 12.0, 15.0],
    
    # Refinar as folhas
    "min_samples_leaf": [5, 10, 15],
    "min_samples_split": [10, 20, 30],
    
    # Vamos dar mais uma oportunidade ao absolute_error agora que temos os params certos
    "criterion": ["squared_error", "absolute_error"]
}

# Podes reduzir iterações porque o espaço de procura é menor e focado
rsCV_final = apply_randomized_search_cv(
    model_dt, 
    param_grid_final, 
    iterations=30, 
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)
# Out:
# Fitting 1 folds for each of 30 candidates, totalling 30 fits
# [CV 1/1] END ccp_alpha=5.0, criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=15, min_samples_split=20; mae: (train=-1413.366, test=-1650.439) r2: (train=0.932, test=0.909) total time=   0.1s
# [CV 1/1] END ccp_alpha=5.0, criterion=squared_error, max_depth=30, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-1298.937, test=-1619.745) r2: (train=0.942, test=0.913) total time=   0.1s
# [CV 1/1] END ccp_alpha=10.0, criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=15, min_samples_split=20; mae: (train=-1413.639, test=-1650.281) r2: (train=0.932, test=0.909) total time=   0.1s
# [CV 1/1] END ccp_alpha=5.0, criterion=absolute_error, max_depth=30, max_features=None, min_samples_leaf=15, min_samples_split=30; mae: (train=-2250.469, test=-2296.945) r2: (train=0.845, test=0.837) total time= 1.2min
# [CV 1/1] END ccp_alpha=8.0, criterion=squared_error, max_depth=30, max_features=None, min_samples_leaf=5, min_samples_split=30; mae: (train=-1277.652, test=-1612.761) r2: (train=0.944, test=0.912) total time=   0.1s
# [CV 1/1] END ccp_alpha=12.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=30; mae: (train=-2521.897, test=-2544.722) r2: (train=0.803, test=0.799) total time= 1.3min
# [CV 1/1] END ccp_alpha=12.0, criterion=absolute_error, max_depth=30, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-2521.897, test=-2544.722) r2: (train=0.803, test=0.799) total time= 1.3min
# [CV 1/1] END ccp_alpha=8.0, criterion=absolute_error, max_depth=30, max_features=None, min_samples_leaf=15, min_samples_split=30; mae: (train=-2414.617, test=-2427.640) r2: (train=0.817, test=0.814) total time= 1.3min
# [CV 1/1] END ccp_alpha=10.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=30; mae: (train=-2467.093, test=-2481.254) r2: (train=0.813, test=0.810) total time= 1.3min
# [CV 1/1] END ccp_alpha=15.0, criterion=squared_error, max_depth=30, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-1300.429, test=-1619.853) r2: (train=0.942, test=0.913) total time=   0.1s
# [CV 1/1] END ccp_alpha=12.0, criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=15, min_samples_split=30; mae: (train=-1413.797, test=-1650.295) r2: (train=0.932, test=0.909) total time=   0.1s
# [CV 1/1] END ccp_alpha=8.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=30; mae: (train=-2405.187, test=-2424.000) r2: (train=0.825, test=0.820) total time= 1.3min
# [CV 1/1] END ccp_alpha=8.0, criterion=absolute_error, max_depth=30, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-2405.187, test=-2424.000) r2: (train=0.825, test=0.820) total time= 1.3min
# [CV 1/1] END ccp_alpha=15.0, criterion=absolute_error, max_depth=30, max_features=None, min_samples_leaf=5, min_samples_split=30; mae: (train=-2617.607, test=-2635.663) r2: (train=0.791, test=0.787) total time= 1.3min
# [CV 1/1] END ccp_alpha=8.0, criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=30; mae: (train=-1344.410, test=-1635.543) r2: (train=0.938, test=0.910) total time=   0.1s
# [CV 1/1] END ccp_alpha=12.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=15, min_samples_split=30; mae: (train=-2521.897, test=-2544.722) r2: (train=0.803, test=0.799) total time= 1.3min
# [CV 1/1] END ccp_alpha=12.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=20; mae: (train=-2521.897, test=-2544.722) r2: (train=0.803, test=0.799) total time= 1.3min
# [CV 1/1] END ccp_alpha=5.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=20; mae: (train=-2245.522, test=-2282.250) r2: (train=0.848, test=0.846) total time= 1.3min
# [CV 1/1] END ccp_alpha=15.0, criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=15, min_samples_split=20; mae: (train=-1414.005, test=-1650.141) r2: (train=0.932, test=0.909) total time=   0.1s
# [CV 1/1] END ccp_alpha=15.0, criterion=squared_error, max_depth=30, max_features=None, min_samples_leaf=10, min_samples_split=10; mae: (train=-1300.429, test=-1619.853) r2: (train=0.942, test=0.913) total time=   0.1s
# [CV 1/1] END ccp_alpha=8.0, criterion=absolute_error, max_depth=30, max_features=None, min_samples_leaf=10, min_samples_split=30; mae: (train=-2405.187, test=-2424.000) r2: (train=0.825, test=0.820) total time= 1.3min
# [CV 1/1] END ccp_alpha=15.0, criterion=squared_error, max_depth=30, max_features=None, min_samples_leaf=10, min_samples_split=30; mae: (train=-1345.062, test=-1635.623) r2: (train=0.938, test=0.910) total time=   0.1s
# [CV 1/1] END ccp_alpha=5.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=30; mae: (train=-2245.522, test=-2282.250) r2: (train=0.848, test=0.846) total time= 1.3min
# [CV 1/1] END ccp_alpha=5.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=15, min_samples_split=20; mae: (train=-2250.469, test=-2296.945) r2: (train=0.845, test=0.837) total time= 1.3min
# [CV 1/1] END ccp_alpha=12.0, criterion=squared_error, max_depth=30, max_features=None, min_samples_leaf=5, min_samples_split=10; mae: (train=-1077.760, test=-1598.498) r2: (train=0.960, test=0.919) total time=   0.2s
# [CV 1/1] END ccp_alpha=15.0, criterion=absolute_error, max_depth=30, max_features=None, min_samples_leaf=15, min_samples_split=10; mae: (train=-2617.607, test=-2635.663) r2: (train=0.791, test=0.787) total time= 1.3min
# [CV 1/1] END ccp_alpha=5.0, criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=10; mae: (train=-1298.937, test=-1619.745) r2: (train=0.942, test=0.913) total time=   0.1s
# [CV 1/1] END ccp_alpha=12.0, criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=10; mae: (train=-1077.760, test=-1598.852) r2: (train=0.960, test=0.919) total time=   0.2s
# [CV 1/1] END ccp_alpha=15.0, criterion=absolute_error, max_depth=30, max_features=None, min_samples_leaf=15, min_samples_split=30; mae: (train=-2617.607, test=-2635.663) r2: (train=0.791, test=0.787) total time= 1.3min
# [CV 1/1] END ccp_alpha=5.0, criterion=absolute_error, max_depth=30, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-2246.326, test=-2284.720) r2: (train=0.847, test=0.845) total time= 1.3min

# %%
evaluate_model(rsCV_final)
# Out:
# Train R2=0.932 | Val R2=0.909 | Train MAE=1413.4 | Val MAE=1650.4 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 5.0}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.9 | Val MAE=1619.7 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 30, 'criterion': 'squared_error', 'ccp_alpha': 5.0}
# Train R2=0.932 | Val R2=0.909 | Train MAE=1413.6 | Val MAE=1650.3 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 10.0}
# Train R2=0.845 | Val R2=0.837 | Train MAE=2250.5 | Val MAE=2296.9 | Gap R2=0.007 | Params={'min_samples_split': 30, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': 30, 'criterion': 'absolute_error', 'ccp_alpha': 5.0}
# Train R2=0.944 | Val R2=0.912 | Train MAE=1277.7 | Val MAE=1612.8 | Gap R2=0.032 | Params={'min_samples_split': 30, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 30, 'criterion': 'squared_error', 'ccp_alpha': 8.0}
# Train R2=0.803 | Val R2=0.799 | Train MAE=2521.9 | Val MAE=2544.7 | Gap R2=0.004 | Params={'min_samples_split': 30, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 12.0}
# Train R2=0.803 | Val R2=0.799 | Train MAE=2521.9 | Val MAE=2544.7 | Gap R2=0.004 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 30, 'criterion': 'absolute_error', 'ccp_alpha': 12.0}
# Train R2=0.817 | Val R2=0.814 | Train MAE=2414.6 | Val MAE=2427.6 | Gap R2=0.003 | Params={'min_samples_split': 30, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': 30, 'criterion': 'absolute_error', 'ccp_alpha': 8.0}
# Train R2=0.813 | Val R2=0.810 | Train MAE=2467.1 | Val MAE=2481.3 | Gap R2=0.003 | Params={'min_samples_split': 30, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 10.0}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1300.4 | Val MAE=1619.9 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 30, 'criterion': 'squared_error', 'ccp_alpha': 15.0}
# Train R2=0.932 | Val R2=0.909 | Train MAE=1413.8 | Val MAE=1650.3 | Gap R2=0.023 | Params={'min_samples_split': 30, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 12.0}
# Train R2=0.825 | Val R2=0.820 | Train MAE=2405.2 | Val MAE=2424.0 | Gap R2=0.005 | Params={'min_samples_split': 30, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 8.0}
# Train R2=0.825 | Val R2=0.820 | Train MAE=2405.2 | Val MAE=2424.0 | Gap R2=0.005 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 30, 'criterion': 'absolute_error', 'ccp_alpha': 8.0}
# Train R2=0.791 | Val R2=0.787 | Train MAE=2617.6 | Val MAE=2635.7 | Gap R2=0.003 | Params={'min_samples_split': 30, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 30, 'criterion': 'absolute_error', 'ccp_alpha': 15.0}
# Train R2=0.938 | Val R2=0.910 | Train MAE=1344.4 | Val MAE=1635.5 | Gap R2=0.028 | Params={'min_samples_split': 30, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 8.0}
# Train R2=0.803 | Val R2=0.799 | Train MAE=2521.9 | Val MAE=2544.7 | Gap R2=0.004 | Params={'min_samples_split': 30, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 12.0}
# Train R2=0.803 | Val R2=0.799 | Train MAE=2521.9 | Val MAE=2544.7 | Gap R2=0.004 | Params={'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 12.0}
# Train R2=0.848 | Val R2=0.846 | Train MAE=2245.5 | Val MAE=2282.3 | Gap R2=0.003 | Params={'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 5.0}
# Train R2=0.932 | Val R2=0.909 | Train MAE=1414.0 | Val MAE=1650.1 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 15.0}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1300.4 | Val MAE=1619.9 | Gap R2=0.029 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 30, 'criterion': 'squared_error', 'ccp_alpha': 15.0}
# Train R2=0.825 | Val R2=0.820 | Train MAE=2405.2 | Val MAE=2424.0 | Gap R2=0.005 | Params={'min_samples_split': 30, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 30, 'criterion': 'absolute_error', 'ccp_alpha': 8.0}
# Train R2=0.938 | Val R2=0.910 | Train MAE=1345.1 | Val MAE=1635.6 | Gap R2=0.028 | Params={'min_samples_split': 30, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 30, 'criterion': 'squared_error', 'ccp_alpha': 15.0}
# Train R2=0.848 | Val R2=0.846 | Train MAE=2245.5 | Val MAE=2282.3 | Gap R2=0.003 | Params={'min_samples_split': 30, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 5.0}
# Train R2=0.845 | Val R2=0.837 | Train MAE=2250.5 | Val MAE=2296.9 | Gap R2=0.007 | Params={'min_samples_split': 20, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 5.0}
# Train R2=0.960 | Val R2=0.919 | Train MAE=1077.8 | Val MAE=1598.5 | Gap R2=0.041 | Params={'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 30, 'criterion': 'squared_error', 'ccp_alpha': 12.0}
# Train R2=0.791 | Val R2=0.787 | Train MAE=2617.6 | Val MAE=2635.7 | Gap R2=0.003 | Params={'min_samples_split': 10, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': 30, 'criterion': 'absolute_error', 'ccp_alpha': 15.0}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.9 | Val MAE=1619.7 | Gap R2=0.029 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 5.0}
# Train R2=0.960 | Val R2=0.919 | Train MAE=1077.8 | Val MAE=1598.9 | Gap R2=0.041 | Params={'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 12.0}
# Train R2=0.791 | Val R2=0.787 | Train MAE=2617.6 | Val MAE=2635.7 | Gap R2=0.003 | Params={'min_samples_split': 30, 'min_samples_leaf': 15, 'max_features': None, 'max_depth': 30, 'criterion': 'absolute_error', 'ccp_alpha': 15.0}
# Train R2=0.847 | Val R2=0.845 | Train MAE=2246.3 | Val MAE=2284.7 | Gap R2=0.003 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 30, 'criterion': 'absolute_error', 'ccp_alpha': 5.0}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9595846126349252
# Best validation R2: 0.9186782320658033
# R2 Gap: 4.262925856720125 %
# Best train MAE: 1077.7596393628116
# Best validation MAE: 1598.4982107599099
# MAE Gap: 48.31676306833748 %
# Best parameters: {'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 30, 'criterion': 'squared_error', 'ccp_alpha': 12.0}

# %%
model_dt = DecisionTreeRegressor(random_state=42)

param_grid_ccp = {
    # DEIXA A ÁRVORE CRESCER (para baixar o MAE):
    # Permite profundidades maiores do que o teu ótimo anterior (que era 8-10)
    "max_depth": [10, 15, 20, None],
    
    # Permite folhas mais detalhadas
    "min_samples_leaf": [5, 10, 20],
    
    # CONTROLA O GAP (usando ccp_alpha):
    # 0.0 = sem poda (árvore completa)
    # Valores positivos aumentam a agressividade da poda.
    # Como não sabemos a escala exata da impureza, tentamos várias ordens de magnitude.
    "ccp_alpha": [0.0, 0.1, 1.0, 10.0, 100.0],
    
    # Restantes parâmetros de qualidade
    "min_samples_split": [20, 40],
    "max_features": [None, "sqrt", 0.8], # 0.8 significa usar 80% das features
    "criterion": ["absolute_error", "squared_error"]
}

rsCV_dt_ccp = apply_randomized_search_cv(
    model_dt, 
    param_grid_ccp, 
    iterations=20, # Importante manter alto para testar combinações de depth alto + alpha
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_dt_ccp)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV 1/1] END ccp_alpha=0.1, criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=20, min_samples_split=20; mae: (train=-1727.138, test=-1894.684) r2: (train=0.903, test=0.882) total time=   0.1s
# [CV 1/1] END ccp_alpha=100.0, criterion=absolute_error, max_depth=None, max_features=0.8, min_samples_leaf=5, min_samples_split=40; mae: (train=-3465.967, test=-3552.494) r2: (train=0.680, test=0.662) total time=  56.7s
# [CV 1/1] END ccp_alpha=0.0, criterion=absolute_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20; mae: (train=-1482.305, test=-1744.827) r2: (train=0.910, test=0.889) total time=  26.4s
# [CV 1/1] END ccp_alpha=100.0, criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=40; mae: (train=-1546.344, test=-1768.261) r2: (train=0.923, test=0.898) total time=   0.0s
# [CV 1/1] END ccp_alpha=10.0, criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20; mae: (train=-2814.214, test=-2851.259) r2: (train=0.786, test=0.784) total time=  25.7s
# [CV 1/1] END ccp_alpha=1.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-1804.206, test=-1904.975) r2: (train=0.895, test=0.888) total time= 1.3min
# [CV 1/1] END ccp_alpha=100.0, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=20, min_samples_split=40; mae: (train=-1503.705, test=-1702.493) r2: (train=0.925, test=0.901) total time=   0.1s
# [CV 1/1] END ccp_alpha=10.0, criterion=squared_error, max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-1299.505, test=-1619.738) r2: (train=0.942, test=0.913) total time=   0.1s
# [CV 1/1] END ccp_alpha=10.0, criterion=squared_error, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=40; mae: (train=-1402.055, test=-1641.320) r2: (train=0.936, test=0.911) total time=   0.1s
# [CV 1/1] END ccp_alpha=100.0, criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-3443.753, test=-3513.223) r2: (train=0.669, test=0.653) total time= 1.3min
# [CV 1/1] END ccp_alpha=0.0, criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=20, min_samples_split=20; mae: (train=-1460.815, test=-1694.248) r2: (train=0.905, test=0.887) total time= 1.3min
# [CV 1/1] END ccp_alpha=10.0, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=20, min_samples_split=20; mae: (train=-1495.720, test=-1699.109) r2: (train=0.925, test=0.901) total time=   0.1s
# [CV 1/1] END ccp_alpha=0.1, criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=40; mae: (train=-1612.200, test=-1825.608) r2: (train=0.903, test=0.889) total time=  25.8s
# [CV 1/1] END ccp_alpha=0.0, criterion=absolute_error, max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=40; mae: (train=-1362.541, test=-1636.092) r2: (train=0.918, test=0.903) total time= 1.3min
# [CV 1/1] END ccp_alpha=0.0, criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=20; mae: (train=-1341.398, test=-1663.212) r2: (train=0.924, test=0.902) total time=  27.3s
# [CV 1/1] END ccp_alpha=1.0, criterion=absolute_error, max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=20; mae: (train=-2019.180, test=-2127.214) r2: (train=0.875, test=0.866) total time=  26.3s
# [CV 1/1] END ccp_alpha=0.1, criterion=squared_error, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=40; mae: (train=-1402.085, test=-1641.249) r2: (train=0.936, test=0.911) total time=   0.1s
# [CV 1/1] END ccp_alpha=10.0, criterion=absolute_error, max_depth=None, max_features=0.8, min_samples_leaf=20, min_samples_split=20; mae: (train=-2513.674, test=-2525.914) r2: (train=0.814, test=0.814) total time=  57.2s
# [CV 1/1] END ccp_alpha=0.1, criterion=squared_error, max_depth=10, max_features=0.8, min_samples_leaf=5, min_samples_split=40; mae: (train=-1769.443, test=-1891.934) r2: (train=0.913, test=0.896) total time=   0.1s
# [CV 1/1] END ccp_alpha=1.0, criterion=absolute_error, max_depth=20, max_features=sqrt, min_samples_leaf=20, min_samples_split=20; mae: (train=-2025.689, test=-2131.316) r2: (train=0.864, test=0.851) total time=  26.2s
# Train R2=0.903 | Val R2=0.882 | Train MAE=1727.1 | Val MAE=1894.7 | Gap R2=0.020 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error', 'ccp_alpha': 0.1}
# Train R2=0.680 | Val R2=0.662 | Train MAE=3466.0 | Val MAE=3552.5 | Gap R2=0.018 | Params={'min_samples_split': 40, 'min_samples_leaf': 5, 'max_features': 0.8, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 100.0}
# Train R2=0.910 | Val R2=0.889 | Train MAE=1482.3 | Val MAE=1744.8 | Gap R2=0.021 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0.0}
# Train R2=0.923 | Val R2=0.898 | Train MAE=1546.3 | Val MAE=1768.3 | Gap R2=0.025 | Params={'min_samples_split': 40, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 100.0}
# Train R2=0.786 | Val R2=0.784 | Train MAE=2814.2 | Val MAE=2851.3 | Gap R2=0.003 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'absolute_error', 'ccp_alpha': 10.0}
# Train R2=0.895 | Val R2=0.888 | Train MAE=1804.2 | Val MAE=1905.0 | Gap R2=0.008 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 1.0}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1503.7 | Val MAE=1702.5 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error', 'ccp_alpha': 100.0}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1299.5 | Val MAE=1619.7 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 10.0}
# Train R2=0.936 | Val R2=0.911 | Train MAE=1402.1 | Val MAE=1641.3 | Gap R2=0.025 | Params={'min_samples_split': 40, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error', 'ccp_alpha': 10.0}
# Train R2=0.669 | Val R2=0.653 | Train MAE=3443.8 | Val MAE=3513.2 | Gap R2=0.016 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'absolute_error', 'ccp_alpha': 100.0}
# Train R2=0.905 | Val R2=0.887 | Train MAE=1460.8 | Val MAE=1694.2 | Gap R2=0.018 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'absolute_error', 'ccp_alpha': 0.0}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1495.7 | Val MAE=1699.1 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error', 'ccp_alpha': 10.0}
# Train R2=0.903 | Val R2=0.889 | Train MAE=1612.2 | Val MAE=1825.6 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'absolute_error', 'ccp_alpha': 0.1}
# Train R2=0.918 | Val R2=0.903 | Train MAE=1362.5 | Val MAE=1636.1 | Gap R2=0.015 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 0.0}
# Train R2=0.924 | Val R2=0.902 | Train MAE=1341.4 | Val MAE=1663.2 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'absolute_error', 'ccp_alpha': 0.0}
# Train R2=0.875 | Val R2=0.866 | Train MAE=2019.2 | Val MAE=2127.2 | Gap R2=0.009 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'absolute_error', 'ccp_alpha': 1.0}
# Train R2=0.936 | Val R2=0.911 | Train MAE=1402.1 | Val MAE=1641.2 | Gap R2=0.025 | Params={'min_samples_split': 40, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error', 'ccp_alpha': 0.1}
# Train R2=0.814 | Val R2=0.814 | Train MAE=2513.7 | Val MAE=2525.9 | Gap R2=-0.000 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 0.8, 'max_depth': None, 'criterion': 'absolute_error', 'ccp_alpha': 10.0}
# Train R2=0.913 | Val R2=0.896 | Train MAE=1769.4 | Val MAE=1891.9 | Gap R2=0.017 | Params={'min_samples_split': 40, 'min_samples_leaf': 5, 'max_features': 0.8, 'max_depth': 10, 'criterion': 'squared_error', 'ccp_alpha': 0.1}
# Train R2=0.864 | Val R2=0.851 | Train MAE=2025.7 | Val MAE=2131.3 | Gap R2=0.013 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'absolute_error', 'ccp_alpha': 1.0}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9418786348895181
# Best validation R2: 0.9130432684921173
# R2 Gap: 3.061473668609458 %
# Best train MAE: 1299.5045891987904
# Best validation MAE: 1619.737902333246
# MAE Gap: 24.642722757285178 %
# Best parameters: {'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error', 'ccp_alpha': 10.0}

# %%
from sklearn.ensemble import ExtraTreesRegressor

# Inicializar o modelo
model_et = ExtraTreesRegressor(random_state=42, n_jobs=-1)

# Espaço de parâmetros (Chamamos 'distributions' em vez de 'grid' no RandomSearch)
param_distributions_et = {
    # ExtraTrees beneficia de muitas árvores (é rápido, por isso abusa aqui)
    "n_estimators": [100, 200, 300, 500],
    
    # Como o ExtraTrees não overfit tanto, podes deixar a profundidade maior
    "max_depth": [10, 20, 30, 40, None],
    
    # Parâmetros de corte
    "min_samples_split": [2, 5, 10, 15],
    "min_samples_leaf": [1, 2, 4, 10],
    
    # CRUCIAL: No ExtraTrees, testar 1.0 (todas as features) é importante
    # "sqrt" e "log2" dão mais variabilidade, 1.0 dá mais força bruta
    "max_features": [1.0, "sqrt", "log2"],
    
    # Bootstrap: False é o padrão do ExtraTrees (usa dataset todo), 
    # mas True aproxima-o do Random Forest (reduz variância)
    "bootstrap": [False, True]
}

# Executar o RANDOM SEARCH
rsCV_et = apply_randomized_search_cv(
    model_et, 
    param_distributions_et, 
    iterations=50,  # O modelo é rápido, se quiseres podes subir para 100
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

# Verificar resultados
evaluate_model(rsCV_et)
# Out:
# Fitting 1 folds for each of 50 candidates, totalling 50 fits
# [CV 1/1] END bootstrap=True, max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; mae: (train=-1115.015, test=-1385.393) r2: (train=0.960, test=0.937) total time=   0.5s
# [CV 1/1] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=200; mae: (train=-2353.114, test=-2392.830) r2: (train=0.860, test=0.853) total time=   0.3s
# [CV 1/1] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; mae: (train=-1204.360, test=-1428.549) r2: (train=0.956, test=0.936) total time=   0.6s
# [CV 1/1] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100; mae: (train=-1780.929, test=-1854.660) r2: (train=0.904, test=0.894) total time=   0.2s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=1.0, min_samples_leaf=2, min_samples_split=5, n_estimators=200; mae: (train=-959.761, test=-1331.990) r2: (train=0.971, test=0.946) total time=   1.0s
# [CV 1/1] END bootstrap=False, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=300; mae: (train=-1097.227, test=-1403.570) r2: (train=0.965, test=0.939) total time=   0.8s
# [CV 1/1] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; mae: (train=-1423.224, test=-1566.061) r2: (train=0.938, test=0.924) total time=   0.4s
# [CV 1/1] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=10, min_samples_split=5, n_estimators=500; mae: (train=-1330.912, test=-1473.140) r2: (train=0.940, test=0.928) total time=   2.4s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; mae: (train=-1135.097, test=-1413.363) r2: (train=0.964, test=0.940) total time=   0.3s
# [CV 1/1] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=500; mae: (train=-1264.865, test=-1459.908) r2: (train=0.951, test=0.932) total time=   1.2s
# [CV 1/1] END bootstrap=False, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=300; mae: (train=-1766.234, test=-1840.892) r2: (train=0.905, test=0.896) total time=   0.5s
# [CV 1/1] END bootstrap=False, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=15, n_estimators=200; mae: (train=-1720.663, test=-1785.730) r2: (train=0.922, test=0.913) total time=   0.6s
# [CV 1/1] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=300; mae: (train=-1039.853, test=-1388.848) r2: (train=0.971, test=0.943) total time=   0.8s
# [CV 1/1] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=500; mae: (train=-163.908, test=-1336.372) r2: (train=0.998, test=0.947) total time=   2.9s
# [CV 1/1] END bootstrap=True, max_depth=40, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=100; mae: (train=-1864.542, test=-1923.877) r2: (train=0.893, test=0.883) total time=   0.2s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300; mae: (train=-1115.471, test=-1384.701) r2: (train=0.960, test=0.937) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; mae: (train=-1528.591, test=-1637.609) r2: (train=0.927, test=0.915) total time=   0.4s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=500; mae: (train=-1115.087, test=-1383.648) r2: (train=0.960, test=0.937) total time=   1.3s
# [CV 1/1] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; mae: (train=-685.195, test=-1321.188) r2: (train=0.986, test=0.947) total time=   2.0s
# [CV 1/1] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; mae: (train=-158.571, test=-1345.395) r2: (train=0.998, test=0.945) total time=   0.5s
# [CV 1/1] END bootstrap=True, max_depth=40, max_features=1.0, min_samples_leaf=4, min_samples_split=5, n_estimators=100; mae: (train=-1184.869, test=-1400.047) r2: (train=0.953, test=0.937) total time=   0.4s
# [CV 1/1] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; mae: (train=-2252.715, test=-2313.602) r2: (train=0.879, test=0.869) total time=   0.2s
# [CV 1/1] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; mae: (train=-2255.513, test=-2305.656) r2: (train=0.876, test=0.869) total time=   0.2s
# [CV 1/1] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; mae: (train=-2269.081, test=-2320.860) r2: (train=0.876, test=0.868) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=300; mae: (train=-1530.533, test=-1639.101) r2: (train=0.927, test=0.916) total time=   0.7s
# [CV 1/1] END bootstrap=False, max_depth=40, max_features=1.0, min_samples_leaf=10, min_samples_split=2, n_estimators=300; mae: (train=-1331.724, test=-1475.271) r2: (train=0.940, test=0.928) total time=   1.5s
# [CV 1/1] END bootstrap=False, max_depth=20, max_features=1.0, min_samples_leaf=10, min_samples_split=2, n_estimators=200; mae: (train=-1337.687, test=-1480.196) r2: (train=0.940, test=0.927) total time=   1.0s
# [CV 1/1] END bootstrap=False, max_depth=20, max_features=1.0, min_samples_leaf=4, min_samples_split=15, n_estimators=100; mae: (train=-1141.240, test=-1377.205) r2: (train=0.958, test=0.940) total time=   0.6s
# [CV 1/1] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; mae: (train=-2239.199, test=-2291.410) r2: (train=0.878, test=0.870) total time=   0.2s
# [CV 1/1] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=500; mae: (train=-1857.456, test=-1913.864) r2: (train=0.894, test=0.886) total time=   0.9s
# [CV 1/1] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; mae: (train=-1228.690, test=-1432.188) r2: (train=0.951, test=0.932) total time=   0.3s
# [CV 1/1] END bootstrap=False, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; mae: (train=-26.774, test=-1383.509) r2: (train=0.999, test=0.943) total time=   0.6s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100; mae: (train=-1864.542, test=-1923.877) r2: (train=0.893, test=0.883) total time=   0.2s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=200; mae: (train=-1851.597, test=-1908.606) r2: (train=0.894, test=0.885) total time=   0.4s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; mae: (train=-1335.736, test=-1510.415) r2: (train=0.947, test=0.930) total time=   0.4s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=1.0, min_samples_leaf=2, min_samples_split=5, n_estimators=500; mae: (train=-958.030, test=-1331.097) r2: (train=0.971, test=0.946) total time=   2.6s
# [CV 1/1] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=300; mae: (train=-1766.234, test=-1840.892) r2: (train=0.905, test=0.896) total time=   0.6s
# [CV 1/1] END bootstrap=False, max_depth=30, max_features=1.0, min_samples_leaf=4, min_samples_split=2, n_estimators=100; mae: (train=-1046.230, test=-1354.644) r2: (train=0.965, test=0.943) total time=   0.6s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=1.0, min_samples_leaf=2, min_samples_split=10, n_estimators=500; mae: (train=-1113.422, test=-1365.996) r2: (train=0.961, test=0.941) total time=   2.3s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=1.0, min_samples_leaf=10, min_samples_split=10, n_estimators=500; mae: (train=-1442.368, test=-1541.132) r2: (train=0.929, test=0.920) total time=   1.8s
# [CV 1/1] END bootstrap=False, max_depth=40, max_features=1.0, min_samples_leaf=4, min_samples_split=5, n_estimators=200; mae: (train=-1044.713, test=-1355.236) r2: (train=0.965, test=0.943) total time=   1.2s
# [CV 1/1] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=300; mae: (train=-2359.935, test=-2400.974) r2: (train=0.859, test=0.853) total time=   0.4s
# [CV 1/1] END bootstrap=True, max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; mae: (train=-1528.591, test=-1637.609) r2: (train=0.927, test=0.915) total time=   0.4s
# [CV 1/1] END bootstrap=False, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=300; mae: (train=-1168.140, test=-1422.648) r2: (train=0.962, test=0.939) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; mae: (train=-2257.699, test=-2300.192) r2: (train=0.871, test=0.865) total time=   0.2s
# [CV 1/1] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=100; mae: (train=-1780.929, test=-1854.660) r2: (train=0.904, test=0.894) total time=   0.2s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=500; mae: (train=-1865.606, test=-1922.212) r2: (train=0.894, test=0.886) total time=   0.9s
# [CV 1/1] END bootstrap=False, max_depth=40, max_features=1.0, min_samples_leaf=1, min_samples_split=5, n_estimators=200; mae: (train=-565.578, test=-1319.391) r2: (train=0.990, test=0.949) total time=   1.7s
# [CV 1/1] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=5, n_estimators=500; mae: (train=-1698.410, test=-1764.988) r2: (train=0.925, test=0.916) total time=   1.4s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=300; mae: (train=-1393.107, test=-1539.472) r2: (train=0.941, test=0.926) total time=   0.6s
# Train R2=0.960 | Val R2=0.937 | Train MAE=1115.0 | Val MAE=1385.4 | Gap R2=0.023 | Params={'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 40, 'bootstrap': True}
# Train R2=0.860 | Val R2=0.853 | Train MAE=2353.1 | Val MAE=2392.8 | Gap R2=0.006 | Params={'n_estimators': 200, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'bootstrap': False}
# Train R2=0.956 | Val R2=0.936 | Train MAE=1204.4 | Val MAE=1428.5 | Gap R2=0.020 | Params={'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 30, 'bootstrap': False}
# Train R2=0.904 | Val R2=0.894 | Train MAE=1780.9 | Val MAE=1854.7 | Gap R2=0.010 | Params={'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': False}
# Train R2=0.971 | Val R2=0.946 | Train MAE=959.8 | Val MAE=1332.0 | Gap R2=0.025 | Params={'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.965 | Val R2=0.939 | Train MAE=1097.2 | Val MAE=1403.6 | Gap R2=0.027 | Params={'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'bootstrap': False}
# Train R2=0.938 | Val R2=0.924 | Train MAE=1423.2 | Val MAE=1566.1 | Gap R2=0.014 | Params={'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 40, 'bootstrap': False}
# Train R2=0.940 | Val R2=0.928 | Train MAE=1330.9 | Val MAE=1473.1 | Gap R2=0.012 | Params={'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 1.0, 'max_depth': None, 'bootstrap': False}
# Train R2=0.964 | Val R2=0.940 | Train MAE=1135.1 | Val MAE=1413.4 | Gap R2=0.024 | Params={'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 20, 'bootstrap': True}
# Train R2=0.951 | Val R2=0.932 | Train MAE=1264.9 | Val MAE=1459.9 | Gap R2=0.019 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 40, 'bootstrap': False}
# Train R2=0.905 | Val R2=0.896 | Train MAE=1766.2 | Val MAE=1840.9 | Gap R2=0.010 | Params={'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': None, 'bootstrap': False}
# Train R2=0.922 | Val R2=0.913 | Train MAE=1720.7 | Val MAE=1785.7 | Gap R2=0.009 | Params={'n_estimators': 200, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 1.0, 'max_depth': 10, 'bootstrap': False}
# Train R2=0.971 | Val R2=0.943 | Train MAE=1039.9 | Val MAE=1388.8 | Gap R2=0.028 | Params={'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 20, 'bootstrap': False}
# Train R2=0.998 | Val R2=0.947 | Train MAE=163.9 | Val MAE=1336.4 | Gap R2=0.051 | Params={'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 30, 'bootstrap': False}
# Train R2=0.893 | Val R2=0.883 | Train MAE=1864.5 | Val MAE=1923.9 | Gap R2=0.010 | Params={'n_estimators': 100, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 40, 'bootstrap': True}
# Train R2=0.960 | Val R2=0.937 | Train MAE=1115.5 | Val MAE=1384.7 | Gap R2=0.023 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True}
# Train R2=0.927 | Val R2=0.915 | Train MAE=1528.6 | Val MAE=1637.6 | Gap R2=0.012 | Params={'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 40, 'bootstrap': True}
# Train R2=0.960 | Val R2=0.937 | Train MAE=1115.1 | Val MAE=1383.6 | Gap R2=0.023 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True}
# Train R2=0.986 | Val R2=0.947 | Train MAE=685.2 | Val MAE=1321.2 | Gap R2=0.039 | Params={'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'bootstrap': False}
# Train R2=0.998 | Val R2=0.945 | Train MAE=158.6 | Val MAE=1345.4 | Gap R2=0.053 | Params={'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 30, 'bootstrap': False}
# Train R2=0.953 | Val R2=0.937 | Train MAE=1184.9 | Val MAE=1400.0 | Gap R2=0.016 | Params={'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 40, 'bootstrap': True}
# Train R2=0.879 | Val R2=0.869 | Train MAE=2252.7 | Val MAE=2313.6 | Gap R2=0.010 | Params={'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 10, 'bootstrap': False}
# Train R2=0.876 | Val R2=0.869 | Train MAE=2255.5 | Val MAE=2305.7 | Gap R2=0.008 | Params={'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'bootstrap': True}
# Train R2=0.876 | Val R2=0.868 | Train MAE=2269.1 | Val MAE=2320.9 | Gap R2=0.008 | Params={'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 10, 'bootstrap': False}
# Train R2=0.927 | Val R2=0.916 | Train MAE=1530.5 | Val MAE=1639.1 | Gap R2=0.011 | Params={'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'bootstrap': True}
# Train R2=0.940 | Val R2=0.928 | Train MAE=1331.7 | Val MAE=1475.3 | Gap R2=0.012 | Params={'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 1.0, 'max_depth': 40, 'bootstrap': False}
# Train R2=0.940 | Val R2=0.927 | Train MAE=1337.7 | Val MAE=1480.2 | Gap R2=0.012 | Params={'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 1.0, 'max_depth': 20, 'bootstrap': False}
# Train R2=0.958 | Val R2=0.940 | Train MAE=1141.2 | Val MAE=1377.2 | Gap R2=0.018 | Params={'n_estimators': 100, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 20, 'bootstrap': False}
# Train R2=0.878 | Val R2=0.870 | Train MAE=2239.2 | Val MAE=2291.4 | Gap R2=0.008 | Params={'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'bootstrap': True}
# Train R2=0.894 | Val R2=0.886 | Train MAE=1857.5 | Val MAE=1913.9 | Gap R2=0.009 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 40, 'bootstrap': True}
# Train R2=0.951 | Val R2=0.932 | Train MAE=1228.7 | Val MAE=1432.2 | Gap R2=0.019 | Params={'n_estimators': 100, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 40, 'bootstrap': True}
# Train R2=0.999 | Val R2=0.943 | Train MAE=26.8 | Val MAE=1383.5 | Gap R2=0.056 | Params={'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': None, 'bootstrap': False}
# Train R2=0.893 | Val R2=0.883 | Train MAE=1864.5 | Val MAE=1923.9 | Gap R2=0.010 | Params={'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True}
# Train R2=0.894 | Val R2=0.885 | Train MAE=1851.6 | Val MAE=1908.6 | Gap R2=0.009 | Params={'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 30, 'bootstrap': True}
# Train R2=0.947 | Val R2=0.930 | Train MAE=1335.7 | Val MAE=1510.4 | Gap R2=0.017 | Params={'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 20, 'bootstrap': True}
# Train R2=0.971 | Val R2=0.946 | Train MAE=958.0 | Val MAE=1331.1 | Gap R2=0.025 | Params={'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.905 | Val R2=0.896 | Train MAE=1766.2 | Val MAE=1840.9 | Gap R2=0.010 | Params={'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 40, 'bootstrap': False}
# Train R2=0.965 | Val R2=0.943 | Train MAE=1046.2 | Val MAE=1354.6 | Gap R2=0.022 | Params={'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': False}
# Train R2=0.961 | Val R2=0.941 | Train MAE=1113.4 | Val MAE=1366.0 | Gap R2=0.019 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 1.0, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.929 | Val R2=0.920 | Train MAE=1442.4 | Val MAE=1541.1 | Gap R2=0.009 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 1.0, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.965 | Val R2=0.943 | Train MAE=1044.7 | Val MAE=1355.2 | Gap R2=0.022 | Params={'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 40, 'bootstrap': False}
# Train R2=0.859 | Val R2=0.853 | Train MAE=2359.9 | Val MAE=2401.0 | Gap R2=0.007 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'bootstrap': False}
# Train R2=0.927 | Val R2=0.915 | Train MAE=1528.6 | Val MAE=1637.6 | Gap R2=0.012 | Params={'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 40, 'bootstrap': True}
# Train R2=0.962 | Val R2=0.939 | Train MAE=1168.1 | Val MAE=1422.6 | Gap R2=0.023 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 20, 'bootstrap': False}
# Train R2=0.871 | Val R2=0.865 | Train MAE=2257.7 | Val MAE=2300.2 | Gap R2=0.006 | Params={'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 10, 'bootstrap': True}
# Train R2=0.904 | Val R2=0.894 | Train MAE=1780.9 | Val MAE=1854.7 | Gap R2=0.010 | Params={'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': False}
# Train R2=0.894 | Val R2=0.886 | Train MAE=1865.6 | Val MAE=1922.2 | Gap R2=0.009 | Params={'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'bootstrap': True}
# Train R2=0.990 | Val R2=0.949 | Train MAE=565.6 | Val MAE=1319.4 | Gap R2=0.041 | Params={'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 1.0, 'max_depth': 40, 'bootstrap': False}
# Train R2=0.925 | Val R2=0.916 | Train MAE=1698.4 | Val MAE=1765.0 | Gap R2=0.009 | Params={'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 1.0, 'max_depth': 10, 'bootstrap': True}
# Train R2=0.941 | Val R2=0.926 | Train MAE=1393.1 | Val MAE=1539.5 | Gap R2=0.015 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': True}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9897764805764893
# Best validation R2: 0.9491827692194131
# R2 Gap: 4.101300864760149 %
# Best train MAE: 565.5781732388235
# Best validation MAE: 1319.3906004847079
# MAE Gap: 133.28173945064464 %
# Best parameters: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 1.0, 'max_depth': 40, 'bootstrap': False}

# %%
model_et_robust = ExtraTreesRegressor(random_state=42, n_jobs=-1)

param_distributions_robust = {
    # 1. A SOLUÇÃO Nº1 PARA O GAP:
    # Forçamos True. Isto vai imediatamente baixar o gap para metade ou menos.
    "bootstrap": [True],
    
    # Compensar o bootstrap com mais árvores (estabiliza a previsão)
    "n_estimators": [300, 400, 500],
    
    # 2. PROIBIR REGRAS PARA "UMA SÓ PESSOA":
    # Valores como 4 ou 8 impedem a memorização de outliers.
    "min_samples_leaf": [4, 6, 8, 12],
    
    # 3. LIMITAR A VISÃO:
    # 1.0 causou o overfit. Vamos tentar 70%, 85% ou 'sqrt'.
    # Isto força as árvores a cooperarem mais.
    "max_features": [0.7, 0.85, "sqrt"],
    
    # Controlar a profundidade (40 era muito fundo para quem tem overfit)
    "max_depth": [15, 20, 25, 30],
    
    # Ajuste fino
    "min_samples_split": [10, 20]
}

rsCV_et_robust = apply_randomized_search_cv(
    model_et_robust, 
    param_distributions_robust, 
    iterations=50, 
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_et_robust)
# Out:
# Fitting 1 folds for each of 50 candidates, totalling 50 fits
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=6, min_samples_split=20, n_estimators=400; mae: (train=-1403.063, test=-1518.766) r2: (train=0.934, test=0.923) total time=   1.3s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=12, min_samples_split=10, n_estimators=300; mae: (train=-1544.074, test=-1623.417) r2: (train=0.919, test=0.911) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=300; mae: (train=-1803.168, test=-1867.734) r2: (train=0.900, test=0.891) total time=   0.5s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.85, min_samples_leaf=6, min_samples_split=20, n_estimators=400; mae: (train=-1442.455, test=-1545.445) r2: (train=0.933, test=0.923) total time=   1.2s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=300; mae: (train=-1772.137, test=-1846.311) r2: (train=0.909, test=0.900) total time=   0.5s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; mae: (train=-1541.109, test=-1649.512) r2: (train=0.926, test=0.915) total time=   0.5s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=300; mae: (train=-1801.630, test=-1866.629) r2: (train=0.901, test=0.892) total time=   0.5s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.7, min_samples_leaf=12, min_samples_split=10, n_estimators=500; mae: (train=-1590.037, test=-1659.304) r2: (train=0.916, test=0.909) total time=   1.1s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=500; mae: (train=-1830.904, test=-1896.218) r2: (train=0.903, test=0.894) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=20, n_estimators=500; mae: (train=-1718.430, test=-1794.169) r2: (train=0.909, test=0.900) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.85, min_samples_leaf=8, min_samples_split=20, n_estimators=500; mae: (train=-1475.942, test=-1570.205) r2: (train=0.928, test=0.919) total time=   1.4s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.85, min_samples_leaf=4, min_samples_split=10, n_estimators=400; mae: (train=-1235.249, test=-1419.061) r2: (train=0.950, test=0.934) total time=   1.4s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=12, min_samples_split=10, n_estimators=500; mae: (train=-1544.692, test=-1622.780) r2: (train=0.919, test=0.911) total time=   1.2s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.7, min_samples_leaf=12, min_samples_split=10, n_estimators=500; mae: (train=-1542.389, test=-1621.568) r2: (train=0.919, test=0.911) total time=   1.3s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.85, min_samples_leaf=8, min_samples_split=10, n_estimators=300; mae: (train=-1403.165, test=-1517.488) r2: (train=0.933, test=0.923) total time=   0.9s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.7, min_samples_leaf=12, min_samples_split=10, n_estimators=400; mae: (train=-1590.106, test=-1659.776) r2: (train=0.916, test=0.909) total time=   1.0s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.7, min_samples_leaf=4, min_samples_split=20, n_estimators=300; mae: (train=-1450.674, test=-1555.268) r2: (train=0.933, test=0.923) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.7, min_samples_leaf=12, min_samples_split=10, n_estimators=300; mae: (train=-1593.080, test=-1662.839) r2: (train=0.916, test=0.908) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.85, min_samples_leaf=6, min_samples_split=20, n_estimators=500; mae: (train=-1441.654, test=-1544.425) r2: (train=0.933, test=0.923) total time=   1.6s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.85, min_samples_leaf=6, min_samples_split=10, n_estimators=500; mae: (train=-1324.449, test=-1467.663) r2: (train=0.941, test=0.929) total time=   1.8s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=6, min_samples_split=20, n_estimators=500; mae: (train=-1403.030, test=-1518.158) r2: (train=0.934, test=0.923) total time=   1.4s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=300; mae: (train=-1905.083, test=-1962.334) r2: (train=0.894, test=0.885) total time=   0.5s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=20, n_estimators=300; mae: (train=-1846.602, test=-1908.372) r2: (train=0.901, test=0.893) total time=   0.5s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=300; mae: (train=-1691.885, test=-1772.696) r2: (train=0.912, test=0.903) total time=   0.5s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.85, min_samples_leaf=12, min_samples_split=20, n_estimators=300; mae: (train=-1549.103, test=-1625.429) r2: (train=0.919, test=0.912) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=4, min_samples_split=20, n_estimators=300; mae: (train=-1350.664, test=-1480.715) r2: (train=0.939, test=0.928) total time=   0.9s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.7, min_samples_leaf=4, min_samples_split=10, n_estimators=300; mae: (train=-1395.768, test=-1521.420) r2: (train=0.940, test=0.928) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.85, min_samples_leaf=8, min_samples_split=20, n_estimators=400; mae: (train=-1412.861, test=-1523.800) r2: (train=0.932, test=0.922) total time=   1.3s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.85, min_samples_leaf=6, min_samples_split=10, n_estimators=500; mae: (train=-1332.128, test=-1470.558) r2: (train=0.940, test=0.928) total time=   1.7s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.85, min_samples_leaf=6, min_samples_split=20, n_estimators=300; mae: (train=-1364.148, test=-1491.352) r2: (train=0.937, test=0.925) total time=   1.0s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.7, min_samples_leaf=12, min_samples_split=10, n_estimators=400; mae: (train=-1542.377, test=-1622.089) r2: (train=0.919, test=0.911) total time=   1.0s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.7, min_samples_leaf=8, min_samples_split=20, n_estimators=300; mae: (train=-1446.849, test=-1549.538) r2: (train=0.929, test=0.919) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.7, min_samples_leaf=6, min_samples_split=10, n_estimators=400; mae: (train=-1360.757, test=-1492.074) r2: (train=0.938, test=0.926) total time=   1.2s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=6, min_samples_split=20, n_estimators=300; mae: (train=-1703.048, test=-1778.903) r2: (train=0.910, test=0.900) total time=   0.5s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.85, min_samples_leaf=6, min_samples_split=10, n_estimators=400; mae: (train=-1324.340, test=-1467.101) r2: (train=0.941, test=0.929) total time=   1.4s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.7, min_samples_leaf=4, min_samples_split=20, n_estimators=400; mae: (train=-1337.404, test=-1473.414) r2: (train=0.940, test=0.928) total time=   1.3s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.7, min_samples_leaf=6, min_samples_split=10, n_estimators=400; mae: (train=-1458.813, test=-1562.380) r2: (train=0.932, test=0.922) total time=   1.1s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=300; mae: (train=-1934.522, test=-1985.427) r2: (train=0.886, test=0.877) total time=   0.6s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.7, min_samples_leaf=8, min_samples_split=10, n_estimators=500; mae: (train=-1445.747, test=-1550.201) r2: (train=0.930, test=0.920) total time=   1.5s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=500; mae: (train=-1906.072, test=-1962.751) r2: (train=0.894, test=0.886) total time=   0.9s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.85, min_samples_leaf=8, min_samples_split=20, n_estimators=500; mae: (train=-1411.944, test=-1522.426) r2: (train=0.932, test=0.922) total time=   1.7s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.85, min_samples_leaf=6, min_samples_split=10, n_estimators=300; mae: (train=-1325.955, test=-1469.425) r2: (train=0.941, test=0.929) total time=   1.1s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.7, min_samples_leaf=6, min_samples_split=20, n_estimators=300; mae: (train=-1483.201, test=-1580.291) r2: (train=0.929, test=0.920) total time=   0.8s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.7, min_samples_leaf=8, min_samples_split=10, n_estimators=400; mae: (train=-1513.180, test=-1603.460) r2: (train=0.926, test=0.917) total time=   1.1s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=400; mae: (train=-1929.236, test=-1981.418) r2: (train=0.886, test=0.878) total time=   0.7s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=300; mae: (train=-1712.243, test=-1789.704) r2: (train=0.911, test=0.901) total time=   0.6s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.85, min_samples_leaf=8, min_samples_split=10, n_estimators=300; mae: (train=-1408.988, test=-1521.441) r2: (train=0.932, test=0.922) total time=   1.0s
# [CV 1/1] END bootstrap=True, max_depth=15, max_features=0.85, min_samples_leaf=4, min_samples_split=20, n_estimators=400; mae: (train=-1409.922, test=-1524.503) r2: (train=0.937, test=0.926) total time=   1.3s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=500; mae: (train=-1930.325, test=-1980.333) r2: (train=0.886, test=0.878) total time=   0.9s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.85, min_samples_leaf=4, min_samples_split=10, n_estimators=300; mae: (train=-1220.791, test=-1412.599) r2: (train=0.950, test=0.935) total time=   1.2s
# Train R2=0.934 | Val R2=0.923 | Train MAE=1403.1 | Val MAE=1518.8 | Gap R2=0.011 | Params={'n_estimators': 400, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 0.7, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.919 | Val R2=0.911 | Train MAE=1544.1 | Val MAE=1623.4 | Gap R2=0.008 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 0.7, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.900 | Val R2=0.891 | Train MAE=1803.2 | Val MAE=1867.7 | Gap R2=0.009 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': True}
# Train R2=0.933 | Val R2=0.923 | Train MAE=1442.5 | Val MAE=1545.4 | Gap R2=0.010 | Params={'n_estimators': 400, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 0.85, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.909 | Val R2=0.900 | Train MAE=1772.1 | Val MAE=1846.3 | Gap R2=0.009 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 15, 'bootstrap': True}
# Train R2=0.926 | Val R2=0.915 | Train MAE=1541.1 | Val MAE=1649.5 | Gap R2=0.012 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 25, 'bootstrap': True}
# Train R2=0.901 | Val R2=0.892 | Train MAE=1801.6 | Val MAE=1866.6 | Gap R2=0.009 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': True}
# Train R2=0.916 | Val R2=0.909 | Train MAE=1590.0 | Val MAE=1659.3 | Gap R2=0.007 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 0.7, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.903 | Val R2=0.894 | Train MAE=1830.9 | Val MAE=1896.2 | Gap R2=0.009 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'max_depth': 15, 'bootstrap': True}
# Train R2=0.909 | Val R2=0.900 | Train MAE=1718.4 | Val MAE=1794.2 | Gap R2=0.009 | Params={'n_estimators': 500, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': True}
# Train R2=0.928 | Val R2=0.919 | Train MAE=1475.9 | Val MAE=1570.2 | Gap R2=0.009 | Params={'n_estimators': 500, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 0.85, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.934 | Train MAE=1235.2 | Val MAE=1419.1 | Gap R2=0.015 | Params={'n_estimators': 400, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.85, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.919 | Val R2=0.911 | Train MAE=1544.7 | Val MAE=1622.8 | Gap R2=0.008 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 0.7, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.919 | Val R2=0.911 | Train MAE=1542.4 | Val MAE=1621.6 | Gap R2=0.008 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 0.7, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.933 | Val R2=0.923 | Train MAE=1403.2 | Val MAE=1517.5 | Gap R2=0.010 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.85, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.916 | Val R2=0.909 | Train MAE=1590.1 | Val MAE=1659.8 | Gap R2=0.007 | Params={'n_estimators': 400, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 0.7, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.933 | Val R2=0.923 | Train MAE=1450.7 | Val MAE=1555.3 | Gap R2=0.010 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 0.7, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.916 | Val R2=0.908 | Train MAE=1593.1 | Val MAE=1662.8 | Gap R2=0.007 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 0.7, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.933 | Val R2=0.923 | Train MAE=1441.7 | Val MAE=1544.4 | Gap R2=0.010 | Params={'n_estimators': 500, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 0.85, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.941 | Val R2=0.929 | Train MAE=1324.4 | Val MAE=1467.7 | Gap R2=0.012 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.85, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.934 | Val R2=0.923 | Train MAE=1403.0 | Val MAE=1518.2 | Gap R2=0.011 | Params={'n_estimators': 500, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 0.7, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.894 | Val R2=0.885 | Train MAE=1905.1 | Val MAE=1962.3 | Gap R2=0.009 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_depth': 15, 'bootstrap': True}
# Train R2=0.901 | Val R2=0.893 | Train MAE=1846.6 | Val MAE=1908.4 | Gap R2=0.009 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'max_depth': 15, 'bootstrap': True}
# Train R2=0.912 | Val R2=0.903 | Train MAE=1691.9 | Val MAE=1772.7 | Gap R2=0.010 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'max_depth': 30, 'bootstrap': True}
# Train R2=0.919 | Val R2=0.912 | Train MAE=1549.1 | Val MAE=1625.4 | Gap R2=0.008 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': 0.85, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.939 | Val R2=0.928 | Train MAE=1350.7 | Val MAE=1480.7 | Gap R2=0.011 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 0.7, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.940 | Val R2=0.928 | Train MAE=1395.8 | Val MAE=1521.4 | Gap R2=0.011 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.7, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.932 | Val R2=0.922 | Train MAE=1412.9 | Val MAE=1523.8 | Gap R2=0.010 | Params={'n_estimators': 400, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 0.85, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.940 | Val R2=0.928 | Train MAE=1332.1 | Val MAE=1470.6 | Gap R2=0.012 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.85, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.937 | Val R2=0.925 | Train MAE=1364.1 | Val MAE=1491.4 | Gap R2=0.011 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 0.85, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.919 | Val R2=0.911 | Train MAE=1542.4 | Val MAE=1622.1 | Gap R2=0.008 | Params={'n_estimators': 400, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 0.7, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.929 | Val R2=0.919 | Train MAE=1446.8 | Val MAE=1549.5 | Gap R2=0.010 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 0.7, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.938 | Val R2=0.926 | Train MAE=1360.8 | Val MAE=1492.1 | Gap R2=0.011 | Params={'n_estimators': 400, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.7, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.910 | Val R2=0.900 | Train MAE=1703.0 | Val MAE=1778.9 | Gap R2=0.009 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'max_depth': 25, 'bootstrap': True}
# Train R2=0.941 | Val R2=0.929 | Train MAE=1324.3 | Val MAE=1467.1 | Gap R2=0.012 | Params={'n_estimators': 400, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.85, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.940 | Val R2=0.928 | Train MAE=1337.4 | Val MAE=1473.4 | Gap R2=0.012 | Params={'n_estimators': 400, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 0.7, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.932 | Val R2=0.922 | Train MAE=1458.8 | Val MAE=1562.4 | Gap R2=0.010 | Params={'n_estimators': 400, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.7, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.886 | Val R2=0.877 | Train MAE=1934.5 | Val MAE=1985.4 | Gap R2=0.009 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_depth': 30, 'bootstrap': True}
# Train R2=0.930 | Val R2=0.920 | Train MAE=1445.7 | Val MAE=1550.2 | Gap R2=0.010 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.7, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.894 | Val R2=0.886 | Train MAE=1906.1 | Val MAE=1962.8 | Gap R2=0.009 | Params={'n_estimators': 500, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_depth': 15, 'bootstrap': True}
# Train R2=0.932 | Val R2=0.922 | Train MAE=1411.9 | Val MAE=1522.4 | Gap R2=0.010 | Params={'n_estimators': 500, 'min_samples_split': 20, 'min_samples_leaf': 8, 'max_features': 0.85, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.941 | Val R2=0.929 | Train MAE=1326.0 | Val MAE=1469.4 | Gap R2=0.012 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 0.85, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.929 | Val R2=0.920 | Train MAE=1483.2 | Val MAE=1580.3 | Gap R2=0.010 | Params={'n_estimators': 300, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 0.7, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.926 | Val R2=0.917 | Train MAE=1513.2 | Val MAE=1603.5 | Gap R2=0.009 | Params={'n_estimators': 400, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.7, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.886 | Val R2=0.878 | Train MAE=1929.2 | Val MAE=1981.4 | Gap R2=0.009 | Params={'n_estimators': 400, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_depth': 25, 'bootstrap': True}
# Train R2=0.911 | Val R2=0.901 | Train MAE=1712.2 | Val MAE=1789.7 | Gap R2=0.009 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': True}
# Train R2=0.932 | Val R2=0.922 | Train MAE=1409.0 | Val MAE=1521.4 | Gap R2=0.010 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 0.85, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.937 | Val R2=0.926 | Train MAE=1409.9 | Val MAE=1524.5 | Gap R2=0.011 | Params={'n_estimators': 400, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 0.85, 'max_depth': 15, 'bootstrap': True}
# Train R2=0.886 | Val R2=0.878 | Train MAE=1930.3 | Val MAE=1980.3 | Gap R2=0.008 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_depth': 30, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.935 | Train MAE=1220.8 | Val MAE=1412.6 | Gap R2=0.015 | Params={'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.85, 'max_depth': 25, 'bootstrap': True}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9502555679490001
# Best validation R2: 0.9351317708664991
# R2 Gap: 1.5915504831130534 %
# Best train MAE: 1220.7908453449709
# Best validation MAE: 1412.5992345501268
# MAE Gap: 15.711814184759445 %
# Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.85, 'max_depth': 25, 'bootstrap': True}

# %% [markdown]
# ### melhor ate agora!!

# %%
from sklearn.ensemble import ExtraTreesRegressor
model_et_expert = ExtraTreesRegressor(random_state=42, n_jobs=-1)

param_grid_expert = {
    # SEGURANÇA BASE:
    "bootstrap": [True],  # Obrigatório para o max_samples funcionar
    "n_estimators": [500, 800], # Quantidade gera estabilidade
    
    # NOVO PARÂMETRO 1: max_samples
    # None = usa tudo (mais risco de overfit)
    # 0.8 / 0.9 = usa 80-90% (menos overfit, mais generalização)
    "max_samples": [None, 0.8, 0.9, 0.95],
    
    # NOVO PARÂMETRO 2: min_impurity_decrease
    # 0.0 = comportamento normal.
    # Valores pequenos cortam splits irrelevantes.
    "min_impurity_decrease": [0.0, 0.001, 0.01, 0.1],
    
    # AJUSTES ANTERIORES (Mantendo o que funcionou):
    # Já tirámos o 2, mantemos a segurança
    "min_samples_leaf": [3, 4, 6],
    
    # Continuamos a testar a visão limitada
    "max_features": [0.8, 0.9, 1.0], 
    
    # Profundidade controlada
    "max_depth": [20, 25, 30, None],
    
    "min_samples_split": [10, 15]
}

rsCV_et_expert = apply_randomized_search_cv(
    model_et_expert, 
    param_grid_expert, 
    iterations=50, 
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_et_expert)
# Out:
# Fitting 1 folds for each of 50 candidates, totalling 50 fits
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.8, max_samples=0.95, min_impurity_decrease=0.001, min_samples_leaf=4, min_samples_split=15, n_estimators=800; mae: (train=-1315.831, test=-1471.893) r2: (train=0.942, test=0.929) total time=   2.5s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.8, max_samples=None, min_impurity_decrease=0.01, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1211.633, test=-1419.209) r2: (train=0.952, test=0.935) total time=   2.8s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=1.0, max_samples=None, min_impurity_decrease=0.01, min_samples_leaf=4, min_samples_split=10, n_estimators=500; mae: (train=-1203.808, test=-1418.068) r2: (train=0.952, test=0.935) total time=   2.0s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=1.0, max_samples=0.95, min_impurity_decrease=0.1, min_samples_leaf=3, min_samples_split=15, n_estimators=800; mae: (train=-1229.065, test=-1424.390) r2: (train=0.949, test=0.934) total time=   2.9s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.9, max_samples=None, min_impurity_decrease=0.0, min_samples_leaf=3, min_samples_split=15, n_estimators=500; mae: (train=-1257.765, test=-1439.237) r2: (train=0.948, test=0.933) total time=   1.7s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=0.8, max_samples=0.8, min_impurity_decrease=0.0, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1225.794, test=-1427.531) r2: (train=0.950, test=0.933) total time=   2.3s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.8, max_samples=0.9, min_impurity_decrease=0.01, min_samples_leaf=3, min_samples_split=15, n_estimators=800; mae: (train=-1273.212, test=-1448.951) r2: (train=0.946, test=0.931) total time=   2.4s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.9, max_samples=None, min_impurity_decrease=0.001, min_samples_leaf=6, min_samples_split=10, n_estimators=800; mae: (train=-1336.794, test=-1488.735) r2: (train=0.940, test=0.927) total time=   2.6s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.8, max_samples=0.9, min_impurity_decrease=0.01, min_samples_leaf=4, min_samples_split=15, n_estimators=500; mae: (train=-1309.940, test=-1468.445) r2: (train=0.942, test=0.929) total time=   1.5s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=1.0, max_samples=0.9, min_impurity_decrease=0.01, min_samples_leaf=4, min_samples_split=10, n_estimators=500; mae: (train=-1221.236, test=-1426.576) r2: (train=0.950, test=0.934) total time=   1.9s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.9, max_samples=0.8, min_impurity_decrease=0.0, min_samples_leaf=6, min_samples_split=10, n_estimators=500; mae: (train=-1370.990, test=-1508.126) r2: (train=0.936, test=0.924) total time=   1.5s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=0.8, max_samples=0.95, min_impurity_decrease=0.001, min_samples_leaf=3, min_samples_split=15, n_estimators=800; mae: (train=-1262.980, test=-1444.287) r2: (train=0.947, test=0.931) total time=   2.5s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=1.0, max_samples=0.8, min_impurity_decrease=0.001, min_samples_leaf=6, min_samples_split=15, n_estimators=800; mae: (train=-1357.800, test=-1495.008) r2: (train=0.937, test=0.926) total time=   2.6s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.9, max_samples=None, min_impurity_decrease=0.01, min_samples_leaf=3, min_samples_split=10, n_estimators=500; mae: (train=-1194.754, test=-1412.188) r2: (train=0.953, test=0.936) total time=   1.8s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.9, max_samples=None, min_impurity_decrease=0.001, min_samples_leaf=4, min_samples_split=15, n_estimators=500; mae: (train=-1280.085, test=-1453.169) r2: (train=0.945, test=0.930) total time=   1.7s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.9, max_samples=0.9, min_impurity_decrease=0.01, min_samples_leaf=3, min_samples_split=15, n_estimators=800; mae: (train=-1258.971, test=-1439.112) r2: (train=0.947, test=0.932) total time=   2.7s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.9, max_samples=0.9, min_impurity_decrease=0.01, min_samples_leaf=4, min_samples_split=15, n_estimators=500; mae: (train=-1308.294, test=-1466.559) r2: (train=0.943, test=0.929) total time=   1.6s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=1.0, max_samples=0.95, min_impurity_decrease=0.001, min_samples_leaf=3, min_samples_split=10, n_estimators=500; mae: (train=-1179.433, test=-1402.861) r2: (train=0.954, test=0.937) total time=   2.0s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=0.8, max_samples=0.8, min_impurity_decrease=0.1, min_samples_leaf=4, min_samples_split=15, n_estimators=800; mae: (train=-1329.307, test=-1479.752) r2: (train=0.940, test=0.927) total time=   2.3s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.9, max_samples=0.9, min_impurity_decrease=0.1, min_samples_leaf=4, min_samples_split=15, n_estimators=500; mae: (train=-1307.910, test=-1465.649) r2: (train=0.943, test=0.929) total time=   1.6s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=0.9, max_samples=0.8, min_impurity_decrease=0.0, min_samples_leaf=6, min_samples_split=15, n_estimators=500; mae: (train=-1381.917, test=-1512.281) r2: (train=0.935, test=0.924) total time=   1.5s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=1.0, max_samples=0.9, min_impurity_decrease=0.0, min_samples_leaf=3, min_samples_split=15, n_estimators=800; mae: (train=-1238.372, test=-1428.450) r2: (train=0.948, test=0.933) total time=   3.0s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.8, max_samples=0.95, min_impurity_decrease=0.01, min_samples_leaf=6, min_samples_split=10, n_estimators=500; mae: (train=-1362.020, test=-1503.841) r2: (train=0.937, test=0.925) total time=   1.5s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.8, max_samples=0.8, min_impurity_decrease=0.1, min_samples_leaf=4, min_samples_split=10, n_estimators=500; mae: (train=-1282.619, test=-1456.909) r2: (train=0.945, test=0.930) total time=   1.5s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.9, max_samples=0.9, min_impurity_decrease=0.1, min_samples_leaf=4, min_samples_split=10, n_estimators=800; mae: (train=-1259.682, test=-1442.781) r2: (train=0.947, test=0.932) total time=   2.7s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.8, max_samples=0.9, min_impurity_decrease=0.0, min_samples_leaf=4, min_samples_split=15, n_estimators=800; mae: (train=-1311.581, test=-1469.857) r2: (train=0.942, test=0.929) total time=   2.4s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=0.9, max_samples=0.8, min_impurity_decrease=0.1, min_samples_leaf=3, min_samples_split=15, n_estimators=500; mae: (train=-1279.384, test=-1450.364) r2: (train=0.945, test=0.931) total time=   1.6s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=1.0, max_samples=None, min_impurity_decrease=0.1, min_samples_leaf=3, min_samples_split=15, n_estimators=500; mae: (train=-1221.324, test=-1421.095) r2: (train=0.950, test=0.934) total time=   2.0s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.9, max_samples=0.95, min_impurity_decrease=0.001, min_samples_leaf=4, min_samples_split=15, n_estimators=500; mae: (train=-1288.143, test=-1456.304) r2: (train=0.944, test=0.930) total time=   1.7s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=0.8, max_samples=None, min_impurity_decrease=0.0, min_samples_leaf=3, min_samples_split=10, n_estimators=500; mae: (train=-1187.127, test=-1411.084) r2: (train=0.953, test=0.935) total time=   1.8s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=1.0, max_samples=None, min_impurity_decrease=0.0, min_samples_leaf=3, min_samples_split=15, n_estimators=800; mae: (train=-1221.434, test=-1421.748) r2: (train=0.950, test=0.934) total time=   3.3s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=1.0, max_samples=0.95, min_impurity_decrease=0.001, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1158.391, test=-1397.640) r2: (train=0.955, test=0.937) total time=   3.4s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.9, max_samples=0.8, min_impurity_decrease=0.001, min_samples_leaf=6, min_samples_split=15, n_estimators=500; mae: (train=-1388.404, test=-1517.280) r2: (train=0.935, test=0.923) total time=   1.5s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.9, max_samples=0.95, min_impurity_decrease=0.01, min_samples_leaf=6, min_samples_split=10, n_estimators=500; mae: (train=-1351.407, test=-1494.679) r2: (train=0.939, test=0.927) total time=   1.7s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.8, max_samples=0.8, min_impurity_decrease=0.0, min_samples_leaf=3, min_samples_split=15, n_estimators=500; mae: (train=-1306.369, test=-1464.589) r2: (train=0.943, test=0.929) total time=   1.5s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=1.0, max_samples=None, min_impurity_decrease=0.0, min_samples_leaf=4, min_samples_split=15, n_estimators=500; mae: (train=-1256.361, test=-1437.441) r2: (train=0.947, test=0.933) total time=   2.0s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=0.8, max_samples=0.9, min_impurity_decrease=0.01, min_samples_leaf=4, min_samples_split=10, n_estimators=800; mae: (train=-1262.344, test=-1446.789) r2: (train=0.947, test=0.932) total time=   2.6s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=0.9, max_samples=0.9, min_impurity_decrease=0.001, min_samples_leaf=3, min_samples_split=10, n_estimators=500; mae: (train=-1190.970, test=-1409.682) r2: (train=0.953, test=0.936) total time=   1.8s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.8, max_samples=None, min_impurity_decrease=0.1, min_samples_leaf=3, min_samples_split=10, n_estimators=500; mae: (train=-1211.910, test=-1419.183) r2: (train=0.952, test=0.935) total time=   1.8s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=1.0, max_samples=0.9, min_impurity_decrease=0.01, min_samples_leaf=4, min_samples_split=15, n_estimators=500; mae: (train=-1284.225, test=-1451.384) r2: (train=0.944, test=0.931) total time=   1.9s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.8, max_samples=None, min_impurity_decrease=0.0, min_samples_leaf=4, min_samples_split=10, n_estimators=500; mae: (train=-1261.745, test=-1446.286) r2: (train=0.948, test=0.932) total time=   1.7s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.8, max_samples=0.9, min_impurity_decrease=0.0, min_samples_leaf=4, min_samples_split=10, n_estimators=500; mae: (train=-1278.431, test=-1455.112) r2: (train=0.946, test=0.931) total time=   1.6s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=1.0, max_samples=0.9, min_impurity_decrease=0.1, min_samples_leaf=3, min_samples_split=15, n_estimators=800; mae: (train=-1238.721, test=-1428.428) r2: (train=0.948, test=0.934) total time=   3.1s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.8, max_samples=None, min_impurity_decrease=0.001, min_samples_leaf=4, min_samples_split=15, n_estimators=500; mae: (train=-1308.055, test=-1469.289) r2: (train=0.943, test=0.929) total time=   1.6s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=1.0, max_samples=0.95, min_impurity_decrease=0.1, min_samples_leaf=4, min_samples_split=10, n_estimators=500; mae: (train=-1225.798, test=-1425.348) r2: (train=0.950, test=0.934) total time=   2.1s
# [CV 1/1] END bootstrap=True, max_depth=None, max_features=0.9, max_samples=0.8, min_impurity_decrease=0.0, min_samples_leaf=3, min_samples_split=15, n_estimators=500; mae: (train=-1278.222, test=-1450.146) r2: (train=0.945, test=0.931) total time=   1.6s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.8, max_samples=0.95, min_impurity_decrease=0.001, min_samples_leaf=4, min_samples_split=15, n_estimators=500; mae: (train=-1302.726, test=-1465.572) r2: (train=0.943, test=0.929) total time=   1.6s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.9, max_samples=0.9, min_impurity_decrease=0.0, min_samples_leaf=4, min_samples_split=10, n_estimators=500; mae: (train=-1245.312, test=-1438.737) r2: (train=0.948, test=0.933) total time=   1.8s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=1.0, max_samples=0.9, min_impurity_decrease=0.01, min_samples_leaf=4, min_samples_split=10, n_estimators=800; mae: (train=-1220.691, test=-1425.055) r2: (train=0.950, test=0.934) total time=   3.2s
# [CV 1/1] END bootstrap=True, max_depth=20, max_features=0.9, max_samples=None, min_impurity_decrease=0.0, min_samples_leaf=6, min_samples_split=10, n_estimators=500; mae: (train=-1345.339, test=-1492.858) r2: (train=0.939, test=0.927) total time=   1.8s
# Train R2=0.942 | Val R2=0.929 | Train MAE=1315.8 | Val MAE=1471.9 | Gap MAE=0.119 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.001, 'max_samples': 0.95, 'max_features': 0.8, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.935 | Train MAE=1211.6 | Val MAE=1419.2 | Gap MAE=0.171 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.01, 'max_samples': None, 'max_features': 0.8, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.935 | Train MAE=1203.8 | Val MAE=1418.1 | Gap MAE=0.178 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.01, 'max_samples': None, 'max_features': 1.0, 'max_depth': None, 'bootstrap': True}
# Train R2=0.949 | Val R2=0.934 | Train MAE=1229.1 | Val MAE=1424.4 | Gap MAE=0.159 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.1, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.948 | Val R2=0.933 | Train MAE=1257.8 | Val MAE=1439.2 | Gap MAE=0.144 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.0, 'max_samples': None, 'max_features': 0.9, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.933 | Train MAE=1225.8 | Val MAE=1427.5 | Gap MAE=0.165 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.0, 'max_samples': 0.8, 'max_features': 0.8, 'max_depth': None, 'bootstrap': True}
# Train R2=0.946 | Val R2=0.931 | Train MAE=1273.2 | Val MAE=1449.0 | Gap MAE=0.138 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.01, 'max_samples': 0.9, 'max_features': 0.8, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.940 | Val R2=0.927 | Train MAE=1336.8 | Val MAE=1488.7 | Gap MAE=0.114 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 6, 'min_impurity_decrease': 0.001, 'max_samples': None, 'max_features': 0.9, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.942 | Val R2=0.929 | Train MAE=1309.9 | Val MAE=1468.4 | Gap MAE=0.121 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.01, 'max_samples': 0.9, 'max_features': 0.8, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.934 | Train MAE=1221.2 | Val MAE=1426.6 | Gap MAE=0.168 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.01, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.936 | Val R2=0.924 | Train MAE=1371.0 | Val MAE=1508.1 | Gap MAE=0.100 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 6, 'min_impurity_decrease': 0.0, 'max_samples': 0.8, 'max_features': 0.9, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.947 | Val R2=0.931 | Train MAE=1263.0 | Val MAE=1444.3 | Gap MAE=0.144 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.001, 'max_samples': 0.95, 'max_features': 0.8, 'max_depth': None, 'bootstrap': True}
# Train R2=0.937 | Val R2=0.926 | Train MAE=1357.8 | Val MAE=1495.0 | Gap MAE=0.101 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 6, 'min_impurity_decrease': 0.001, 'max_samples': 0.8, 'max_features': 1.0, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.953 | Val R2=0.936 | Train MAE=1194.8 | Val MAE=1412.2 | Gap MAE=0.182 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.01, 'max_samples': None, 'max_features': 0.9, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.945 | Val R2=0.930 | Train MAE=1280.1 | Val MAE=1453.2 | Gap MAE=0.135 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.001, 'max_samples': None, 'max_features': 0.9, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.947 | Val R2=0.932 | Train MAE=1259.0 | Val MAE=1439.1 | Gap MAE=0.143 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.01, 'max_samples': 0.9, 'max_features': 0.9, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.943 | Val R2=0.929 | Train MAE=1308.3 | Val MAE=1466.6 | Gap MAE=0.121 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.01, 'max_samples': 0.9, 'max_features': 0.9, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.954 | Val R2=0.937 | Train MAE=1179.4 | Val MAE=1402.9 | Gap MAE=0.189 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.001, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.940 | Val R2=0.927 | Train MAE=1329.3 | Val MAE=1479.8 | Gap MAE=0.113 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.1, 'max_samples': 0.8, 'max_features': 0.8, 'max_depth': None, 'bootstrap': True}
# Train R2=0.943 | Val R2=0.929 | Train MAE=1307.9 | Val MAE=1465.6 | Gap MAE=0.121 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.1, 'max_samples': 0.9, 'max_features': 0.9, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.935 | Val R2=0.924 | Train MAE=1381.9 | Val MAE=1512.3 | Gap MAE=0.094 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 6, 'min_impurity_decrease': 0.0, 'max_samples': 0.8, 'max_features': 0.9, 'max_depth': None, 'bootstrap': True}
# Train R2=0.948 | Val R2=0.933 | Train MAE=1238.4 | Val MAE=1428.4 | Gap MAE=0.153 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.0, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': None, 'bootstrap': True}
# Train R2=0.937 | Val R2=0.925 | Train MAE=1362.0 | Val MAE=1503.8 | Gap MAE=0.104 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 6, 'min_impurity_decrease': 0.01, 'max_samples': 0.95, 'max_features': 0.8, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.945 | Val R2=0.930 | Train MAE=1282.6 | Val MAE=1456.9 | Gap MAE=0.136 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.1, 'max_samples': 0.8, 'max_features': 0.8, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.947 | Val R2=0.932 | Train MAE=1259.7 | Val MAE=1442.8 | Gap MAE=0.145 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.1, 'max_samples': 0.9, 'max_features': 0.9, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.942 | Val R2=0.929 | Train MAE=1311.6 | Val MAE=1469.9 | Gap MAE=0.121 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.0, 'max_samples': 0.9, 'max_features': 0.8, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.945 | Val R2=0.931 | Train MAE=1279.4 | Val MAE=1450.4 | Gap MAE=0.134 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.1, 'max_samples': 0.8, 'max_features': 0.9, 'max_depth': None, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.934 | Train MAE=1221.3 | Val MAE=1421.1 | Gap MAE=0.164 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.1, 'max_samples': None, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.944 | Val R2=0.930 | Train MAE=1288.1 | Val MAE=1456.3 | Gap MAE=0.131 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.001, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.953 | Val R2=0.935 | Train MAE=1187.1 | Val MAE=1411.1 | Gap MAE=0.189 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.0, 'max_samples': None, 'max_features': 0.8, 'max_depth': None, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.934 | Train MAE=1221.4 | Val MAE=1421.7 | Gap MAE=0.164 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.0, 'max_samples': None, 'max_features': 1.0, 'max_depth': None, 'bootstrap': True}
# Train R2=0.955 | Val R2=0.937 | Train MAE=1158.4 | Val MAE=1397.6 | Gap MAE=0.207 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.001, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.935 | Val R2=0.923 | Train MAE=1388.4 | Val MAE=1517.3 | Gap MAE=0.093 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 6, 'min_impurity_decrease': 0.001, 'max_samples': 0.8, 'max_features': 0.9, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.939 | Val R2=0.927 | Train MAE=1351.4 | Val MAE=1494.7 | Gap MAE=0.106 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 6, 'min_impurity_decrease': 0.01, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.943 | Val R2=0.929 | Train MAE=1306.4 | Val MAE=1464.6 | Gap MAE=0.121 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.0, 'max_samples': 0.8, 'max_features': 0.8, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.947 | Val R2=0.933 | Train MAE=1256.4 | Val MAE=1437.4 | Gap MAE=0.144 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.0, 'max_samples': None, 'max_features': 1.0, 'max_depth': None, 'bootstrap': True}
# Train R2=0.947 | Val R2=0.932 | Train MAE=1262.3 | Val MAE=1446.8 | Gap MAE=0.146 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.01, 'max_samples': 0.9, 'max_features': 0.8, 'max_depth': None, 'bootstrap': True}
# Train R2=0.953 | Val R2=0.936 | Train MAE=1191.0 | Val MAE=1409.7 | Gap MAE=0.184 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.001, 'max_samples': 0.9, 'max_features': 0.9, 'max_depth': None, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.935 | Train MAE=1211.9 | Val MAE=1419.2 | Gap MAE=0.171 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.1, 'max_samples': None, 'max_features': 0.8, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.944 | Val R2=0.931 | Train MAE=1284.2 | Val MAE=1451.4 | Gap MAE=0.130 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.01, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.948 | Val R2=0.932 | Train MAE=1261.7 | Val MAE=1446.3 | Gap MAE=0.146 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.0, 'max_samples': None, 'max_features': 0.8, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.946 | Val R2=0.931 | Train MAE=1278.4 | Val MAE=1455.1 | Gap MAE=0.138 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.0, 'max_samples': 0.9, 'max_features': 0.8, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.948 | Val R2=0.934 | Train MAE=1238.7 | Val MAE=1428.4 | Gap MAE=0.153 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.1, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.943 | Val R2=0.929 | Train MAE=1308.1 | Val MAE=1469.3 | Gap MAE=0.123 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.001, 'max_samples': None, 'max_features': 0.8, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.934 | Train MAE=1225.8 | Val MAE=1425.3 | Gap MAE=0.163 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.1, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 20, 'bootstrap': True}
# Train R2=0.945 | Val R2=0.931 | Train MAE=1278.2 | Val MAE=1450.1 | Gap MAE=0.135 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.0, 'max_samples': 0.8, 'max_features': 0.9, 'max_depth': None, 'bootstrap': True}
# Train R2=0.943 | Val R2=0.929 | Train MAE=1302.7 | Val MAE=1465.6 | Gap MAE=0.125 | Params={'n_estimators': 500, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.001, 'max_samples': 0.95, 'max_features': 0.8, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.948 | Val R2=0.933 | Train MAE=1245.3 | Val MAE=1438.7 | Gap MAE=0.155 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.0, 'max_samples': 0.9, 'max_features': 0.9, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.934 | Train MAE=1220.7 | Val MAE=1425.1 | Gap MAE=0.167 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 4, 'min_impurity_decrease': 0.01, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.939 | Val R2=0.927 | Train MAE=1345.3 | Val MAE=1492.9 | Gap MAE=0.110 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 6, 'min_impurity_decrease': 0.0, 'max_samples': None, 'max_features': 0.9, 'max_depth': 20, 'bootstrap': True}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9552556251039521
# Best validation R2: 0.937317052224356
# Gap R2: 1.8778819415634436 %
# Best train MAE: 1158.391439722947
# Best validation MAE: 1397.6404437548515
# Gap MAE: 20.65355421558758 %
# Best parameters: {'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'min_impurity_decrease': 0.001, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}

# %%
model_et_kaggle = ExtraTreesRegressor(random_state=42, n_jobs=-1)

param_grid_kaggle = {
    # MANTEMOS A POTÊNCIA (Para o MAE não subir):
    "bootstrap": [True],
    "n_estimators": [800, 1000, 1200], # Mais árvores = Melhor MAE
    "max_features": [0.9, 1.0],        # Deixamos ver quase tudo
    "max_samples": [0.9, 0.95, 1.0],   # Deixamos ver quase tudo
    
    # AQUI ENTRA A TUA ARMA SECRETA (ccp_alpha):
    # Valores pequenos cortam o ruído sem estragar a árvore.
    # Como o target (preço) é alto, os valores de alpha têm de ser testados.
    "ccp_alpha": [0.0, 0.1, 1.0, 5.0, 10.0],
    
    # MANTEMOS O RESTO QUE FUNCIONOU:
    # 3 e 4 foram os melhores. O 2 dava muito overfit.
    "min_samples_leaf": [3, 4, 5], 
    
    # Profundidade
    "max_depth": [25, 30, 35, None],
    
    # Split
    "min_samples_split": [10, 15]
}

# NOTA: Se aplicares o Log Transform no y (Dica 1), 
# lembra-te que os valores de ccp_alpha teriam de ser muito menores (ex: 0.0001).
# Esta grelha assume y normal (preços reais).

rsCV_et_kaggle = apply_randomized_search_cv(
    model_et_kaggle, 
    param_grid_kaggle, 
    iterations=40, # Random search precisa de explorar o ccp_alpha
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_et_kaggle)
# Out:
# Fitting 1 folds for each of 40 candidates, totalling 40 fits
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=25, max_features=0.9, max_samples=0.9, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; mae: (train=-1245.922, test=-1438.335) r2: (train=0.948, test=0.933) total time=   3.7s
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=35, max_features=0.9, max_samples=0.95, min_samples_leaf=3, min_samples_split=10, n_estimators=1200; mae: (train=-1180.521, test=-1406.105) r2: (train=0.954, test=0.936) total time=   4.9s
# [CV 1/1] END bootstrap=True, ccp_alpha=1.0, max_depth=None, max_features=0.9, max_samples=1.0, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; mae: (train=-1314.387, test=-1473.036) r2: (train=0.942, test=0.928) total time=   4.0s
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=None, max_features=0.9, max_samples=0.95, min_samples_leaf=4, min_samples_split=15, n_estimators=1000; mae: (train=-1287.179, test=-1455.223) r2: (train=0.944, test=0.930) total time=   3.5s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=30, max_features=1.0, max_samples=0.95, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; mae: (train=-1299.871, test=-1463.360) r2: (train=0.943, test=0.930) total time=   4.0s
# [CV 1/1] END bootstrap=True, ccp_alpha=1.0, max_depth=35, max_features=1.0, max_samples=1.0, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; mae: (train=-1221.107, test=-1421.549) r2: (train=0.950, test=0.934) total time=   4.1s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=25, max_features=1.0, max_samples=1.0, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; mae: (train=-1221.962, test=-1421.436) r2: (train=0.950, test=0.934) total time=   4.3s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=30, max_features=0.9, max_samples=0.95, min_samples_leaf=4, min_samples_split=15, n_estimators=1000; mae: (train=-1287.207, test=-1455.073) r2: (train=0.944, test=0.930) total time=   3.6s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.0, max_depth=30, max_features=1.0, max_samples=0.95, min_samples_leaf=4, min_samples_split=10, n_estimators=800; mae: (train=-1211.786, test=-1420.704) r2: (train=0.951, test=0.935) total time=   3.2s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.0, max_depth=25, max_features=0.9, max_samples=0.95, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1182.485, test=-1406.267) r2: (train=0.954, test=0.936) total time=   2.9s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.0, max_depth=None, max_features=1.0, max_samples=0.9, min_samples_leaf=3, min_samples_split=15, n_estimators=800; mae: (train=-1238.372, test=-1428.450) r2: (train=0.948, test=0.933) total time=   3.1s
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=35, max_features=1.0, max_samples=0.9, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; mae: (train=-1273.807, test=-1451.657) r2: (train=0.945, test=0.931) total time=   4.2s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.1, max_depth=25, max_features=0.9, max_samples=1.0, min_samples_leaf=3, min_samples_split=15, n_estimators=1200; mae: (train=-1241.815, test=-1431.344) r2: (train=0.948, test=0.933) total time=   4.4s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.1, max_depth=35, max_features=1.0, max_samples=0.9, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; mae: (train=-1273.779, test=-1451.718) r2: (train=0.945, test=0.931) total time=   4.7s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.0, max_depth=25, max_features=1.0, max_samples=0.9, min_samples_leaf=4, min_samples_split=15, n_estimators=800; mae: (train=-1275.326, test=-1448.251) r2: (train=0.945, test=0.931) total time=   3.0s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.1, max_depth=None, max_features=0.9, max_samples=0.95, min_samples_leaf=4, min_samples_split=10, n_estimators=800; mae: (train=-1236.204, test=-1432.174) r2: (train=0.949, test=0.933) total time=   3.0s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.0, max_depth=35, max_features=1.0, max_samples=1.0, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; mae: (train=-1202.714, test=-1416.952) r2: (train=0.951, test=0.935) total time=   4.3s
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=30, max_features=1.0, max_samples=0.9, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; mae: (train=-1307.753, test=-1467.062) r2: (train=0.942, test=0.929) total time=   3.9s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.1, max_depth=None, max_features=0.9, max_samples=1.0, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1172.213, test=-1402.725) r2: (train=0.955, test=0.937) total time=   3.3s
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=25, max_features=0.9, max_samples=0.95, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; mae: (train=-1323.714, test=-1477.543) r2: (train=0.941, test=0.928) total time=   3.7s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=25, max_features=1.0, max_samples=0.95, min_samples_leaf=5, min_samples_split=15, n_estimators=800; mae: (train=-1299.637, test=-1462.945) r2: (train=0.943, test=0.929) total time=   3.4s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.0, max_depth=35, max_features=1.0, max_samples=1.0, min_samples_leaf=5, min_samples_split=10, n_estimators=800; mae: (train=-1257.373, test=-1445.214) r2: (train=0.947, test=0.932) total time=   3.3s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.1, max_depth=35, max_features=1.0, max_samples=0.95, min_samples_leaf=4, min_samples_split=15, n_estimators=1200; mae: (train=-1265.761, test=-1443.602) r2: (train=0.946, test=0.932) total time=   4.9s
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=25, max_features=0.9, max_samples=1.0, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; mae: (train=-1242.018, test=-1431.690) r2: (train=0.949, test=0.933) total time=   4.0s
# [CV 1/1] END bootstrap=True, ccp_alpha=1.0, max_depth=None, max_features=1.0, max_samples=0.9, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; mae: (train=-1168.103, test=-1401.712) r2: (train=0.955, test=0.937) total time=   4.6s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.0, max_depth=30, max_features=1.0, max_samples=0.95, min_samples_leaf=5, min_samples_split=10, n_estimators=1200; mae: (train=-1264.262, test=-1447.186) r2: (train=0.946, test=0.932) total time=   4.9s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.0, max_depth=30, max_features=0.9, max_samples=1.0, min_samples_leaf=5, min_samples_split=10, n_estimators=800; mae: (train=-1282.362, test=-1456.027) r2: (train=0.945, test=0.930) total time=   3.0s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.1, max_depth=35, max_features=0.9, max_samples=0.9, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; mae: (train=-1258.388, test=-1438.521) r2: (train=0.947, test=0.932) total time=   3.6s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=35, max_features=0.9, max_samples=0.95, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1181.242, test=-1406.608) r2: (train=0.954, test=0.936) total time=   3.8s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=35, max_features=0.9, max_samples=0.95, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; mae: (train=-1181.055, test=-1406.337) r2: (train=0.954, test=0.936) total time=   4.8s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=None, max_features=1.0, max_samples=0.9, min_samples_leaf=4, min_samples_split=15, n_estimators=1200; mae: (train=-1274.559, test=-1447.118) r2: (train=0.945, test=0.931) total time=   5.1s
# [CV 1/1] END bootstrap=True, ccp_alpha=0.1, max_depth=35, max_features=0.9, max_samples=0.95, min_samples_leaf=3, min_samples_split=15, n_estimators=1200; mae: (train=-1248.924, test=-1435.298) r2: (train=0.948, test=0.932) total time=   4.5s
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=35, max_features=1.0, max_samples=0.95, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; mae: (train=-1299.546, test=-1463.474) r2: (train=0.943, test=0.930) total time=   5.0s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=25, max_features=0.9, max_samples=0.9, min_samples_leaf=5, min_samples_split=15, n_estimators=800; mae: (train=-1330.966, test=-1482.376) r2: (train=0.940, test=0.927) total time=   4.3s
# [CV 1/1] END bootstrap=True, ccp_alpha=1.0, max_depth=35, max_features=1.0, max_samples=0.95, min_samples_leaf=3, min_samples_split=15, n_estimators=1200; mae: (train=-1229.447, test=-1424.136) r2: (train=0.949, test=0.934) total time=   8.4s
# [CV 1/1] END bootstrap=True, ccp_alpha=1.0, max_depth=None, max_features=1.0, max_samples=1.0, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; mae: (train=-1291.294, test=-1458.596) r2: (train=0.943, test=0.930) total time=   6.8s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=35, max_features=1.0, max_samples=1.0, min_samples_leaf=4, min_samples_split=15, n_estimators=1200; mae: (train=-1257.138, test=-1438.664) r2: (train=0.947, test=0.932) total time=   8.8s
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=None, max_features=0.9, max_samples=1.0, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1172.389, test=-1402.748) r2: (train=0.955, test=0.937) total time=   6.0s
# [CV 1/1] END bootstrap=True, ccp_alpha=5.0, max_depth=35, max_features=1.0, max_samples=0.95, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; mae: (train=-1229.608, test=-1424.326) r2: (train=0.949, test=0.934) total time=   7.1s
# [CV 1/1] END bootstrap=True, ccp_alpha=10.0, max_depth=25, max_features=1.0, max_samples=1.0, min_samples_leaf=5, min_samples_split=15, n_estimators=1200; mae: (train=-1291.519, test=-1458.014) r2: (train=0.944, test=0.930) total time=   8.5s
# Train R2=0.948 | Val R2=0.933 | Train MAE=1245.9 | Val MAE=1438.3 | Gap MAE=0.154 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_samples': 0.9, 'max_features': 0.9, 'max_depth': 25, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.954 | Val R2=0.936 | Train MAE=1180.5 | Val MAE=1406.1 | Gap MAE=0.191 | Params={'n_estimators': 1200, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': 35, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.942 | Val R2=0.928 | Train MAE=1314.4 | Val MAE=1473.0 | Gap MAE=0.121 | Params={'n_estimators': 1200, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_samples': 1.0, 'max_features': 0.9, 'max_depth': None, 'ccp_alpha': 1.0, 'bootstrap': True}
# Train R2=0.944 | Val R2=0.930 | Train MAE=1287.2 | Val MAE=1455.2 | Gap MAE=0.131 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': None, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.943 | Val R2=0.930 | Train MAE=1299.9 | Val MAE=1463.4 | Gap MAE=0.126 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 30, 'ccp_alpha': 10.0, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.934 | Train MAE=1221.1 | Val MAE=1421.5 | Gap MAE=0.164 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_samples': 1.0, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 1.0, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.934 | Train MAE=1222.0 | Val MAE=1421.4 | Gap MAE=0.163 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_samples': 1.0, 'max_features': 1.0, 'max_depth': 25, 'ccp_alpha': 10.0, 'bootstrap': True}
# Train R2=0.944 | Val R2=0.930 | Train MAE=1287.2 | Val MAE=1455.1 | Gap MAE=0.130 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': 30, 'ccp_alpha': 10.0, 'bootstrap': True}
# Train R2=0.951 | Val R2=0.935 | Train MAE=1211.8 | Val MAE=1420.7 | Gap MAE=0.172 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 30, 'ccp_alpha': 0.0, 'bootstrap': True}
# Train R2=0.954 | Val R2=0.936 | Train MAE=1182.5 | Val MAE=1406.3 | Gap MAE=0.189 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': 25, 'ccp_alpha': 0.0, 'bootstrap': True}
# Train R2=0.948 | Val R2=0.933 | Train MAE=1238.4 | Val MAE=1428.4 | Gap MAE=0.153 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': None, 'ccp_alpha': 0.0, 'bootstrap': True}
# Train R2=0.945 | Val R2=0.931 | Train MAE=1273.8 | Val MAE=1451.7 | Gap MAE=0.140 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.948 | Val R2=0.933 | Train MAE=1241.8 | Val MAE=1431.3 | Gap MAE=0.153 | Params={'n_estimators': 1200, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_samples': 1.0, 'max_features': 0.9, 'max_depth': 25, 'ccp_alpha': 0.1, 'bootstrap': True}
# Train R2=0.945 | Val R2=0.931 | Train MAE=1273.8 | Val MAE=1451.7 | Gap MAE=0.140 | Params={'n_estimators': 1200, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 0.1, 'bootstrap': True}
# Train R2=0.945 | Val R2=0.931 | Train MAE=1275.3 | Val MAE=1448.3 | Gap MAE=0.136 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': 25, 'ccp_alpha': 0.0, 'bootstrap': True}
# Train R2=0.949 | Val R2=0.933 | Train MAE=1236.2 | Val MAE=1432.2 | Gap MAE=0.159 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': None, 'ccp_alpha': 0.1, 'bootstrap': True}
# Train R2=0.951 | Val R2=0.935 | Train MAE=1202.7 | Val MAE=1417.0 | Gap MAE=0.178 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_samples': 1.0, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 0.0, 'bootstrap': True}
# Train R2=0.942 | Val R2=0.929 | Train MAE=1307.8 | Val MAE=1467.1 | Gap MAE=0.122 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': 30, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.955 | Val R2=0.937 | Train MAE=1172.2 | Val MAE=1402.7 | Gap MAE=0.197 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_samples': 1.0, 'max_features': 0.9, 'max_depth': None, 'ccp_alpha': 0.1, 'bootstrap': True}
# Train R2=0.941 | Val R2=0.928 | Train MAE=1323.7 | Val MAE=1477.5 | Gap MAE=0.116 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': 25, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.943 | Val R2=0.929 | Train MAE=1299.6 | Val MAE=1462.9 | Gap MAE=0.126 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 25, 'ccp_alpha': 10.0, 'bootstrap': True}
# Train R2=0.947 | Val R2=0.932 | Train MAE=1257.4 | Val MAE=1445.2 | Gap MAE=0.149 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_samples': 1.0, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 0.0, 'bootstrap': True}
# Train R2=0.946 | Val R2=0.932 | Train MAE=1265.8 | Val MAE=1443.6 | Gap MAE=0.141 | Params={'n_estimators': 1200, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 0.1, 'bootstrap': True}
# Train R2=0.949 | Val R2=0.933 | Train MAE=1242.0 | Val MAE=1431.7 | Gap MAE=0.153 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_samples': 1.0, 'max_features': 0.9, 'max_depth': 25, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.955 | Val R2=0.937 | Train MAE=1168.1 | Val MAE=1401.7 | Gap MAE=0.200 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': None, 'ccp_alpha': 1.0, 'bootstrap': True}
# Train R2=0.946 | Val R2=0.932 | Train MAE=1264.3 | Val MAE=1447.2 | Gap MAE=0.145 | Params={'n_estimators': 1200, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 30, 'ccp_alpha': 0.0, 'bootstrap': True}
# Train R2=0.945 | Val R2=0.930 | Train MAE=1282.4 | Val MAE=1456.0 | Gap MAE=0.135 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_samples': 1.0, 'max_features': 0.9, 'max_depth': 30, 'ccp_alpha': 0.0, 'bootstrap': True}
# Train R2=0.947 | Val R2=0.932 | Train MAE=1258.4 | Val MAE=1438.5 | Gap MAE=0.143 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_samples': 0.9, 'max_features': 0.9, 'max_depth': 35, 'ccp_alpha': 0.1, 'bootstrap': True}
# Train R2=0.954 | Val R2=0.936 | Train MAE=1181.2 | Val MAE=1406.6 | Gap MAE=0.191 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': 35, 'ccp_alpha': 10.0, 'bootstrap': True}
# Train R2=0.954 | Val R2=0.936 | Train MAE=1181.1 | Val MAE=1406.3 | Gap MAE=0.191 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': 35, 'ccp_alpha': 10.0, 'bootstrap': True}
# Train R2=0.945 | Val R2=0.931 | Train MAE=1274.6 | Val MAE=1447.1 | Gap MAE=0.135 | Params={'n_estimators': 1200, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': None, 'ccp_alpha': 10.0, 'bootstrap': True}
# Train R2=0.948 | Val R2=0.932 | Train MAE=1248.9 | Val MAE=1435.3 | Gap MAE=0.149 | Params={'n_estimators': 1200, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_samples': 0.95, 'max_features': 0.9, 'max_depth': 35, 'ccp_alpha': 0.1, 'bootstrap': True}
# Train R2=0.943 | Val R2=0.930 | Train MAE=1299.5 | Val MAE=1463.5 | Gap MAE=0.126 | Params={'n_estimators': 1200, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.940 | Val R2=0.927 | Train MAE=1331.0 | Val MAE=1482.4 | Gap MAE=0.114 | Params={'n_estimators': 800, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_samples': 0.9, 'max_features': 0.9, 'max_depth': 25, 'ccp_alpha': 10.0, 'bootstrap': True}
# Train R2=0.949 | Val R2=0.934 | Train MAE=1229.4 | Val MAE=1424.1 | Gap MAE=0.158 | Params={'n_estimators': 1200, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 1.0, 'bootstrap': True}
# Train R2=0.943 | Val R2=0.930 | Train MAE=1291.3 | Val MAE=1458.6 | Gap MAE=0.130 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_samples': 1.0, 'max_features': 1.0, 'max_depth': None, 'ccp_alpha': 1.0, 'bootstrap': True}
# Train R2=0.947 | Val R2=0.932 | Train MAE=1257.1 | Val MAE=1438.7 | Gap MAE=0.144 | Params={'n_estimators': 1200, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_samples': 1.0, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 10.0, 'bootstrap': True}
# Train R2=0.955 | Val R2=0.937 | Train MAE=1172.4 | Val MAE=1402.7 | Gap MAE=0.196 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_samples': 1.0, 'max_features': 0.9, 'max_depth': None, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.949 | Val R2=0.934 | Train MAE=1229.6 | Val MAE=1424.3 | Gap MAE=0.158 | Params={'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_samples': 0.95, 'max_features': 1.0, 'max_depth': 35, 'ccp_alpha': 5.0, 'bootstrap': True}
# Train R2=0.944 | Val R2=0.930 | Train MAE=1291.5 | Val MAE=1458.0 | Gap MAE=0.129 | Params={'n_estimators': 1200, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_samples': 1.0, 'max_features': 1.0, 'max_depth': 25, 'ccp_alpha': 10.0, 'bootstrap': True}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9545112578223218
# Best validation R2: 0.9369074899097763
# Gap R2: 1.8442703287447597 %
# Best train MAE: 1168.1031627986433
# Best validation MAE: 1401.711639498569
# Gap MAE: 19.998959350493163 %
# Best parameters: {'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_samples': 0.9, 'max_features': 1.0, 'max_depth': None, 'ccp_alpha': 1.0, 'bootstrap': True}

# %%
# import numpy as np
# from sklearn.metrics import mean_absolute_error

# # 1. Transformar o Y
# y_fit_log = np.log1p(y_combined)  # log1p é log(1 + x), útil para evitar log(0)

# # 2. Definir os parâmetros MAS COM CCP_ALPHA A ZERO
# best_params_corrected = {
#     'n_estimators': 1000, 
#     'min_samples_split': 10, 
#     'min_samples_leaf': 3, 
#     'max_samples': 0.9, 
#     'max_features': 1.0, 
#     'max_depth': None, 
    
#     # MUDANÇA CRITICA:
#     'ccp_alpha': 0.0, # Em dados log, o alpha tem de ser zero ou 0.00001
    
#     'bootstrap': True,
#     'n_jobs': -1,
#     'random_state': 42
# }

# model_log = ExtraTreesRegressor(**best_params_corrected)

# # 3. Treinar
# print("A treinar com Log Transform (versão corrigida)...")
# model_log.fit(X_combined, y_fit_log)

# # 4. Prever
# preds_log = model_log.predict(X_combined) # Usar X_combined para comparar com o teu gap

# # 5. Reverter
# final_preds = np.expm1(preds_log)

# # 6. Avaliar
# mae_real = mean_absolute_error(y_combined, final_preds)
# print(f"MAE Final (Log Corrigido): {mae_real:.4f}")
# Out:
# A treinar com Log Transform (versão corrigida)...
# MAE Final (Log Corrigido): 1148.2265

# %%
# from sklearn.compose import TransformedTargetRegressor
# from sklearn.model_selection import cross_validate
# import numpy as np

# # 1. Definir o modelo base com os teus melhores parâmetros
# # Nota: Mantemos o ccp_alpha a 0.0 porque estamos no mundo Log
# params_vencedores = {
#     'n_estimators': 1000, 
#     'min_samples_split': 10, 
#     'min_samples_leaf': 3, 
#     'max_samples': 0.9, 
#     'max_features': 1.0, 
#     'max_depth': None, 
#     'ccp_alpha': 0.0,      # Zero obrigatório aqui
#     'bootstrap': True,
#     'n_jobs': -1,
#     'random_state': 42
# }

# model_base = ExtraTreesRegressor(**params_vencedores)

# # 2. Criar o "Wrapper" que faz o Log antes e o Exp depois automaticamente
# model_log_pipeline = TransformedTargetRegressor(
#     regressor=model_base, 
#     func=np.log1p,       # Transforma Y em Log antes de treinar
#     inverse_func=np.expm1 # Transforma Previsão em Real (Exp) no fim
# )

# # 3. Validar com Cross-Validation (Usando o teu 'ps' split)
# # Isto vai dar-te o MAE REAL de validação
# cv_results = cross_validate(
#     model_log_pipeline, 
#     X_combined, 
#     y_combined, 
#     cv=ps, 
#     scoring='neg_mean_absolute_error',
#     return_train_score=True,
#     n_jobs=-1
# )

# # 4. Apresentar os resultados finais
# mae_train = -cv_results['train_score'].mean()
# mae_val = -cv_results['test_score'].mean()
# gap = ((mae_val - mae_train) / mae_train) * 100

# print(f"=== RESULTADO FINAL (LOG TRANSFORM) ===")
# print(f"Treino MAE: {mae_train:.2f}")
# print(f"Validação MAE: {mae_val:.2f}")
# print(f"Gap: {gap:.2f}%")
# Out:
# === RESULTADO FINAL (LOG TRANSFORM) ===
# Treino MAE: 1169.96
# Validação MAE: 1395.71
# Gap: 19.30%

# %%
model_et_final = ExtraTreesRegressor(random_state=42, n_jobs=-1)

param_grid_fine_tune = {
    # MANTEMOS A SEGURANÇA (Isto é inegociável para não voltar aos 133% de gap)
    "bootstrap": [True],
    
    # FORÇA BRUTA: Mais árvores para polir o resultado e "alisar" o erro
    "n_estimators": [500, 800, 1000],
    
    # MICRO-AJUSTE NAS FOLHAS:
    # O 4 foi seguro. Vamos testar o 2 e o 3. 
    # O 2 vai dar melhor MAE, mas tens de vigiar se o Gap não dispara acima de 20-25%.
    "min_samples_leaf": [3, 4],
    
    # MICRO-AJUSTE NA VISÃO:
    # 0.85 foi bom. Vamos tentar dar-lhe um bocadinho mais (0.9, 0.95)
    # ou até 1.0 mas SÓ porque temos bootstrap=True e leaf > 1.
    "max_features": [0.85, 0.9, 0.95, 1.0],
    
    # PROFUNDIDADE:
    # O modelo anterior escolheu 25. Vamos dar margem à volta disso.
    "max_depth": [25, 30, 35],
    
    # SPLIT:
    # Refinar para valores mais baixos para permitir cortes precisos
    "min_samples_split": [5, 8, 10]
}

rsCV_et_final = apply_randomized_search_cv(
    model_et_final, 
    param_grid_fine_tune, 
    iterations=30,  # Menos iterações, mas cada modelo demora mais (muitas árvores)
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_et_final)
# Out:
# Fitting 1 folds for each of 30 candidates, totalling 30 fits
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=1.0, min_samples_leaf=4, min_samples_split=10, n_estimators=500; mae: (train=-1197.647, test=-1402.114) r2: (train=0.952, test=0.936) total time=   2.0s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.95, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; mae: (train=-1192.750, test=-1398.783) r2: (train=0.953, test=0.937) total time=   3.7s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=1.0, min_samples_leaf=4, min_samples_split=8, n_estimators=800; mae: (train=-1181.715, test=-1394.073) r2: (train=0.953, test=0.937) total time=   3.2s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.9, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; mae: (train=-1219.751, test=-1410.756) r2: (train=0.950, test=0.935) total time=   3.5s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.9, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1164.862, test=-1384.280) r2: (train=0.955, test=0.938) total time=   3.0s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=1.0, min_samples_leaf=4, min_samples_split=5, n_estimators=500; mae: (train=-1181.813, test=-1396.698) r2: (train=0.954, test=0.937) total time=   2.1s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.85, min_samples_leaf=4, min_samples_split=8, n_estimators=800; mae: (train=-1206.254, test=-1404.871) r2: (train=0.952, test=0.936) total time=   2.9s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=1.0, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1142.189, test=-1378.244) r2: (train=0.957, test=0.939) total time=   3.3s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.9, min_samples_leaf=3, min_samples_split=5, n_estimators=800; mae: (train=-1113.019, test=-1366.787) r2: (train=0.960, test=0.941) total time=   3.2s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.9, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; mae: (train=-1205.211, test=-1402.611) r2: (train=0.952, test=0.936) total time=   3.7s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=0.85, min_samples_leaf=3, min_samples_split=8, n_estimators=800; mae: (train=-1135.119, test=-1375.526) r2: (train=0.958, test=0.939) total time=   3.1s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.9, min_samples_leaf=3, min_samples_split=5, n_estimators=500; mae: (train=-1112.589, test=-1367.720) r2: (train=0.960, test=0.940) total time=   2.0s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=1.0, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; mae: (train=-1196.170, test=-1401.349) r2: (train=0.952, test=0.937) total time=   4.3s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=1.0, min_samples_leaf=4, min_samples_split=10, n_estimators=800; mae: (train=-1196.065, test=-1401.710) r2: (train=0.952, test=0.937) total time=   3.4s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.95, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; mae: (train=-1206.233, test=-1404.282) r2: (train=0.951, test=0.936) total time=   3.9s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=0.85, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; mae: (train=-1205.211, test=-1402.611) r2: (train=0.952, test=0.936) total time=   3.7s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.85, min_samples_leaf=3, min_samples_split=10, n_estimators=800; mae: (train=-1164.862, test=-1384.280) r2: (train=0.955, test=0.938) total time=   3.1s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=0.9, min_samples_leaf=3, min_samples_split=8, n_estimators=800; mae: (train=-1135.119, test=-1375.526) r2: (train=0.958, test=0.939) total time=   3.2s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=1.0, min_samples_leaf=3, min_samples_split=8, n_estimators=800; mae: (train=-1111.945, test=-1369.416) r2: (train=0.959, test=0.940) total time=   3.6s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=0.9, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; mae: (train=-1135.345, test=-1374.753) r2: (train=0.958, test=0.939) total time=   4.0s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.9, min_samples_leaf=3, min_samples_split=5, n_estimators=500; mae: (train=-1113.676, test=-1367.153) r2: (train=0.960, test=0.941) total time=   2.2s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.9, min_samples_leaf=4, min_samples_split=8, n_estimators=800; mae: (train=-1206.254, test=-1404.871) r2: (train=0.952, test=0.936) total time=   3.2s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=1.0, min_samples_leaf=3, min_samples_split=10, n_estimators=500; mae: (train=-1142.181, test=-1379.244) r2: (train=0.957, test=0.939) total time=   2.3s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=1.0, min_samples_leaf=4, min_samples_split=8, n_estimators=500; mae: (train=-1181.813, test=-1396.698) r2: (train=0.954, test=0.937) total time=   2.4s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.95, min_samples_leaf=4, min_samples_split=8, n_estimators=500; mae: (train=-1193.084, test=-1398.965) r2: (train=0.953, test=0.937) total time=   2.2s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=1.0, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; mae: (train=-1197.768, test=-1402.017) r2: (train=0.952, test=0.936) total time=   4.5s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.95, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; mae: (train=-1153.424, test=-1381.010) r2: (train=0.956, test=0.939) total time=   4.3s
# [CV 1/1] END bootstrap=True, max_depth=30, max_features=1.0, min_samples_leaf=3, min_samples_split=8, n_estimators=500; mae: (train=-1112.172, test=-1368.426) r2: (train=0.959, test=0.941) total time=   2.3s
# [CV 1/1] END bootstrap=True, max_depth=25, max_features=0.95, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; mae: (train=-1124.143, test=-1370.950) r2: (train=0.958, test=0.940) total time=   4.4s
# [CV 1/1] END bootstrap=True, max_depth=35, max_features=0.85, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; mae: (train=-1135.345, test=-1374.753) r2: (train=0.958, test=0.939) total time=   4.1s
# Train R2=0.952 | Val R2=0.936 | Train MAE=1197.6 | Val MAE=1402.1 | Gap R2=0.016 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.953 | Val R2=0.937 | Train MAE=1192.8 | Val MAE=1398.8 | Gap R2=0.016 | Params={'n_estimators': 1000, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.95, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.953 | Val R2=0.937 | Train MAE=1181.7 | Val MAE=1394.1 | Gap R2=0.016 | Params={'n_estimators': 800, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.950 | Val R2=0.935 | Train MAE=1219.8 | Val MAE=1410.8 | Gap R2=0.015 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.9, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.955 | Val R2=0.938 | Train MAE=1164.9 | Val MAE=1384.3 | Gap R2=0.017 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.9, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.954 | Val R2=0.937 | Train MAE=1181.8 | Val MAE=1396.7 | Gap R2=0.016 | Params={'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 35, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.936 | Train MAE=1206.3 | Val MAE=1404.9 | Gap R2=0.016 | Params={'n_estimators': 800, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.85, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.957 | Val R2=0.939 | Train MAE=1142.2 | Val MAE=1378.2 | Gap R2=0.017 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.960 | Val R2=0.941 | Train MAE=1113.0 | Val MAE=1366.8 | Gap R2=0.019 | Params={'n_estimators': 800, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.9, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.936 | Train MAE=1205.2 | Val MAE=1402.6 | Gap R2=0.016 | Params={'n_estimators': 1000, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.9, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.958 | Val R2=0.939 | Train MAE=1135.1 | Val MAE=1375.5 | Gap R2=0.018 | Params={'n_estimators': 800, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.85, 'max_depth': 35, 'bootstrap': True}
# Train R2=0.960 | Val R2=0.940 | Train MAE=1112.6 | Val MAE=1367.7 | Gap R2=0.019 | Params={'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.9, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.937 | Train MAE=1196.2 | Val MAE=1401.3 | Gap R2=0.015 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 35, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.937 | Train MAE=1196.1 | Val MAE=1401.7 | Gap R2=0.015 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 35, 'bootstrap': True}
# Train R2=0.951 | Val R2=0.936 | Train MAE=1206.2 | Val MAE=1404.3 | Gap R2=0.015 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 0.95, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.936 | Train MAE=1205.2 | Val MAE=1402.6 | Gap R2=0.016 | Params={'n_estimators': 1000, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.85, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.955 | Val R2=0.938 | Train MAE=1164.9 | Val MAE=1384.3 | Gap R2=0.017 | Params={'n_estimators': 800, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.85, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.958 | Val R2=0.939 | Train MAE=1135.1 | Val MAE=1375.5 | Gap R2=0.018 | Params={'n_estimators': 800, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.9, 'max_depth': 35, 'bootstrap': True}
# Train R2=0.959 | Val R2=0.940 | Train MAE=1111.9 | Val MAE=1369.4 | Gap R2=0.019 | Params={'n_estimators': 800, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 1.0, 'max_depth': 35, 'bootstrap': True}
# Train R2=0.958 | Val R2=0.939 | Train MAE=1135.3 | Val MAE=1374.8 | Gap R2=0.018 | Params={'n_estimators': 1000, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.9, 'max_depth': 35, 'bootstrap': True}
# Train R2=0.960 | Val R2=0.941 | Train MAE=1113.7 | Val MAE=1367.2 | Gap R2=0.019 | Params={'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.9, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.936 | Train MAE=1206.3 | Val MAE=1404.9 | Gap R2=0.016 | Params={'n_estimators': 800, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.9, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.957 | Val R2=0.939 | Train MAE=1142.2 | Val MAE=1379.2 | Gap R2=0.018 | Params={'n_estimators': 500, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 1.0, 'max_depth': 35, 'bootstrap': True}
# Train R2=0.954 | Val R2=0.937 | Train MAE=1181.8 | Val MAE=1396.7 | Gap R2=0.016 | Params={'n_estimators': 500, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 35, 'bootstrap': True}
# Train R2=0.953 | Val R2=0.937 | Train MAE=1193.1 | Val MAE=1399.0 | Gap R2=0.016 | Params={'n_estimators': 500, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.95, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.952 | Val R2=0.936 | Train MAE=1197.8 | Val MAE=1402.0 | Gap R2=0.015 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 1.0, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.956 | Val R2=0.939 | Train MAE=1153.4 | Val MAE=1381.0 | Gap R2=0.017 | Params={'n_estimators': 1000, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 0.95, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.959 | Val R2=0.941 | Train MAE=1112.2 | Val MAE=1368.4 | Gap R2=0.019 | Params={'n_estimators': 500, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 1.0, 'max_depth': 30, 'bootstrap': True}
# Train R2=0.958 | Val R2=0.940 | Train MAE=1124.1 | Val MAE=1370.9 | Gap R2=0.018 | Params={'n_estimators': 1000, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.95, 'max_depth': 25, 'bootstrap': True}
# Train R2=0.958 | Val R2=0.939 | Train MAE=1135.3 | Val MAE=1374.8 | Gap R2=0.018 | Params={'n_estimators': 1000, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 0.85, 'max_depth': 35, 'bootstrap': True}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9596866921942265
# Best validation R2: 0.9405932302703587
# R2 Gap: 1.9895515983672316 %
# Best train MAE: 1113.018651995112
# Best validation MAE: 1366.7873144573443
# MAE Gap: 22.800036819450078 %
# Best parameters: {'n_estimators': 800, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.9, 'max_depth': 25, 'bootstrap': True}

# %%
#check with diferent max_depth and min_samples_leaf values

model_dt = DecisionTreeRegressor(random_state=42)

# define the optimized parameter grid for Decision Tree Regressor
param_grid_dt = {
    # Control of SIZE (The most important)
    "max_depth": [None, 10, 15, 20],
    
    # Control of SPLIT (Prevents memorizing rare data)
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    
    # Control of VARIABILITY
    "max_features": [None, "sqrt", "log2"],

    # CRITERION OF ERROR
    "criterion": ["squared_error", "friedman_mse", "absolute_error"]}

#with tqdm_joblib(tqdm(desc="RandomizedSearch - LR", total=20)):

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=20, # is a good number to cover this variety
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

# check results
evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV 1/1] END criterion=friedman_mse, max_depth=20, max_features=None, min_samples_leaf=30, min_samples_split=5; mae: (train=-1608.311, test=-1765.294) r2: (train=0.913, test=0.891) total time=   0.1s
# [CV 1/1] END criterion=friedman_mse, max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=10; mae: (train=-1604.466, test=-1829.590) r2: (train=0.917, test=0.895) total time=   0.0s
# [CV 1/1] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2; mae: (train=-1610.136, test=-1825.351) r2: (train=0.914, test=0.887) total time=   0.0s
# [CV 1/1] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=20, min_samples_split=20; mae: (train=-1478.049, test=-1701.891) r2: (train=0.905, test=0.887) total time= 1.4min
# [CV 1/1] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=40; mae: (train=-2165.506, test=-2252.782) r2: (train=0.874, test=0.863) total time=   0.0s
# [CV 1/1] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=2; mae: (train=-2187.817, test=-2257.420) r2: (train=0.868, test=0.861) total time=   0.0s
# [CV 1/1] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20; mae: (train=-1828.500, test=-1950.640) r2: (train=0.886, test=0.875) total time=   0.0s
# [CV 1/1] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=20; mae: (train=-1828.500, test=-1950.640) r2: (train=0.886, test=0.875) total time=   0.0s
# [CV 1/1] END criterion=friedman_mse, max_depth=15, max_features=log2, min_samples_leaf=30, min_samples_split=20; mae: (train=-1925.022, test=-2036.435) r2: (train=0.876, test=0.864) total time=   0.0s
# [CV 1/1] END criterion=absolute_error, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=10; mae: (train=-1620.641, test=-1865.511) r2: (train=0.898, test=0.872) total time=  23.9s
# [CV 1/1] END criterion=absolute_error, max_depth=10, max_features=sqrt, min_samples_leaf=30, min_samples_split=5; mae: (train=-2185.418, test=-2256.798) r2: (train=0.844, test=0.840) total time=  23.8s
# [CV 1/1] END criterion=absolute_error, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20; mae: (train=-1620.641, test=-1865.511) r2: (train=0.898, test=0.872) total time=  24.0s
# [CV 1/1] END criterion=squared_error, max_depth=15, max_features=log2, min_samples_leaf=20, min_samples_split=10; mae: (train=-1854.200, test=-1981.740) r2: (train=0.885, test=0.873) total time=   0.0s
# [CV 1/1] END criterion=friedman_mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5; mae: (train=-2171.754, test=-2255.208) r2: (train=0.873, test=0.864) total time=   0.0s
# [CV 1/1] END criterion=friedman_mse, max_depth=20, max_features=log2, min_samples_leaf=30, min_samples_split=20; mae: (train=-1977.987, test=-2083.754) r2: (train=0.874, test=0.855) total time=   0.0s
# [CV 1/1] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=30, min_samples_split=10; mae: (train=-1977.987, test=-2083.754) r2: (train=0.874, test=0.855) total time=   0.0s
# [CV 1/1] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=30, min_samples_split=20; mae: (train=-1987.880, test=-2088.067) r2: (train=0.875, test=0.859) total time=   0.0s
# [CV 1/1] END criterion=absolute_error, max_depth=20, max_features=None, min_samples_leaf=10, min_samples_split=2; mae: (train=-1259.931, test=-1612.675) r2: (train=0.924, test=0.908) total time= 1.4min
# [CV 1/1] END criterion=squared_error, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=20; mae: (train=-1362.795, test=-1634.030) r2: (train=0.939, test=0.913) total time=   0.1s
# [CV 1/1] END criterion=friedman_mse, max_depth=20, max_features=None, min_samples_leaf=30, min_samples_split=10; mae: (train=-1608.311, test=-1765.294) r2: (train=0.913, test=0.891) total time=   0.1s
# Train R2=0.913 | Val R2=0.891 | Train MAE=1608.3 | Val MAE=1765.3 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.895 | Train MAE=1604.5 | Val MAE=1829.6 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.914 | Val R2=0.887 | Train MAE=1610.1 | Val MAE=1825.4 | Gap R2=0.027 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.905 | Val R2=0.887 | Train MAE=1478.0 | Val MAE=1701.9 | Gap R2=0.018 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 15, 'criterion': 'absolute_error'}
# Train R2=0.874 | Val R2=0.863 | Train MAE=2165.5 | Val MAE=2252.8 | Gap R2=0.011 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.868 | Val R2=0.861 | Train MAE=2187.8 | Val MAE=2257.4 | Gap R2=0.007 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.886 | Val R2=0.875 | Train MAE=1828.5 | Val MAE=1950.6 | Gap R2=0.011 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.875 | Train MAE=1828.5 | Val MAE=1950.6 | Gap R2=0.011 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.864 | Train MAE=1925.0 | Val MAE=2036.4 | Gap R2=0.013 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.898 | Val R2=0.872 | Train MAE=1620.6 | Val MAE=1865.5 | Gap R2=0.025 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'absolute_error'}
# Train R2=0.844 | Val R2=0.840 | Train MAE=2185.4 | Val MAE=2256.8 | Gap R2=0.004 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'absolute_error'}
# Train R2=0.898 | Val R2=0.872 | Train MAE=1620.6 | Val MAE=1865.5 | Gap R2=0.025 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'absolute_error'}
# Train R2=0.885 | Val R2=0.873 | Train MAE=1854.2 | Val MAE=1981.7 | Gap R2=0.013 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.873 | Val R2=0.864 | Train MAE=2171.8 | Val MAE=2255.2 | Gap R2=0.009 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.874 | Val R2=0.855 | Train MAE=1978.0 | Val MAE=2083.8 | Gap R2=0.019 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.874 | Val R2=0.855 | Train MAE=1978.0 | Val MAE=2083.8 | Gap R2=0.019 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.875 | Val R2=0.859 | Train MAE=1987.9 | Val MAE=2088.1 | Gap R2=0.015 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.908 | Train MAE=1259.9 | Val MAE=1612.7 | Gap R2=0.017 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'absolute_error'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1362.8 | Val MAE=1634.0 | Gap R2=0.026 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1608.3 | Val MAE=1765.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 20, 'criterion': 'friedman_mse'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.92448381873029
# Best validation R2: 0.9079012886708234
# R2 Gap: 1.7937069014622022 %
# Best train MAE: 1259.931356740926
# Best validation MAE: 1612.675156301415
# MAE Gap: 27.99706489351404 %
# Best parameters: {'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'absolute_error'}

# %%
# 
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.925088497105742
# Best validation R2: 0.9071667922840271
# R2 Gap: 1.9372962562809188 %
# Best train MAE: 1252.8512784231136
# Best validation MAE: 1623.9755840737084
# MAE Gap: 29.62237514078335 %
# Best parameters: {'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'absolute_error'}
# # 
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9247624105613201
# Best validation R2: 0.9078272230888982
# R2 Gap: 1.8313014541910815 %
# Best train MAE: 1257.4814406528678
# Best validation MAE: 1615.4614017769004
# MAE Gap: 28.468011499094096 %
# Best parameters: {'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'absolute_error'}

# %%
#check without max_features and absolute_error
model_dt = DecisionTreeRegressor(random_state=42)


param_grid_dt = {
   
    "max_depth": [None, 10, 15, 20],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    "criterion": ["squared_error", "friedman_mse"]
}

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=20,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.911 | Val R2=0.899 | Train MAE=1757.7 | Val MAE=1871.8 | Gap R2=0.012 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1397.9 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9421423073951416
# Best validation R2: 0.913369999094361
# R2 Gap: 3.053923815429856 %
# Best train MAE: 1294.8176601251953
# Best validation MAE: 1619.5345798820404
# MAE Gap: 25.07819670342219 %
# Best parameters: {'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}

# %%
#check without max_features and absolute_error with 100 iterations
model_dt = DecisionTreeRegressor(random_state=42)


param_grid_dt = {
   
    "max_depth": [None, 10, 15, 20],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    "criterion": ["squared_error", "friedman_mse"]
}

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=100,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.911 | Val R2=0.899 | Train MAE=1757.7 | Val MAE=1871.8 | Gap R2=0.012 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1397.9 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.911 | Val R2=0.899 | Train MAE=1757.7 | Val MAE=1871.8 | Gap R2=0.012 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.930 | Val R2=0.911 | Train MAE=1439.9 | Val MAE=1656.8 | Gap R2=0.019 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1396.4 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1396.4 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1397.9 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9419758103595577
# Best validation R2: 0.9133889602467964
# R2 Gap: 3.034775394269363 %
# Best train MAE: 1298.7062496668436
# Best validation MAE: 1618.7133125436078
# MAE Gap: 24.640449906116597 %
# Best parameters: {'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}

# %%
#check without absolute error
model_dt = DecisionTreeRegressor(random_state=42)

param_grid_dt = {
    "max_depth": [None, 10, 15, 20],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    "max_features": [None, "sqrt", "log2"],
    "criterion": ["squared_error", "friedman_mse"]}

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=20,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)
# Check results
evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.903 | Val R2=0.880 | Train MAE=1663.5 | Val MAE=1853.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.916 | Val R2=0.898 | Train MAE=1614.1 | Val MAE=1816.5 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.903 | Val R2=0.880 | Train MAE=1663.5 | Val MAE=1853.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.865 | Train MAE=2104.6 | Val MAE=2202.5 | Gap R2=0.013 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9419758103595577
# Best validation R2: 0.9133889602467964
# R2 Gap: 3.034775394269363 %
# Best train MAE: 1298.7062496668436
# Best validation MAE: 1618.7133125436078
# MAE Gap: 24.640449906116597 %
# Best parameters: {'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}

# %%
#check without absolute error
model_dt = DecisionTreeRegressor(random_state=42)

param_grid_dt = {
    "max_depth": [None, 10, 15, 20],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    "max_features": [None, "sqrt", "log2"],
    "criterion": ["squared_error", "friedman_mse"]}

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=100,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)
# Check results
evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.903 | Val R2=0.880 | Train MAE=1663.5 | Val MAE=1853.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.916 | Val R2=0.898 | Train MAE=1614.1 | Val MAE=1816.5 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.903 | Val R2=0.880 | Train MAE=1663.5 | Val MAE=1853.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.865 | Train MAE=2104.6 | Val MAE=2202.5 | Gap R2=0.013 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1630.7 | Val MAE=1826.4 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.916 | Val R2=0.898 | Train MAE=1614.1 | Val MAE=1816.5 | Gap R2=0.018 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1630.7 | Val MAE=1826.4 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.848 | Val R2=0.829 | Train MAE=2298.7 | Val MAE=2408.6 | Gap R2=0.020 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.910 | Val R2=0.887 | Train MAE=1677.3 | Val MAE=1875.8 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.916 | Val R2=0.898 | Train MAE=1614.1 | Val MAE=1816.5 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.848 | Val R2=0.829 | Train MAE=2298.7 | Val MAE=2408.6 | Gap R2=0.020 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.865 | Train MAE=2104.6 | Val MAE=2202.5 | Gap R2=0.013 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.930 | Val R2=0.911 | Train MAE=1439.9 | Val MAE=1656.8 | Gap R2=0.019 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.910 | Val R2=0.887 | Train MAE=1677.3 | Val MAE=1875.8 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.865 | Val R2=0.852 | Train MAE=2226.3 | Val MAE=2307.6 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.848 | Val R2=0.829 | Train MAE=2298.7 | Val MAE=2408.6 | Gap R2=0.020 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1397.9 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.894 | Val R2=0.870 | Train MAE=1793.4 | Val MAE=1958.7 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.894 | Val R2=0.870 | Train MAE=1793.4 | Val MAE=1958.7 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1630.7 | Val MAE=1826.4 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.894 | Val R2=0.870 | Train MAE=1793.4 | Val MAE=1958.7 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.910 | Val R2=0.887 | Train MAE=1677.3 | Val MAE=1875.8 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.865 | Val R2=0.852 | Train MAE=2226.3 | Val MAE=2307.6 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.865 | Val R2=0.852 | Train MAE=2226.3 | Val MAE=2307.6 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.865 | Val R2=0.852 | Train MAE=2226.3 | Val MAE=2307.6 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.848 | Val R2=0.829 | Train MAE=2298.7 | Val MAE=2408.6 | Gap R2=0.020 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.894 | Val R2=0.870 | Train MAE=1793.4 | Val MAE=1958.7 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1630.7 | Val MAE=1826.4 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9419758103595577
# Best validation R2: 0.9133889602467964
# R2 Gap: 3.034775394269363 %
# Best train MAE: 1298.7062496668436
# Best validation MAE: 1618.7133125436078
# MAE Gap: 24.640449906116597 %
# Best parameters: {'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}

# %% [markdown]
# # testar agora random forest

# %% [markdown]
# <a class="anchor" id="9_3_1">
#
# ## **9.3.1** KNN
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# Check best number of neighbors

# %%
model_KNN = KNeighborsRegressor()
numberK_list=np.arange(1,21) # with a range of 1 to 70 neighbors, gave the same results
high_score= -np.inf
best_k = None           
score_list_train =[]
score_list_val =[]
for n in numberK_list:
    model = KNeighborsRegressor(n_neighbors=n).fit(X_train, y_train)
    score_train = model.score(X_train, y_train)
    score_val = model.score(X_val, y_val)
    score_list_train.append(score_train)
    score_list_val.append(score_val)
    
    if(score_val>high_score):
        high_score = score_val
        best_k = n
print(f"Best number of neighbors: {best_k}")
print(f"R2 in train with {best_k} neighbors: {score_list_train[best_k-1]:.4f}")
print(f"R2 in validation with {best_k} neighbors: {high_score:.4f}")
# Out:
# Best number of neighbors: 4
# R2 in train with 4 neighbors: 0.9563
# R2 in validation with 4 neighbors: 0.9271

# %%
numberK_list=np.arange(1,11)
low_MAE=1000
nof=0           
mae_list_train =[]
mae_list_val =[]
for n in numberK_list:
    model = KNeighborsRegressor(n_neighbors = n).fit(X_train, y_train)
    pred_train_knn = model.predict(X_train)
    pred_val_knn = model.predict(X_val)
    error_train = mean_absolute_error(y_train, pred_train_knn)
    error_val = mean_absolute_error(y_val, pred_val_knn)
    mae_list_train.append(error_train)
    mae_list_val.append(error_val)
    print('Number of neighbors: ' + str(n))
    print(error_train)
    print(error_val)
    print("Difference train and validation:", str(error_val - error_train))
    print('....................')
# Out:
# Number of neighbors: 1
# 25.27128237191089
# 1749.1253701875617
# Difference train and validation: 1723.8540878156507
# ....................
# Number of neighbors: 2
# 867.8867764651683
# 1598.3676867390589
# Difference train and validation: 730.4809102738906
# ....................
# Number of neighbors: 3
# 1058.1163688615397
# 1547.3639355051005
# Difference train and validation: 489.24756664356073
# ....................
# Number of neighbors: 4
# 1153.102742768765
# 1534.3519085225403
# Difference train and validation: 381.2491657537753
# ....................
# Number of neighbors: 5
# 1219.59512981671
# 1526.955169463639
# Difference train and validation: 307.3600396469292
# ....................
# Number of neighbors: 6
# 1268.220957144581
# 1537.1293846660085
# Difference train and validation: 268.9084275214275
# ....................
# Number of neighbors: 7
# 1308.7947424585025
# 1544.7614628872277
# Difference train and validation: 235.96672042872524
# ....................
# Number of neighbors: 8
# 1343.1391683668433
# 1549.5566386969397
# Difference train and validation: 206.41747033009642
# ....................
# Number of neighbors: 9
# 1371.2879404462872
# 1559.9416255347153
# Difference train and validation: 188.65368508842812
# ....................
# Number of neighbors: 10
# 1397.7094458521176
# 1571.2073971701216
# Difference train and validation: 173.49795131800397
# ....................

# %% [markdown]
# <a class="anchor" id="5_3_1">
#
# ### 9.3.1 Define Model and Grid Parameters
#
# [Back to TOP](#TOP)
# </a>

# %%
model_KNN = KNeighborsRegressor()
param_grid_knn = {
    "n_neighbors": [10, 20, 30, 40, 50, 80, 100],              # 3..80
    "weights": ["uniform", "distance"],
    "p": [1, 2],                                # Manhattan vs Euclidiana
    "leaf_size": [2, 5, 8, 12, 17, 25, 30, 40, 50, 60, 70, 80, 90, 100],
    "algorithm": ["auto", "ball_tree", "kd_tree", "brute"],
}

# %% [markdown]
# <a class="anchor" id="5_3_2">
#
# ### 9.3.2 Test KNN using Samples
#
# [Back to TOP](#TOP)
# </a>

# %%
rsCV_KNN_sample = apply_randomized_search_cv(
    model_KNN, 
    param_grid_knn, 
    iterations= 15, 
    scoring = scoring, 
    refit = 'mae',
    pred_split = ps_sample,
    X_fit = sample_X_combined,
    y_fit = sample_y_combined
)

evaluate_model(rsCV_KNN_sample)
# Out:
# Fitting 1 folds for each of 15 candidates, totalling 15 fits
# Train R2=1.000 | Val R2=0.784 | Train MAE=-0.0 | Val MAE=2936.9 | Gap R2=0.216 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 50, 'leaf_size': 5, 'algorithm': 'brute'}
# Train R2=1.000 | Val R2=0.742 | Train MAE=-0.0 | Val MAE=3131.3 | Gap R2=0.258 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 80, 'leaf_size': 12, 'algorithm': 'ball_tree'}
# Train R2=1.000 | Val R2=0.817 | Train MAE=-0.0 | Val MAE=2747.6 | Gap R2=0.183 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 30, 'leaf_size': 50, 'algorithm': 'auto'}
# Train R2=1.000 | Val R2=0.817 | Train MAE=-0.0 | Val MAE=2747.6 | Gap R2=0.183 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 30, 'leaf_size': 60, 'algorithm': 'kd_tree'}
# Train R2=1.000 | Val R2=0.866 | Train MAE=-0.0 | Val MAE=2426.9 | Gap R2=0.134 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 10, 'leaf_size': 2, 'algorithm': 'auto'}
# Train R2=0.772 | Val R2=0.743 | Train MAE=3050.5 | Val MAE=3258.1 | Gap R2=0.029 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 70, 'algorithm': 'ball_tree'}
# Train R2=0.781 | Val R2=0.747 | Train MAE=3037.3 | Val MAE=3179.5 | Gap R2=0.033 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 50, 'leaf_size': 2, 'algorithm': 'kd_tree'}
# Train R2=0.846 | Val R2=0.809 | Train MAE=2571.5 | Val MAE=2835.2 | Gap R2=0.037 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 20, 'leaf_size': 80, 'algorithm': 'brute'}
# Train R2=1.000 | Val R2=0.812 | Train MAE=-0.0 | Val MAE=2757.2 | Gap R2=0.188 | Params={'weights': 'distance', 'p': 2, 'n_neighbors': 30, 'leaf_size': 30, 'algorithm': 'ball_tree'}
# Train R2=0.814 | Val R2=0.785 | Train MAE=2811.3 | Val MAE=2995.8 | Gap R2=0.030 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 30, 'leaf_size': 2, 'algorithm': 'kd_tree'}
# Train R2=0.884 | Val R2=0.850 | Train MAE=2249.0 | Val MAE=2595.1 | Gap R2=0.035 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 60, 'algorithm': 'kd_tree'}
# Train R2=0.707 | Val R2=0.672 | Train MAE=3390.6 | Val MAE=3545.4 | Gap R2=0.036 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 100, 'leaf_size': 90, 'algorithm': 'ball_tree'}
# Train R2=1.000 | Val R2=0.742 | Train MAE=-0.0 | Val MAE=3131.3 | Gap R2=0.258 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 80, 'leaf_size': 40, 'algorithm': 'brute'}
# Train R2=1.000 | Val R2=0.733 | Train MAE=-0.0 | Val MAE=3163.7 | Gap R2=0.267 | Params={'weights': 'distance', 'p': 2, 'n_neighbors': 80, 'leaf_size': 25, 'algorithm': 'brute'}
# Train R2=1.000 | Val R2=0.866 | Train MAE=-0.0 | Val MAE=2426.9 | Gap R2=0.134 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 10, 'leaf_size': 5, 'algorithm': 'ball_tree'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 1.0
# Best validation R2: 0.8658093992739091
# R2 Gap: 13.41906007260909 %
# Best train MAE: -0.0
# Best validation MAE: 2426.889117381197
# MAE Gap: -inf %
# Best parameters: {'weights': 'distance', 'p': 1, 'n_neighbors': 10, 'leaf_size': 2, 'algorithm': 'auto'}
# /Users/eduardohenrique/Documents/margarida nova ims/Machine-Learning-Project-25-26/ENTREGA FINAL/notebooks/model_and_assessment.py:75: RuntimeWarning: divide by zero encountered in scalar divide
#   print("MAE Gap:", (best_val_mae - best_train_mae) / best_train_mae * 100, "%")

# %% [markdown]
# <a class="anchor" id="5_3_3">
#
# ### 9.3.3 Test KNN using the entire Dataset
#
# [Back to TOP](#TOP)
# </a>

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations= 15,
    scoring = scoring,
    refit = 'mae', 
    pred_split = ps,
    X_fit = X_combined,
    y_fit = y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 15 candidates, totalling 15 fits
# Train R2=1.000 | Val R2=0.923 | Train MAE=23.5 | Val MAE=1530.4 | Gap R2=0.077 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 50, 'leaf_size': 5, 'algorithm': 'brute'}
# Train R2=1.000 | Val R2=0.916 | Train MAE=23.5 | Val MAE=1592.0 | Gap R2=0.083 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 80, 'leaf_size': 12, 'algorithm': 'ball_tree'}
# Train R2=1.000 | Val R2=0.928 | Train MAE=23.5 | Val MAE=1479.9 | Gap R2=0.071 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 30, 'leaf_size': 50, 'algorithm': 'auto'}
# Train R2=1.000 | Val R2=0.928 | Train MAE=23.5 | Val MAE=1479.8 | Gap R2=0.071 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 30, 'leaf_size': 60, 'algorithm': 'kd_tree'}
# Train R2=1.000 | Val R2=0.935 | Train MAE=23.5 | Val MAE=1426.9 | Gap R2=0.064 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 10, 'leaf_size': 2, 'algorithm': 'auto'}
# Train R2=0.907 | Val R2=0.901 | Train MAE=1675.7 | Val MAE=1731.3 | Gap R2=0.006 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 70, 'algorithm': 'ball_tree'}
# Train R2=0.898 | Val R2=0.892 | Train MAE=1758.4 | Val MAE=1807.8 | Gap R2=0.005 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 50, 'leaf_size': 2, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.918 | Train MAE=1473.8 | Val MAE=1570.2 | Gap R2=0.007 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 20, 'leaf_size': 80, 'algorithm': 'brute'}
# Train R2=1.000 | Val R2=0.919 | Train MAE=23.5 | Val MAE=1558.3 | Gap R2=0.080 | Params={'weights': 'distance', 'p': 2, 'n_neighbors': 30, 'leaf_size': 30, 'algorithm': 'ball_tree'}
# Train R2=0.917 | Val R2=0.911 | Train MAE=1559.7 | Val MAE=1634.1 | Gap R2=0.007 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 30, 'leaf_size': 2, 'algorithm': 'kd_tree'}
# Train R2=0.939 | Val R2=0.926 | Train MAE=1327.8 | Val MAE=1500.3 | Gap R2=0.013 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 60, 'algorithm': 'kd_tree'}
# Train R2=0.880 | Val R2=0.876 | Train MAE=1932.6 | Val MAE=1960.5 | Gap R2=0.004 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 100, 'leaf_size': 90, 'algorithm': 'ball_tree'}
# Train R2=1.000 | Val R2=0.916 | Train MAE=23.5 | Val MAE=1592.0 | Gap R2=0.083 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 80, 'leaf_size': 40, 'algorithm': 'brute'}
# Train R2=1.000 | Val R2=0.906 | Train MAE=23.5 | Val MAE=1680.2 | Gap R2=0.093 | Params={'weights': 'distance', 'p': 2, 'n_neighbors': 80, 'leaf_size': 25, 'algorithm': 'brute'}
# Train R2=1.000 | Val R2=0.935 | Train MAE=23.5 | Val MAE=1426.8 | Gap R2=0.064 | Params={'weights': 'distance', 'p': 1, 'n_neighbors': 10, 'leaf_size': 5, 'algorithm': 'ball_tree'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9995098630287543
# Best validation R2: 0.9350420936361977
# R2 Gap: 6.449938292475056 %
# Best train MAE: 23.493470760357628
# Best validation MAE: 1426.8471001278006
# MAE Gap: 5973.377214810812 %
# Best parameters: {'weights': 'distance', 'p': 1, 'n_neighbors': 10, 'leaf_size': 5, 'algorithm': 'ball_tree'}

# %% [markdown]
# Analyzing the previous results, we observed that the models using weights='distance' displayed clear signs of overfitting. Based on this, we defined a new parameter grid that excludes this option in order to evaluate whether better and more stable results can be achieved.

# %%
model_KNN = KNeighborsRegressor()
param_grid_knn = {
    "n_neighbors": [10, 20, 30, 40, 50, 80, 100],
    "weights": ["uniform"],
    "p": [1, 2],                                # Manhattan vs Euclidiane
    "leaf_size": [2, 5, 8, 12, 17, 25, 30, 40, 50, 60, 70, 80, 90, 100],
    "algorithm": ["auto", "ball_tree", "kd_tree", "brute"],
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations= 15,
    scoring = scoring,
    refit = 'mae',
    pred_split = ps,
    X_fit = X_combined,
    y_fit = y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 15 candidates, totalling 15 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 rsCV_KNN = apply_randomized_search_cv(
#       2     model_KNN,
#       3     param_grid_knn,
#       4     iterations= 15,
#       5     scoring = scoring,
#       6     refit = 'mae',
#       7     pred_split = ps,
#       8     X_fit = X_combined,
#       9     y_fit = y_combined
#      10 )
#      12 evaluate_model(rsCV_KNN)
#
# File ~/Documents/margarida nova ims/Machine-Learning-Project-25-26/ENTREGA FINAL/notebooks/model_and_assessment.py:24, in apply_randomized_search_cv(model, param_grid, iterations, scoring, refit, pred_split, X_fit, y_fit)
#      11 randomized_model = RandomizedSearchCV(
#      12     estimator=model,
#      13     param_distributions=param_grid,
#    (...)     20     random_state=40111
#      21 )
#      23 # Fit the model
# ---> 24 randomized_model.fit(X_fit, y_fit)
#      26 return randomized_model
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1051, in BaseSearchCV.fit(self, X, y, **params)
#    1045     results = self._format_results(
#    1046         all_candidate_params, n_splits, all_out, all_more_results
#    1047     )
#    1049     return results
# -> 1051 self._run_search(evaluate_candidates)
#    1053 # multimetric is determined here because in the case of a callable
#    1054 # self.scoring the return type is only known after calling
#    1055 first_test_score = all_out[0]["test_scores"]
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1992, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1990 def _run_search(self, evaluate_candidates):
#    1991     """Search n_iter candidates from param_distributions"""
# -> 1992     evaluate_candidates(
#    1993         ParameterSampler(
#    1994             self.param_distributions, self.n_iter, random_state=self.random_state
#    1995         )
#    1996     )
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/model_selection/_search.py:997, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     989 if self.verbose > 0:
#     990     print(
#     991         "Fitting {0} folds for each of {1} candidates,"
#     992         " totalling {2} fits".format(
#     993             n_splits, n_candidates, n_candidates * n_splits
#     994         )
#     995     )
# --> 997 out = parallel(
#     998     delayed(_fit_and_score)(
#     999         clone(base_estimator),
#    1000         X,
#    1001         y,
#    1002         train=train,
#    1003         test=test,
#    1004         parameters=parameters,
#    1005         split_progress=(split_idx, n_splits),
#    1006         candidate_progress=(cand_idx, n_candidates),
#    1007         **fit_and_score_kwargs,
#    1008     )
#    1009     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1010         enumerate(candidate_params),
#    1011         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1012     )
#    1013 )
#    1015 if len(out) < 1:
#    1016     raise ValueError(
#    1017         "No fits were performed. "
#    1018         "Was the CV iterator empty? "
#    1019         "Were there no candidates?"
#    1020     )
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/utils/parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:881, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     878 result["fit_error"] = None
#     880 fit_time = time.time() - start_time
# --> 881 test_scores = _score(
#     882     estimator, X_test, y_test, scorer, score_params_test, error_score
#     883 )
#     884 score_time = time.time() - start_time - fit_time
#     885 if return_train_score:
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:942, in _score(estimator, X_test, y_test, scorer, score_params, error_score)
#     940         scores = scorer(estimator, X_test, **score_params)
#     941     else:
# --> 942         scores = scorer(estimator, X_test, y_test, **score_params)
#     943 except Exception:
#     944     if isinstance(scorer, _MultimetricScorer):
#     945         # If `_MultimetricScorer` raises exception, the `error_score`
#     946         # parameter is equal to "raise".
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/metrics/_scorer.py:152, in _MultimetricScorer.__call__(self, estimator, *args, **kwargs)
#     150 try:
#     151     if isinstance(scorer, _BaseScorer):
# --> 152         score = scorer._score(
#     153             cached_call, estimator, *args, **routed_params.get(name).score
#     154         )
#     155     else:
#     156         score = scorer(estimator, *args, **routed_params.get(name).score)
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/metrics/_scorer.py:400, in _Scorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     398 pos_label = None if is_regressor(estimator) else self._get_pos_label()
#     399 response_method = _check_response_method(estimator, self._response_method)
# --> 400 y_pred = method_caller(
#     401     estimator,
#     402     _get_response_method_name(response_method),
#     403     X,
#     404     pos_label=pos_label,
#     405 )
#     407 scoring_kwargs = {**self._kwargs, **kwargs}
#     408 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/metrics/_scorer.py:90, in _cached_call(cache, estimator, response_method, *args, **kwargs)
#      87 if cache is not None and response_method in cache:
#      88     return cache[response_method]
# ---> 90 result, _ = _get_response_values(
#      91     estimator, *args, response_method=response_method, **kwargs
#      92 )
#      94 if cache is not None:
#      95     cache[response_method] = result
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/utils/_response.py:242, in _get_response_values(estimator, X, response_method, pos_label, return_response_method_used)
#     235         raise ValueError(
#     236             f"{estimator.__class__.__name__} should either be a classifier to be "
#     237             f"used with response_method={response_method} or the response_method "
#     238             "should be 'predict'. Got a regressor with response_method="
#     239             f"{response_method} instead."
#     240         )
#     241     prediction_method = estimator.predict
# --> 242     y_pred, pos_label = prediction_method(X), None
#     244 if return_response_method_used:
#     245     return y_pred, pos_label, prediction_method.__name__
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/neighbors/_regression.py:243, in KNeighborsRegressor.predict(self, X)
#     225 """Predict the target for the provided data.
#     226
#     227 Parameters
#    (...)    238     Target values.
#     239 """
#     240 if self.weights == "uniform":
#     241     # In that case, we do not need the distances to perform
#     242     # the weighting so we do not compute them.
# --> 243     neigh_ind = self.kneighbors(X, return_distance=False)
#     244     neigh_dist = None
#     245 else:
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/neighbors/_base.py:923, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     918     if issparse(X):
#     919         raise ValueError(
#     920             "%s does not work with sparse matrices. Densify the data, "
#     921             "or set algorithm='brute'" % self._fit_method
#     922         )
# --> 923     chunked_results = Parallel(n_jobs, prefer="threads")(
#     924         delayed(self._tree.query)(X[s], n_neighbors, return_distance)
#     925         for s in gen_even_slices(X.shape[0], n_jobs)
#     926     )
#     927 else:
#     928     raise ValueError("internal: _fit_method not recognized")
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File /opt/anaconda3/envs/DataMining/lib/python3.13/site-packages/sklearn/utils/parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
#best_mae_knn = -rsCV_KNN.best_score_
#preds_knn = rsCV_KNN.best_estimator_.predict(test)

# %% [markdown]
# TESTAR À NOITE

# %% [markdown]
# notas: p:1, neighbors:10, weight:uniform têm dado melhor performance

# %%
model_KNN = KNeighborsRegressor()

# %%
param_grid_knn = {
    'n_neighbors': [5, 7, 10, 12, 17],
    'p': [1, 2],
    'weights': ['uniform'],
    'leaf_size': [30],
    'algorithm': ['auto']
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations=20, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# c:\Users\Catarina\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 10 is smaller than n_iter=20. Running 10 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 1 folds for each of 10 candidates, totalling 10 fits
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.948 | Val R2=0.921 | Train MAE=1254.9 | Val MAE=1573.8 | Gap R2=0.027 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.945 | Val R2=0.925 | Train MAE=1278.2 | Val MAE=1515.6 | Gap R2=0.019 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 7, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.939 | Val R2=0.919 | Train MAE=1348.4 | Val MAE=1582.1 | Gap R2=0.020 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 7, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.930 | Val R2=0.915 | Train MAE=1439.8 | Val MAE=1610.9 | Gap R2=0.015 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 10, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.933 | Val R2=0.922 | Train MAE=1405.6 | Val MAE=1556.2 | Gap R2=0.011 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 12, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.925 | Val R2=0.913 | Train MAE=1484.9 | Val MAE=1636.7 | Gap R2=0.013 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 12, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.926 | Val R2=0.918 | Train MAE=1484.7 | Val MAE=1596.5 | Gap R2=0.008 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 17, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.918 | Val R2=0.907 | Train MAE=1570.2 | Val MAE=1686.6 | Gap R2=0.011 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 17, 'leaf_size': 30, 'algorithm': 'auto'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9519822719287925
# Best validation R2: 0.9292278697698063
# R2 Gap: 2.3902128043712327 %
# Best train MAE: 1194.4546513541084
# Best validation MAE: 1497.8082790391577
# MAE Gap: 25.396830875173766 %
# Best parameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'auto'}

# %%
param_grid_knn = {
    'n_neighbors': [5, 10],
    'p': [1],
    'weights': ['uniform'],
    'leaf_size': [30],
    'algorithm': ['auto', "ball_tree", "kd_tree", "brute"]
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations=15, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 8 candidates, totalling 8 fits
# c:\Users\Catarina\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 8 is smaller than n_iter=15. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1498.0 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'ball_tree'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.6 | Val MAE=1541.1 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 30, 'algorithm': 'ball_tree'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.3 | Val MAE=1498.5 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'kd_tree'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 30, 'algorithm': 'kd_tree'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'brute'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 30, 'algorithm': 'brute'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9519822719287925
# Best validation R2: 0.9292278697698063
# R2 Gap: 2.3902128043712327 %
# Best train MAE: 1194.4546513541084
# Best validation MAE: 1497.8082790391577
# MAE Gap: 25.396830875173766 %
# Best parameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'auto'}

# %%
param_grid_knn = {
    'n_neighbors': [5, 10],
    'p': [1],
    'weights': ['uniform'],
    'leaf_size': [30, 45, 60, 70, 80, 100],
    'algorithm': ['auto', "brute"]
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations=20, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 70, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 45, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 60, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 70, 'algorithm': 'brute'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 30, 'algorithm': 'brute'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 70, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 100, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 80, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 70, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 80, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 100, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 80, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 45, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 100, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 45, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 60, 'algorithm': 'brute'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 100, 'algorithm': 'brute'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 45, 'algorithm': 'auto'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9519822719287925
# Best validation R2: 0.9292278697698063
# R2 Gap: 2.3902128043712327 %
# Best train MAE: 1194.4546513541084
# Best validation MAE: 1497.8082790391577
# MAE Gap: 25.396830875173766 %
# Best parameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 70, 'algorithm': 'auto'}

# %%
param_grid_knn = {
    'n_neighbors': [5, 10],
    'p': [1],
    'weights': ['uniform'],
    'leaf_size': [2, 4, 5, 7, 8, 10],
    'algorithm': ['auto', "brute"]
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations=20, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 7, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 4, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 5, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 7, 'algorithm': 'brute'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 2, 'algorithm': 'brute'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 7, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 10, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 8, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 7, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 8, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 10, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 8, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 4, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 2, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 2, 'algorithm': 'auto'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 10, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 4, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 5, 'algorithm': 'brute'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 10, 'algorithm': 'brute'}
# Train R2=0.937 | Val R2=0.923 | Train MAE=1364.7 | Val MAE=1541.3 | Gap R2=0.014 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 10, 'leaf_size': 4, 'algorithm': 'auto'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9519822719287925
# Best validation R2: 0.9292278697698063
# R2 Gap: 2.3902128043712327 %
# Best train MAE: 1194.4546513541084
# Best validation MAE: 1497.8082790391577
# MAE Gap: 25.396830875173766 %
# Best parameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 7, 'algorithm': 'auto'}

# %%
param_grid_knn = {
    'n_neighbors': [5],
    'p': [1],
    'weights': ['uniform'],
    "leaf_size": [2, 5, 7, 8, 12, 17, 25, 30, 40, 50, 60, 70, 80, 90, 100],
    'algorithm': ['auto', "brute"]
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations=30, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 30 candidates, totalling 30 fits
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 2, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 5, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 7, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 8, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 12, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 17, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 25, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 40, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 50, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 60, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 70, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 80, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 90, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 100, 'algorithm': 'auto'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 2, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 5, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 7, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 8, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 12, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 17, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 25, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 30, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 40, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 50, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 60, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 70, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 80, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 90, 'algorithm': 'brute'}
# Train R2=0.952 | Val R2=0.929 | Train MAE=1194.5 | Val MAE=1497.8 | Gap R2=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 100, 'algorithm': 'brute'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9519822719287925
# Best validation R2: 0.9292278697698063
# R2 Gap: 2.3902128043712327 %
# Best train MAE: 1194.4546513541084
# Best validation MAE: 1497.8082790391577
# MAE Gap: 25.396830875173766 %
# Best parameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 5, 'leaf_size': 2, 'algorithm': 'auto'}

# %% [markdown]
# <a class="anchor" id="9_3_1">
#
# ## **9.3.1** Neural Networks
#
# [Back to TOP](#TOP)
# </a>

# %%
modelMLP = MLPRegressor(max_iter=500)

param_grid_mlp = {
    "hidden_layer_sizes": [
        # Tier 2 — Best performers in your tests
        (200, 100),

        # Tier 3 — Larger models for marginal gains
        (200, 150, 100), (256, 128), (256, 128, 64),
    ],
    "activation": ["relu"],   # Activation. Best for tabular data
    "solver": ["adam"],       # Optimizer Adam is far superior for MLP in sklearn
    "alpha": [0.0005, 0.001, 0.002, 0.005],  # Regularization (L2 penalty), centered around your winning value (0.001)
    "learning_rate_init": [0.0003, 0.0005, 0.0007, 0.001], # Learning rate grid (finely tuned)
    "learning_rate": ["adaptive"],  # LR schedule. Works best with relu + large datasets
    "batch_size": [64, 128], # Batch sizes (scaling-friendly)
    "early_stopping": [True], # Generalization
}

# %% [markdown]
# <a class="anchor" id="5_5_2">
#
# ### 5.5.2 Test Neural Networks using Samples
#
# [Back to TOP](#TOP)
# </a>

# %%
rsCV_mlp_sample = apply_randomized_search_cv(modelMLP, param_grid_mlp, iterations= 25, scoring = scoring, refit = 'mae', 
                                      pred_split = ps_sample, X_fit = sample_X_combined, y_fit = sample_y_combined)

evaluate_model(rsCV_mlp_sample)
# Out:
# Fitting 1 folds for each of 25 candidates, totalling 25 fits
# Train R2=0.858 | Val R2=0.825 | Train MAE=2607.6 | Val MAE=2906.0 | Gap R2=0.033 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.888 | Val R2=0.847 | Train MAE=2241.0 | Val MAE=2558.6 | Gap R2=0.041 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.001, 'activation': 'relu'}
# Train R2=0.872 | Val R2=0.832 | Train MAE=2464.5 | Val MAE=2804.5 | Gap R2=0.040 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.818 | Val R2=0.788 | Train MAE=3065.7 | Val MAE=3291.5 | Gap R2=0.029 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.814 | Val R2=0.791 | Train MAE=3155.5 | Val MAE=3299.5 | Gap R2=0.023 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.820 | Val R2=0.799 | Train MAE=3040.3 | Val MAE=3181.2 | Gap R2=0.021 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.872 | Val R2=0.830 | Train MAE=2417.2 | Val MAE=2757.9 | Gap R2=0.042 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.854 | Val R2=0.820 | Train MAE=2697.2 | Val MAE=2988.1 | Gap R2=0.034 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.767 | Val R2=0.747 | Train MAE=3669.9 | Val MAE=3809.7 | Gap R2=0.020 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.001, 'activation': 'relu'}
# Train R2=0.882 | Val R2=0.841 | Train MAE=2330.4 | Val MAE=2638.5 | Gap R2=0.041 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.891 | Val R2=0.843 | Train MAE=2228.9 | Val MAE=2584.4 | Gap R2=0.047 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.846 | Val R2=0.813 | Train MAE=2781.9 | Val MAE=3034.2 | Gap R2=0.033 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.866 | Val R2=0.831 | Train MAE=2536.7 | Val MAE=2821.4 | Gap R2=0.034 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.865 | Val R2=0.835 | Train MAE=2519.7 | Val MAE=2774.6 | Gap R2=0.031 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.857 | Val R2=0.822 | Train MAE=2663.8 | Val MAE=2945.5 | Gap R2=0.035 | Params={'solver': 'adam', 'learning_rate_init': 0.0005, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.001, 'activation': 'relu'}
# Train R2=0.783 | Val R2=0.762 | Train MAE=3478.8 | Val MAE=3619.1 | Gap R2=0.021 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.813 | Val R2=0.787 | Train MAE=3099.0 | Val MAE=3303.7 | Gap R2=0.025 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.879 | Val R2=0.837 | Train MAE=2380.7 | Val MAE=2707.7 | Gap R2=0.042 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.822 | Val R2=0.796 | Train MAE=3051.9 | Val MAE=3209.9 | Gap R2=0.026 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.796 | Val R2=0.771 | Train MAE=3323.3 | Val MAE=3515.8 | Gap R2=0.024 | Params={'solver': 'adam', 'learning_rate_init': 0.0005, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.896 | Val R2=0.847 | Train MAE=2154.7 | Val MAE=2519.0 | Gap R2=0.049 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.872 | Val R2=0.838 | Train MAE=2439.4 | Val MAE=2710.5 | Gap R2=0.034 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.803 | Val R2=0.778 | Train MAE=3240.1 | Val MAE=3447.9 | Gap R2=0.026 | Params={'solver': 'adam', 'learning_rate_init': 0.0005, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.001, 'activation': 'relu'}
# Train R2=0.808 | Val R2=0.783 | Train MAE=3168.0 | Val MAE=3368.1 | Gap R2=0.025 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.841 | Val R2=0.810 | Train MAE=2815.7 | Val MAE=3104.9 | Gap R2=0.031 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.001, 'activation': 'relu'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8955917121688379
# Best validation R2: 0.8469601547622421
# R2 Gap: 5.430103555651013 %
# Best train MAE: 2154.654169273657
# Best validation MAE: 2519.0480314068914
# MAE Gap: 16.911941940830033 %
# Best parameters: {'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.002, 'activation': 'relu'}

# %% [markdown]
# <a class="anchor" id="5_5_3">
#
# ### 5.5.3 Test Neural Networks using the entire Dataset
#
# [Back to TOP](#TOP)
# </a>

# %%
rsCV_mlp = apply_randomized_search_cv(modelMLP, param_grid_mlp, iterations=25, scoring = scoring, refit = 'mae', 
                                      pred_split = ps, X_fit = X_combined, y_fit = y_combined)

evaluate_model(rsCV_mlp)
# Out:
# Fitting 1 folds for each of 25 candidates, totalling 25 fits
# Train R2=0.927 | Val R2=0.913 | Train MAE=1594.7 | Val MAE=1700.1 | Gap R2=0.014 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.939 | Val R2=0.922 | Train MAE=1497.7 | Val MAE=1627.1 | Gap R2=0.018 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.001, 'activation': 'relu'}
# Train R2=0.922 | Val R2=0.913 | Train MAE=1627.6 | Val MAE=1705.9 | Gap R2=0.009 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.915 | Val R2=0.908 | Train MAE=1681.8 | Val MAE=1731.0 | Gap R2=0.007 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.914 | Val R2=0.906 | Train MAE=1703.5 | Val MAE=1765.7 | Gap R2=0.008 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.920 | Val R2=0.910 | Train MAE=1640.4 | Val MAE=1710.4 | Gap R2=0.011 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.927 | Val R2=0.915 | Train MAE=1595.9 | Val MAE=1687.0 | Gap R2=0.012 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.927 | Val R2=0.914 | Train MAE=1587.3 | Val MAE=1682.8 | Gap R2=0.012 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.905 | Val R2=0.900 | Train MAE=1775.7 | Val MAE=1811.8 | Gap R2=0.004 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.001, 'activation': 'relu'}
# Train R2=0.925 | Val R2=0.916 | Train MAE=1587.8 | Val MAE=1679.4 | Gap R2=0.010 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.933 | Val R2=0.920 | Train MAE=1545.9 | Val MAE=1645.2 | Gap R2=0.013 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.929 | Val R2=0.916 | Train MAE=1567.8 | Val MAE=1673.6 | Gap R2=0.013 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.921 | Val R2=0.912 | Train MAE=1651.6 | Val MAE=1726.0 | Gap R2=0.009 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.919 | Val R2=0.910 | Train MAE=1654.4 | Val MAE=1721.1 | Gap R2=0.009 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.930 | Val R2=0.918 | Train MAE=1571.4 | Val MAE=1671.2 | Gap R2=0.012 | Params={'solver': 'adam', 'learning_rate_init': 0.0005, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128, 64), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.001, 'activation': 'relu'}
# Train R2=0.907 | Val R2=0.902 | Train MAE=1763.8 | Val MAE=1804.1 | Gap R2=0.005 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.918 | Val R2=0.909 | Train MAE=1652.6 | Val MAE=1723.7 | Gap R2=0.009 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.930 | Val R2=0.917 | Train MAE=1573.5 | Val MAE=1674.0 | Gap R2=0.014 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.005, 'activation': 'relu'}
# Train R2=0.925 | Val R2=0.914 | Train MAE=1613.3 | Val MAE=1692.6 | Gap R2=0.012 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.912 | Val R2=0.905 | Train MAE=1716.1 | Val MAE=1766.3 | Gap R2=0.007 | Params={'solver': 'adam', 'learning_rate_init': 0.0005, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.919 | Val R2=0.909 | Train MAE=1649.2 | Val MAE=1719.2 | Gap R2=0.010 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.002, 'activation': 'relu'}
# Train R2=0.926 | Val R2=0.916 | Train MAE=1603.1 | Val MAE=1683.7 | Gap R2=0.010 | Params={'solver': 'adam', 'learning_rate_init': 0.0007, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.917 | Val R2=0.911 | Train MAE=1661.6 | Val MAE=1716.4 | Gap R2=0.006 | Params={'solver': 'adam', 'learning_rate_init': 0.0005, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.001, 'activation': 'relu'}
# Train R2=0.917 | Val R2=0.910 | Train MAE=1680.7 | Val MAE=1733.8 | Gap R2=0.006 | Params={'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 100), 'early_stopping': True, 'batch_size': 128, 'alpha': 0.0005, 'activation': 'relu'}
# Train R2=0.911 | Val R2=0.906 | Train MAE=1714.3 | Val MAE=1753.9 | Gap R2=0.005 | Params={'solver': 'adam', 'learning_rate_init': 0.0003, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (256, 128), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.001, 'activation': 'relu'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9392577592453302
# Best validation R2: 0.9215601264686135
# R2 Gap: 1.8842147006521675 %
# Best train MAE: 1497.7211185492774
# Best validation MAE: 1627.1221369250757
# MAE Gap: 8.639860703916536 %
# Best parameters: {'solver': 'adam', 'learning_rate_init': 0.001, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (200, 150, 100), 'early_stopping': True, 'batch_size': 64, 'alpha': 0.001, 'activation': 'relu'}

# %%
mlp_losses= rsCV_mlp.best_estimator_.loss_curve_
mlp_iterations= rsCV_mlp.best_estimator_.n_iter_
sns.lineplot(x=range(mlp_iterations), y=mlp_losses)
# Out:
# <Axes: >

# %%
print(f"Total Loss: {rsCV_mlp.best_estimator_.loss_}")
print(f"Number of Iterations: {rsCV_mlp.best_estimator_.n_iter_}")
print(f"Columns: {X_train.columns.tolist()}")
print(f"Coefficients: {rsCV_mlp.best_estimator_.coefs_}")
# Out:
# Total Loss: 3199372.4400050733
# Number of Iterations: 132
# Columns: ['model_target', 'year', 'is_automatic', 'fuel_efficiency_score', 'Brand_target', 'engineSize', 'brand_avg_engineSize', 'mileage', 'transmission_Semi-Auto_ohe', 'brand_avg_age', 'mpg', 'tax', 'fueltype_avg_mpg', 'tax_to_engine_ratio']
# Coefficients: [array([[ 1.40890050e-01, -4.77730490e-02, -1.65472910e-01, ...,
#          9.78389460e-01,  9.63667791e-02,  7.52481596e-01],
#        [-1.13525474e-01, -6.19353189e-02,  1.80117183e-02, ...,
#          1.11336073e-02, -4.69771591e-01,  9.78294605e-01],
#        [ 1.08078269e-01,  2.40261594e-02,  1.13912854e-03, ...,
#         -2.08957652e-02, -1.23012133e+00,  9.86178006e-02],
#        ...,
#        [ 4.12544699e-01, -2.66640132e-02, -1.09743892e-01, ...,
#         -4.77593859e-01,  8.69246003e-02,  1.74096131e-01],
#        [ 3.32457106e-01,  1.37839639e-01,  1.09301200e+00, ...,
#          7.13266948e-02,  6.25565035e-02, -5.30440092e-01],
#        [ 5.22292078e-01, -1.28946576e-01, -2.13490767e-01, ...,
#          3.04282920e-01, -9.72932971e-02,  1.31433072e-03]]), array([[0.36736654, 0.47448429, 0.58317377, ..., 0.45807953, 0.55993211,
#         0.37788502],
#        [0.17671528, 0.08429041, 0.19902458, ..., 0.14283189, 0.08402371,
#         0.05784851],
#        [0.38796173, 0.31959142, 0.38492866, ..., 0.4235618 , 0.32189321,
#         0.18374089],
#        ...,
#        [0.38993927, 0.50756349, 0.5898511 , ..., 0.4839215 , 0.42490802,
#         0.31950531],
#        [0.25336984, 0.41938589, 0.26425463, ..., 0.25517022, 0.24202744,
#         0.34152368],
#        [1.29370487, 1.23536828, 1.27824778, ..., 1.23669401, 1.29200947,
#         1.17426808]]), array([[ 4.53368639e-001,  1.63823722e-001, -2.54551558e-316, ...,
#         -6.94407388e-317,  2.80570715e-316, -2.61514534e-316],
#        [ 3.79682970e-001,  1.16960570e-001, -5.94552620e-317, ...,
#         -8.66196631e-317,  1.25222277e-316, -4.30861359e-317],
#        [ 2.48200170e-001,  1.44432479e-001, -1.19670980e-316, ...,
#         -1.94169439e-316, -3.53999280e-316, -1.74117380e-317],
#        ...,
#        [ 1.82454008e-001,  1.59120256e-001,  1.22127514e-316, ...,
#          8.73292995e-317,  1.07085216e-316,  3.58572046e-317],
#        [ 2.73150945e-001,  1.60895798e-001, -5.25748939e-317, ...,
#         -2.62629369e-316,  2.37828948e-316,  2.67288941e-316],
#        [ 1.45553074e-001,  4.72635968e-002,  2.77544054e-316, ...,
#         -8.17603398e-317, -3.53478940e-316,  1.92959971e-316]]), array([[ 8.71852299e-001],
#        [ 1.23717402e+000],
#        [ 5.00725898e-317],
#        [-3.16459372e-317],
#        [ 9.41589758e-128],
#        [ 1.06742853e-316],
#        [-1.66492853e-045],
#        [ 7.58826582e-317],
#        [ 1.10522672e+000],
#        [ 3.04220576e-316],
#        [ 9.97820960e-001],
#        [ 1.09876310e+000],
#        [ 9.36162470e-001],
#        [ 9.88232700e-001],
#        [ 9.36272685e-001],
#        [ 9.27094375e-001],
#        [ 1.13219049e+000],
#        [-9.71326587e-317],
#        [-2.37811236e-316],
#        [ 9.26861781e-001],
#        [-3.18736718e-317],
#        [ 1.00997094e+000],
#        [ 8.51394928e-001],
#        [ 1.20511417e+000],
#        [-4.72356154e-317],
#        [ 9.72980769e-318],
#        [ 9.13610619e-001],
#        [ 8.74237704e-001],
#        [ 1.13625829e+000],
#        [-2.75638394e-316],
#        [ 1.12207368e+000],
#        [ 1.02916616e+000],
#        [ 1.07006124e+000],
#        [ 9.97409735e-001],
#        [ 1.53354440e+000],
#        [-1.65473467e-002],
#        [ 9.02103133e-001],
#        [ 1.03216937e+000],
#        [ 1.07336708e+000],
#        [-8.34977068e-317],
#        [ 8.82209775e-001],
#        [ 5.45197191e-317],
#        [ 9.93495666e-001],
#        [ 9.11875041e-001],
#        [ 9.74906343e-001],
#        [ 3.37808472e-316],
#        [-3.51306341e-316],
#        [ 4.54343756e-318],
#        [ 9.46252560e-001],
#        [-9.69192422e-317],
#        [-1.34968340e-002],
#        [ 9.33683029e-001],
#        [ 1.99605164e+000],
#        [ 2.46999276e-317],
#        [ 1.04243548e-316],
#        [-1.83795869e-316],
#        [ 1.01240622e+000],
#        [ 9.88977550e-001],
#        [ 9.33505523e-001],
#        [ 7.04094582e-317],
#        [ 7.09552822e-317],
#        [ 1.71938763e-316],
#        [ 5.40369626e-317],
#        [-3.09380820e-002],
#        [ 3.78446313e-003],
#        [ 1.06095343e+000],
#        [-8.22703291e-318],
#        [ 8.76712801e-001],
#        [ 4.26241500e-317],
#        [ 9.33747986e-001],
#        [ 1.39138485e+000],
#        [ 3.51344636e-316],
#        [ 9.53554479e-001],
#        [-8.52430876e-317],
#        [ 8.48594299e-001],
#        [ 9.96628084e-317],
#        [ 9.62294670e-001],
#        [ 1.06361423e-003],
#        [ 2.77900710e-317],
#        [ 1.88527973e+000],
#        [-6.93510856e-317],
#        [ 1.52661946e+000],
#        [ 3.64797470e-317],
#        [ 2.19237604e-316],
#        [-2.10979493e-311],
#        [ 3.73392225e-005],
#        [ 2.39891677e-316],
#        [-4.44877211e-317],
#        [ 1.00961762e+000],
#        [ 1.04830966e+000],
#        [ 2.19574062e-316],
#        [-7.60467366e-003],
#        [ 1.30517667e+000],
#        [-1.21577500e-316],
#        [ 9.57379118e-001],
#        [ 3.68400938e-317],
#        [ 9.80357015e-001],
#        [-3.52833320e-316],
#        [ 4.45224539e-317],
#        [ 5.73043324e-317]])]

# %% [markdown]
# <a class="anchor" id="6">
#
# # **10. Save results to Kaggle**
#
# [Back to TOP](#TOP)
# </a>

# %%
best_mae_model = min(best_mae_knn, best_mae_rf, )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 best_mae_model = min(best_mae_knn, best_mae_rf, )
#
# NameError: name 'best_mae_knn' is not defined

# %%
# Go one level up from the notebooks folder to reach the repo root
selected_dir = "../results/kaggle_submissions/"
os.makedirs(selected_dir, exist_ok=True)

# %%
# Extract carID
car_ids = test.index.values

# Create DataFrame with best model predictions
best_model_df = pd.DataFrame({
    'carID': car_ids,
    'price': preds_knn
})

# Save predictions to CSV
best_model_df.to_csv(f"{selected_dir}/predictions_knn.csv", index=False)

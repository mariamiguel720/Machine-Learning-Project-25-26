# %% [markdown]
# <b><font size="6"> Cars 4 You: Predicting Car Values with ML </font></b><br><br>
#
# `Group 40`
#
# Ana Macedo (20250405)<br>
# Catarina Mendinhas (20250422)<br>
# Lourenço Silva (20250453)<br>
# Maria Fonseca (20250380)<br>

# %% [markdown]
# ### <font color= '#0400ffff'>**Methodology** </font><a class="anchor" id='top'></a>
#
# - [1. Abstract](#1)
# - [2. Import Libraries](#2)
# - [3. Metadata](#3)
# - [4. Import Datasets](#4)
#     - [4.1 Define new index](#4_1)
# - [5. Data Preprocessing](#5)
#     - [5.1 Types Correction](#5_1)
#         - [5.1.1 Year and previousOwners columns correction](#5_1_1)
#         - [5.1.2 hasDamage Column Correction](#5_1_2)
#     - [5.2 Categorical Features correction](#5_2)
#         - [5.2.1 Correct the values](#5_2_1)
#         - [5.2.2 Check corrections](#5_2_2)
#     - [5.3 Invalid Values](#5_3)
#         - [5.3.1 Invalid Values Analysis](#5_3_1)
#         - [5.3.2 Invalid Values Treatment](#5_3_2)
# - [6. Data Partition](#6)
# - [7. Data Transformation](#7)
#     - [7.1 Outliers Treatment](#7_1)
#     - [7.2 Feature Engineering ](#7_2)
#     - [7.3 Missing Values Imputation](#7_3)
#     - [7.4 Scaling Features](#7_4)
#     - [7.5 Save the Processed Data](#7_5)
#     - [7.6 Encoding](#7_6)
# - [8. Feature Selection](#8)
#     - [8.1 Remove paintQuality%](#8_1)
#     - [8.2 Filter Methods](#8_2)
#         - [8.2.1 Removing Constant Features](#8_2_1)
#         - [8.2.2 Correlation between features - Redundant Features](#8_2_2)
#         - [8.2.3 Correlation with the target - Relevant Features](#8_2_3)
#     - [8.3 Wrapped Methods](#8_3)
#         - [8.3.1 RFE](#8_3_1)
#     - [8.4 Embedded Methods](#8_4)
#         - [8.4.1 Lasso](#8_4_1)
#     - [8.5 Comparison between Models](#8_5)
# - [9. Model and Assessment](#9)
#     - [9.1 Create a Sample to Test Models](#9_1)
#     - [9.2 Define the Scores to Evaluate](#9_2)
#     - [9.3 KNN](#9_3)
#         - [9.3.1 Define Model and Grid Parameters](#9_3_1)
#         - [9.3.2 Test KNN using Samples](#9_3_2)
#         - [9.3.3 Test KNN using the entire Dataset](#9_3_3)
# - [10. Save results to Kaggle](#10)
# - [11. End of the Notebook](#11)

# %% [markdown]
# <a class="anchor" id="1">
#
# # **1. Abstract**
#
# [Back to TOP](#TOP)
# </a>
#
# !!!colocar o abstract final depois

# %% [markdown]
# <a class="anchor" id="2">
#
# # **2. Import Libraries**
#
# [Back to TOP](#TOP)
# </a>
#
# The development of the analyses and models for this project relies on a robust set of Python libraries. Pandas and NumPy are utilized for efficient data manipulation, cleaning, and numerical operations, while Matplotlib and Seaborn support the creation of clear and informative visualizations. Auxiliary libraries such as os, math, and difflib facilitate file management, mathematical calculations, and the correction of categorical variables via text similarity, respectively.
#
# Data preprocessing is executed using Scikit-learn, employing tools like OneHotEncoder for encoding, and a combination of MinMaxScaler, StandardScaler, and RobustScaler for normalization, ensuring resilience against outliers. Missing value handling is managed through simple and nearest-neighbor (KNNImputer) imputation strategies.
#
# Feature selection is addressed comprehensively through three methodologies: filter methods (including VarianceThreshold, Spearman correlation, SelectKBest, and Mutual Information), wrapper methods (RFE - Recursive Feature Elimination), and embedded methods (Lasso).
#
# For predictive modeling, the project explores various regression algorithms, including K-Nearest Neighbors (KNN), Random Forest, and Neural Networks (MLPRegressor), with hyperparameter optimization conducted via RandomizedSearchCV. Rigorous performance evaluation is ensured by metrics such as R^2, MAE, MSE, and MAPE, complemented by detailed statistical analysis provided by Statsmodels. Finally, result reproducibility is guaranteed through the definition of random seeds.

# %%
# General Useful Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from math import ceil
import math

# Text Similarity - Categorical Features Correction
from difflib import SequenceMatcher

# Scaling and Encoding
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, TargetEncoder, MinMaxScaler, StandardScaler, RobustScaler

# Missing Value Imputation
from sklearn.impute import KNNImputer, SimpleImputer

# Data Partition
from sklearn.model_selection import train_test_split

#filter methods
from sklearn.feature_selection import VarianceThreshold
from scipy.stats import spearmanr

# spearman 
from sklearn.feature_selection import SelectKBest, f_regression

# mutual information
from sklearn.feature_selection import mutual_info_classif

#wrapper methods
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.feature_selection import RFE

# embedded methods
from sklearn.linear_model import Lasso

from sklearn.model_selection import RandomizedSearchCV, PredefinedSplit

#KNN
from sklearn.neighbors import KNeighborsRegressor

# Random Forest
from sklearn.ensemble import RandomForestRegressor

#Neural Network
from sklearn.neural_network import MLPRegressor

# DecisionTree
from sklearn.tree import DecisionTreeRegressor

# Ensemble Methods
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor


#Model evaluation
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, median_absolute_error, mean_absolute_percentage_error
import statsmodels.api as sm

# Load Created Functions
import sys
sys.path.append("../")

from Source.visualizations import *
from Source.data_preprocessing import *
from Source.feature_engineering import *
from Source.feature_selection import *
from Source.model_and_assessment import *

# Set random seed for reproducibility
np.random.seed(40111)

# library to hide warnings
#import warnings
#warnings.filterwarnings('ignore')

#!pip install tqdm tqdm-joblib

from tqdm.auto import tqdm
from tqdm_joblib import tqdm_joblib

# %% [markdown]
# <a class="anchor" id="3">
#
# # **3. Metadata**
#
# [Back to TOP](#TOP)
# </a>
#
# Understanding the features is essential to interpret the data correctly and conduct the subsequent analysis and modeling steps. This section provides a brief description of each feature in the dataset, explaining its meaning and type.

# %% [markdown]
# **carID:** An attribute that contains an identifier for each car.
#
# **Brand:** The car's main brand (e.g., Ford, Toyota).
#
# **model:** The car model.
#
# **year:** The year of registration of the car.
#
# **price:** The car's price when purchased by Cars 4 You (in £).
#
# **transmission:** The car's type of transmission.
#
# **mileage:** The total reported distance travelled by the car (in miles).
#
# **tax:** The amount of road tax (in £) that, in 2020, was applicable to the car in question.
#
# **fuelType:** The type of fuel used by the car (Diesel, Petrol, Hybrid, Electric).
#
# **mpg:** The car's consumption of fuel expressed in average miles per gallon.
#
# **engineSize:** Size of the engine in liters (Cubic Decimeters).
#
# **paintQuality%** The mechanic’s assessment of the cars’ overall paint quality and hull integrity (filled by the mechanic during evaluation).
#
# **previousOwner:** Number of previous registered owners of the vehicle.
#
# **hasDamage:** Boolean marker filled by the seller at the time of registration stating whether the car is damaged or not.

# %% [markdown]
# <a class="anchor" id="4">
#
# # **4. Import Datasets**
#
# [Back to TOP](#TOP)
# </a>
#
# Here, we are importing with pd.read_csv() the files to start our project and converting them into Pandas DataFrames. CarID was set to index since it's the unique identifier in all data sets.

# %%
train = pd.read_csv('../../data/train.csv')
test = pd.read_csv('../../data/test.csv')

# %% [markdown]
# <a class="anchor" id="4">
#
# ## **4.1** Define new index
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# For all partitions we will assign the "carID" column as the index, as it represents the number identifier for each individual car.

# %%
train.set_index('carID', inplace = True)
test.set_index('carID', inplace = True)

# %% [markdown]
# <a class="anchor" id="5">
#
# # **5. Data Cleaning**
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# <a class="anchor" id="5_1">
#
# ## **5.1** Metric Features Correction
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# During the Exploratory Data Analysis (EDA) we identified some erros that will now be treated:
#
# - In the columns `Year`, `hasDamage` and `previousOwners` floats exist but these columns should only have integers as they represent discrete variables and a boolean in the case of hasDamage.
#
# - In some columns negative values exist that make no sense.
#
# - The column hasDamage is binary but only has 0's and Nan, what lead us to think that the Nan values represent the 1's.
#
# For these mistakes we will:
#
# - Consider the integer part to the floats that should be integers.
#
# - Replace the negative values with Nan to later be treated has missing values.
#
# - Fill the Nan values with 1's in the hasDamage feature.

# %% [markdown]
# Regarding the negative tax values, we thought they could represent to incentives on electric vehicles, so we will see if this checks out.

# %%
negtax_electric = train[(train['tax'] < 0) & (train['fuelType'] == 'Electric')]
print(f"Number of rows with negative 'tax' and 'Electric' fuel type: {len(negtax_electric)}")
negtax_electric[['tax', 'fuelType']].head(10)
# Out:
# Number of rows with negative 'tax' and 'Electric' fuel type: 0
# Empty DataFrame
# Columns: [tax, fuelType]
# Index: []

# %% [markdown]
# From this analysis, we see that there are no electric vehicles with negative tax, so we eliminate that possibility and correct all negative values by using a function defined by us on the `data_preprocessing.py` file.

# %%
train = correct_metric_features(train)
test = correct_metric_features(test)

# %% [markdown]
# <a class="anchor" id="5_2">
#
# ## **5.2** Categorical Features Correction
#
# [Back to TOP](#TOP)

# %% [markdown]
# We had identified earlier that the categorical features present a lot of misspellings. We will address that here using a function specifically created to correct these values.

# %% [markdown]
# <a class="anchor" id="5_2_1">
#
# ### **5.2.1** Correct the values
#
# [Back to TOP](#TOP)

# %% [markdown]
# Now we are able to correct the values by calling the function.
#
# To reach the thresholds for each feature, we used a trial and error approach. We found that the optimal thresholds depend both on the length of the word and on the number and similarity between unique observations of each feature.
#
# To address these challenges, we created two thresholds, one for shorter words (<=5 characters) and another for longer words (>5 characters). This was important because the word similarity function we used (SequenceMatcher) uses ratios to identify similar words and so each character has different 'weights' based on the length of the word.
#
# Because of the reduced number of unique observations on most features, we saw that this solution was particularly important for the "model" feature since it has a very high number of unique observations and also very similar model names.

# %%
# Correct 'Brand' column
train = clean_with_diff(train, 'Brand', threshold_short=0.6, threshold_long=0.6)
test = clean_with_diff(test, 'Brand', threshold_short=0.6, threshold_long=0.6)

# Correct 'transmission' column
train = clean_with_diff(train, 'transmission', threshold_short=0.7, threshold_long=0.7)
test = clean_with_diff(test, 'transmission', threshold_short=0.7, threshold_long=0.7)

# Correct 'model' column
train = clean_with_diff(train, 'model', threshold_short=0.70, threshold_long=0.90)
test = clean_with_diff(test, 'model', threshold_short=0.70, threshold_long=0.90)

# Correct 'fuelType' column
train = clean_with_diff(train, 'fuelType', threshold_short=0.8, threshold_long=0.8)
test = clean_with_diff(test, 'fuelType', threshold_short=0.8, threshold_long=0.8)

# %% [markdown]
# <a class="anchor" id="5_2_2">
#
# ### **5.2.2** Check corrections
#
# [Back to TOP](#TOP)
#
# Now we will analyse the results of our treatments for each feature.

# %%
corrected_columns = ['Brand', 'transmission', 'model', 'fuelType']

for column in corrected_columns:
    unique_values_train = train[column].unique()
    print(f"Unique values on the column '{column}' (train): {unique_values_train}")
    print('')
    print('-----------------------------------')
    print('')
# Out:
# Unique values on the column 'Brand' (train): ['VW' 'Toyota' 'Audi' 'Ford' 'BMW' 'Skoda' 'Opel' 'Mercedes' 'Hyundai' nan]
#
# -----------------------------------
#
# Unique values on the column 'transmission' (train): ['Semi-Auto' 'Manual' 'Automatic' nan 'unknown' 'Other']
#
# -----------------------------------
#
# Unique values on the column 'model' (train): [' Golf' ' Yaris' ' Q2' ' Fiesta' ' 2 Series' ' 3 Series' ' A3' ' Octavia'
#  ' Passat' ' Focus' ' Insignia' ' A Class' ' Q3' ' Fabia' ' Ka+'
#  ' GLC Class' ' I10' ' C Class' ' Polo' ' E Class' ' Q5' ' Up' ' C-HR'
#  ' Mokka X' ' Corsa' ' Astra' ' TT' ' 5 Series' ' Aygo' ' 4 Series' ' SLK'
#  ' Viva' ' T-Roc' ' EcoSport' ' Tucson' nan ' X-CLASS' ' X2' ' Rapid'
#  ' A1' ' Auris' ' Sharan' ' Adam' ' X3' ' A8' ' B-MAX' ' A4' ' Kona'
#  ' Mokka' ' S-MAX' ' Crossland X' ' Tiguan' ' A5' ' Zafira' ' Ioniq' ' A6'
#  ' Mondeo' ' Yeti Outdoor' ' X1' ' Scala' ' SL CLASS' ' 1 Series' ' Kamiq'
#  ' Kuga' ' Tourneo Connect' ' Q7' ' Arteon' ' Santa Fe' ' Grandland X'
#  ' I800' ' Touran' ' Citigo' ' Roomster' ' Prius' ' Corolla' ' B Class'
#  ' Kodiaq' ' V Class' ' Caddy Maxi Life' ' Superb' ' Getz' ' Combo Life'
#  ' Beetle' ' Galaxy' ' M3' ' GTC' ' X4' ' 3 Serie'
#  ' Grand Tourneo Connect' ' M4' ' Tourneo Custom' ' Z4' ' X5' ' Meriva'
#  ' RS6' ' Verso' ' Touareg' ' Shuttle' ' CLS Class' ' C-MAX' ' Puma'
#  ' Tiguan Allspace' ' 6 Series' ' Caravelle' ' Karoq' ' Grand C-MAX'
#  ' T-Cross' ' A7' ' GLE Clas' ' Golf SV' 'A Class' ' Agila' ' GT86'
#  ' Yeti' ' California' ' Land Cruiser' ' Edge' ' X6' 'Toura' ' Caddy Life'
#  ' 8 Series' ' Fusion' ' Scirocco' ' Z3' ' SL CLAS' ' PROACE VERSO'
#  ' Hilux' 'GLA Class' ' Amarok' 'CLA Class' ' CC' ' 7 Series' ' Avensis'
#  ' Eos' ' M Class' ' Zafira Tourer' ' R8' ' Mustang' 'GLE Class' ' I1'
#  ' Antara' ' Q8' ' Camry' 'RAV4' ' Jetta' ' Kadjar' 'U' ' Supra' ' X7'
#  ' G Class' 'I10' ' S3' 'Focu' 'I40' ' Tigra' ' Escort' ' GLA Clas'
#  ' CL Clas' ' Vivaro' ' Verso-S' ' M5' '2 Serie' ' Veloste' ' S4' ' IQ'
#  ' A2' ' Caddy Maxi' '200' 'SL CLASS' ' Streetka' ' Caddy' ' Cascada'
#  'B-MA' ' Accent' 'Octavi' ' S8' 'C Clas' 'X2' ' K' ' Ranger' 'Fiest'
#  'Zafir' '220' ' VECTRA' 'Insigni' '230' ' Ampera' ' Fox' ' Urban Cruiser'
#  ' GLS Clas' 'Arteo' ' M2' 'Tigua' 'Golf S' 'Yari' ' S5' 'Tucso' 'i3' 'KA'
#  ' M6' 'CLK' 'Mokka ' 'IX35' 'Mokk' 'RS3' ' Terracan']
#
# -----------------------------------
#
# Unique values on the column 'fuelType' (train): ['Petrol' 'Diesel' 'Hybrid' nan 'Other' 'Electric']
#
# -----------------------------------

# %% [markdown]
# **Important Note:** For most of the columns that were corrected, the function seems to have worked properly. However, in the case of the 'model' column, the results were not as good as in the other columns. This is because the original data contained a high number of unique and incorrect values, some of which were very similar to each other, having just one character difference between the wrong and correct model, but also just one different character from another model's name. This makes it impossible to achieve a perfect correction with this approach.
#
# Example: 2 Serie (wrong), 3 Serie (wrong), 2 Series (correct), 3 Series (correct)
#
# Nevertheless, the vast majority of the data is now properly cleaned and corrected and we will stick with this method.

# %% [markdown]
# Also based on the previous unique values analysis, we decided to check the percentage of the 'Other' category in the 'transmission' column. If the proportion is not significant, we believe it would be reasonable to replace it with an 'Unknown' category, as this simplification could make the next steps of our analysis easier and more consistent.

# %%
(train[train['transmission'] == 'Other'].shape[0] / train.shape[0] * 100).__round__(4)
# Out:
# 0.0066

# %% [markdown]
# The percentage is very small so we are going to replace the category as mentioned before.

# %%
train = replace_category_transmission(train)
test = replace_category_transmission(test)

# %% [markdown]
# **Important:** Before applying any outliers treatment we need to split the data into train and validation sets. This is important to avoid data leakage. After splitting the data we can apply the method using only the training set statistics.

# %% [markdown]
# <a class="anchor" id="6">
#
# # **6. Data Partition**
#
# [Back to TOP](#TOP)

# %% [markdown]
# Define the independent features as X and the dependent as Y

# %%
X = train.drop('price', axis = 1)
y = train['price']

# %% [markdown]
# Split the dataset into train and validation

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size = 0.2, random_state = 0,  shuffle = True)

# %% [markdown]
# <a class="anchor" id="7">
#
# # **7. Data Transformation**
#
# [Back to TOP](#TOP)

# %% [markdown]
# <a class="anchor" id="7_1">
#
# ## **7.1** Outliers Treatment
#
# [Back to TOP](#TOP)

# %% [markdown]
# To identify outliers, we decided to use the **Interquartile Range (IQR) method** and apply it to all numerical features.
#
# The following analysis identifies the number and percentage of outliers per features, helping to evaluate whether data cleaning or transformation is be necessary before modeling.

# %% [markdown]
# Here we will create a function to return a summary of the total number of outliers per feature and how much they represent of the total in percentage. This summary is based on the IQR method and we will analyse the train dataset only.

# %%
outlier_summary(X_train)
# Out:
#            Column  Total Outliers  Percentage (%)
# 0            year            1437            2.36
# 1         mileage            2603            4.28
# 2             tax           15938           26.22
# 3             mpg             922            1.52
# 4      engineSize             494            0.81
# 5   paintQuality%               0            0.00
# 6  previousOwners               0            0.00
# 7       hasDamage            1257            2.07

# %% [markdown]
# From this, we take that most numeric features do not have a big share of outliers, as they represent less than 5% of all observations. Only the feature `tax` has a very big number of ouliers, with 26.23% of the whole population.
#
# We are now going to analyse these graphically through boxplots.

# %%
create_boxplots(X_train)

# %% [markdown]
# We started by applying the IQR method and then we realized it eliminated too much data, which then hurt the model's results and decided to create different thresholds specific for each feature:
#
# - `year:` between 1990 and 2020
# - `mileage`,`tax`, `mpg`: 2.2 IQR multiplier
# - `engineSize:` between 0.9L and 5.5L
# - `previousOwners:` between 0 and 6
#
# To reach the 2.2 IQR multiplier and the upper and lower limits, we used a trial and error approach. We found that 2.2 was a good middle ground because the default multiplier eliminated too many features and this is a way to widen the range of accepted results while eliminating extreme outliers.

# %% [markdown]
# Now specifically for each feature:
#
# - `year:` Cars older than 1990 were extremely rare and introduced high price variance, while years beyond 2020 are not possible (dataset is from 2020); restricting the range improves data realism and model stability.
# - `mileage:` Mileage has a strong right-skew; using a 2.2 IQR multiplier caps extreme values that disproportionately reduce accuracy without removing legitimate high-mileage cases.
# - `tax:` Very high tax values occur infrequently and are often errors or special situations; applying a 2.2 IQR multiplier reduces the effect of unrealistic taxation outliers.
# - `mpg:` Fuel efficiency extremes are uncommon and distort pricing; a 2.2 IQR multiplier tightens the distribution while preserving real variability across models.
# - `engineSize:` Values below 0.9L or above 5.5L correspond to niche or erroneous entries; bounding engine size maintains realistic ranges and limits skew.
# - `previousOwners:` The IQR visualisation shows no outliers for this feature and more than 6 previous owners is highly atypical. It signals noisy observations and capping reduces their undue influence on vehicle price.

# %% [markdown]
# Apply custom thresholds

# %%
X_train_clean = treat_outliers_custom(X_train, X_train)
X_val_clean = treat_outliers_custom(X_train, X_val)
test_clean = treat_outliers_custom(X_train, test)

# %%
X_train = X_train_clean.copy()
X_val = X_val_clean.copy()
test = test_clean.copy()

# %% [markdown]
# Visualize results after the outlier treatment

# %%
create_boxplots(X_train)

# %% [markdown]
# Analysing our results, we see that the distributions are much more balanced, with fewer outliers. The outliers that remain should be significant for our analysis, as they are close to the IQR limits and have a significant number of observations.

# %% [markdown]
# <a class="anchor" id="7_2">
#
# ## **7.2** Feature Engineering
#
# [Back to TOP](#TOP)

# %% [markdown]
# In this stage of the project, we created new features designed to enhance the predictive power of our model. These engineered variables fall into two main groups:
#
# 1. Features derived directly from existing variables, without using statistical aggregates such as mean, median or mode.
# 2. Features computed using aggregate statistics, which must be calculated exclusively on the training set (X_train) to avoid data leakage.
#
# Below, we describe each feature and the motivation behind its inclusion.
#
# **1. Directly Engineered Features**
#
# - `car_age:` calculate the age of the car considering the current year and the year of its registration. This feature helps us to capture depreciation, this is, older cars tend to be cheaper.
#
# - `is_recent_car:` binary flag, 1 if the car is less than 3 years old, otherwise 0. We decided to create this feature because highlights newer cars, usually have higher resale prices.
#
# - `mileage_category:` transforms the original continuous mileage feature into an ordered categorical feature with five usage levels according to the total mileage.  This way it's easier to capture differences in vehicle wear and market value.
#
# - `is_hybrid_or_eletric:` binary indicator that is 1 if the fuel type is Hybrid or Electric. Eco-friendly cars often hold higher market value.
#
# - `is_automatic:`binary indicator that is 1 if the type of transmission is automatic or semi-automatic. Automatics typically cost more to buy and maintain.
#
# - `fuel_eficciency_score:` Ratio of mpg / engineSize. Captures how efficiently the car converts fuel given engine capacity.
#
# - `tax_to_engine_ratio:` Tax value divided by engine size. Indicates how expensive it is to maintain the car relative to its power.
#
# - `tax_efficency:` mpg / tax. Measures how fuel-efficient the car is relative to its yearly tax burden.
#
# - `is_first_owner:` binary indicator that is 1 if there were no previous owners. First-owner cars tend to have less wear, better care and higher prices.
#
# - `ownership_ratio:` previousOwner / car_age. Captures how frequently ownership changed. Frequent changes might signal reliability issues.
#
#
# **2. Features Based on Statistical Aggregation (Train-Only)**
#
# - `brand_median_mileage:` median mileage per brand. Typical mileage level for each brand that is able to capture brand usage patterns.
#
# - `brand_avg_engineSize`: engineSize mean per brand. Represents typical engine capacity of each brand.
#
# - `model_median_tax:` median tax per model. Captures model-specific taxation tendencies.
#
# - `fueltype_avg_mpg:` mpg mean per fuelType. Average fuel efficiency for each fuel type.
#
# - `brand_avg_age:` car_age mean per brand. Average car age per brand, basically compare newer against older brands.
#
# All feature engineering steps were encapsulated in a dedicated function, stored in the file feature_engineering.py, which was already imported and will be now applied to the dataset as needed.

# %%
X_train.shape
# Out:
# (60778, 12)

# %%
X_train_fe = create_features(X_train, X_train, current_year=2020, threshold=3)
X_val_fe = create_features(X_train, X_val, current_year=2020, threshold=3)
test_fe = create_features(X_train, test, current_year=2020, threshold=3)

# Update dataframes to include new features
X_train = X_train_fe.copy()  
X_val = X_val_fe.copy()
test = test_fe.copy()

# %%
X_train.shape
# Out:
# (60778, 26)

# %% [markdown]
# <a class="anchor" id="7_3">
#
# ## **7.3** Missing Values Imputation
#
# [Back to TOP](#TOP)

# %% [markdown]
# Before starting to fill missing values, we plot a table with the missing value percentages. With this we can easily identify columns with many absent entries and decide whether they are relevant for the model or should be discarded or imputed.

# %%
missing_df = missing_values_table(X_train)
missing_df
# Out:
#                   Feature  Missing_Percent
# 0     tax_to_engine_ratio        12.708546
# 1          tax_efficiency        12.701965
# 2   fuel_efficiency_score        12.305439
# 3                     tax        10.867419
# 4                     mpg        10.446214
# 5          previousOwners         2.515713
# 6          is_first_owner         2.515713
# 7                 mileage         2.364342
# 8        mileage_category         2.364342
# 9              engineSize         2.089572
# 10           transmission         2.031985
# 11          paintQuality%         2.025404
# 12   brand_median_mileage         1.992497
# 13                  Brand         1.992497
# 14          brand_avg_age         1.992497
# 15   brand_avg_engineSize         1.992497
# 16                   year         1.971108
# 17                car_age         1.971108
# 18          is_recent_car         1.971108
# 19               fuelType         1.956300
# 20       fueltype_avg_mpg         1.956300
# 21       model_median_tax         1.948073
# 22                  model         1.946428
# 23           is_automatic         0.000000
# 24              hasDamage         0.000000
# 25  is_hybrid_or_electric         0.000000

# %% [markdown]
# Although some features have missing values, none have a sufficiently high percentage to warrant removal. All columns are considered relevant and can be retained for modeling, with missing values handled through imputation where necessary.

# %% [markdown]
# Now we verify that there are no missing values left in the datasets

# %% [markdown]
# <a class="anchor" id="7_4">
#
# ## **7.4** Encoding
#
# [Back to TOP](#TOP)

# %% [markdown]
# Before training machine learning models, it is necessary to convert categorical features into a numerical format, as most algorithms cannot process non-numeric data directly. This step, known as encoding, ensures that the categorical information can be effectively interpreted by the models without losing its meaning.
#
# In this section, we will apply `One-Hot Encoding` to features with a small number of categories (Brand, Transmission, fuelType) and use a `Ordinal Encoder` for the features that contains many distinct categories (model). This approach allows us to represent all categorical features in a consistent and efficient way, preparing the dataset for further preprocessing and model development.

# %%
X_train_encoded = encoding_features(X_train, y_train, X_train)
X_val_encoded = encoding_features(X_train, y_train, X_val)
test_encoded = encoding_features(X_train, y_train, test)
# A warning may appear if some categories in validation/test were not present in training. This happens because the Encoder was fitted only on the training data.
# With this, the program emits a warning and assigns zeros to those unseen categories, but continues to run normally.

# %%
# Update dataframes to encoded versions
X_train = X_train_encoded.copy()
X_val = X_val_encoded.copy()
test = test_encoded.copy()

# %%
X_train
# Out:
#        year  mileage    tax   mpg  engineSize  paintQuality%  previousOwners  \
# carID
# 59459  2016  29601.0   81.0  62.8         1.0           42.0               2
# 49082  2017  62140.0  145.0  64.2         2.0           40.0               3
# 14425  2008  87470.8  189.0  42.2         2.0           59.0               1
# 13190  2019  11208.0  145.0  52.3         2.0           72.0               4
# 60655  2019   2357.0  145.0  44.8         1.2           81.0               3
# ...     ...      ...    ...   ...         ...            ...             ...
# 47192  2019   4797.0  145.0  62.8         1.6           95.0               1
# 71813  2012  87470.8  189.0  47.7         2.0           99.0               3
# 4910   2019   1800.0  145.0  47.9         1.0           92.0               2
# 67195  2017  29827.0  125.0  57.6         2.0           41.0            <NA>
# 15659  2017  30605.0    NaN   NaN         1.5           34.0               0
#
#        hasDamage  car_age  is_recent_car  ...  transmission_Manual_ohe  \
# carID                                     ...
# 59459          0        4              0  ...                      1.0
# 49082          0        3              1  ...                      1.0
# 14425          0       12              0  ...                      0.0
# 13190          0        1              1  ...                      0.0
# 60655          0        1              1  ...                      1.0
# ...          ...      ...            ...  ...                      ...
# 47192          0        1              1  ...                      0.0
# 71813          0        8              0  ...                      0.0
# 4910           0        1              1  ...                      1.0
# 67195          0        3              1  ...                      0.0
# 15659          0        3              1  ...                      1.0
#
#        transmission_Semi-Auto_ohe  transmission_unknown_ohe  \
# carID
# 59459                         0.0                       0.0
# 49082                         0.0                       0.0
# 14425                         0.0                       0.0
# 13190                         1.0                       0.0
# 60655                         0.0                       0.0
# ...                           ...                       ...
# 47192                         0.0                       0.0
# 71813                         0.0                       0.0
# 4910                          0.0                       0.0
# 67195                         1.0                       0.0
# 15659                         0.0                       0.0
#
#        transmission_nan_ohe  fuelType_Electric_ohe  fuelType_Hybrid_ohe  \
# carID
# 59459                   0.0                    0.0                  0.0
# 49082                   0.0                    0.0                  0.0
# 14425                   0.0                    0.0                  0.0
# 13190                   0.0                    0.0                  0.0
# 60655                   0.0                    0.0                  0.0
# ...                     ...                    ...                  ...
# 47192                   0.0                    0.0                  0.0
# 71813                   0.0                    0.0                  0.0
# 4910                    0.0                    0.0                  0.0
# 67195                   0.0                    0.0                  0.0
# 15659                   0.0                    0.0                  0.0
#
#        fuelType_Other_ohe  fuelType_Petrol_ohe  fuelType_nan_ohe  \
# carID
# 59459                 0.0                  1.0               0.0
# 49082                 0.0                  0.0               0.0
# 14425                 0.0                  1.0               0.0
# 13190                 0.0                  0.0               0.0
# 60655                 0.0                  1.0               0.0
# ...                   ...                  ...               ...
# 47192                 0.0                  0.0               0.0
# 71813                 0.0                  0.0               0.0
# 4910                  0.0                  1.0               0.0
# 67195                 0.0                  0.0               1.0
# 15659                 0.0                  0.0               0.0
#
#        mileage_category_ordinal
# carID
# 59459                         1
# 49082                         2
# 14425                         2
# 13190                         1
# 60655                         0
# ...                         ...
# 47192                         0
# 71813                         2
# 4910                          0
# 67195                         1
# 15659                         1
#
# [60778 rows x 33 columns]

# %% [markdown]
# <a class="anchor" id="7_5">
#
# ## **7.5** Scaling Features
#
# [Back to TOP](#TOP)

# %% [markdown]
# Numerical features are scaled to ensure all features are in a comparable scale. This preserves relative relationships while preventing features with larger ranges from dominating distance or gradient based algorithms, improving model performance and stability.

# %%
# Scale numeric features using our scaling function
X_train_scaled = scaling_features(X_train, X_train, method="standard")
X_val_scaled = scaling_features(X_train, X_val, method="standard")
test_scaled = scaling_features(X_train, test, method="standard")

# %%
# Create copies of the treated datasets
X_train = X_train_scaled.copy()
X_val = X_val_scaled.copy()
test = test_scaled.copy()

# %% [markdown]
# # Imputation w KNN

# %%
# Impute missing values with KNN to see differences in the model results
X_train_treated = impute_missing(X_train, X_train, method='knn')
X_val_treated = impute_missing(X_train, X_val, method='knn')
test_treated = impute_missing(X_train, test, method='knn')

# %%
X_train = X_train_treated.copy()
X_val = X_val_treated.copy()
test = test_treated.copy()

# %%
# Check that there are no missing values left
if all(df.isnull().sum().sum() == 0 for df in [X_train, X_val]):
    print("PERFECT! All datasets are treated and have no missing values.")
else:
    print("ATENTTION!!!! There are still missing values in at least one of the datasets.")
# Out:
# PERFECT! All datasets are treated and have no missing values.

# %% [markdown]
# <a class="anchor" id="1">
#
# # **8. Feature Selection**
#
# [Back to TOP](#TOP)
# </a>
#
# In this stage of the project, we design and implement a structured feature selection pipeline. The process begins by removing the feature 'paintQuality%' derived from the mechanic’s evaluation, as these feature will not be considered for modelling.
#
# After this initial reduction, we apply a sequence of filter-based methods to identify and exclude features that are constant, redundant, or highly correlated with the target variable.
#
# Next, we incorporate a wrapper method which is the Recursive Feature Elimination (RFE) to evaluate subsets of features based on model performance. Finally, we use Lasso regression as an embedded method, allowing the model itself to perform feature selection through regularisation.
#
# The rationale is to apply these three complementary approaches (Filter, Wrapper, and Embedded) to the same preprocessed dataset to obtain a robust and diversified assessment of feature relevance. At the end of the process, we compare the sets of features retained by each method. The final subset of features used for modelling is defined by selecting those chosen by at least a predefined number of methods (e.g., 1, 2, or all 3), a threshold that can be adjusted according to project needs.
# This ensures that the final modelling dataset is composed only of the most informative and consistently relevant features.
#
# We also want to note that throughout this notebook we repeatedly inspect the shape of the X_train dataset to verify whether features are being retained or removed as intended during each step of the selection process.

# %% [markdown]
# <a class="anchor" id="5_1">
#
# ## **8.1 Remove paintQuality%**
#
# [Back to TOP](#TOP)
# </a>
#
# This decision is supported by our Exploratory Data Analysis (EDA), where we concluded that these attribute originate from the mechanic’s evaluation. Since the objective of this machine learning project is precisely to replace this stage of the process, the model must operate without relying on such information.

# %%
X_train.shape
# Out:
# (60778, 33)

# %%
X_train = X_train.drop(['paintQuality%'], axis=1, errors='ignore')
X_val = X_val.drop(['paintQuality%'], axis=1, errors='ignore')

# %%
X_train.shape
# Out:
# (60778, 32)

# %% [markdown]
# <a class="anchor" id="5_1">
#
# ## **8.2 Filter Methods**
#
# [Back to TOP](#TOP)
# </a>
#
# Filter methods are ideal for an initial screening of high-dimensional datasets due to their simplicity, even though they are considered less effective than model-based methods.
# In this section, we will explore three filter-based techniques to select the features.

# %% [markdown]
# <a class="anchor" id="5_1_1">
#
# ### **8.2.1 Removing Constant Features**
#
# [Back to TOP](#TOP)
# </a>
#
# This method identifies features that have low or zero variance, which are unlikely to contribute meaningful information to the model, and thus can help to reduce noise and improve efficiency.

# %%
fm_1 = apply_variance_filter(X_train, threshold=0.02, return_summary=True)
# Out:
# {'year': np.float64(0.9934314239630367), 'mileage': np.float64(0.9923932123311437), 'tax': np.float64(0.9609525160233404), 'mpg': np.float64(0.9807778980368085), 'engineSize': np.float64(0.9939546043671307), 'previousOwners': np.float64(0.9815491639897392), 'hasDamage': np.float64(1.0000000000000002), 'car_age': np.float64(0.9934314239630366), 'is_recent_car': np.float64(0.9931205606668055), 'is_hybrid_or_electric': np.float64(1.0), 'is_automatic': np.float64(0.9999999999999998), 'fuel_efficiency_score': np.float64(0.9866228930805075), 'tax_to_engine_ratio': np.float64(1.0023489383614461), 'tax_efficiency': np.float64(0.9766758838258551), 'is_first_owner': np.float64(0.9815721811754136), 'brand_median_mileage': np.float64(0.989439956903697), 'brand_avg_engineSize': np.float64(0.9865665318544335), 'model_median_tax': np.float64(0.9884199547409767), 'fueltype_avg_mpg': np.float64(0.9875951863700984), 'brand_avg_age': np.float64(0.9950009928898671), 'Brand_target': np.float64(1.0000000000000002), 'model_target': np.float64(1.0), 'transmission_Manual_ohe': np.float64(0.24770285632170005), 'transmission_Semi-Auto_ohe': np.float64(0.17310233200339947), 'transmission_unknown_ohe': np.float64(0.009790665103608482), 'transmission_nan_ohe': np.float64(0.019906956169434324), 'fuelType_Electric_ohe': np.float64(6.58089563139489e-05), 'fuelType_Hybrid_ohe': np.float64(0.028072786024591144), 'fuelType_Other_ohe': np.float64(0.002216264737370499), 'fuelType_Petrol_ohe': np.float64(0.24829448857375883), 'fuelType_nan_ohe': np.float64(0.01918028880966603), 'mileage_category_ordinal': np.float64(1.0)}
# Total features kept: 27
# Features selected: ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'previousOwners', 'hasDamage', 'car_age', 'is_recent_car', 'is_hybrid_or_electric', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'tax_efficiency', 'is_first_owner', 'brand_median_mileage', 'brand_avg_engineSize', 'model_median_tax', 'fueltype_avg_mpg', 'brand_avg_age', 'Brand_target', 'model_target', 'transmission_Manual_ohe', 'transmission_Semi-Auto_ohe', 'fuelType_Hybrid_ohe', 'fuelType_Petrol_ohe', 'mileage_category_ordinal']
# Nº Features eliminated: 5

# %%
#Check the amount of features that were removed
len(fm_1)
# Out:
# 27

# %% [markdown]
# <a class="anchor" id="5_1_2">
#
# ### **8.2.2 Correlation between features - Redundant Features**
#
# [Back to TOP](#TOP)
# </a>
#
# We use correlation measures to identify highly correlated features. Removing redundant features helps reduce multicollinearity and simplifies the dataset, making the model more efficient and easier to interpret.

# %%
fm_2 = remove_highly_correlated_features(X_train[fm_1], threshold=0.85, return_summary=True)
# Out:
# Total features kept: 21
# Features selected: ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'previousOwners', 'hasDamage', 'is_recent_car', 'is_hybrid_or_electric', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'is_first_owner', 'brand_median_mileage', 'brand_avg_engineSize', 'model_median_tax', 'fueltype_avg_mpg', 'brand_avg_age', 'Brand_target', 'model_target', 'transmission_Semi-Auto_ohe']
# Nº Features eliminated: 6

# %%
# Check that some features were removed
len(fm_2)
# Out:
# 21

# %% [markdown]
# <a class="anchor" id="5_1_3">
#
# ### **8.2.3 Correlation with the target - Relevant Features**
#
# [Back to TOP](#TOP)
# </a>
#
# These processes consist of setting a correlation threshold and keeping only the features that show a meaningful relationship with the target feature.
#
# We decided to utilize Spearman correlation because it measures monotonic relationships rather than being strictly limited to linear relationships, as is the case with the Pearson coefficient. This is crucial because, in the context of car pricing, the depreciation (for example mileage) or the impact of other characteristics is often non-linear. Additionally, Spearman is based on rankings, which makes it significantly more robust to outliers, providing a more reliable measure of feature relevance for our dataset.

# %%
filter_cols = spearman_correlation_selection(X_train[fm_2], y_train, threshold=0.2, return_summary=True)
# Out:
# Total features kept: 15
# Features selected by Spearman method: ['model_target', 'fuel_efficiency_score', 'year', 'is_automatic', 'Brand_target', 'engineSize', 'brand_avg_engineSize', 'mileage', 'is_recent_car', 'transmission_Semi-Auto_ohe', 'brand_avg_age', 'mpg', 'tax', 'fueltype_avg_mpg', 'tax_to_engine_ratio']
# Nº Features eliminated: 6

# %% [markdown]
# <a class="anchor" id="5_2">
#
# ## **8.3 Wrapped Methods**
#
# [Back to TOP](#TOP)
# </a>
#
# Wrapper methods evaluate subsets of features by training and assessing a predictive model, making them more computationally expensive but generally more effective than filter approaches. Because they consider feature interactions and model performance directly, they provide a more nuanced selection.
# In this section, we apply a wrapper-based technique to identify the most informative features for our target variable.

# %% [markdown]
# <a class="anchor" id="5_2_1">
#
# ### **8.3.1 RFE**
#
# [Back to TOP](#TOP)
# </a>
#
# Here we use LinearRegression as the estimator for RFE because it is simple, fast to train, and provides a clear interpretation of feature importance through its coefficients.
# We selected 30 features because this represents a meaningful number of predictors while still reducing the dimensionality of the dataset. This choice offers a good balance between model simplicity and information retention, and it also allows for a consistent comparison with the other feature selection methods. We also observed that the filter methods retained fewer than 30 features, which further supports using this threshold for RFE.

# %%
wrapped = rfe_selection(X_train[fm_2], X_val[fm_2], y_train, y_val, LinearRegression, return_summary=True)
wrapped_cols = wrapped[0]
# Out:
# Total Features Kept: 16
# Features Selected by RFE Method: ['year', 'mileage', 'mpg', 'engineSize', 'is_recent_car', 'is_hybrid_or_electric', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'brand_median_mileage', 'brand_avg_engineSize', 'fueltype_avg_mpg', 'brand_avg_age', 'Brand_target', 'model_target', 'transmission_Semi-Auto_ohe']
# Score with 16 features: 2571.792812
# Nº Features eliminated: 5

# %%
train_mae_list = wrapped[1]
val_mae_list = wrapped[2]

plt.plot(list(range(1,len(train_mae_list)+1)), train_mae_list, label="MAE on Training Set", color='yellowgreen')
plt.plot(list(range(1,len(val_mae_list)+1)), val_mae_list, label="MAE on Validation Set", color='dimgray')
plt.xlabel("Number of Features")
plt.ylabel("Mean Absolute Error")
plt.legend()
plt.show()

# %% [markdown]
# <a class="anchor" id="5_3">
#
# ## **8.4 Embedded Methods**
#
# [Back to TOP](#TOP)
# </a>
#
# Embedded methods perform feature selection as part of the model training process itself. By incorporating regularisation or other model-driven selection criteria, they offer a balance between the efficiency of filter methods and the predictive power of wrapper methods.
# Now, we use an embedded method to select features based on their contribution to the model’s optimisation procedure.

# %% [markdown]
# <a class="anchor" id="5_3_1">
#
# ### **8.4.1 Lasso**
#
# [Back to TOP](#TOP)
# </a>
#
# Lasso is a linear regression method that incorporates L1 regularisation to constrain the model’s coefficients. This penalty forces some coefficients to shrink exactly to zero, which means that Lasso performs feature selection as part of the training process. By using this method, we can also define a threshold that helps determine which features should be considered irrelevant when their coefficients are close to zero.

# %%
embedded_cols = lasso_selection(X_train[fm_2], y_train, coef_threshold=100, return_summary=True)
# Out:
# [ 2421.09465002 -1949.73766345   -68.558776   -3233.82959869
#   4149.2995825     16.62378345   -21.79680452   440.06047753
#    466.49037608   552.01704087  3223.78298926  -810.14578753
#    -22.59615117   160.18392438 -1211.96749523    45.74385683
#    455.42823261   179.51080131  2030.71679641  3577.98192957
#    857.78408579]
# Total features kept: 16
# Features selected by Lasso method: ['year', 'mileage', 'mpg', 'engineSize', 'is_recent_car', 'is_hybrid_or_electric', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'brand_median_mileage', 'brand_avg_engineSize', 'fueltype_avg_mpg', 'brand_avg_age', 'Brand_target', 'model_target', 'transmission_Semi-Auto_ohe']
# Nº Features eliminated: 5

# %% [markdown]
# <a class="anchor" id="8_5">
#
# ## **8.5 Feature Importance**
#
# [Back to TOP](#TOP)
# </a>

# %%
mae_importance = DecisionTreeRegressor(criterion='absolute_error', random_state=42).fit(X_train[fm_2], y_train).feature_importances_
df_fi = pd.DataFrame(mae_importance, index=X_train[fm_2].columns, columns=['MAE Importance'])

# %%
df_fi = pd.DataFrame(mae_importance, index=X_train[fm_2].columns, columns=['MAE Importance'])
df_fi['MAE Importance'].sort_values().plot(kind='barh', figsize=(12,6))
# Out:
# <Axes: >

# %%
feature_importance_cols = (
    df_fi
    .sort_values('MAE Importance', ascending=False)
    .head(8)
    .index
    .tolist()
)
feature_importance_cols
# Out:
# ['model_target',
#  'year',
#  'mileage',
#  'engineSize',
#  'fuel_efficiency_score',
#  'mpg',
#  'tax_to_engine_ratio',
#  'previousOwners']

# %% [markdown]
# <a class="anchor" id="5_4">
#
# ## **8.5 Comparison between Models**
#
# [Back to TOP](#TOP)
# </a>
#
# As mentioned previously, we will compare the outputs of the different feature selection methods and identify the features that consistently appear as important for our regression model.
# The function we defined performs this comparison by selecting the features that are retained by at least a minimum number of methods (n_agreed). For example, if n_agreed = 2, the function returns all features that were selected by two or more of the three methods.
#
# We assign the resulting set of selected features to a variable so that we can later use it to build our final modelling dataset, which will include only these chosen predictors.

# %%
comparison_feature_selection(X_train[fm_2], filter_cols, wrapped_cols, embedded_cols, 
                                                 feature_importance_cols, n_agreed=2, return_summary=True)[1]
# Out:
# Total features before selection: 21
# Total features selected by at least 2 methods: 16
# Selected features: ['year', 'mileage', 'mpg', 'engineSize', 'is_recent_car', 'is_hybrid_or_electric', 'is_automatic', 'fuel_efficiency_score', 'tax_to_engine_ratio', 'brand_median_mileage', 'brand_avg_engineSize', 'fueltype_avg_mpg', 'brand_avg_age', 'Brand_target', 'model_target', 'transmission_Semi-Auto_ohe']
#                        Feature  Lasso  RFE  Spearman  Feature Importance  Sum
# 0                         year      1    1         1                   1    4
# 1                      mileage      1    1         1                   1    4
# 2                          tax      0    0         1                   0    1
# 3                          mpg      1    1         1                   1    4
# 4                   engineSize      1    1         1                   1    4
# 5               previousOwners      0    0         0                   1    1
# 6                    hasDamage      0    0         0                   0    0
# 7                is_recent_car      1    1         1                   0    3
# 8        is_hybrid_or_electric      1    1         0                   0    2
# 9                 is_automatic      1    1         1                   0    3
# 10       fuel_efficiency_score      1    1         1                   1    4
# 11         tax_to_engine_ratio      1    1         1                   1    4
# 12              is_first_owner      0    0         0                   0    0
# 13        brand_median_mileage      1    1         0                   0    2
# 14        brand_avg_engineSize      1    1         1                   0    3
# 15            model_median_tax      0    0         0                   0    0
# 16            fueltype_avg_mpg      1    1         1                   0    3
# 17               brand_avg_age      1    1         1                   0    3
# 18                Brand_target      1    1         1                   0    3
# 19                model_target      1    1         1                   1    4
# 20  transmission_Semi-Auto_ohe      1    1         1                   0    3

# %%
selected_features = comparison_feature_selection(X_train[fm_2], filter_cols, wrapped_cols, embedded_cols, 
                                                 feature_importance_cols, n_agreed=2)[0]

# Define final datasets with selected features
X_train_final = X_train[selected_features]
X_val_final = X_val[selected_features]
test_final = test[selected_features]

# %% [markdown]
# <a class="anchor" id="1">
#
# # **9. Model and Assessment**
#
# [Back to TOP](#TOP)
# </a>
#
# Having identified the most significant features through the selection process, we now proceed to train and evaluate the regression models. We start by establishing a baseline and progressively explore more complex models to predict car resale prices effectively. This structured workflow ensures that our models are built upon the most relevant data, optimizing both efficiency and accuracy.
#
# Throughout this section, we continue to utilize the custom functions from our .py files to streamline model implementation and performance assessment.

# %% [markdown]
# We begin by concatenating the training and validation datasets and assigning each instance a label that will later be used to create a PredefinedSplit. The purpose of this setup is to ensure that the RandomizedSearchCV uses our custom train–validation split when tuning the hyperparameters of the models we intend to evaluate.

# %%
X_train = X_train_final.copy()
X_val = X_val_final.copy()
test = test_final.copy()

# %%
# Combine train and validation datasets
X_combined = np.concatenate([X_train, X_val], axis=0)
y_combined = np.concatenate([y_train, y_val], axis=0)

# Create a test fold index (-1 for train, 0 for validation)
test_fold = [-1] * len(X_train) + [0] * len(X_val)

print('Test fold: ', len(test_fold))
print('X_combined: ', len(X_combined))
print('y_combined: ', len(y_combined))

# Define the PredefinedSplit
ps = PredefinedSplit(test_fold=test_fold) # aqui diz que os dados de treino são os que têm label -1 e os de validação são os que têm label 0
# Out:
# Test fold:  75973
# X_combined:  75973
# y_combined:  75973

# %% [markdown]
# <a class="anchor" id="5_1">
#
# ## **9.1** Create a Sample to Test Models
#
# [Back to TOP](#TOP)
# </a>
#
# In this subsection, we create a sample of our datasets to test the modelling structure and ensure that the code is correctly implemented. Working with a smaller subset speeds up experimentation and allows us to verify the functionality of our models more efficiently. This approach also helps us identify potential issues earlier in the process.

# %%
X_train_s = X_train.sample(1000, random_state=42)
y_train_s = y_train.loc[X_train_s.index]
X_val_s = X_val.sample(500, random_state=42)
y_val_s = y_val.loc[X_val_s.index]

# Recriar combined sample
sample_X_combined = np.concatenate([X_train_s, X_val_s])
sample_y_combined = np.concatenate([y_train_s, y_val_s])

# Novo fold correto!
sample_test_fold = [-1] * len(X_train_s) + [0] * len(X_val_s)

ps_sample = PredefinedSplit(sample_test_fold)

# %% [markdown]
# <a class="anchor" id="9_2">
#
# ## **9.2** Define the Scores to Evaluate
#
# [Back to TOP](#TOP)
# </a>
#
# In this subsection, we define the evaluation metrics that will be used to assess model performance. We create a dictionary containing the selected scoring functions, which can later be passed directly to the RandomizedSearchCV during hyperparameter tuning.

# %%
scoring = {
    'r2': 'r2',
    'mae': 'neg_mean_absolute_error'
}

# %% [markdown]
# <a class="anchor" id="9_3">
#
# ## **9.3** Test Different Models
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# <a class="anchor" id="9_3_1">
#
# ## **9.3.1** LinearRegression
#
# [Back to TOP](#TOP)
# </a>

# %%
# Linear Regression with Randomized Search CV
model_lr = LinearRegression()

# We test only if the model should calculate the intercept (the base value) or not
param_grid_lr = {
    "fit_intercept": [True, False], 
    "positive": [False, True], # True, forces the coefficients to be positive
    "n_jobs": [None, -1],
}
# Apply Randomized Search CV
rsCV_lr = apply_randomized_search_cv(
    model_lr, 
    param_grid_lr, 
    iterations=2, 
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

# Check results
evaluate_model(rsCV_lr)
# Out:
# Fitting 1 folds for each of 2 candidates, totalling 2 fits
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'positive': False, 'n_jobs': -1, 'fit_intercept': True}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'positive': False, 'n_jobs': None, 'fit_intercept': True}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8129715071954543
# Best validation R2: 0.8087654433030559
# R2 Gap: 0.517369164253772 %
# Best train MAE: 2640.3307169461677
# Best validation MAE: 2663.6179756840215
# MAE Gap: 0.8819826466582966 %
# Best parameters: {'positive': False, 'n_jobs': -1, 'fit_intercept': True}

# %%
# ALTERANDO A FS E FICAMOS COM 20 FEATURES

# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8153412078259057
# Best validation R2: 0.8112872331797634
# R2 Gap: 0.4972120392335107 %
# Best train MAE: 2621.3742491203975
# Best validation MAE: 2642.357565396345
# MAE Gap: 0.8004700695823307 %
# Best parameters: {'positive': False, 'n_jobs': -1, 'fit_intercept': True}




# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8133559243300086
# Best validation R2: 0.8088425208375885
# R2 Gap: 0.5549112457916857 %
# Best train MAE: 2638.1491769684803
# Best validation MAE: 2664.2397591437125
# MAE Gap: 0.9889729664648103 %
# Best parameters: {'positive': False, 'n_jobs': -1, 'fit_intercept': True}

# %% [markdown]
# <a class="anchor" id="9_3_2">
#
# ## **9.3.2** Ridge
#
# [Back to TOP](#TOP)
# </a>

# %%
#Ridge Regression with Randomized Search CV
from sklearn.linear_model import Ridge
model_ridge = Ridge()
# Define parameter grid for Ridge Regression
param_grid_ridge = {
    "alpha": [0.01, 0.1, 1.0, 10.0, 100.0, 500.0],
    "solver": ['auto', 'svd', 'cholesky', 'lsqr']
}   
# 3. Execute Randomized Search CV for Ridge Regression
rsCV_ridge = apply_randomized_search_cv(
    model_ridge, 
    param_grid_ridge, 
    iterations=20,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)       
# Check results
evaluate_model(rsCV_ridge)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'solver': 'cholesky', 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.2 | Val MAE=2663.5 | Gap R2=0.004 | Params={'solver': 'cholesky', 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'solver': 'auto', 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2639.2 | Val MAE=2662.5 | Gap R2=0.004 | Params={'solver': 'lsqr', 'alpha': 100.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.2 | Val MAE=2663.5 | Gap R2=0.004 | Params={'solver': 'svd', 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'solver': 'lsqr', 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'solver': 'cholesky', 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2637.0 | Val MAE=2660.2 | Gap R2=0.005 | Params={'solver': 'svd', 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2639.2 | Val MAE=2662.5 | Gap R2=0.004 | Params={'solver': 'cholesky', 'alpha': 100.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2637.0 | Val MAE=2660.2 | Gap R2=0.005 | Params={'solver': 'auto', 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2637.0 | Val MAE=2660.2 | Gap R2=0.005 | Params={'solver': 'cholesky', 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'solver': 'auto', 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.2 | Val MAE=2663.5 | Gap R2=0.004 | Params={'solver': 'lsqr', 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.2 | Val MAE=2663.5 | Gap R2=0.004 | Params={'solver': 'auto', 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'solver': 'auto', 'alpha': 0.01}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'solver': 'lsqr', 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'solver': 'cholesky', 'alpha': 0.01}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2639.2 | Val MAE=2662.5 | Gap R2=0.004 | Params={'solver': 'auto', 'alpha': 100.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2637.0 | Val MAE=2660.3 | Gap R2=0.005 | Params={'solver': 'lsqr', 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'solver': 'lsqr', 'alpha': 0.01}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8127441765170883
# Best validation R2: 0.808154052396448
# R2 Gap: 0.5647686262497379 %
# Best train MAE: 2636.9840250962716
# Best validation MAE: 2660.2295776651954
# MAE Gap: 0.8815204167979424 %
# Best parameters: {'solver': 'svd', 'alpha': 500.0}

# %%
# ALTERANDO A FS E FICAMOS COM 20 FEATURES
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8151085980282142
# Best validation R2: 0.8106740933731881
# R2 Gap: 0.5440385079673339 %
# Best train MAE: 2618.624584930066
# Best validation MAE: 2639.448181252241
# MAE Gap: 0.795211212863915 %
# Best parameters: {'solver': 'svd', 'alpha': 500.0}


# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8131463298945936
# Best validation R2: 0.8083148408153084
# R2 Gap: 0.5941721559404329 %
# Best train MAE: 2633.9591076884317
# Best validation MAE: 2659.3526952912057
# MAE Gap: 0.9640843522836416 %
# Best parameters: {'solver': 'auto', 'alpha': 500.0}

# %% [markdown]
# <a class="anchor" id="9_3_3">
#
# ## **9.3.3** Lasso
#
# [Back to TOP](#TOP)
# </a>

# %%
# Lasso Regression with Randomized Search CV
model_lasso = Lasso(random_state=42)

# Define parameter grid for Lasso Regression
param_grid_lasso = {
    "alpha": [0.001, 0.01, 0.1, 1.0, 10.0, 500.0],
    "max_iter": [1000, 5000, 10000]
}
# Apply Randomized Search CV for Lasso Regression
rsCV_lasso = apply_randomized_search_cv(
    model_lasso, 
    param_grid_lasso, 
    iterations=15, 
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

# Check results
evaluate_model(rsCV_lasso)
# Out:
# Fitting 1 folds for each of 15 candidates, totalling 15 fits
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'max_iter': 1000, 'alpha': 0.1}
# Train R2=0.793 | Val R2=0.786 | Train MAE=2715.7 | Val MAE=2732.1 | Gap R2=0.007 | Params={'max_iter': 5000, 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'max_iter': 5000, 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2638.9 | Val MAE=2662.3 | Gap R2=0.004 | Params={'max_iter': 1000, 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2638.9 | Val MAE=2662.3 | Gap R2=0.004 | Params={'max_iter': 5000, 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.808 | Train MAE=2638.9 | Val MAE=2662.3 | Gap R2=0.004 | Params={'max_iter': 10000, 'alpha': 10.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.0 | Val MAE=2663.3 | Gap R2=0.004 | Params={'max_iter': 5000, 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'max_iter': 5000, 'alpha': 0.01}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'max_iter': 10000, 'alpha': 0.1}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.0 | Val MAE=2663.3 | Gap R2=0.004 | Params={'max_iter': 10000, 'alpha': 1.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'max_iter': 10000, 'alpha': 0.001}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'max_iter': 1000, 'alpha': 0.001}
# Train R2=0.793 | Val R2=0.786 | Train MAE=2715.7 | Val MAE=2732.1 | Gap R2=0.007 | Params={'max_iter': 1000, 'alpha': 500.0}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'max_iter': 1000, 'alpha': 0.01}
# Train R2=0.813 | Val R2=0.809 | Train MAE=2640.3 | Val MAE=2663.6 | Gap R2=0.004 | Params={'max_iter': 5000, 'alpha': 0.001}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8128444311797334
# Best validation R2: 0.8084124492253925
# R2 Gap: 0.5452435649843222 %
# Best train MAE: 2638.8743711454235
# Best validation MAE: 2662.2729953117564
# MAE Gap: 0.8866895833383881 %
# Best parameters: {'max_iter': 1000, 'alpha': 10.0}

# %%
# ALTERANDO A FS E FICAMOS COM 20 FEATURES
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8151986480434059
# Best validation R2: 0.8109014517319679
# R2 Gap: 0.5271348672807394 %
# Best train MAE: 2619.507488232406
# Best validation MAE: 2640.5275221707725
# MAE Gap: 0.8024422160575809 %
# Best parameters: {'max_iter': 1000, 'alpha': 10.0}


# === BEST MODEL (based on MAE) ===
# Best train R2: 0.8132372057436164
# Best validation R2: 0.8085573696085282
# R2 Gap: 0.5754577018901832 %
# Best train MAE: 2636.0988748293953
# Best validation MAE: 2661.61552640847
# MAE Gap: 0.9679702010694168 %
# Best parameters: {'max_iter': 1000, 'alpha': 10.0}

# %% [markdown]
# <a class="anchor" id="9_3_3">
#
# ## **9.4** Decision Trees
#
# [Back to TOP](#TOP)
# </a>

# %%
from sklearn.tree import DecisionTreeRegressor

model_dt = DecisionTreeRegressor(random_state=42)

# Define the optimized parameter grid for Decision Tree Regressor
param_grid_dt = {
    "max_depth": [None, 10, 20, 30, 40, 50],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [1, 2, 4, 8, 12],
    "max_features": [None, "sqrt", "log2"],
    "criterion": ["squared_error", "friedman_mse", "absolute_error"]
}

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=20, # is a good number to cover this variety
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

# Check results
evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# Train R2=0.979 | Val R2=0.890 | Train MAE=705.2 | Val MAE=1784.7 | Gap R2=0.089 | Params={'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 30, 'criterion': 'friedman_mse'}
# Train R2=0.962 | Val R2=0.900 | Train MAE=1133.8 | Val MAE=1730.4 | Gap R2=0.062 | Params={'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.910 | Train MAE=1107.2 | Val MAE=1598.9 | Gap R2=0.032 | Params={'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 40, 'criterion': 'absolute_error'}
# Train R2=0.894 | Val R2=0.878 | Train MAE=1638.1 | Val MAE=1864.3 | Gap R2=0.016 | Params={'min_samples_split': 2, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_depth': 50, 'criterion': 'absolute_error'}
# Train R2=0.906 | Val R2=0.888 | Train MAE=1662.3 | Val MAE=1874.6 | Gap R2=0.019 | Params={'min_samples_split': 5, 'min_samples_leaf': 12, 'max_features': 'log2', 'max_depth': 40, 'criterion': 'friedman_mse'}
# Train R2=0.906 | Val R2=0.888 | Train MAE=1662.3 | Val MAE=1874.6 | Gap R2=0.019 | Params={'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_depth': 30, 'criterion': 'squared_error'}
# Train R2=0.964 | Val R2=0.899 | Train MAE=885.5 | Val MAE=1623.1 | Gap R2=0.065 | Params={'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 20, 'criterion': 'absolute_error'}
# Train R2=0.887 | Val R2=0.857 | Train MAE=2173.1 | Val MAE=2335.1 | Gap R2=0.030 | Params={'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.955 | Val R2=0.916 | Train MAE=1146.9 | Val MAE=1605.3 | Gap R2=0.039 | Params={'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 50, 'criterion': 'friedman_mse'}
# Train R2=0.966 | Val R2=0.917 | Train MAE=998.3 | Val MAE=1627.7 | Gap R2=0.048 | Params={'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 40, 'criterion': 'squared_error'}
# Train R2=0.894 | Val R2=0.878 | Train MAE=1638.1 | Val MAE=1864.3 | Gap R2=0.016 | Params={'min_samples_split': 5, 'min_samples_leaf': 12, 'max_features': 'log2', 'max_depth': 30, 'criterion': 'absolute_error'}
# Train R2=0.927 | Val R2=0.893 | Train MAE=1548.8 | Val MAE=1823.6 | Gap R2=0.033 | Params={'min_samples_split': 40, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 50, 'criterion': 'squared_error'}
# Train R2=0.916 | Val R2=0.888 | Train MAE=1457.8 | Val MAE=1774.3 | Gap R2=0.028 | Params={'min_samples_split': 40, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 30, 'criterion': 'absolute_error'}
# Train R2=0.854 | Val R2=0.836 | Train MAE=2185.9 | Val MAE=2299.5 | Gap R2=0.018 | Params={'min_samples_split': 20, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'absolute_error'}
# Train R2=0.956 | Val R2=0.883 | Train MAE=998.0 | Val MAE=1786.6 | Gap R2=0.073 | Params={'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'criterion': 'absolute_error'}
# Train R2=0.932 | Val R2=0.901 | Train MAE=1446.6 | Val MAE=1739.5 | Gap R2=0.032 | Params={'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 50, 'criterion': 'friedman_mse'}
# Train R2=0.881 | Val R2=0.862 | Train MAE=2199.5 | Val MAE=2324.9 | Gap R2=0.019 | Params={'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.968 | Val R2=0.918 | Train MAE=962.9 | Val MAE=1639.5 | Gap R2=0.051 | Params={'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 50, 'criterion': 'friedman_mse'}
# Train R2=0.951 | Val R2=0.895 | Train MAE=1035.9 | Val MAE=1606.7 | Gap R2=0.056 | Params={'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 40, 'criterion': 'absolute_error'}
# Train R2=0.949 | Val R2=0.867 | Train MAE=1021.3 | Val MAE=1809.6 | Gap R2=0.082 | Params={'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 30, 'criterion': 'absolute_error'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9419173484309481
# Best validation R2: 0.9102185333508301
# R2 Gap: 3.3653499569704337 %
# Best train MAE: 1107.2269571226432
# Best validation MAE: 1598.9107930240211
# MAE Gap: 44.406779724648274 %
# Best parameters: {'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 40, 'criterion': 'absolute_error'}

# %%
# ALTERANDO A FS E FICAMOS COM 20 FEATURES
# # === BEST MODEL (based on MAE) ===
# Best train R2: 0.9553401901738583
# Best validation R2: 0.9165061007899149
# R2 Gap: 4.064948777762207 %
# Best train MAE: 1146.1573810209316
# Best validation MAE: 1602.4034522076447
# MAE Gap: 39.806581429534155 %
# Best parameters: {'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 50, 'criterion': 'friedman_mse'}




# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9409230173091558
# Best validation R2: 0.9108876161761694
# R2 Gap: 3.1921209897576337 %
# Best train MAE: 1111.8210043107704
# Best validation MAE: 1581.678545574202
# MAE Gap: 42.2601785216948 %
# Best parameters: {'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 40, 'criterion': 'absolute_error'}

# %%
# def objective(trial):
#     params = {
#         "max_depth": trial.suggest_int("max_depth", 1, 20),
#         "min_samples_split": trial.suggest_int("min_samples_split", 2, 40),
#         "min_samples_leaf": trial.suggest_int("min_samples_leaf", 10, 30),
#         "max_features": trial.suggest_categorical("max_features", [None, "sqrt", "log2"]),
#         "criterion": trial.suggest_categorical("criterion", ["squared_error", "friedman_mse", "absolute_error"])
#     }

#     model = DecisionTreeRegressor(random_state=42, **params)

#     rsCV_dt = apply_randomized_search_cv(
#     model_dt, 
#     param_grid_dt, 
#     iterations=20, # is a good number to cover this variety
#     scoring=scoring, 
#     refit='mae', 
#     pred_split=ps, 
#     X_fit=X_combined, 
#     y_fit=y_combined)

#     return evaluate_model(rsCV_dt)

# import optuna
# study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=20, show_progress_bar=True)
# Out:
# [I 2025-12-09 20:43:17,069] A new study created in memory with name: no-name-634aceef-46c8-4355-8cf8-f2194387ebd9
#   0%|          | 0/20 [00:00<?, ?it/s]
# Fitting 1 folds for each of 20 candidates, totalling 20 fits

# %%
#check with diferent max_depth and min_samples_leaf values

model_dt = DecisionTreeRegressor(random_state=42)

# define the optimized parameter grid for Decision Tree Regressor
param_grid_dt = {
    # Control of SIZE (The most important)
    "max_depth": [None, 10, 15, 20],
    
    # Control of SPLIT (Prevents memorizing rare data)
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    
    # Control of VARIABILITY
    "max_features": [None, "sqrt", "log2"],

    # CRITERION OF ERROR
    "criterion": ["squared_error", "friedman_mse", "absolute_error"]}

#with tqdm_joblib(tqdm(desc="RandomizedSearch - LR", total=20)):

    rsCV_dt = apply_randomized_search_cv(
        model_dt, 
        param_grid_dt, 
        iterations=20, # is a good number to cover this variety
        scoring=scoring, 
        refit='mae', 
        pred_split=ps, 
        X_fit=X_combined, 
        y_fit=y_combined
    )

# check results
evaluate_model(rsCV_dt)
# Out:
# RandomizedSearch - LR:   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Fitting 1 folds for each of 20 candidates, totalling 20 fits

# %%
# 
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.925088497105742
# Best validation R2: 0.9071667922840271
# R2 Gap: 1.9372962562809188 %
# Best train MAE: 1252.8512784231136
# Best validation MAE: 1623.9755840737084
# MAE Gap: 29.62237514078335 %
# Best parameters: {'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'absolute_error'}
# # 
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9247624105613201
# Best validation R2: 0.9078272230888982
# R2 Gap: 1.8313014541910815 %
# Best train MAE: 1257.4814406528678
# Best validation MAE: 1615.4614017769004
# MAE Gap: 28.468011499094096 %
# Best parameters: {'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'absolute_error'}

# %%
#check without max_features and absolute_error
model_dt = DecisionTreeRegressor(random_state=42)


param_grid_dt = {
   
    "max_depth": [None, 10, 15, 20],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    "criterion": ["squared_error", "friedman_mse"]
}

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=20,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.911 | Val R2=0.899 | Train MAE=1757.7 | Val MAE=1871.8 | Gap R2=0.012 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1397.9 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9421423073951416
# Best validation R2: 0.913369999094361
# R2 Gap: 3.053923815429856 %
# Best train MAE: 1294.8176601251953
# Best validation MAE: 1619.5345798820404
# MAE Gap: 25.07819670342219 %
# Best parameters: {'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}

# %%
#check without max_features and absolute_error with 100 iterations
model_dt = DecisionTreeRegressor(random_state=42)


param_grid_dt = {
   
    "max_depth": [None, 10, 15, 20],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    "criterion": ["squared_error", "friedman_mse"]
}

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=100,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.911 | Val R2=0.899 | Train MAE=1757.7 | Val MAE=1871.8 | Gap R2=0.012 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1397.9 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.911 | Val R2=0.899 | Train MAE=1757.7 | Val MAE=1871.8 | Gap R2=0.012 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.930 | Val R2=0.911 | Train MAE=1439.9 | Val MAE=1656.8 | Gap R2=0.019 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1396.4 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1396.4 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1397.9 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_depth': 10, 'criterion': 'squared_error'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9419758103595577
# Best validation R2: 0.9133889602467964
# R2 Gap: 3.034775394269363 %
# Best train MAE: 1298.7062496668436
# Best validation MAE: 1618.7133125436078
# MAE Gap: 24.640449906116597 %
# Best parameters: {'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 20, 'criterion': 'friedman_mse'}

# %%
#check without absolute error
model_dt = DecisionTreeRegressor(random_state=42)

param_grid_dt = {
    "max_depth": [None, 10, 15, 20],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    "max_features": [None, "sqrt", "log2"],
    "criterion": ["squared_error", "friedman_mse"]}

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=20,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)
# Check results
evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.903 | Val R2=0.880 | Train MAE=1663.5 | Val MAE=1853.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.916 | Val R2=0.898 | Train MAE=1614.1 | Val MAE=1816.5 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.903 | Val R2=0.880 | Train MAE=1663.5 | Val MAE=1853.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.865 | Train MAE=2104.6 | Val MAE=2202.5 | Gap R2=0.013 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9419758103595577
# Best validation R2: 0.9133889602467964
# R2 Gap: 3.034775394269363 %
# Best train MAE: 1298.7062496668436
# Best validation MAE: 1618.7133125436078
# MAE Gap: 24.640449906116597 %
# Best parameters: {'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}

# %%
#check without absolute error
model_dt = DecisionTreeRegressor(random_state=42)

param_grid_dt = {
    "max_depth": [None, 10, 15, 20],
    "min_samples_split": [2, 5, 10, 20, 40],
    "min_samples_leaf": [10, 20, 30],
    "max_features": [None, "sqrt", "log2"],
    "criterion": ["squared_error", "friedman_mse"]}

rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=100,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)
# Check results
evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.903 | Val R2=0.880 | Train MAE=1663.5 | Val MAE=1853.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.916 | Val R2=0.898 | Train MAE=1614.1 | Val MAE=1816.5 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.903 | Val R2=0.880 | Train MAE=1663.5 | Val MAE=1853.7 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1298.7 | Val MAE=1618.7 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.865 | Train MAE=2104.6 | Val MAE=2202.5 | Gap R2=0.013 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1630.7 | Val MAE=1826.4 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.916 | Val R2=0.898 | Train MAE=1614.1 | Val MAE=1816.5 | Gap R2=0.018 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1630.7 | Val MAE=1826.4 | Gap R2=0.022 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.848 | Val R2=0.829 | Train MAE=2298.7 | Val MAE=2408.6 | Gap R2=0.020 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.910 | Val R2=0.887 | Train MAE=1677.3 | Val MAE=1875.8 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.916 | Val R2=0.898 | Train MAE=1614.1 | Val MAE=1816.5 | Gap R2=0.018 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.848 | Val R2=0.829 | Train MAE=2298.7 | Val MAE=2408.6 | Gap R2=0.020 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.901 | Val R2=0.882 | Train MAE=1815.9 | Val MAE=1928.2 | Gap R2=0.018 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.865 | Train MAE=2104.6 | Val MAE=2202.5 | Gap R2=0.013 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.930 | Val R2=0.911 | Train MAE=1439.9 | Val MAE=1656.8 | Gap R2=0.019 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.910 | Val R2=0.887 | Train MAE=1677.3 | Val MAE=1875.8 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.865 | Val R2=0.852 | Train MAE=2226.3 | Val MAE=2307.6 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.942 | Val R2=0.913 | Train MAE=1294.8 | Val MAE=1619.5 | Gap R2=0.029 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.1 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.848 | Val R2=0.829 | Train MAE=2298.7 | Val MAE=2408.6 | Gap R2=0.020 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.932 | Val R2=0.912 | Train MAE=1397.9 | Val MAE=1639.7 | Gap R2=0.020 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.894 | Val R2=0.870 | Train MAE=1793.4 | Val MAE=1958.7 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.894 | Val R2=0.870 | Train MAE=1793.4 | Val MAE=1958.7 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.924 | Val R2=0.901 | Train MAE=1514.3 | Val MAE=1705.7 | Gap R2=0.023 | Params={'min_samples_split': 20, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1630.7 | Val MAE=1826.4 | Gap R2=0.022 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1607.2 | Val MAE=1767.3 | Gap R2=0.022 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1615.8 | Val MAE=1770.8 | Gap R2=0.022 | Params={'min_samples_split': 40, 'min_samples_leaf': 30, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.894 | Val R2=0.870 | Train MAE=1793.4 | Val MAE=1958.7 | Gap R2=0.024 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.910 | Val R2=0.887 | Train MAE=1677.3 | Val MAE=1875.8 | Gap R2=0.023 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.865 | Val R2=0.852 | Train MAE=2226.3 | Val MAE=2307.6 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.865 | Val R2=0.852 | Train MAE=2226.3 | Val MAE=2307.6 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.5 | Val MAE=1699.4 | Gap R2=0.024 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': None, 'criterion': 'squared_error'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 2, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.865 | Val R2=0.852 | Train MAE=2226.3 | Val MAE=2307.6 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.888 | Train MAE=1675.7 | Val MAE=1878.6 | Gap R2=0.025 | Params={'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.886 | Val R2=0.872 | Train MAE=1887.7 | Val MAE=1997.3 | Gap R2=0.013 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.848 | Val R2=0.829 | Train MAE=2298.7 | Val MAE=2408.6 | Gap R2=0.020 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.939 | Val R2=0.913 | Train MAE=1364.5 | Val MAE=1633.4 | Gap R2=0.026 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 15, 'criterion': 'squared_error'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 5, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'friedman_mse'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.908 | Val R2=0.891 | Train MAE=1777.5 | Val MAE=1894.8 | Gap R2=0.017 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.925 | Val R2=0.901 | Train MAE=1493.8 | Val MAE=1698.8 | Gap R2=0.024 | Params={'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.894 | Val R2=0.870 | Train MAE=1793.4 | Val MAE=1958.7 | Gap R2=0.024 | Params={'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'friedman_mse'}
# Train R2=0.863 | Val R2=0.854 | Train MAE=2139.8 | Val MAE=2226.7 | Gap R2=0.009 | Params={'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.917 | Val R2=0.901 | Train MAE=1733.0 | Val MAE=1860.3 | Gap R2=0.016 | Params={'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error'}
# Train R2=0.893 | Val R2=0.879 | Train MAE=1788.3 | Val MAE=1896.7 | Gap R2=0.014 | Params={'min_samples_split': 5, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.888 | Val R2=0.874 | Train MAE=1854.6 | Val MAE=1982.7 | Gap R2=0.014 | Params={'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 'log2', 'max_depth': 15, 'criterion': 'friedman_mse'}
# Train R2=0.913 | Val R2=0.891 | Train MAE=1630.7 | Val MAE=1826.4 | Gap R2=0.022 | Params={'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_depth': 20, 'criterion': 'squared_error'}
# Train R2=0.878 | Val R2=0.864 | Train MAE=1924.4 | Val MAE=2045.5 | Gap R2=0.014 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'friedman_mse'}
# Train R2=0.876 | Val R2=0.860 | Train MAE=1942.5 | Val MAE=2051.6 | Gap R2=0.015 | Params={'min_samples_split': 20, 'min_samples_leaf': 30, 'max_features': 'log2', 'max_depth': None, 'criterion': 'friedman_mse'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9419758103595577
# Best validation R2: 0.9133889602467964
# R2 Gap: 3.034775394269363 %
# Best train MAE: 1298.7062496668436
# Best validation MAE: 1618.7133125436078
# MAE Gap: 24.640449906116597 %
# Best parameters: {'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'max_depth': 20, 'criterion': 'squared_error'}

# %% [markdown]
# <a class="anchor" id="9_3_1">
#
# ## **9.3.1** KNN
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# <a class="anchor" id="5_3_1">
#
# ### 9.3.1 Define Model and Grid Parameters
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# Analyzing the previous results, we observed that the models using weights='distance' displayed clear signs of overfitting. Based on this, we defined a new parameter grid that excludes this option in order to evaluate whether better and more stable results can be achieved.
#
# Low number of neighbors has more change of overfitting, but different leaf sizes don't show huge differences in model performance.

# %%
#best_mae_knn = -rsCV_KNN.best_score_
#preds_knn = rsCV_KNN.best_estimator_.predict(test)

# %% [markdown]
# TESTAR À NOITE

# %% [markdown]
# notas: p:1, neighbors:10, weight:uniform têm dado melhor performance

# %%
model_KNN = KNeighborsRegressor(random_state=42)

# %% [markdown]
# ## Impute missing values with KNN

# %%
param_grid_knn = {
    'n_neighbors': list(range(22,100)),
    'weights': ['uniform'],
    'algorithm': ['auto']
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations=50, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 50 candidates, totalling 50 fits
# [CV 1/1] END algorithm=auto, n_neighbors=97, weights=uniform; mae: (train=-1849.388, test=-1864.705) r2: (train=0.889, test=0.888) total time=   5.4s
# [CV 1/1] END algorithm=auto, n_neighbors=41, weights=uniform; mae: (train=-1666.796, test=-1709.757) r2: (train=0.908, test=0.904) total time=   3.9s
# [CV 1/1] END algorithm=auto, n_neighbors=82, weights=uniform; mae: (train=-1811.937, test=-1831.579) r2: (train=0.893, test=0.891) total time=   6.9s
# [CV 1/1] END algorithm=auto, n_neighbors=53, weights=uniform; mae: (train=-1720.317, test=-1751.622) r2: (train=0.903, test=0.900) total time=   4.6s
# [CV 1/1] END algorithm=auto, n_neighbors=57, weights=uniform; mae: (train=-1733.744, test=-1763.576) r2: (train=0.902, test=0.899) total time=   3.3s
# [CV 1/1] END algorithm=auto, n_neighbors=71, weights=uniform; mae: (train=-1780.698, test=-1804.237) r2: (train=0.897, test=0.894) total time=   3.8s
# [CV 1/1] END algorithm=auto, n_neighbors=80, weights=uniform; mae: (train=-1806.626, test=-1826.492) r2: (train=0.894, test=0.892) total time=   3.9s
# [CV 1/1] END algorithm=auto, n_neighbors=75, weights=uniform; mae: (train=-1792.262, test=-1814.190) r2: (train=0.896, test=0.893) total time=   3.8s
# [CV 1/1] END algorithm=auto, n_neighbors=29, weights=uniform; mae: (train=-1599.358, test=-1659.384) r2: (train=0.915, test=0.910) total time=   2.5s
# [CV 1/1] END algorithm=auto, n_neighbors=60, weights=uniform; mae: (train=-1744.455, test=-1772.737) r2: (train=0.900, test=0.898) total time=   3.4s
# [CV 1/1] END algorithm=auto, n_neighbors=99, weights=uniform; mae: (train=-1853.763, test=-1869.753) r2: (train=0.889, test=0.887) total time=   6.4s
# [CV 1/1] END algorithm=auto, n_neighbors=95, weights=uniform; mae: (train=-1844.258, test=-1860.566) r2: (train=0.890, test=0.888) total time=   6.8s
# [CV 1/1] END algorithm=auto, n_neighbors=66, weights=uniform; mae: (train=-1764.540, test=-1791.121) r2: (train=0.898, test=0.896) total time=   6.4s
# [CV 1/1] END algorithm=auto, n_neighbors=22, weights=uniform; mae: (train=-1546.672, test=-1622.304) r2: (train=0.920, test=0.914) total time=   3.6s
# [CV 1/1] END algorithm=auto, n_neighbors=54, weights=uniform; mae: (train=-1723.557, test=-1754.847) r2: (train=0.903, test=0.900) total time=   4.5s
# [CV 1/1] END algorithm=auto, n_neighbors=25, weights=uniform; mae: (train=-1572.137, test=-1640.883) r2: (train=0.918, test=0.912) total time=   2.3s
# [CV 1/1] END algorithm=auto, n_neighbors=96, weights=uniform; mae: (train=-1846.808, test=-1862.845) r2: (train=0.890, test=0.888) total time=   4.6s
# [CV 1/1] END algorithm=auto, n_neighbors=49, weights=uniform; mae: (train=-1704.371, test=-1739.292) r2: (train=0.905, test=0.901) total time=   4.1s
# [CV 1/1] END algorithm=auto, n_neighbors=63, weights=uniform; mae: (train=-1755.314, test=-1781.322) r2: (train=0.899, test=0.897) total time=   5.4s
# [CV 1/1] END algorithm=auto, n_neighbors=37, weights=uniform; mae: (train=-1646.945, test=-1695.775) r2: (train=0.910, test=0.906) total time=   2.7s
# [CV 1/1] END algorithm=auto, n_neighbors=67, weights=uniform; mae: (train=-1767.637, test=-1793.536) r2: (train=0.898, test=0.895) total time=   4.5s
# [CV 1/1] END algorithm=auto, n_neighbors=98, weights=uniform; mae: (train=-1851.601, test=-1867.308) r2: (train=0.889, test=0.887) total time=   4.6s
# [CV 1/1] END algorithm=auto, n_neighbors=27, weights=uniform; mae: (train=-1585.820, test=-1649.992) r2: (train=0.916, test=0.911) total time=   2.8s
# [CV 1/1] END algorithm=auto, n_neighbors=90, weights=uniform; mae: (train=-1832.333, test=-1849.658) r2: (train=0.891, test=0.889) total time=   5.3s
# [CV 1/1] END algorithm=auto, n_neighbors=44, weights=uniform; mae: (train=-1681.962, test=-1721.351) r2: (train=0.907, test=0.903) total time=   3.4s
# [CV 1/1] END algorithm=auto, n_neighbors=94, weights=uniform; mae: (train=-1841.866, test=-1858.370) r2: (train=0.890, test=0.889) total time=   5.5s
# [CV 1/1] END algorithm=auto, n_neighbors=79, weights=uniform; mae: (train=-1803.819, test=-1824.542) r2: (train=0.894, test=0.892) total time=   4.3s
# [CV 1/1] END algorithm=auto, n_neighbors=45, weights=uniform; mae: (train=-1686.519, test=-1725.134) r2: (train=0.906, test=0.903) total time=   2.9s
# [CV 1/1] END algorithm=auto, n_neighbors=62, weights=uniform; mae: (train=-1751.776, test=-1778.588) r2: (train=0.900, test=0.897) total time=   3.5s
# [CV 1/1] END algorithm=auto, n_neighbors=42, weights=uniform; mae: (train=-1671.708, test=-1713.977) r2: (train=0.908, test=0.904) total time=   2.9s
# [CV 1/1] END algorithm=auto, n_neighbors=74, weights=uniform; mae: (train=-1789.215, test=-1811.239) r2: (train=0.896, test=0.894) total time=   4.4s
# [CV 1/1] END algorithm=auto, n_neighbors=85, weights=uniform; mae: (train=-1819.848, test=-1839.243) r2: (train=0.893, test=0.890) total time=   4.1s
# [CV 1/1] END algorithm=auto, n_neighbors=28, weights=uniform; mae: (train=-1592.395, test=-1653.846) r2: (train=0.916, test=0.911) total time=   2.9s
# [CV 1/1] END algorithm=auto, n_neighbors=73, weights=uniform; mae: (train=-1786.413, test=-1808.877) r2: (train=0.896, test=0.894) total time=   4.6s
# [CV 1/1] END algorithm=auto, n_neighbors=87, weights=uniform; mae: (train=-1824.949, test=-1842.954) r2: (train=0.892, test=0.890) total time=   6.0s
# [CV 1/1] END algorithm=auto, n_neighbors=84, weights=uniform; mae: (train=-1817.431, test=-1836.748) r2: (train=0.893, test=0.891) total time=   4.1s
# [CV 1/1] END algorithm=auto, n_neighbors=39, weights=uniform; mae: (train=-1656.721, test=-1702.351) r2: (train=0.909, test=0.905) total time=   2.9s
# [CV 1/1] END algorithm=auto, n_neighbors=35, weights=uniform; mae: (train=-1636.269, test=-1687.450) r2: (train=0.911, test=0.907) total time=   2.6s
# [CV 1/1] END algorithm=auto, n_neighbors=40, weights=uniform; mae: (train=-1661.661, test=-1705.781) r2: (train=0.909, test=0.905) total time=   2.7s
# [CV 1/1] END algorithm=auto, n_neighbors=92, weights=uniform; mae: (train=-1837.120, test=-1853.914) r2: (train=0.891, test=0.889) total time=   4.3s
# [CV 1/1] END algorithm=auto, n_neighbors=26, weights=uniform; mae: (train=-1579.198, test=-1646.231) r2: (train=0.917, test=0.912) total time=   2.4s
# [CV 1/1] END algorithm=auto, n_neighbors=89, weights=uniform; mae: (train=-1829.874, test=-1847.439) r2: (train=0.891, test=0.889) total time=   4.1s
# [CV 1/1] END algorithm=auto, n_neighbors=72, weights=uniform; mae: (train=-1783.776, test=-1806.311) r2: (train=0.896, test=0.894) total time=   3.9s
# [CV 1/1] END algorithm=auto, n_neighbors=52, weights=uniform; mae: (train=-1716.601, test=-1748.701) r2: (train=0.903, test=0.900) total time=   3.2s
# [CV 1/1] END algorithm=auto, n_neighbors=68, weights=uniform; mae: (train=-1770.860, test=-1796.138) r2: (train=0.898, test=0.895) total time=   3.6s
# [CV 1/1] END algorithm=auto, n_neighbors=65, weights=uniform; mae: (train=-1761.695, test=-1787.598) r2: (train=0.899, test=0.896) total time=   4.1s
# [CV 1/1] END algorithm=auto, n_neighbors=32, weights=uniform; mae: (train=-1618.125, test=-1673.548) r2: (train=0.913, test=0.908) total time=   2.6s
# [CV 1/1] END algorithm=auto, n_neighbors=48, weights=uniform; mae: (train=-1699.919, test=-1736.342) r2: (train=0.905, test=0.901) total time=   3.1s
# [CV 1/1] END algorithm=auto, n_neighbors=69, weights=uniform; mae: (train=-1774.095, test=-1798.938) r2: (train=0.897, test=0.895) total time=   3.6s
# [CV 1/1] END algorithm=auto, n_neighbors=78, weights=uniform; mae: (train=-1801.170, test=-1821.664) r2: (train=0.895, test=0.892) total time=   3.9s
# Train R2=0.889 | Val R2=0.888 | Train MAE=1849.4 | Val MAE=1864.7 | Gap MAE=0.008 | Params={'weights': 'uniform', 'n_neighbors': 97, 'algorithm': 'auto'}
# Train R2=0.908 | Val R2=0.904 | Train MAE=1666.8 | Val MAE=1709.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'n_neighbors': 41, 'algorithm': 'auto'}
# Train R2=0.893 | Val R2=0.891 | Train MAE=1811.9 | Val MAE=1831.6 | Gap MAE=0.011 | Params={'weights': 'uniform', 'n_neighbors': 82, 'algorithm': 'auto'}
# Train R2=0.903 | Val R2=0.900 | Train MAE=1720.3 | Val MAE=1751.6 | Gap MAE=0.018 | Params={'weights': 'uniform', 'n_neighbors': 53, 'algorithm': 'auto'}
# Train R2=0.902 | Val R2=0.899 | Train MAE=1733.7 | Val MAE=1763.6 | Gap MAE=0.017 | Params={'weights': 'uniform', 'n_neighbors': 57, 'algorithm': 'auto'}
# Train R2=0.897 | Val R2=0.894 | Train MAE=1780.7 | Val MAE=1804.2 | Gap MAE=0.013 | Params={'weights': 'uniform', 'n_neighbors': 71, 'algorithm': 'auto'}
# Train R2=0.894 | Val R2=0.892 | Train MAE=1806.6 | Val MAE=1826.5 | Gap MAE=0.011 | Params={'weights': 'uniform', 'n_neighbors': 80, 'algorithm': 'auto'}
# Train R2=0.896 | Val R2=0.893 | Train MAE=1792.3 | Val MAE=1814.2 | Gap MAE=0.012 | Params={'weights': 'uniform', 'n_neighbors': 75, 'algorithm': 'auto'}
# Train R2=0.915 | Val R2=0.910 | Train MAE=1599.4 | Val MAE=1659.4 | Gap MAE=0.038 | Params={'weights': 'uniform', 'n_neighbors': 29, 'algorithm': 'auto'}
# Train R2=0.900 | Val R2=0.898 | Train MAE=1744.5 | Val MAE=1772.7 | Gap MAE=0.016 | Params={'weights': 'uniform', 'n_neighbors': 60, 'algorithm': 'auto'}
# Train R2=0.889 | Val R2=0.887 | Train MAE=1853.8 | Val MAE=1869.8 | Gap MAE=0.009 | Params={'weights': 'uniform', 'n_neighbors': 99, 'algorithm': 'auto'}
# Train R2=0.890 | Val R2=0.888 | Train MAE=1844.3 | Val MAE=1860.6 | Gap MAE=0.009 | Params={'weights': 'uniform', 'n_neighbors': 95, 'algorithm': 'auto'}
# Train R2=0.898 | Val R2=0.896 | Train MAE=1764.5 | Val MAE=1791.1 | Gap MAE=0.015 | Params={'weights': 'uniform', 'n_neighbors': 66, 'algorithm': 'auto'}
# Train R2=0.920 | Val R2=0.914 | Train MAE=1546.7 | Val MAE=1622.3 | Gap MAE=0.049 | Params={'weights': 'uniform', 'n_neighbors': 22, 'algorithm': 'auto'}
# Train R2=0.903 | Val R2=0.900 | Train MAE=1723.6 | Val MAE=1754.8 | Gap MAE=0.018 | Params={'weights': 'uniform', 'n_neighbors': 54, 'algorithm': 'auto'}
# Train R2=0.918 | Val R2=0.912 | Train MAE=1572.1 | Val MAE=1640.9 | Gap MAE=0.044 | Params={'weights': 'uniform', 'n_neighbors': 25, 'algorithm': 'auto'}
# Train R2=0.890 | Val R2=0.888 | Train MAE=1846.8 | Val MAE=1862.8 | Gap MAE=0.009 | Params={'weights': 'uniform', 'n_neighbors': 96, 'algorithm': 'auto'}
# Train R2=0.905 | Val R2=0.901 | Train MAE=1704.4 | Val MAE=1739.3 | Gap MAE=0.020 | Params={'weights': 'uniform', 'n_neighbors': 49, 'algorithm': 'auto'}
# Train R2=0.899 | Val R2=0.897 | Train MAE=1755.3 | Val MAE=1781.3 | Gap MAE=0.015 | Params={'weights': 'uniform', 'n_neighbors': 63, 'algorithm': 'auto'}
# Train R2=0.910 | Val R2=0.906 | Train MAE=1646.9 | Val MAE=1695.8 | Gap MAE=0.030 | Params={'weights': 'uniform', 'n_neighbors': 37, 'algorithm': 'auto'}
# Train R2=0.898 | Val R2=0.895 | Train MAE=1767.6 | Val MAE=1793.5 | Gap MAE=0.015 | Params={'weights': 'uniform', 'n_neighbors': 67, 'algorithm': 'auto'}
# Train R2=0.889 | Val R2=0.887 | Train MAE=1851.6 | Val MAE=1867.3 | Gap MAE=0.008 | Params={'weights': 'uniform', 'n_neighbors': 98, 'algorithm': 'auto'}
# Train R2=0.916 | Val R2=0.911 | Train MAE=1585.8 | Val MAE=1650.0 | Gap MAE=0.040 | Params={'weights': 'uniform', 'n_neighbors': 27, 'algorithm': 'auto'}
# Train R2=0.891 | Val R2=0.889 | Train MAE=1832.3 | Val MAE=1849.7 | Gap MAE=0.009 | Params={'weights': 'uniform', 'n_neighbors': 90, 'algorithm': 'auto'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1682.0 | Val MAE=1721.4 | Gap MAE=0.023 | Params={'weights': 'uniform', 'n_neighbors': 44, 'algorithm': 'auto'}
# Train R2=0.890 | Val R2=0.889 | Train MAE=1841.9 | Val MAE=1858.4 | Gap MAE=0.009 | Params={'weights': 'uniform', 'n_neighbors': 94, 'algorithm': 'auto'}
# Train R2=0.894 | Val R2=0.892 | Train MAE=1803.8 | Val MAE=1824.5 | Gap MAE=0.011 | Params={'weights': 'uniform', 'n_neighbors': 79, 'algorithm': 'auto'}
# Train R2=0.906 | Val R2=0.903 | Train MAE=1686.5 | Val MAE=1725.1 | Gap MAE=0.023 | Params={'weights': 'uniform', 'n_neighbors': 45, 'algorithm': 'auto'}
# Train R2=0.900 | Val R2=0.897 | Train MAE=1751.8 | Val MAE=1778.6 | Gap MAE=0.015 | Params={'weights': 'uniform', 'n_neighbors': 62, 'algorithm': 'auto'}
# Train R2=0.908 | Val R2=0.904 | Train MAE=1671.7 | Val MAE=1714.0 | Gap MAE=0.025 | Params={'weights': 'uniform', 'n_neighbors': 42, 'algorithm': 'auto'}
# Train R2=0.896 | Val R2=0.894 | Train MAE=1789.2 | Val MAE=1811.2 | Gap MAE=0.012 | Params={'weights': 'uniform', 'n_neighbors': 74, 'algorithm': 'auto'}
# Train R2=0.893 | Val R2=0.890 | Train MAE=1819.8 | Val MAE=1839.2 | Gap MAE=0.011 | Params={'weights': 'uniform', 'n_neighbors': 85, 'algorithm': 'auto'}
# Train R2=0.916 | Val R2=0.911 | Train MAE=1592.4 | Val MAE=1653.8 | Gap MAE=0.039 | Params={'weights': 'uniform', 'n_neighbors': 28, 'algorithm': 'auto'}
# Train R2=0.896 | Val R2=0.894 | Train MAE=1786.4 | Val MAE=1808.9 | Gap MAE=0.013 | Params={'weights': 'uniform', 'n_neighbors': 73, 'algorithm': 'auto'}
# Train R2=0.892 | Val R2=0.890 | Train MAE=1824.9 | Val MAE=1843.0 | Gap MAE=0.010 | Params={'weights': 'uniform', 'n_neighbors': 87, 'algorithm': 'auto'}
# Train R2=0.893 | Val R2=0.891 | Train MAE=1817.4 | Val MAE=1836.7 | Gap MAE=0.011 | Params={'weights': 'uniform', 'n_neighbors': 84, 'algorithm': 'auto'}
# Train R2=0.909 | Val R2=0.905 | Train MAE=1656.7 | Val MAE=1702.4 | Gap MAE=0.028 | Params={'weights': 'uniform', 'n_neighbors': 39, 'algorithm': 'auto'}
# Train R2=0.911 | Val R2=0.907 | Train MAE=1636.3 | Val MAE=1687.4 | Gap MAE=0.031 | Params={'weights': 'uniform', 'n_neighbors': 35, 'algorithm': 'auto'}
# Train R2=0.909 | Val R2=0.905 | Train MAE=1661.7 | Val MAE=1705.8 | Gap MAE=0.027 | Params={'weights': 'uniform', 'n_neighbors': 40, 'algorithm': 'auto'}
# Train R2=0.891 | Val R2=0.889 | Train MAE=1837.1 | Val MAE=1853.9 | Gap MAE=0.009 | Params={'weights': 'uniform', 'n_neighbors': 92, 'algorithm': 'auto'}
# Train R2=0.917 | Val R2=0.912 | Train MAE=1579.2 | Val MAE=1646.2 | Gap MAE=0.042 | Params={'weights': 'uniform', 'n_neighbors': 26, 'algorithm': 'auto'}
# Train R2=0.891 | Val R2=0.889 | Train MAE=1829.9 | Val MAE=1847.4 | Gap MAE=0.010 | Params={'weights': 'uniform', 'n_neighbors': 89, 'algorithm': 'auto'}
# Train R2=0.896 | Val R2=0.894 | Train MAE=1783.8 | Val MAE=1806.3 | Gap MAE=0.013 | Params={'weights': 'uniform', 'n_neighbors': 72, 'algorithm': 'auto'}
# Train R2=0.903 | Val R2=0.900 | Train MAE=1716.6 | Val MAE=1748.7 | Gap MAE=0.019 | Params={'weights': 'uniform', 'n_neighbors': 52, 'algorithm': 'auto'}
# Train R2=0.898 | Val R2=0.895 | Train MAE=1770.9 | Val MAE=1796.1 | Gap MAE=0.014 | Params={'weights': 'uniform', 'n_neighbors': 68, 'algorithm': 'auto'}
# Train R2=0.899 | Val R2=0.896 | Train MAE=1761.7 | Val MAE=1787.6 | Gap MAE=0.015 | Params={'weights': 'uniform', 'n_neighbors': 65, 'algorithm': 'auto'}
# Train R2=0.913 | Val R2=0.908 | Train MAE=1618.1 | Val MAE=1673.5 | Gap MAE=0.034 | Params={'weights': 'uniform', 'n_neighbors': 32, 'algorithm': 'auto'}
# Train R2=0.905 | Val R2=0.901 | Train MAE=1699.9 | Val MAE=1736.3 | Gap MAE=0.021 | Params={'weights': 'uniform', 'n_neighbors': 48, 'algorithm': 'auto'}
# Train R2=0.897 | Val R2=0.895 | Train MAE=1774.1 | Val MAE=1798.9 | Gap MAE=0.014 | Params={'weights': 'uniform', 'n_neighbors': 69, 'algorithm': 'auto'}
# Train R2=0.895 | Val R2=0.892 | Train MAE=1801.2 | Val MAE=1821.7 | Gap MAE=0.011 | Params={'weights': 'uniform', 'n_neighbors': 78, 'algorithm': 'auto'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9200144607745593
# Best validation R2: 0.9136898729955085
# Gap R2: 0.6874443879638693 %
# Best train MAE: 1546.6719304832188
# Best validation MAE: 1622.3043973795207
# Gap MAE: 4.890013544932723 %
# Best parameters: {'weights': 'uniform', 'n_neighbors': 22, 'algorithm': 'auto'}

# %%
param_grid_knn = {
    "n_neighbors": list(range(30, 80)),
    "weights": ["uniform"],
    "p": [1, 2],                                # Manhattan vs Euclidiane
    "leaf_size": [2, 5, 8, 12, 17, 25, 30, 40, 50, 60, 70, 80, 90, 100],
    "algorithm": ["auto", "ball_tree", "kd_tree", "brute"],
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations=50, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 50 candidates, totalling 50 fits
# [CV 1/1] END algorithm=auto, leaf_size=8, n_neighbors=46, p=2, weights=uniform; mae: (train=-1690.960, test=-1729.102) r2: (train=0.906, test=0.902) total time=   4.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=8, n_neighbors=76, p=2, weights=uniform; mae: (train=-1795.175, test=-1816.717) r2: (train=0.895, test=0.893) total time=   6.6s
# [CV 1/1] END algorithm=kd_tree, leaf_size=90, n_neighbors=78, p=2, weights=uniform; mae: (train=-1801.174, test=-1821.671) r2: (train=0.895, test=0.892) total time=   7.0s
# [CV 1/1] END algorithm=ball_tree, leaf_size=8, n_neighbors=47, p=2, weights=uniform; mae: (train=-1695.795, test=-1732.371) r2: (train=0.906, test=0.902) total time=  24.3s
# [CV 1/1] END algorithm=ball_tree, leaf_size=12, n_neighbors=62, p=2, weights=uniform; mae: (train=-1751.772, test=-1778.624) r2: (train=0.900, test=0.897) total time=  23.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=80, n_neighbors=45, p=2, weights=uniform; mae: (train=-1686.527, test=-1725.178) r2: (train=0.906, test=0.903) total time=   4.7s
# [CV 1/1] END algorithm=ball_tree, leaf_size=2, n_neighbors=74, p=1, weights=uniform; mae: (train=-1706.657, test=-1736.430) r2: (train=0.905, test=0.902) total time=  14.0s
# [CV 1/1] END algorithm=kd_tree, leaf_size=70, n_neighbors=64, p=1, weights=uniform; mae: (train=-1675.796, test=-1710.500) r2: (train=0.908, test=0.905) total time=   7.9s
# [CV 1/1] END algorithm=auto, leaf_size=70, n_neighbors=48, p=1, weights=uniform; mae: (train=-1616.598, test=-1656.582) r2: (train=0.914, test=0.910) total time=   7.1s
# [CV 1/1] END algorithm=auto, leaf_size=40, n_neighbors=57, p=1, weights=uniform; mae: (train=-1652.121, test=-1687.642) r2: (train=0.910, test=0.907) total time=   7.9s
# [CV 1/1] END algorithm=auto, leaf_size=100, n_neighbors=76, p=2, weights=uniform; mae: (train=-1795.164, test=-1816.737) r2: (train=0.895, test=0.893) total time=   7.6s
# [CV 1/1] END algorithm=kd_tree, leaf_size=25, n_neighbors=73, p=2, weights=uniform; mae: (train=-1786.416, test=-1808.880) r2: (train=0.896, test=0.894) total time=   5.2s
# [CV 1/1] END algorithm=ball_tree, leaf_size=70, n_neighbors=64, p=2, weights=uniform; mae: (train=-1758.763, test=-1784.135) r2: (train=0.899, test=0.896) total time=  36.7s
# [CV 1/1] END algorithm=ball_tree, leaf_size=2, n_neighbors=38, p=2, weights=uniform; mae: (train=-1651.857, test=-1698.624) r2: (train=0.910, test=0.905) total time=  18.8s
# [CV 1/1] END algorithm=ball_tree, leaf_size=100, n_neighbors=57, p=1, weights=uniform; mae: (train=-1652.115, test=-1687.583) r2: (train=0.910, test=0.907) total time=  29.8s
# [CV 1/1] END algorithm=kd_tree, leaf_size=8, n_neighbors=53, p=1, weights=uniform; mae: (train=-1637.288, test=-1673.242) r2: (train=0.912, test=0.908) total time=   5.4s
# [CV 1/1] END algorithm=ball_tree, leaf_size=50, n_neighbors=30, p=2, weights=uniform; mae: (train=-1605.446, test=-1664.684) r2: (train=0.915, test=0.910) total time=  28.8s
# [CV 1/1] END algorithm=brute, leaf_size=25, n_neighbors=40, p=2, weights=uniform; mae: (train=-1661.653, test=-1705.780) r2: (train=0.909, test=0.905) total time=   3.5s
# [CV 1/1] END algorithm=auto, leaf_size=90, n_neighbors=75, p=2, weights=uniform; mae: (train=-1792.271, test=-1814.174) r2: (train=0.896, test=0.893) total time=   4.6s
# [CV 1/1] END algorithm=kd_tree, leaf_size=50, n_neighbors=58, p=2, weights=uniform; mae: (train=-1737.568, test=-1766.505) r2: (train=0.901, test=0.898) total time=   4.0s
# [CV 1/1] END algorithm=kd_tree, leaf_size=30, n_neighbors=76, p=1, weights=uniform; mae: (train=-1712.113, test=-1740.736) r2: (train=0.905, test=0.902) total time=   5.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=25, n_neighbors=48, p=1, weights=uniform; mae: (train=-1616.632, test=-1656.582) r2: (train=0.914, test=0.910) total time=   4.3s
# [CV 1/1] END algorithm=brute, leaf_size=60, n_neighbors=35, p=1, weights=uniform; mae: (train=-1553.981, test=-1604.465) r2: (train=0.920, test=0.915) total time=   4.4s
# [CV 1/1] END algorithm=brute, leaf_size=5, n_neighbors=54, p=2, weights=uniform; mae: (train=-1723.600, test=-1754.861) r2: (train=0.903, test=0.900) total time=   7.4s
# [CV 1/1] END algorithm=auto, leaf_size=80, n_neighbors=45, p=1, weights=uniform; mae: (train=-1602.946, test=-1645.336) r2: (train=0.915, test=0.910) total time=   5.6s
# [CV 1/1] END algorithm=ball_tree, leaf_size=2, n_neighbors=50, p=2, weights=uniform; mae: (train=-1708.368, test=-1742.507) r2: (train=0.904, test=0.901) total time=  17.5s
# [CV 1/1] END algorithm=auto, leaf_size=12, n_neighbors=41, p=1, weights=uniform; mae: (train=-1583.946, test=-1629.204) r2: (train=0.917, test=0.912) total time=   7.1s
# [CV 1/1] END algorithm=ball_tree, leaf_size=8, n_neighbors=49, p=2, weights=uniform; mae: (train=-1704.340, test=-1739.266) r2: (train=0.905, test=0.901) total time=  22.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=30, n_neighbors=62, p=1, weights=uniform; mae: (train=-1669.301, test=-1704.118) r2: (train=0.909, test=0.905) total time=   5.6s
# [CV 1/1] END algorithm=ball_tree, leaf_size=50, n_neighbors=73, p=2, weights=uniform; mae: (train=-1786.410, test=-1808.876) r2: (train=0.896, test=0.894) total time=  31.5s
# [CV 1/1] END algorithm=auto, leaf_size=5, n_neighbors=57, p=1, weights=uniform; mae: (train=-1652.115, test=-1687.612) r2: (train=0.910, test=0.907) total time=   5.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=12, n_neighbors=77, p=2, weights=uniform; mae: (train=-1798.405, test=-1819.251) r2: (train=0.895, test=0.893) total time=   5.0s
# [CV 1/1] END algorithm=ball_tree, leaf_size=70, n_neighbors=51, p=1, weights=uniform; mae: (train=-1629.288, test=-1666.363) r2: (train=0.913, test=0.909) total time=  31.0s
# [CV 1/1] END algorithm=kd_tree, leaf_size=100, n_neighbors=33, p=1, weights=uniform; mae: (train=-1543.304, test=-1594.484) r2: (train=0.921, test=0.916) total time=   4.5s
# [CV 1/1] END algorithm=auto, leaf_size=17, n_neighbors=58, p=1, weights=uniform; mae: (train=-1655.683, test=-1691.738) r2: (train=0.910, test=0.907) total time=   4.8s
# [CV 1/1] END algorithm=auto, leaf_size=100, n_neighbors=75, p=1, weights=uniform; mae: (train=-1709.500, test=-1738.907) r2: (train=0.905, test=0.902) total time=   6.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=70, n_neighbors=76, p=2, weights=uniform; mae: (train=-1795.164, test=-1816.737) r2: (train=0.895, test=0.893) total time=   5.1s
# [CV 1/1] END algorithm=kd_tree, leaf_size=60, n_neighbors=70, p=1, weights=uniform; mae: (train=-1694.854, test=-1726.739) r2: (train=0.906, test=0.903) total time=   6.5s
# [CV 1/1] END algorithm=brute, leaf_size=100, n_neighbors=56, p=2, weights=uniform; mae: (train=-1730.093, test=-1760.626) r2: (train=0.902, test=0.899) total time=   2.6s
# [CV 1/1] END algorithm=auto, leaf_size=2, n_neighbors=74, p=1, weights=uniform; mae: (train=-1706.673, test=-1736.417) r2: (train=0.905, test=0.902) total time=   7.4s
# [CV 1/1] END algorithm=brute, leaf_size=5, n_neighbors=45, p=1, weights=uniform; mae: (train=-1602.949, test=-1645.329) r2: (train=0.915, test=0.910) total time=   5.8s
# [CV 1/1] END algorithm=ball_tree, leaf_size=100, n_neighbors=33, p=1, weights=uniform; mae: (train=-1543.319, test=-1594.529) r2: (train=0.921, test=0.916) total time=  22.3s
# [CV 1/1] END algorithm=brute, leaf_size=40, n_neighbors=43, p=1, weights=uniform; mae: (train=-1593.603, test=-1637.458) r2: (train=0.916, test=0.911) total time=   6.7s
# [CV 1/1] END algorithm=ball_tree, leaf_size=25, n_neighbors=46, p=2, weights=uniform; mae: (train=-1690.982, test=-1729.150) r2: (train=0.906, test=0.902) total time=  22.7s
# [CV 1/1] END algorithm=ball_tree, leaf_size=30, n_neighbors=62, p=2, weights=uniform; mae: (train=-1751.770, test=-1778.607) r2: (train=0.900, test=0.897) total time=  37.0s
# [CV 1/1] END algorithm=kd_tree, leaf_size=12, n_neighbors=60, p=2, weights=uniform; mae: (train=-1744.466, test=-1772.766) r2: (train=0.900, test=0.898) total time=   3.7s
# [CV 1/1] END algorithm=ball_tree, leaf_size=30, n_neighbors=62, p=1, weights=uniform; mae: (train=-1669.317, test=-1704.099) r2: (train=0.909, test=0.905) total time=  18.1s
# [CV 1/1] END algorithm=brute, leaf_size=40, n_neighbors=33, p=2, weights=uniform; mae: (train=-1623.990, test=-1678.169) r2: (train=0.913, test=0.907) total time=   5.4s
# [CV 1/1] END algorithm=kd_tree, leaf_size=12, n_neighbors=67, p=1, weights=uniform; mae: (train=-1685.851, test=-1718.545) r2: (train=0.907, test=0.904) total time=   5.5s
# [CV 1/1] END algorithm=auto, leaf_size=5, n_neighbors=66, p=1, weights=uniform; mae: (train=-1682.255, test=-1715.377) r2: (train=0.907, test=0.904) total time=   5.5s
# Train R2=0.906 | Val R2=0.902 | Train MAE=1691.0 | Val MAE=1729.1 | Gap MAE=0.023 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 46, 'leaf_size': 8, 'algorithm': 'auto'}
# Train R2=0.895 | Val R2=0.893 | Train MAE=1795.2 | Val MAE=1816.7 | Gap MAE=0.012 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 76, 'leaf_size': 8, 'algorithm': 'kd_tree'}
# Train R2=0.895 | Val R2=0.892 | Train MAE=1801.2 | Val MAE=1821.7 | Gap MAE=0.011 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 78, 'leaf_size': 90, 'algorithm': 'kd_tree'}
# Train R2=0.906 | Val R2=0.902 | Train MAE=1695.8 | Val MAE=1732.4 | Gap MAE=0.022 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 47, 'leaf_size': 8, 'algorithm': 'ball_tree'}
# Train R2=0.900 | Val R2=0.897 | Train MAE=1751.8 | Val MAE=1778.6 | Gap MAE=0.015 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 62, 'leaf_size': 12, 'algorithm': 'ball_tree'}
# Train R2=0.906 | Val R2=0.903 | Train MAE=1686.5 | Val MAE=1725.2 | Gap MAE=0.023 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 45, 'leaf_size': 80, 'algorithm': 'kd_tree'}
# Train R2=0.905 | Val R2=0.902 | Train MAE=1706.7 | Val MAE=1736.4 | Gap MAE=0.017 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 74, 'leaf_size': 2, 'algorithm': 'ball_tree'}
# Train R2=0.908 | Val R2=0.905 | Train MAE=1675.8 | Val MAE=1710.5 | Gap MAE=0.021 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 64, 'leaf_size': 70, 'algorithm': 'kd_tree'}
# Train R2=0.914 | Val R2=0.910 | Train MAE=1616.6 | Val MAE=1656.6 | Gap MAE=0.025 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 48, 'leaf_size': 70, 'algorithm': 'auto'}
# Train R2=0.910 | Val R2=0.907 | Train MAE=1652.1 | Val MAE=1687.6 | Gap MAE=0.022 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 57, 'leaf_size': 40, 'algorithm': 'auto'}
# Train R2=0.895 | Val R2=0.893 | Train MAE=1795.2 | Val MAE=1816.7 | Gap MAE=0.012 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 76, 'leaf_size': 100, 'algorithm': 'auto'}
# Train R2=0.896 | Val R2=0.894 | Train MAE=1786.4 | Val MAE=1808.9 | Gap MAE=0.013 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 73, 'leaf_size': 25, 'algorithm': 'kd_tree'}
# Train R2=0.899 | Val R2=0.896 | Train MAE=1758.8 | Val MAE=1784.1 | Gap MAE=0.014 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 64, 'leaf_size': 70, 'algorithm': 'ball_tree'}
# Train R2=0.910 | Val R2=0.905 | Train MAE=1651.9 | Val MAE=1698.6 | Gap MAE=0.028 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 38, 'leaf_size': 2, 'algorithm': 'ball_tree'}
# Train R2=0.910 | Val R2=0.907 | Train MAE=1652.1 | Val MAE=1687.6 | Gap MAE=0.021 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 57, 'leaf_size': 100, 'algorithm': 'ball_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1637.3 | Val MAE=1673.2 | Gap MAE=0.022 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 53, 'leaf_size': 8, 'algorithm': 'kd_tree'}
# Train R2=0.915 | Val R2=0.910 | Train MAE=1605.4 | Val MAE=1664.7 | Gap MAE=0.037 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 30, 'leaf_size': 50, 'algorithm': 'ball_tree'}
# Train R2=0.909 | Val R2=0.905 | Train MAE=1661.7 | Val MAE=1705.8 | Gap MAE=0.027 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 40, 'leaf_size': 25, 'algorithm': 'brute'}
# Train R2=0.896 | Val R2=0.893 | Train MAE=1792.3 | Val MAE=1814.2 | Gap MAE=0.012 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 75, 'leaf_size': 90, 'algorithm': 'auto'}
# Train R2=0.901 | Val R2=0.898 | Train MAE=1737.6 | Val MAE=1766.5 | Gap MAE=0.017 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 58, 'leaf_size': 50, 'algorithm': 'kd_tree'}
# Train R2=0.905 | Val R2=0.902 | Train MAE=1712.1 | Val MAE=1740.7 | Gap MAE=0.017 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 76, 'leaf_size': 30, 'algorithm': 'kd_tree'}
# Train R2=0.914 | Val R2=0.910 | Train MAE=1616.6 | Val MAE=1656.6 | Gap MAE=0.025 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 48, 'leaf_size': 25, 'algorithm': 'kd_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1554.0 | Val MAE=1604.5 | Gap MAE=0.032 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 35, 'leaf_size': 60, 'algorithm': 'brute'}
# Train R2=0.903 | Val R2=0.900 | Train MAE=1723.6 | Val MAE=1754.9 | Gap MAE=0.018 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 54, 'leaf_size': 5, 'algorithm': 'brute'}
# Train R2=0.915 | Val R2=0.910 | Train MAE=1602.9 | Val MAE=1645.3 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 45, 'leaf_size': 80, 'algorithm': 'auto'}
# Train R2=0.904 | Val R2=0.901 | Train MAE=1708.4 | Val MAE=1742.5 | Gap MAE=0.020 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 50, 'leaf_size': 2, 'algorithm': 'ball_tree'}
# Train R2=0.917 | Val R2=0.912 | Train MAE=1583.9 | Val MAE=1629.2 | Gap MAE=0.029 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 41, 'leaf_size': 12, 'algorithm': 'auto'}
# Train R2=0.905 | Val R2=0.901 | Train MAE=1704.3 | Val MAE=1739.3 | Gap MAE=0.020 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 49, 'leaf_size': 8, 'algorithm': 'ball_tree'}
# Train R2=0.909 | Val R2=0.905 | Train MAE=1669.3 | Val MAE=1704.1 | Gap MAE=0.021 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 62, 'leaf_size': 30, 'algorithm': 'kd_tree'}
# Train R2=0.896 | Val R2=0.894 | Train MAE=1786.4 | Val MAE=1808.9 | Gap MAE=0.013 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 73, 'leaf_size': 50, 'algorithm': 'ball_tree'}
# Train R2=0.910 | Val R2=0.907 | Train MAE=1652.1 | Val MAE=1687.6 | Gap MAE=0.021 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 57, 'leaf_size': 5, 'algorithm': 'auto'}
# Train R2=0.895 | Val R2=0.893 | Train MAE=1798.4 | Val MAE=1819.3 | Gap MAE=0.012 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 77, 'leaf_size': 12, 'algorithm': 'kd_tree'}
# Train R2=0.913 | Val R2=0.909 | Train MAE=1629.3 | Val MAE=1666.4 | Gap MAE=0.023 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 51, 'leaf_size': 70, 'algorithm': 'ball_tree'}
# Train R2=0.921 | Val R2=0.916 | Train MAE=1543.3 | Val MAE=1594.5 | Gap MAE=0.033 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 100, 'algorithm': 'kd_tree'}
# Train R2=0.910 | Val R2=0.907 | Train MAE=1655.7 | Val MAE=1691.7 | Gap MAE=0.022 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 58, 'leaf_size': 17, 'algorithm': 'auto'}
# Train R2=0.905 | Val R2=0.902 | Train MAE=1709.5 | Val MAE=1738.9 | Gap MAE=0.017 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 75, 'leaf_size': 100, 'algorithm': 'auto'}
# Train R2=0.895 | Val R2=0.893 | Train MAE=1795.2 | Val MAE=1816.7 | Gap MAE=0.012 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 76, 'leaf_size': 70, 'algorithm': 'kd_tree'}
# Train R2=0.906 | Val R2=0.903 | Train MAE=1694.9 | Val MAE=1726.7 | Gap MAE=0.019 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 70, 'leaf_size': 60, 'algorithm': 'kd_tree'}
# Train R2=0.902 | Val R2=0.899 | Train MAE=1730.1 | Val MAE=1760.6 | Gap MAE=0.018 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 56, 'leaf_size': 100, 'algorithm': 'brute'}
# Train R2=0.905 | Val R2=0.902 | Train MAE=1706.7 | Val MAE=1736.4 | Gap MAE=0.017 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 74, 'leaf_size': 2, 'algorithm': 'auto'}
# Train R2=0.915 | Val R2=0.910 | Train MAE=1602.9 | Val MAE=1645.3 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 45, 'leaf_size': 5, 'algorithm': 'brute'}
# Train R2=0.921 | Val R2=0.916 | Train MAE=1543.3 | Val MAE=1594.5 | Gap MAE=0.033 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 100, 'algorithm': 'ball_tree'}
# Train R2=0.916 | Val R2=0.911 | Train MAE=1593.6 | Val MAE=1637.5 | Gap MAE=0.028 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 43, 'leaf_size': 40, 'algorithm': 'brute'}
# Train R2=0.906 | Val R2=0.902 | Train MAE=1691.0 | Val MAE=1729.2 | Gap MAE=0.023 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 46, 'leaf_size': 25, 'algorithm': 'ball_tree'}
# Train R2=0.900 | Val R2=0.897 | Train MAE=1751.8 | Val MAE=1778.6 | Gap MAE=0.015 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 62, 'leaf_size': 30, 'algorithm': 'ball_tree'}
# Train R2=0.900 | Val R2=0.898 | Train MAE=1744.5 | Val MAE=1772.8 | Gap MAE=0.016 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 60, 'leaf_size': 12, 'algorithm': 'kd_tree'}
# Train R2=0.909 | Val R2=0.905 | Train MAE=1669.3 | Val MAE=1704.1 | Gap MAE=0.021 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 62, 'leaf_size': 30, 'algorithm': 'ball_tree'}
# Train R2=0.913 | Val R2=0.907 | Train MAE=1624.0 | Val MAE=1678.2 | Gap MAE=0.033 | Params={'weights': 'uniform', 'p': 2, 'n_neighbors': 33, 'leaf_size': 40, 'algorithm': 'brute'}
# Train R2=0.907 | Val R2=0.904 | Train MAE=1685.9 | Val MAE=1718.5 | Gap MAE=0.019 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 67, 'leaf_size': 12, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.904 | Train MAE=1682.3 | Val MAE=1715.4 | Gap MAE=0.020 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 66, 'leaf_size': 5, 'algorithm': 'auto'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9208770925796292
# Best validation R2: 0.9158864708287063
# Gap R2: 0.5419422191231631 %
# Best train MAE: 1543.30412818833
# Best validation MAE: 1594.4835821193176
# Gap MAE: 3.31622607600141 %
# Best parameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 100, 'algorithm': 'kd_tree'}

# %% [markdown]
# DURANTE EXPLICAÇÕES

# %%
param_grid_knn = {
    "n_neighbors": [22, 28, 33, 40, 50],
    "weights": ["uniform"],
    "p": [1],                                
    "leaf_size": list(range(20,50)),
    "algorithm": ["auto", "ball_tree", "kd_tree"],
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_KNN,
    param_grid_knn,
    iterations=100, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# [CV 1/1] END algorithm=kd_tree, leaf_size=48, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.099, test=-1554.974) r2: (train=0.925, test=0.920) total time=   5.2s
# [CV 1/1] END algorithm=auto, leaf_size=31, n_neighbors=33, p=1, weights=uniform; mae: (train=-1561.011, test=-1620.503) r2: (train=0.916, test=0.912) total time=   6.0s
# [CV 1/1] END algorithm=auto, leaf_size=41, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.682, test=-1659.718) r2: (train=0.912, test=0.908) total time=   5.8s
# [CV 1/1] END algorithm=auto, leaf_size=28, n_neighbors=33, p=1, weights=uniform; mae: (train=-1561.011, test=-1620.503) r2: (train=0.916, test=0.912) total time=   5.8s
# [CV 1/1] END algorithm=kd_tree, leaf_size=44, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.701, test=-1659.771) r2: (train=0.912, test=0.908) total time=   8.0s
# [CV 1/1] END algorithm=auto, leaf_size=47, n_neighbors=33, p=1, weights=uniform; mae: (train=-1561.011, test=-1620.503) r2: (train=0.916, test=0.912) total time=   5.7s
# [CV 1/1] END algorithm=auto, leaf_size=47, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.158, test=-1554.820) r2: (train=0.925, test=0.920) total time=   5.9s
# [CV 1/1] END algorithm=auto, leaf_size=37, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.839, test=-1592.100) r2: (train=0.920, test=0.915) total time=   5.8s
# [CV 1/1] END algorithm=kd_tree, leaf_size=26, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.109, test=-1554.917) r2: (train=0.925, test=0.920) total time=   7.6s
# [CV 1/1] END algorithm=auto, leaf_size=44, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.158, test=-1554.820) r2: (train=0.925, test=0.920) total time=   7.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=36, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.701, test=-1659.771) r2: (train=0.912, test=0.908) total time=   7.5s
# [CV 1/1] END algorithm=ball_tree, leaf_size=23, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.981, test=-1620.541) r2: (train=0.916, test=0.912) total time=  20.8s
# [CV 1/1] END algorithm=kd_tree, leaf_size=38, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.819, test=-1592.116) r2: (train=0.920, test=0.915) total time=   6.4s
# [CV 1/1] END algorithm=kd_tree, leaf_size=36, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.972, test=-1620.494) r2: (train=0.916, test=0.912) total time=   6.8s
# [CV 1/1] END algorithm=kd_tree, leaf_size=40, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.819, test=-1592.116) r2: (train=0.920, test=0.915) total time=   6.7s
# [CV 1/1] END algorithm=auto, leaf_size=41, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.158, test=-1554.820) r2: (train=0.925, test=0.920) total time=   5.6s
# [CV 1/1] END algorithm=kd_tree, leaf_size=37, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.972, test=-1620.494) r2: (train=0.916, test=0.912) total time=   7.5s
# [CV 1/1] END algorithm=ball_tree, leaf_size=23, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.807, test=-1702.722) r2: (train=0.907, test=0.903) total time=  24.1s
# [CV 1/1] END algorithm=ball_tree, leaf_size=43, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.680, test=-1659.782) r2: (train=0.912, test=0.908) total time=  31.4s
# [CV 1/1] END algorithm=kd_tree, leaf_size=48, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.819, test=-1592.116) r2: (train=0.920, test=0.915) total time=   6.8s
# [CV 1/1] END algorithm=ball_tree, leaf_size=34, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.991, test=-1620.468) r2: (train=0.916, test=0.912) total time=  28.7s
# [CV 1/1] END algorithm=auto, leaf_size=43, n_neighbors=33, p=1, weights=uniform; mae: (train=-1561.011, test=-1620.503) r2: (train=0.916, test=0.912) total time=   7.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=23, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.846, test=-1592.113) r2: (train=0.920, test=0.915) total time=   5.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=49, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.819, test=-1592.116) r2: (train=0.920, test=0.915) total time=   6.5s
# [CV 1/1] END algorithm=ball_tree, leaf_size=26, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.807, test=-1702.722) r2: (train=0.907, test=0.903) total time=  23.0s
# [CV 1/1] END algorithm=auto, leaf_size=41, n_neighbors=33, p=1, weights=uniform; mae: (train=-1561.011, test=-1620.503) r2: (train=0.916, test=0.912) total time=   7.1s
# [CV 1/1] END algorithm=ball_tree, leaf_size=22, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.807, test=-1702.722) r2: (train=0.907, test=0.903) total time=  23.8s
# [CV 1/1] END algorithm=auto, leaf_size=23, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.682, test=-1659.718) r2: (train=0.912, test=0.908) total time=   7.1s
# [CV 1/1] END algorithm=auto, leaf_size=25, n_neighbors=33, p=1, weights=uniform; mae: (train=-1561.011, test=-1620.503) r2: (train=0.916, test=0.912) total time=   7.1s
# [CV 1/1] END algorithm=kd_tree, leaf_size=32, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.972, test=-1620.494) r2: (train=0.916, test=0.912) total time=   7.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=43, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.099, test=-1554.974) r2: (train=0.925, test=0.920) total time=   5.8s
# [CV 1/1] END algorithm=auto, leaf_size=27, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.839, test=-1592.100) r2: (train=0.920, test=0.915) total time=   8.2s
# [CV 1/1] END algorithm=ball_tree, leaf_size=22, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.981, test=-1620.541) r2: (train=0.916, test=0.912) total time=  24.1s
# [CV 1/1] END algorithm=kd_tree, leaf_size=24, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.109, test=-1554.917) r2: (train=0.925, test=0.920) total time=   4.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=28, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.846, test=-1592.113) r2: (train=0.920, test=0.915) total time=   7.1s
# [CV 1/1] END algorithm=auto, leaf_size=20, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.838, test=-1702.784) r2: (train=0.907, test=0.903) total time=   7.5s
# [CV 1/1] END algorithm=auto, leaf_size=32, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.682, test=-1659.718) r2: (train=0.912, test=0.908) total time=   6.8s
# [CV 1/1] END algorithm=auto, leaf_size=31, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.839, test=-1592.100) r2: (train=0.920, test=0.915) total time=   6.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=27, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.712, test=-1659.807) r2: (train=0.912, test=0.908) total time=   6.2s
# [CV 1/1] END algorithm=auto, leaf_size=35, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.158, test=-1554.820) r2: (train=0.925, test=0.920) total time=   7.1s
# [CV 1/1] END algorithm=auto, leaf_size=32, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.838, test=-1702.784) r2: (train=0.907, test=0.903) total time=   7.2s
# [CV 1/1] END algorithm=ball_tree, leaf_size=21, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.807, test=-1702.722) r2: (train=0.907, test=0.903) total time=  23.0s
# [CV 1/1] END algorithm=ball_tree, leaf_size=41, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.991, test=-1620.468) r2: (train=0.916, test=0.912) total time=  25.6s
# [CV 1/1] END algorithm=kd_tree, leaf_size=27, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.970, test=-1620.462) r2: (train=0.916, test=0.912) total time=   5.4s
# [CV 1/1] END algorithm=kd_tree, leaf_size=45, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.099, test=-1554.974) r2: (train=0.925, test=0.920) total time=   6.5s
# [CV 1/1] END algorithm=ball_tree, leaf_size=32, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.148, test=-1554.966) r2: (train=0.925, test=0.920) total time=  28.8s
# [CV 1/1] END algorithm=ball_tree, leaf_size=30, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.821, test=-1702.744) r2: (train=0.907, test=0.903) total time=  34.1s
# [CV 1/1] END algorithm=auto, leaf_size=45, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.838, test=-1702.784) r2: (train=0.907, test=0.903) total time=   6.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=34, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.701, test=-1659.771) r2: (train=0.912, test=0.908) total time=   7.1s
# [CV 1/1] END algorithm=ball_tree, leaf_size=44, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.991, test=-1620.468) r2: (train=0.916, test=0.912) total time=  25.3s
# [CV 1/1] END algorithm=kd_tree, leaf_size=35, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.099, test=-1554.974) r2: (train=0.925, test=0.920) total time=   5.3s
# [CV 1/1] END algorithm=ball_tree, leaf_size=44, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.821, test=-1702.744) r2: (train=0.907, test=0.903) total time=  28.5s
# [CV 1/1] END algorithm=kd_tree, leaf_size=47, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.099, test=-1554.974) r2: (train=0.925, test=0.920) total time=   5.5s
# [CV 1/1] END algorithm=kd_tree, leaf_size=46, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.809, test=-1702.767) r2: (train=0.907, test=0.903) total time=   7.8s
# [CV 1/1] END algorithm=ball_tree, leaf_size=49, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.148, test=-1554.966) r2: (train=0.925, test=0.920) total time=  25.2s
# [CV 1/1] END algorithm=ball_tree, leaf_size=33, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.991, test=-1620.468) r2: (train=0.916, test=0.912) total time=  25.0s
# [CV 1/1] END algorithm=ball_tree, leaf_size=47, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.680, test=-1659.782) r2: (train=0.912, test=0.908) total time=  25.7s
# [CV 1/1] END algorithm=ball_tree, leaf_size=45, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.148, test=-1554.966) r2: (train=0.925, test=0.920) total time=  26.2s
# [CV 1/1] END algorithm=auto, leaf_size=49, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.682, test=-1659.718) r2: (train=0.912, test=0.908) total time=   6.8s
# [CV 1/1] END algorithm=auto, leaf_size=34, n_neighbors=33, p=1, weights=uniform; mae: (train=-1561.011, test=-1620.503) r2: (train=0.916, test=0.912) total time=   8.8s
# [CV 1/1] END algorithm=auto, leaf_size=36, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.158, test=-1554.820) r2: (train=0.925, test=0.920) total time=   8.1s
# [CV 1/1] END algorithm=ball_tree, leaf_size=48, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.830, test=-1592.084) r2: (train=0.920, test=0.915) total time=  26.1s
# [CV 1/1] END algorithm=kd_tree, leaf_size=25, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.109, test=-1554.917) r2: (train=0.925, test=0.920) total time=   4.7s
# [CV 1/1] END algorithm=ball_tree, leaf_size=23, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.695, test=-1659.752) r2: (train=0.912, test=0.908) total time=  21.1s
# [CV 1/1] END algorithm=ball_tree, leaf_size=41, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.830, test=-1592.084) r2: (train=0.920, test=0.915) total time=  25.1s
# [CV 1/1] END algorithm=kd_tree, leaf_size=39, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.819, test=-1592.116) r2: (train=0.920, test=0.915) total time=   5.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=49, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.701, test=-1659.771) r2: (train=0.912, test=0.908) total time=   7.2s
# [CV 1/1] END algorithm=kd_tree, leaf_size=28, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.109, test=-1554.917) r2: (train=0.925, test=0.920) total time=   4.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=26, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.846, test=-1592.113) r2: (train=0.920, test=0.915) total time=   5.3s
# [CV 1/1] END algorithm=ball_tree, leaf_size=36, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.148, test=-1554.966) r2: (train=0.925, test=0.920) total time=  26.1s
# [CV 1/1] END algorithm=auto, leaf_size=35, n_neighbors=33, p=1, weights=uniform; mae: (train=-1561.011, test=-1620.503) r2: (train=0.916, test=0.912) total time=   6.6s
# [CV 1/1] END algorithm=kd_tree, leaf_size=45, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.809, test=-1702.767) r2: (train=0.907, test=0.903) total time=   7.9s
# [CV 1/1] END algorithm=ball_tree, leaf_size=39, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.830, test=-1592.084) r2: (train=0.920, test=0.915) total time=  26.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=43, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.701, test=-1659.771) r2: (train=0.912, test=0.908) total time=   7.2s
# [CV 1/1] END algorithm=auto, leaf_size=21, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.838, test=-1702.784) r2: (train=0.907, test=0.903) total time=   6.6s
# [CV 1/1] END algorithm=ball_tree, leaf_size=39, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.821, test=-1702.744) r2: (train=0.907, test=0.903) total time=  28.1s
# [CV 1/1] END algorithm=ball_tree, leaf_size=41, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.821, test=-1702.744) r2: (train=0.907, test=0.903) total time=  28.1s
# [CV 1/1] END algorithm=auto, leaf_size=45, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.839, test=-1592.100) r2: (train=0.920, test=0.915) total time=   6.5s
# [CV 1/1] END algorithm=ball_tree, leaf_size=27, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.807, test=-1702.722) r2: (train=0.907, test=0.903) total time=  21.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=40, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.701, test=-1659.771) r2: (train=0.912, test=0.908) total time=   7.0s
# [CV 1/1] END algorithm=kd_tree, leaf_size=42, n_neighbors=40, p=1, weights=uniform; mae: (train=-1604.701, test=-1659.771) r2: (train=0.912, test=0.908) total time=   8.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=49, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.972, test=-1620.494) r2: (train=0.916, test=0.912) total time=   6.5s
# [CV 1/1] END algorithm=auto, leaf_size=28, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.839, test=-1592.100) r2: (train=0.920, test=0.915) total time=   7.5s
# [CV 1/1] END algorithm=auto, leaf_size=38, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.158, test=-1554.820) r2: (train=0.925, test=0.920) total time=   6.8s
# [CV 1/1] END algorithm=kd_tree, leaf_size=37, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.809, test=-1702.767) r2: (train=0.907, test=0.903) total time=   8.1s
# [CV 1/1] END algorithm=ball_tree, leaf_size=38, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.830, test=-1592.084) r2: (train=0.920, test=0.915) total time=  25.9s
# [CV 1/1] END algorithm=kd_tree, leaf_size=25, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.970, test=-1620.462) r2: (train=0.916, test=0.912) total time=   5.9s
# [CV 1/1] END algorithm=auto, leaf_size=40, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.838, test=-1702.784) r2: (train=0.907, test=0.903) total time=   6.9s
# [CV 1/1] END algorithm=ball_tree, leaf_size=38, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.148, test=-1554.966) r2: (train=0.925, test=0.920) total time=  24.6s
# [CV 1/1] END algorithm=kd_tree, leaf_size=42, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.809, test=-1702.767) r2: (train=0.907, test=0.903) total time=   8.0s
# [CV 1/1] END algorithm=ball_tree, leaf_size=29, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.140, test=-1554.840) r2: (train=0.925, test=0.920) total time=  18.7s
# [CV 1/1] END algorithm=kd_tree, leaf_size=21, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.970, test=-1620.462) r2: (train=0.916, test=0.912) total time=   5.7s
# [CV 1/1] END algorithm=ball_tree, leaf_size=42, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.991, test=-1620.468) r2: (train=0.916, test=0.912) total time=  28.7s
# [CV 1/1] END algorithm=ball_tree, leaf_size=26, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.140, test=-1554.840) r2: (train=0.925, test=0.920) total time=  19.5s
# [CV 1/1] END algorithm=kd_tree, leaf_size=27, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.810, test=-1702.717) r2: (train=0.907, test=0.903) total time=   6.8s
# [CV 1/1] END algorithm=kd_tree, leaf_size=40, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.809, test=-1702.767) r2: (train=0.907, test=0.903) total time=   7.9s
# [CV 1/1] END algorithm=ball_tree, leaf_size=37, n_neighbors=33, p=1, weights=uniform; mae: (train=-1560.991, test=-1620.468) r2: (train=0.916, test=0.912) total time=  25.4s
# [CV 1/1] END algorithm=kd_tree, leaf_size=24, n_neighbors=28, p=1, weights=uniform; mae: (train=-1523.846, test=-1592.113) r2: (train=0.920, test=0.915) total time=   5.1s
# [CV 1/1] END algorithm=kd_tree, leaf_size=35, n_neighbors=50, p=1, weights=uniform; mae: (train=-1658.809, test=-1702.767) r2: (train=0.907, test=0.903) total time=   7.9s
# [CV 1/1] END algorithm=ball_tree, leaf_size=43, n_neighbors=22, p=1, weights=uniform; mae: (train=-1470.148, test=-1554.966) r2: (train=0.925, test=0.920) total time=  24.9s
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 48, 'algorithm': 'kd_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 31, 'algorithm': 'auto'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.7 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 41, 'algorithm': 'auto'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 28, 'algorithm': 'auto'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 44, 'algorithm': 'kd_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 47, 'algorithm': 'auto'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.2 | Val MAE=1554.8 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 47, 'algorithm': 'auto'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 37, 'algorithm': 'auto'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1554.9 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 26, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.2 | Val MAE=1554.8 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 44, 'algorithm': 'auto'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 36, 'algorithm': 'kd_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 23, 'algorithm': 'ball_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 38, 'algorithm': 'kd_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 36, 'algorithm': 'kd_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 40, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.2 | Val MAE=1554.8 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 41, 'algorithm': 'auto'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 37, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 23, 'algorithm': 'ball_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 43, 'algorithm': 'ball_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 48, 'algorithm': 'kd_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 34, 'algorithm': 'ball_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 43, 'algorithm': 'auto'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 23, 'algorithm': 'kd_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 49, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 26, 'algorithm': 'ball_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 41, 'algorithm': 'auto'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 22, 'algorithm': 'ball_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.7 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 23, 'algorithm': 'auto'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 25, 'algorithm': 'auto'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 32, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 43, 'algorithm': 'kd_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 27, 'algorithm': 'auto'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 22, 'algorithm': 'ball_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1554.9 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 24, 'algorithm': 'kd_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 28, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 20, 'algorithm': 'auto'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.7 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 32, 'algorithm': 'auto'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 31, 'algorithm': 'auto'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 27, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.2 | Val MAE=1554.8 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 35, 'algorithm': 'auto'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 32, 'algorithm': 'auto'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 21, 'algorithm': 'ball_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 41, 'algorithm': 'ball_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 27, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 45, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 32, 'algorithm': 'ball_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 30, 'algorithm': 'ball_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 45, 'algorithm': 'auto'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 34, 'algorithm': 'kd_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 44, 'algorithm': 'ball_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 35, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 44, 'algorithm': 'ball_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 47, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 46, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 49, 'algorithm': 'ball_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 33, 'algorithm': 'ball_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 47, 'algorithm': 'ball_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 45, 'algorithm': 'ball_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.7 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 49, 'algorithm': 'auto'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 34, 'algorithm': 'auto'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.2 | Val MAE=1554.8 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 36, 'algorithm': 'auto'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 48, 'algorithm': 'ball_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1554.9 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 25, 'algorithm': 'kd_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 23, 'algorithm': 'ball_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 41, 'algorithm': 'ball_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 39, 'algorithm': 'kd_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 49, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1554.9 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 28, 'algorithm': 'kd_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 26, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 36, 'algorithm': 'ball_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 35, 'algorithm': 'auto'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 45, 'algorithm': 'kd_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 39, 'algorithm': 'ball_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 43, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 21, 'algorithm': 'auto'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 39, 'algorithm': 'ball_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 41, 'algorithm': 'ball_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 45, 'algorithm': 'auto'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 27, 'algorithm': 'ball_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 40, 'algorithm': 'kd_tree'}
# Train R2=0.912 | Val R2=0.908 | Train MAE=1604.7 | Val MAE=1659.8 | Gap MAE=0.034 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 40, 'leaf_size': 42, 'algorithm': 'kd_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 49, 'algorithm': 'kd_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 28, 'algorithm': 'auto'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.2 | Val MAE=1554.8 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 38, 'algorithm': 'auto'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 37, 'algorithm': 'kd_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 38, 'algorithm': 'ball_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 25, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 40, 'algorithm': 'auto'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 38, 'algorithm': 'ball_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 42, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1554.8 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 29, 'algorithm': 'ball_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 21, 'algorithm': 'kd_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 42, 'algorithm': 'ball_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1554.8 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 26, 'algorithm': 'ball_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.7 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 27, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 40, 'algorithm': 'kd_tree'}
# Train R2=0.916 | Val R2=0.912 | Train MAE=1561.0 | Val MAE=1620.5 | Gap MAE=0.038 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 33, 'leaf_size': 37, 'algorithm': 'ball_tree'}
# Train R2=0.920 | Val R2=0.915 | Train MAE=1523.8 | Val MAE=1592.1 | Gap MAE=0.045 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 28, 'leaf_size': 24, 'algorithm': 'kd_tree'}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1658.8 | Val MAE=1702.8 | Gap MAE=0.026 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 50, 'leaf_size': 35, 'algorithm': 'kd_tree'}
# Train R2=0.925 | Val R2=0.920 | Train MAE=1470.1 | Val MAE=1555.0 | Gap MAE=0.058 | Params={'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 43, 'algorithm': 'ball_tree'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9245151550415119
# Best validation R2: 0.919509443302711
# Gap R2: 0.5414418261836033 %
# Best train MAE: 1470.1584110877443
# Best validation MAE: 1554.820440336235
# Gap MAE: 5.7587011447188665 %
# Best parameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 22, 'leaf_size': 47, 'algorithm': 'auto'}

# %% [markdown]
# <a class="anchor" id="9_3_2">
#
# ## **9.3.2** Bagging
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# --------------------------------------------

# %%
best_model_knn = rsCV_KNN.best_estimator_
preds_knn = best_model_knn.predict(test.values)

# %%
estimator_knn = KNeighborsRegressor(weights='uniform', p=1, n_neighbors=10, metric='manhattan' , leaf_size=12, algorithm='kd_tree', random_state=42)
model_bag_knn = BaggingRegressor(estimator=estimator_knn, random_state=42)
                                 
param_grid_knn = {
    "n_estimators": [10, 30, 50], 
    "max_samples": [0.5, 0.7, 0.9],      # Fraction of the dataset to sample
    "max_features": [0.5, 0.6, 0.7],     # Fraction of features to sample
    "bootstrap": [True, False],          # Sampling with or without replacement
    "bootstrap_features": [True, False]  # Feature sampling with or without replacement
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_bag_knn,
    param_grid_knn,
    iterations=15, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 15 candidates, totalling 15 fits
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=30; mae: (train=-1549.676, test=-1628.359) r2: (train=0.923, test=0.916) total time=  19.7s
# [CV 1/1] END bootstrap=True, bootstrap_features=True, max_features=0.7, max_samples=0.5, n_estimators=30; mae: (train=-1565.622, test=-1648.741) r2: (train=0.920, test=0.914) total time=  24.2s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.7, max_samples=0.9, n_estimators=30; mae: (train=-1317.779, test=-1464.002) r2: (train=0.940, test=0.930) total time=  50.9s
# [CV 1/1] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.9, n_estimators=30; mae: (train=-1544.874, test=-1662.317) r2: (train=0.924, test=0.913) total time=  25.5s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=50; mae: (train=-1539.641, test=-1633.462) r2: (train=0.922, test=0.915) total time=  47.0s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=10; mae: (train=-1605.038, test=-1715.205) r2: (train=0.916, test=0.904) total time=   5.0s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.9, n_estimators=30; mae: (train=-1370.881, test=-1519.471) r2: (train=0.938, test=0.928) total time=  34.1s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.9, n_estimators=50; mae: (train=-1329.749, test=-1461.661) r2: (train=0.940, test=0.931) total time=  59.0s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=10; mae: (train=-1710.951, test=-1827.474) r2: (train=0.908, test=0.894) total time=   6.3s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=30; mae: (train=-1644.238, test=-1724.771) r2: (train=0.915, test=0.907) total time=  16.1s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.6, max_samples=0.7, n_estimators=30; mae: (train=-1411.861, test=-1532.310) r2: (train=0.934, test=0.926) total time=  27.2s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.7, n_estimators=50; mae: (train=-1348.617, test=-1465.472) r2: (train=0.937, test=0.930) total time= 1.2min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.5, n_estimators=30; mae: (train=-1417.292, test=-1501.002) r2: (train=0.930, test=0.925) total time=  35.1s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.6, max_samples=0.9, n_estimators=50; mae: (train=-1592.685, test=-1729.373) r2: (train=0.923, test=0.913) total time=  50.3s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.7, max_samples=0.9, n_estimators=30; mae: (train=-1424.887, test=-1552.578) r2: (train=0.935, test=0.925) total time=  39.0s
# Train R2=0.923 | Val R2=0.916 | Train MAE=1549.7 | Val MAE=1628.4 | Gap MAE=0.051 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.920 | Val R2=0.914 | Train MAE=1565.6 | Val MAE=1648.7 | Gap MAE=0.053 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.7, 'bootstrap_features': True, 'bootstrap': True}
# Train R2=0.940 | Val R2=0.930 | Train MAE=1317.8 | Val MAE=1464.0 | Gap MAE=0.111 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.924 | Val R2=0.913 | Train MAE=1544.9 | Val MAE=1662.3 | Gap MAE=0.076 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': True}
# Train R2=0.922 | Val R2=0.915 | Train MAE=1539.6 | Val MAE=1633.5 | Gap MAE=0.061 | Params={'n_estimators': 50, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.916 | Val R2=0.904 | Train MAE=1605.0 | Val MAE=1715.2 | Gap MAE=0.069 | Params={'n_estimators': 10, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.938 | Val R2=0.928 | Train MAE=1370.9 | Val MAE=1519.5 | Gap MAE=0.108 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.940 | Val R2=0.931 | Train MAE=1329.7 | Val MAE=1461.7 | Gap MAE=0.099 | Params={'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.908 | Val R2=0.894 | Train MAE=1711.0 | Val MAE=1827.5 | Gap MAE=0.068 | Params={'n_estimators': 10, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.915 | Val R2=0.907 | Train MAE=1644.2 | Val MAE=1724.8 | Gap MAE=0.049 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.934 | Val R2=0.926 | Train MAE=1411.9 | Val MAE=1532.3 | Gap MAE=0.085 | Params={'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.937 | Val R2=0.930 | Train MAE=1348.6 | Val MAE=1465.5 | Gap MAE=0.087 | Params={'n_estimators': 50, 'max_samples': 0.7, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.930 | Val R2=0.925 | Train MAE=1417.3 | Val MAE=1501.0 | Gap MAE=0.059 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.923 | Val R2=0.913 | Train MAE=1592.7 | Val MAE=1729.4 | Gap MAE=0.086 | Params={'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.6, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.935 | Val R2=0.925 | Train MAE=1424.9 | Val MAE=1552.6 | Gap MAE=0.090 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.7, 'bootstrap_features': True, 'bootstrap': False}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9402434973593445
# Best validation R2: 0.9311993265053382
# Gap R2: 0.9618966660664715 %
# Best train MAE: 1329.7488851229064
# Best validation MAE: 1461.6605176702863
# Gap MAE: 9.920040845545627 %
# Best parameters: {'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}

# %%
estimator_knn = KNeighborsRegressor(weights='uniform', p=1, n_neighbors=10, metric='manhattan' , leaf_size=12, algorithm='kd_tree', random_state=42)
model_bag_knn = BaggingRegressor(estimator=estimator_knn, random_state=42)
                                 
param_grid_knn = {
    "n_estimators": [10, 30, 50], 
    "max_samples": [0.5, 0.7, 0.9],      # Fraction of the dataset to sample
    "max_features": [0.5, 0.6, 0.7],     # Fraction of features to sample
    "bootstrap": [True, False],          # Sampling with or without replacement
    "bootstrap_features": [True, False]  # Feature sampling with or without replacement
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_bag_knn,
    param_grid_knn,
    iterations=30, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 30 candidates, totalling 30 fits
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=30; mae: (train=-1574.865, test=-1656.963) r2: (train=0.919, test=0.912) total time=  21.0s
# [CV 1/1] END bootstrap=True, bootstrap_features=True, max_features=0.7, max_samples=0.5, n_estimators=30; mae: (train=-1555.998, test=-1643.078) r2: (train=0.920, test=0.911) total time=  24.0s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.7, max_samples=0.9, n_estimators=30; mae: (train=-1307.823, test=-1446.368) r2: (train=0.942, test=0.935) total time=  59.6s
# [CV 1/1] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.9, n_estimators=30; mae: (train=-1624.069, test=-1766.545) r2: (train=0.920, test=0.907) total time=  25.2s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=50; mae: (train=-1541.400, test=-1632.555) r2: (train=0.921, test=0.914) total time=  34.4s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=10; mae: (train=-1834.706, test=-1939.367) r2: (train=0.902, test=0.891) total time=   6.3s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.9, n_estimators=30; mae: (train=-1340.954, test=-1483.927) r2: (train=0.940, test=0.931) total time=  37.5s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.9, n_estimators=50; mae: (train=-1379.067, test=-1518.657) r2: (train=0.938, test=0.929) total time=  59.6s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=10; mae: (train=-1553.606, test=-1634.695) r2: (train=0.922, test=0.916) total time=   8.2s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.5, max_samples=0.5, n_estimators=30; mae: (train=-1676.862, test=-1767.258) r2: (train=0.912, test=0.902) total time=  22.9s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.6, max_samples=0.7, n_estimators=30; mae: (train=-1392.073, test=-1506.434) r2: (train=0.935, test=0.928) total time=  33.8s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.7, n_estimators=50; mae: (train=-1385.274, test=-1501.564) r2: (train=0.935, test=0.928) total time= 1.4min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.5, n_estimators=30; mae: (train=-1461.080, test=-1553.011) r2: (train=0.927, test=0.921) total time=  49.5s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.6, max_samples=0.9, n_estimators=50; mae: (train=-1509.551, test=-1656.425) r2: (train=0.930, test=0.918) total time=  59.8s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.7, max_samples=0.9, n_estimators=30; mae: (train=-1376.949, test=-1509.879) r2: (train=0.938, test=0.929) total time=  46.7s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.5, n_estimators=10; mae: (train=-1542.999, test=-1638.809) r2: (train=0.923, test=0.915) total time=   8.9s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.7, n_estimators=30; mae: (train=-1381.845, test=-1493.969) r2: (train=0.935, test=0.927) total time=  36.4s
# [CV 1/1] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.7, n_estimators=10; mae: (train=-1710.126, test=-1818.839) r2: (train=0.912, test=0.902) total time=   9.5s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.7, max_samples=0.9, n_estimators=10; mae: (train=-1334.663, test=-1475.585) r2: (train=0.938, test=0.929) total time=  20.6s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.5, max_samples=0.9, n_estimators=10; mae: (train=-1754.093, test=-1844.997) r2: (train=0.907, test=0.900) total time=  10.8s
# [CV 1/1] END bootstrap=True, bootstrap_features=True, max_features=0.7, max_samples=0.7, n_estimators=30; mae: (train=-1449.124, test=-1561.632) r2: (train=0.931, test=0.923) total time=  38.5s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.5, max_samples=0.9, n_estimators=30; mae: (train=-1587.278, test=-1697.784) r2: (train=0.922, test=0.912) total time=  30.2s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.6, max_samples=0.7, n_estimators=10; mae: (train=-1383.591, test=-1489.734) r2: (train=0.936, test=0.929) total time=  11.1s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.5, n_estimators=50; mae: (train=-1492.992, test=-1576.036) r2: (train=0.925, test=0.919) total time=  44.6s
# [CV 1/1] END bootstrap=False, bootstrap_features=True, max_features=0.6, max_samples=0.5, n_estimators=50; mae: (train=-1622.287, test=-1710.532) r2: (train=0.915, test=0.906) total time=  49.0s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.7, n_estimators=30; mae: (train=-1435.428, test=-1555.219) r2: (train=0.932, test=0.922) total time=  23.8s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.7, n_estimators=10; mae: (train=-1459.214, test=-1584.404) r2: (train=0.929, test=0.920) total time=   8.2s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.7, max_samples=0.5, n_estimators=10; mae: (train=-1493.111, test=-1579.151) r2: (train=0.926, test=0.920) total time=  10.6s
# [CV 1/1] END bootstrap=True, bootstrap_features=False, max_features=0.5, max_samples=0.9, n_estimators=50; mae: (train=-1442.652, test=-1580.870) r2: (train=0.933, test=0.923) total time=  49.1s
# [CV 1/1] END bootstrap=True, bootstrap_features=True, max_features=0.5, max_samples=0.7, n_estimators=50; mae: (train=-1566.768, test=-1665.990) r2: (train=0.923, test=0.915) total time=  35.9s
# Train R2=0.919 | Val R2=0.912 | Train MAE=1574.9 | Val MAE=1657.0 | Gap MAE=0.052 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.920 | Val R2=0.911 | Train MAE=1556.0 | Val MAE=1643.1 | Gap MAE=0.056 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.7, 'bootstrap_features': True, 'bootstrap': True}
# Train R2=0.942 | Val R2=0.935 | Train MAE=1307.8 | Val MAE=1446.4 | Gap MAE=0.106 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.920 | Val R2=0.907 | Train MAE=1624.1 | Val MAE=1766.5 | Gap MAE=0.088 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': True}
# Train R2=0.921 | Val R2=0.914 | Train MAE=1541.4 | Val MAE=1632.6 | Gap MAE=0.059 | Params={'n_estimators': 50, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.902 | Val R2=0.891 | Train MAE=1834.7 | Val MAE=1939.4 | Gap MAE=0.057 | Params={'n_estimators': 10, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.940 | Val R2=0.931 | Train MAE=1341.0 | Val MAE=1483.9 | Gap MAE=0.107 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.938 | Val R2=0.929 | Train MAE=1379.1 | Val MAE=1518.7 | Gap MAE=0.101 | Params={'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.922 | Val R2=0.916 | Train MAE=1553.6 | Val MAE=1634.7 | Gap MAE=0.052 | Params={'n_estimators': 10, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.912 | Val R2=0.902 | Train MAE=1676.9 | Val MAE=1767.3 | Gap MAE=0.054 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.935 | Val R2=0.928 | Train MAE=1392.1 | Val MAE=1506.4 | Gap MAE=0.082 | Params={'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.935 | Val R2=0.928 | Train MAE=1385.3 | Val MAE=1501.6 | Gap MAE=0.084 | Params={'n_estimators': 50, 'max_samples': 0.7, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.927 | Val R2=0.921 | Train MAE=1461.1 | Val MAE=1553.0 | Gap MAE=0.063 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.930 | Val R2=0.918 | Train MAE=1509.6 | Val MAE=1656.4 | Gap MAE=0.097 | Params={'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.6, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.938 | Val R2=0.929 | Train MAE=1376.9 | Val MAE=1509.9 | Gap MAE=0.097 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.7, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.923 | Val R2=0.915 | Train MAE=1543.0 | Val MAE=1638.8 | Gap MAE=0.062 | Params={'n_estimators': 10, 'max_samples': 0.5, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.935 | Val R2=0.927 | Train MAE=1381.8 | Val MAE=1494.0 | Gap MAE=0.081 | Params={'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.912 | Val R2=0.902 | Train MAE=1710.1 | Val MAE=1818.8 | Gap MAE=0.064 | Params={'n_estimators': 10, 'max_samples': 0.7, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': True}
# Train R2=0.938 | Val R2=0.929 | Train MAE=1334.7 | Val MAE=1475.6 | Gap MAE=0.106 | Params={'n_estimators': 10, 'max_samples': 0.9, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.907 | Val R2=0.900 | Train MAE=1754.1 | Val MAE=1845.0 | Gap MAE=0.052 | Params={'n_estimators': 10, 'max_samples': 0.9, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.931 | Val R2=0.923 | Train MAE=1449.1 | Val MAE=1561.6 | Gap MAE=0.078 | Params={'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.7, 'bootstrap_features': True, 'bootstrap': True}
# Train R2=0.922 | Val R2=0.912 | Train MAE=1587.3 | Val MAE=1697.8 | Gap MAE=0.070 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.936 | Val R2=0.929 | Train MAE=1383.6 | Val MAE=1489.7 | Gap MAE=0.077 | Params={'n_estimators': 10, 'max_samples': 0.7, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.925 | Val R2=0.919 | Train MAE=1493.0 | Val MAE=1576.0 | Gap MAE=0.056 | Params={'n_estimators': 50, 'max_samples': 0.5, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.915 | Val R2=0.906 | Train MAE=1622.3 | Val MAE=1710.5 | Gap MAE=0.054 | Params={'n_estimators': 50, 'max_samples': 0.5, 'max_features': 0.6, 'bootstrap_features': True, 'bootstrap': False}
# Train R2=0.932 | Val R2=0.922 | Train MAE=1435.4 | Val MAE=1555.2 | Gap MAE=0.083 | Params={'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.929 | Val R2=0.920 | Train MAE=1459.2 | Val MAE=1584.4 | Gap MAE=0.086 | Params={'n_estimators': 10, 'max_samples': 0.7, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.926 | Val R2=0.920 | Train MAE=1493.1 | Val MAE=1579.2 | Gap MAE=0.058 | Params={'n_estimators': 10, 'max_samples': 0.5, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.933 | Val R2=0.923 | Train MAE=1442.7 | Val MAE=1580.9 | Gap MAE=0.096 | Params={'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': True}
# Train R2=0.923 | Val R2=0.915 | Train MAE=1566.8 | Val MAE=1666.0 | Gap MAE=0.063 | Params={'n_estimators': 50, 'max_samples': 0.7, 'max_features': 0.5, 'bootstrap_features': True, 'bootstrap': True}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9418963533581799
# Best validation R2: 0.9345107984383622
# Gap R2: 0.7841154595710803 %
# Best train MAE: 1307.8234452707668
# Best validation MAE: 1446.367730832511
# Gap MAE: 10.59350067952486 %
# Best parameters: {'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': True}

# %%
estimator_knn = KNeighborsRegressor(weights='uniform', p=1, n_neighbors=10, metric='manhattan' , leaf_size=12, algorithm='kd_tree', random_state=42)
model_bag_knn = BaggingRegressor(estimator=estimator_knn, random_state=42)
                                 
param_grid_knn = {
    "n_estimators": [30, 50], 
    "max_samples": [0.2, 0.3, 0.5, 0.7, 0.9],      # Fraction of the dataset to sample
    "max_features": [0.5, 0.6, 0.7, 0.9],     # Fraction of features to sample
    "bootstrap": [False],          # Sampling with or without replacement
    "bootstrap_features": [False]  # Feature sampling with or without replacement
}

# %%
rsCV_KNN = apply_randomized_search_cv(
    model_bag_knn,
    param_grid_knn,
    iterations=50, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)

evaluate_model(rsCV_KNN)
# Out:
# Fitting 1 folds for each of 40 candidates, totalling 40 fits
# c:\Users\Catarina\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 40 is smaller than n_iter=50. Running 40 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.2, n_estimators=30; mae: (train=-1721.691, test=-1767.994) r2: (train=0.903, test=0.897) total time=  13.2s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.2, n_estimators=50; mae: (train=-1714.609, test=-1758.725) r2: (train=0.902, test=0.897) total time=  21.4s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.3, n_estimators=30; mae: (train=-1568.322, test=-1628.325) r2: (train=0.917, test=0.911) total time=  21.7s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.3, n_estimators=50; mae: (train=-1612.743, test=-1668.052) r2: (train=0.913, test=0.907) total time=  29.2s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=30; mae: (train=-1513.016, test=-1602.089) r2: (train=0.924, test=0.917) total time=  27.3s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.5, n_estimators=50; mae: (train=-1538.229, test=-1627.209) r2: (train=0.921, test=0.912) total time=  41.6s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.7, n_estimators=30; mae: (train=-1481.335, test=-1604.749) r2: (train=0.930, test=0.920) total time=  27.9s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.7, n_estimators=50; mae: (train=-1490.777, test=-1611.521) r2: (train=0.929, test=0.920) total time=  48.1s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.9, n_estimators=30; mae: (train=-1456.449, test=-1599.032) r2: (train=0.933, test=0.922) total time=  41.2s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.5, max_samples=0.9, n_estimators=50; mae: (train=-1379.025, test=-1505.801) r2: (train=0.938, test=0.929) total time= 1.3min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.2, n_estimators=30; mae: (train=-1655.237, test=-1695.450) r2: (train=0.908, test=0.903) total time=  25.9s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.2, n_estimators=50; mae: (train=-1678.856, test=-1720.776) r2: (train=0.906, test=0.901) total time=  30.5s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.3, n_estimators=30; mae: (train=-1642.075, test=-1702.729) r2: (train=0.911, test=0.905) total time=  20.3s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.3, n_estimators=50; mae: (train=-1639.871, test=-1701.107) r2: (train=0.912, test=0.906) total time=  31.8s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.5, n_estimators=30; mae: (train=-1508.889, test=-1603.151) r2: (train=0.924, test=0.916) total time=  30.4s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.5, n_estimators=50; mae: (train=-1478.507, test=-1574.925) r2: (train=0.926, test=0.917) total time=  35.5s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.7, n_estimators=30; mae: (train=-1361.046, test=-1474.168) r2: (train=0.936, test=0.928) total time=  49.2s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.7, n_estimators=50; mae: (train=-1414.537, test=-1530.795) r2: (train=0.932, test=0.923) total time=  46.1s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.9, n_estimators=30; mae: (train=-1390.312, test=-1540.024) r2: (train=0.935, test=0.925) total time=  34.7s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.6, max_samples=0.9, n_estimators=50; mae: (train=-1370.683, test=-1505.863) r2: (train=0.938, test=0.930) total time= 1.3min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.2, n_estimators=30; mae: (train=-1676.896, test=-1724.958) r2: (train=0.907, test=0.903) total time=  26.1s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.2, n_estimators=50; mae: (train=-1654.811, test=-1699.578) r2: (train=0.909, test=0.903) total time=  40.4s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.3, n_estimators=30; mae: (train=-1569.181, test=-1630.430) r2: (train=0.916, test=0.911) total time=  39.7s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.3, n_estimators=50; mae: (train=-1544.537, test=-1607.926) r2: (train=0.918, test=0.913) total time=  52.0s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.5, n_estimators=30; mae: (train=-1449.742, test=-1534.500) r2: (train=0.928, test=0.922) total time=  46.8s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.5, n_estimators=50; mae: (train=-1429.563, test=-1516.792) r2: (train=0.929, test=0.923) total time= 1.3min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.7, n_estimators=30; mae: (train=-1374.869, test=-1494.454) r2: (train=0.935, test=0.928) total time=  48.5s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.7, n_estimators=50; mae: (train=-1357.751, test=-1468.868) r2: (train=0.937, test=0.930) total time= 1.4min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.9, n_estimators=30; mae: (train=-1300.624, test=-1441.738) r2: (train=0.943, test=0.935) total time=  52.4s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.7, max_samples=0.9, n_estimators=50; mae: (train=-1322.891, test=-1461.579) r2: (train=0.940, test=0.932) total time= 1.4min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.2, n_estimators=30; mae: (train=-1639.125, test=-1679.207) r2: (train=0.909, test=0.905) total time=  33.9s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.2, n_estimators=50; mae: (train=-1641.844, test=-1685.831) r2: (train=0.909, test=0.904) total time=  55.5s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.3, n_estimators=30; mae: (train=-1552.029, test=-1610.251) r2: (train=0.918, test=0.913) total time=  38.1s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.3, n_estimators=50; mae: (train=-1540.109, test=-1597.713) r2: (train=0.918, test=0.914) total time= 1.3min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.5, n_estimators=30; mae: (train=-1422.125, test=-1513.932) r2: (train=0.929, test=0.924) total time=  57.0s
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.5, n_estimators=50; mae: (train=-1423.061, test=-1512.376) r2: (train=0.929, test=0.924) total time= 1.6min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.7, n_estimators=30; mae: (train=-1353.426, test=-1465.688) r2: (train=0.936, test=0.929) total time= 1.1min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.7, n_estimators=50; mae: (train=-1345.677, test=-1462.423) r2: (train=0.937, test=0.930) total time= 2.1min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.9, n_estimators=30; mae: (train=-1282.962, test=-1421.092) r2: (train=0.942, test=0.935) total time= 1.8min
# [CV 1/1] END bootstrap=False, bootstrap_features=False, max_features=0.9, max_samples=0.9, n_estimators=50; mae: (train=-1292.856, test=-1430.027) r2: (train=0.941, test=0.934) total time= 2.6min
# Train R2=0.903 | Val R2=0.897 | Train MAE=1721.7 | Val MAE=1768.0 | Gap MAE=0.027 | Params={'n_estimators': 30, 'max_samples': 0.2, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.902 | Val R2=0.897 | Train MAE=1714.6 | Val MAE=1758.7 | Gap MAE=0.026 | Params={'n_estimators': 50, 'max_samples': 0.2, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.917 | Val R2=0.911 | Train MAE=1568.3 | Val MAE=1628.3 | Gap MAE=0.038 | Params={'n_estimators': 30, 'max_samples': 0.3, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.913 | Val R2=0.907 | Train MAE=1612.7 | Val MAE=1668.1 | Gap MAE=0.034 | Params={'n_estimators': 50, 'max_samples': 0.3, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.924 | Val R2=0.917 | Train MAE=1513.0 | Val MAE=1602.1 | Gap MAE=0.059 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.921 | Val R2=0.912 | Train MAE=1538.2 | Val MAE=1627.2 | Gap MAE=0.058 | Params={'n_estimators': 50, 'max_samples': 0.5, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.930 | Val R2=0.920 | Train MAE=1481.3 | Val MAE=1604.7 | Gap MAE=0.083 | Params={'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.929 | Val R2=0.920 | Train MAE=1490.8 | Val MAE=1611.5 | Gap MAE=0.081 | Params={'n_estimators': 50, 'max_samples': 0.7, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.933 | Val R2=0.922 | Train MAE=1456.4 | Val MAE=1599.0 | Gap MAE=0.098 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.938 | Val R2=0.929 | Train MAE=1379.0 | Val MAE=1505.8 | Gap MAE=0.092 | Params={'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.5, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.908 | Val R2=0.903 | Train MAE=1655.2 | Val MAE=1695.5 | Gap MAE=0.024 | Params={'n_estimators': 30, 'max_samples': 0.2, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.906 | Val R2=0.901 | Train MAE=1678.9 | Val MAE=1720.8 | Gap MAE=0.025 | Params={'n_estimators': 50, 'max_samples': 0.2, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.911 | Val R2=0.905 | Train MAE=1642.1 | Val MAE=1702.7 | Gap MAE=0.037 | Params={'n_estimators': 30, 'max_samples': 0.3, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.912 | Val R2=0.906 | Train MAE=1639.9 | Val MAE=1701.1 | Gap MAE=0.037 | Params={'n_estimators': 50, 'max_samples': 0.3, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.924 | Val R2=0.916 | Train MAE=1508.9 | Val MAE=1603.2 | Gap MAE=0.062 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.926 | Val R2=0.917 | Train MAE=1478.5 | Val MAE=1574.9 | Gap MAE=0.065 | Params={'n_estimators': 50, 'max_samples': 0.5, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.936 | Val R2=0.928 | Train MAE=1361.0 | Val MAE=1474.2 | Gap MAE=0.083 | Params={'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.932 | Val R2=0.923 | Train MAE=1414.5 | Val MAE=1530.8 | Gap MAE=0.082 | Params={'n_estimators': 50, 'max_samples': 0.7, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.935 | Val R2=0.925 | Train MAE=1390.3 | Val MAE=1540.0 | Gap MAE=0.108 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.938 | Val R2=0.930 | Train MAE=1370.7 | Val MAE=1505.9 | Gap MAE=0.099 | Params={'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.6, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.907 | Val R2=0.903 | Train MAE=1676.9 | Val MAE=1725.0 | Gap MAE=0.029 | Params={'n_estimators': 30, 'max_samples': 0.2, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.909 | Val R2=0.903 | Train MAE=1654.8 | Val MAE=1699.6 | Gap MAE=0.027 | Params={'n_estimators': 50, 'max_samples': 0.2, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.916 | Val R2=0.911 | Train MAE=1569.2 | Val MAE=1630.4 | Gap MAE=0.039 | Params={'n_estimators': 30, 'max_samples': 0.3, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.918 | Val R2=0.913 | Train MAE=1544.5 | Val MAE=1607.9 | Gap MAE=0.041 | Params={'n_estimators': 50, 'max_samples': 0.3, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.928 | Val R2=0.922 | Train MAE=1449.7 | Val MAE=1534.5 | Gap MAE=0.058 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.929 | Val R2=0.923 | Train MAE=1429.6 | Val MAE=1516.8 | Gap MAE=0.061 | Params={'n_estimators': 50, 'max_samples': 0.5, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.935 | Val R2=0.928 | Train MAE=1374.9 | Val MAE=1494.5 | Gap MAE=0.087 | Params={'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.937 | Val R2=0.930 | Train MAE=1357.8 | Val MAE=1468.9 | Gap MAE=0.082 | Params={'n_estimators': 50, 'max_samples': 0.7, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.943 | Val R2=0.935 | Train MAE=1300.6 | Val MAE=1441.7 | Gap MAE=0.108 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.940 | Val R2=0.932 | Train MAE=1322.9 | Val MAE=1461.6 | Gap MAE=0.105 | Params={'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.7, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.909 | Val R2=0.905 | Train MAE=1639.1 | Val MAE=1679.2 | Gap MAE=0.024 | Params={'n_estimators': 30, 'max_samples': 0.2, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.909 | Val R2=0.904 | Train MAE=1641.8 | Val MAE=1685.8 | Gap MAE=0.027 | Params={'n_estimators': 50, 'max_samples': 0.2, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.918 | Val R2=0.913 | Train MAE=1552.0 | Val MAE=1610.3 | Gap MAE=0.038 | Params={'n_estimators': 30, 'max_samples': 0.3, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.918 | Val R2=0.914 | Train MAE=1540.1 | Val MAE=1597.7 | Gap MAE=0.037 | Params={'n_estimators': 50, 'max_samples': 0.3, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.929 | Val R2=0.924 | Train MAE=1422.1 | Val MAE=1513.9 | Gap MAE=0.065 | Params={'n_estimators': 30, 'max_samples': 0.5, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.929 | Val R2=0.924 | Train MAE=1423.1 | Val MAE=1512.4 | Gap MAE=0.063 | Params={'n_estimators': 50, 'max_samples': 0.5, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.936 | Val R2=0.929 | Train MAE=1353.4 | Val MAE=1465.7 | Gap MAE=0.083 | Params={'n_estimators': 30, 'max_samples': 0.7, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.937 | Val R2=0.930 | Train MAE=1345.7 | Val MAE=1462.4 | Gap MAE=0.087 | Params={'n_estimators': 50, 'max_samples': 0.7, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.942 | Val R2=0.935 | Train MAE=1283.0 | Val MAE=1421.1 | Gap MAE=0.108 | Params={'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
# Train R2=0.941 | Val R2=0.934 | Train MAE=1292.9 | Val MAE=1430.0 | Gap MAE=0.106 | Params={'n_estimators': 50, 'max_samples': 0.9, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9421362472085062
# Best validation R2: 0.9352316829569607
# Gap R2: 0.732862605807103 %
# Best train MAE: 1282.9619029912137
# Best validation MAE: 1421.09205396512
# Gap MAE: 10.766504496498069 %
# Best parameters: {'n_estimators': 30, 'max_samples': 0.9, 'max_features': 0.9, 'bootstrap_features': False, 'bootstrap': False}

# %% [markdown]
# <a class="anchor" id="9_3_3">
#
# ## **9.3.3** SVR
#
# [Back to TOP](#TOP)
# </a>

# %% [markdown]
# Support Vector Machine (SVR) was tested but it was not explored due to it's high computational cost and poor performance on this dataset. Given the large number of observations, even a limited Randomized Search required a long time to run, making tuning impractical.  Additionally, the evaluated SVR configurations resulted in high MAE and low R^2 on the validation set which makes us conclude that the model isn't able to generalize well.

# %%
model_svr = SVR(random_state=42)
param_grid_svr = {
    "C": [50, 70],
    "kernel": ["rbf", 'linear', 'sigmoid'],
    "gamma": ["scale", "auto"]
}

# %%
rsCV_SVR = apply_randomized_search_cv(
    model_svr,
    param_grid_svr,
    iterations=15, 
    scoring=scoring,
    refit='mae',
    pred_split=ps,
    X_fit=X_combined,
    y_fit=y_combined
)
# Out:
# c:\Users\Catarina\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=15. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV 1/1] END C=50, gamma=scale, kernel=rbf; mae: (train=-2162.444, test=-2180.464) r2: (train=0.796, test=0.781) total time= 8.0min
# [CV 1/1] END C=50, gamma=scale, kernel=linear; mae: (train=-2504.037, test=-2500.487) r2: (train=0.814, test=0.812) total time= 2.9min
# [CV 1/1] END C=50, gamma=scale, kernel=sigmoid; mae: (train=-15091.278, test=-15208.327) r2: (train=-5.780, test=-5.905) total time= 8.0min
# [CV 1/1] END C=50, gamma=auto, kernel=rbf; mae: (train=-2160.206, test=-2177.577) r2: (train=0.798, test=0.784) total time= 5.0min
# [CV 1/1] END C=50, gamma=auto, kernel=linear; mae: (train=-2504.037, test=-2500.487) r2: (train=0.814, test=0.812) total time= 3.0min
# [CV 1/1] END C=50, gamma=auto, kernel=sigmoid; mae: (train=-13358.976, test=-13470.751) r2: (train=-4.527, test=-4.648) total time= 4.9min
# [CV 1/1] END C=70, gamma=scale, kernel=rbf; mae: (train=-2087.578, test=-2105.914) r2: (train=0.811, test=0.798) total time= 5.0min
# [CV 1/1] END C=70, gamma=scale, kernel=linear; mae: (train=-2503.990, test=-2500.412) r2: (train=0.814, test=0.812) total time= 3.1min
# [CV 1/1] END C=70, gamma=scale, kernel=sigmoid; mae: (train=-20937.648, test=-21147.169) r2: (train=-12.075, test=-12.526) total time= 8.9min
# [CV 1/1] END C=70, gamma=auto, kernel=rbf; mae: (train=-2088.211, test=-2105.647) r2: (train=0.813, test=0.800) total time= 5.7min
# [CV 1/1] END C=70, gamma=auto, kernel=linear; mae: (train=-2503.990, test=-2500.412) r2: (train=0.814, test=0.812) total time= 3.3min
# [CV 1/1] END C=70, gamma=auto, kernel=sigmoid; mae: (train=-18393.085, test=-18542.685) r2: (train=-9.181, test=-9.382) total time= 5.4min

# %% [markdown]
# <a class="anchor" id="9.3.4">
#
# # **9.3.4 Decision Trees**
#
# [Back to TOP](#TOP)
# </a>

# %%
model_dt = DecisionTreeRegressor(random_state=42)
param_grid_dt = {
    "max_depth": [8, 11, 14],
    "min_samples_split": [20, 40, 80, 160],
    "min_samples_leaf": [10, 40, 80],
    "max_features": ["sqrt", 0.5, 0.8],
    #"ccp_alpha": [0.0, 0.1, 0.9, 1e-5, 1e-4, 1e-3],
    "criterion": ["absolute_error"]
}

# %%
rsCV_dt = apply_randomized_search_cv(
    model_dt, 
    param_grid_dt, 
    iterations=30,
    scoring=scoring, 
    refit='mae', 
    pred_split=ps, 
    X_fit=X_combined, 
    y_fit=y_combined
)

evaluate_model(rsCV_dt)
# Out:
# Fitting 1 folds for each of 30 candidates, totalling 30 fits
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=80, min_samples_split=80; mae: (train=-2061.029, test=-2118.237) r2: (train=0.857, test=0.853) total time= 1.1min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=0.5, min_samples_leaf=40, min_samples_split=160; mae: (train=-2088.563, test=-2148.445) r2: (train=0.861, test=0.855) total time= 2.1min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=0.5, min_samples_leaf=40, min_samples_split=20; mae: (train=-1773.295, test=-1886.182) r2: (train=0.883, test=0.864) total time= 2.0min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=sqrt, min_samples_leaf=40, min_samples_split=160; mae: (train=-2336.274, test=-2388.612) r2: (train=0.836, test=0.828) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=80, min_samples_split=160; mae: (train=-2061.029, test=-2118.237) r2: (train=0.857, test=0.853) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=0.5, min_samples_leaf=40, min_samples_split=80; mae: (train=-1773.295, test=-1886.182) r2: (train=0.883, test=0.864) total time= 2.1min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=0.8, min_samples_leaf=10, min_samples_split=40; mae: (train=-1390.039, test=-1602.527) r2: (train=0.920, test=0.908) total time= 3.2min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=0.8, min_samples_leaf=10, min_samples_split=80; mae: (train=-1512.266, test=-1681.446) r2: (train=0.908, test=0.895) total time= 2.8min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=0.8, min_samples_leaf=10, min_samples_split=160; mae: (train=-2044.327, test=-2094.672) r2: (train=0.863, test=0.857) total time= 2.8min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=0.5, min_samples_leaf=40, min_samples_split=160; mae: (train=-1868.212, test=-1965.682) r2: (train=0.875, test=0.862) total time= 1.9min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=sqrt, min_samples_leaf=40, min_samples_split=20; mae: (train=-1928.558, test=-2005.820) r2: (train=0.870, test=0.868) total time= 1.1min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=0.8, min_samples_leaf=80, min_samples_split=20; mae: (train=-1808.212, test=-1885.304) r2: (train=0.873, test=0.868) total time= 2.8min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=0.8, min_samples_leaf=40, min_samples_split=20; mae: (train=-1630.282, test=-1758.241) r2: (train=0.893, test=0.884) total time= 2.8min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=0.8, min_samples_leaf=80, min_samples_split=160; mae: (train=-1842.849, test=-1928.738) r2: (train=0.876, test=0.864) total time= 2.6min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=sqrt, min_samples_leaf=40, min_samples_split=160; mae: (train=-1995.021, test=-2062.743) r2: (train=0.864, test=0.859) total time= 1.1min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=0.5, min_samples_leaf=40, min_samples_split=80; mae: (train=-1716.882, test=-1848.278) r2: (train=0.890, test=0.875) total time= 1.9min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=0.5, min_samples_leaf=80, min_samples_split=80; mae: (train=-1865.624, test=-1933.082) r2: (train=0.867, test=0.857) total time= 1.8min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=sqrt, min_samples_leaf=10, min_samples_split=160; mae: (train=-2324.270, test=-2353.777) r2: (train=0.838, test=0.838) total time= 1.0min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=0.5, min_samples_leaf=10, min_samples_split=160; mae: (train=-1795.446, test=-1875.323) r2: (train=0.882, test=0.872) total time= 1.8min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=0.8, min_samples_leaf=10, min_samples_split=20; mae: (train=-1565.980, test=-1729.760) r2: (train=0.916, test=0.904) total time= 2.9min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=0.5, min_samples_leaf=80, min_samples_split=80; mae: (train=-2158.788, test=-2207.642) r2: (train=0.847, test=0.843) total time= 2.0min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=0.8, min_samples_leaf=10, min_samples_split=40; mae: (train=-1577.692, test=-1714.911) r2: (train=0.911, test=0.902) total time= 2.9min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=sqrt, min_samples_leaf=10, min_samples_split=160; mae: (train=-2001.308, test=-2077.132) r2: (train=0.871, test=0.863) total time= 1.2min
# [CV 1/1] END criterion=absolute_error, max_depth=14, max_features=0.5, min_samples_leaf=80, min_samples_split=20; mae: (train=-1865.624, test=-1933.082) r2: (train=0.867, test=0.857) total time= 1.9min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=0.8, min_samples_leaf=40, min_samples_split=40; mae: (train=-1708.535, test=-1817.909) r2: (train=0.890, test=0.878) total time= 2.7min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=0.8, min_samples_leaf=40, min_samples_split=160; mae: (train=-2042.862, test=-2098.930) r2: (train=0.867, test=0.861) total time= 2.6min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=0.8, min_samples_leaf=40, min_samples_split=80; mae: (train=-2016.284, test=-2087.290) r2: (train=0.869, test=0.861) total time= 2.7min
# [CV 1/1] END criterion=absolute_error, max_depth=11, max_features=sqrt, min_samples_leaf=80, min_samples_split=40; mae: (train=-2102.119, test=-2153.935) r2: (train=0.851, test=0.850) total time= 1.0min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=0.8, min_samples_leaf=80, min_samples_split=160; mae: (train=-2046.143, test=-2077.550) r2: (train=0.857, test=0.851) total time= 2.6min
# [CV 1/1] END criterion=absolute_error, max_depth=8, max_features=sqrt, min_samples_leaf=40, min_samples_split=40; mae: (train=-2448.859, test=-2485.779) r2: (train=0.826, test=0.825) total time= 1.0min
# Train R2=0.857 | Val R2=0.853 | Train MAE=2061.0 | Val MAE=2118.2 | Gap MAE=0.028 | Params={'min_samples_split': 80, 'min_samples_leaf': 80, 'max_features': 'sqrt', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.861 | Val R2=0.855 | Train MAE=2088.6 | Val MAE=2148.4 | Gap MAE=0.029 | Params={'min_samples_split': 160, 'min_samples_leaf': 40, 'max_features': 0.5, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.883 | Val R2=0.864 | Train MAE=1773.3 | Val MAE=1886.2 | Gap MAE=0.064 | Params={'min_samples_split': 20, 'min_samples_leaf': 40, 'max_features': 0.5, 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.836 | Val R2=0.828 | Train MAE=2336.3 | Val MAE=2388.6 | Gap MAE=0.022 | Params={'min_samples_split': 160, 'min_samples_leaf': 40, 'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.857 | Val R2=0.853 | Train MAE=2061.0 | Val MAE=2118.2 | Gap MAE=0.028 | Params={'min_samples_split': 160, 'min_samples_leaf': 80, 'max_features': 'sqrt', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.883 | Val R2=0.864 | Train MAE=1773.3 | Val MAE=1886.2 | Gap MAE=0.064 | Params={'min_samples_split': 80, 'min_samples_leaf': 40, 'max_features': 0.5, 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.920 | Val R2=0.908 | Train MAE=1390.0 | Val MAE=1602.5 | Gap MAE=0.153 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 0.8, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.908 | Val R2=0.895 | Train MAE=1512.3 | Val MAE=1681.4 | Gap MAE=0.112 | Params={'min_samples_split': 80, 'min_samples_leaf': 10, 'max_features': 0.8, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.863 | Val R2=0.857 | Train MAE=2044.3 | Val MAE=2094.7 | Gap MAE=0.025 | Params={'min_samples_split': 160, 'min_samples_leaf': 10, 'max_features': 0.8, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.875 | Val R2=0.862 | Train MAE=1868.2 | Val MAE=1965.7 | Gap MAE=0.052 | Params={'min_samples_split': 160, 'min_samples_leaf': 40, 'max_features': 0.5, 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.870 | Val R2=0.868 | Train MAE=1928.6 | Val MAE=2005.8 | Gap MAE=0.040 | Params={'min_samples_split': 20, 'min_samples_leaf': 40, 'max_features': 'sqrt', 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.873 | Val R2=0.868 | Train MAE=1808.2 | Val MAE=1885.3 | Gap MAE=0.043 | Params={'min_samples_split': 20, 'min_samples_leaf': 80, 'max_features': 0.8, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.893 | Val R2=0.884 | Train MAE=1630.3 | Val MAE=1758.2 | Gap MAE=0.078 | Params={'min_samples_split': 20, 'min_samples_leaf': 40, 'max_features': 0.8, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.876 | Val R2=0.864 | Train MAE=1842.8 | Val MAE=1928.7 | Gap MAE=0.047 | Params={'min_samples_split': 160, 'min_samples_leaf': 80, 'max_features': 0.8, 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.864 | Val R2=0.859 | Train MAE=1995.0 | Val MAE=2062.7 | Gap MAE=0.034 | Params={'min_samples_split': 160, 'min_samples_leaf': 40, 'max_features': 'sqrt', 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.890 | Val R2=0.875 | Train MAE=1716.9 | Val MAE=1848.3 | Gap MAE=0.077 | Params={'min_samples_split': 80, 'min_samples_leaf': 40, 'max_features': 0.5, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.867 | Val R2=0.857 | Train MAE=1865.6 | Val MAE=1933.1 | Gap MAE=0.036 | Params={'min_samples_split': 80, 'min_samples_leaf': 80, 'max_features': 0.5, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.838 | Val R2=0.838 | Train MAE=2324.3 | Val MAE=2353.8 | Gap MAE=0.013 | Params={'min_samples_split': 160, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.882 | Val R2=0.872 | Train MAE=1795.4 | Val MAE=1875.3 | Gap MAE=0.044 | Params={'min_samples_split': 160, 'min_samples_leaf': 10, 'max_features': 0.5, 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.916 | Val R2=0.904 | Train MAE=1566.0 | Val MAE=1729.8 | Gap MAE=0.105 | Params={'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.8, 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.847 | Val R2=0.843 | Train MAE=2158.8 | Val MAE=2207.6 | Gap MAE=0.023 | Params={'min_samples_split': 80, 'min_samples_leaf': 80, 'max_features': 0.5, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.911 | Val R2=0.902 | Train MAE=1577.7 | Val MAE=1714.9 | Gap MAE=0.087 | Params={'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 0.8, 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.871 | Val R2=0.863 | Train MAE=2001.3 | Val MAE=2077.1 | Gap MAE=0.038 | Params={'min_samples_split': 160, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.867 | Val R2=0.857 | Train MAE=1865.6 | Val MAE=1933.1 | Gap MAE=0.036 | Params={'min_samples_split': 20, 'min_samples_leaf': 80, 'max_features': 0.5, 'max_depth': 14, 'criterion': 'absolute_error'}
# Train R2=0.890 | Val R2=0.878 | Train MAE=1708.5 | Val MAE=1817.9 | Gap MAE=0.064 | Params={'min_samples_split': 40, 'min_samples_leaf': 40, 'max_features': 0.8, 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.867 | Val R2=0.861 | Train MAE=2042.9 | Val MAE=2098.9 | Gap MAE=0.027 | Params={'min_samples_split': 160, 'min_samples_leaf': 40, 'max_features': 0.8, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.869 | Val R2=0.861 | Train MAE=2016.3 | Val MAE=2087.3 | Gap MAE=0.035 | Params={'min_samples_split': 80, 'min_samples_leaf': 40, 'max_features': 0.8, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.851 | Val R2=0.850 | Train MAE=2102.1 | Val MAE=2153.9 | Gap MAE=0.025 | Params={'min_samples_split': 40, 'min_samples_leaf': 80, 'max_features': 'sqrt', 'max_depth': 11, 'criterion': 'absolute_error'}
# Train R2=0.857 | Val R2=0.851 | Train MAE=2046.1 | Val MAE=2077.5 | Gap MAE=0.015 | Params={'min_samples_split': 160, 'min_samples_leaf': 80, 'max_features': 0.8, 'max_depth': 8, 'criterion': 'absolute_error'}
# Train R2=0.826 | Val R2=0.825 | Train MAE=2448.9 | Val MAE=2485.8 | Gap MAE=0.015 | Params={'min_samples_split': 40, 'min_samples_leaf': 40, 'max_features': 'sqrt', 'max_depth': 8, 'criterion': 'absolute_error'}
#
# === BEST MODEL (based on MAE) ===
# Best train R2: 0.9196723822370115
# Best validation R2: 0.9083031818502515
# Gap R2: 1.2362228774452908 %
# Best train MAE: 1390.0387146664912
# Best validation MAE: 1602.5270154656137
# Gap MAE: 15.28650235113087 %
# Best parameters: {'min_samples_split': 40, 'min_samples_leaf': 10, 'max_features': 0.8, 'max_depth': 14, 'criterion': 'absolute_error'}

# %% [markdown]
# <a class="anchor" id="6">
#
# # **10. Save results to Kaggle**
#
# [Back to TOP](#TOP)
# </a>

# %%
best_mae_model = min(best_mae_knn, best_mae_rf, )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 best_mae_model = min(best_mae_knn, best_mae_rf, )
#
# NameError: name 'best_mae_knn' is not defined

# %%
# Go one level up from the notebooks folder to reach the repo root
selected_dir = "../results/kaggle_submissions/"
os.makedirs(selected_dir, exist_ok=True)

# %%
# Extract carID
car_ids = test.index.values

# Create DataFrame with best model predictions
best_model_df = pd.DataFrame({
    'carID': car_ids,
    'price': preds_knn
})

# Save predictions to CSV
best_model_df.to_csv(f"{selected_dir}/predictions_knn.csv", index=False)
